# %%
import numpy as np
import pandas as pd

# %%
eventCodes = pd.read_csv('Event_Codes.txt', sep='\t')
#Strip excess whitespace that I noticed in Event Message Type Description
eventCodes['Event_Msg_Type_Description'] = eventCodes['Event_Msg_Type_Description'].map(str.strip)
#eventCodes['Action_Type_Description'] = eventCodes['Action_Type_Description'].map(str.strip)

GameLineup = pd.read_csv('Game_Lineup.txt', sep='\t')
PlayByPlay = pd.read_csv('Play_by_Play.txt', sep='\t')

# %%
eventCodes[eventCodes['Event_Msg_Type'] == 10]
# Out:
#      Event_Msg_Type  Action_Type Event_Msg_Type_Description  \
# 266              10            0                  Jump Ball
#
#     Action_Type_Description
# 266

# %%
def sortedPlayByPlay(PlayByPlay):
    """Returns PlayByPlay with nested sorted given by hackathon pdf file.
    
    Input:
        PlayByPlay: Pandas Dataframe from reading Play_by_Play csv file"""
    return PlayByPlay.sort_values(['Period', 'PC_Time', 'WC_Time', 'Event_Num'], ascending=[True, False, True,True])

# %%
GameIDs = PlayByPlay['Game_id'].unique()
#PlayByPlay[PlayByPlay['Game_id'] == GameIDs[0]].sort_values(['Period', 'PC_Time', 'WC_Time', 'Event_Num'], ascending=[True, False, True,True])

# %%
GameIDs
# Out:
# array(['006728e4c10e957011e1f24878e6054a',
#        '03ac65b9a32fde1e201bfb427f6e41e4',
#        '096e231adad0be6ab1cc89cce56847f8',
#        '117a5a71c34c2d8a39ff66d884462bd7',
#        '1ea0a33aafb4a3cb31ba79cff049300c',
#        '1ef70f0ed41e6862e3860613e3f21054',
#        '25a5ddd58e1b7af731e179e2f98ed42f',
#        '27caeb326b241334bfb308787974f959',
#        '2877e9e9980619126420db0163ee0779',
#        '32f2054d115f0b36efaa76e3a80a97d6',
#        '3792cf8c80b4b4bda5e2aaeb403e96af',
#        '394fd09c602f2cfe11644107673ae1c1',
#        '3a4e6bebf52d096f4006d199ea7e1c16',
#        '3b088c7d19b1d7b56f5842e39b29e06d',
#        '3ce947db2df86b08a40b7526e2faaccb',
#        '403719b7c2a6208e817387e06ffefb77',
#        '426251168251f96f7ea501fcd0dafa7c',
#        '476e6303a0d6728a5848a179a119bb32',
#        '4c586da09a05a775832969387305b688',
#        '4d475b083c4c975deabe3d9bfe98dd90',
#        '559912f00a5ed116f71cb72ecc991a5b',
#        '58f4e85cad83adedfa96749b0cde2564',
#        '5a2bb80caeb8ee7d84bca860e2c38249',
#        '62083f5d100803b41537d7afa1de25b3',
#        '624e85db99e59ea7bbbdc0f74923f645',
#        '681bafe84c48e522bc72eba7b3a04b4a',
#        '68f62f1c5cb84257932676bef8cc7a1a',
#        '6b17d80707e8791747fabb15c754a6e7',
#        '70a984edc9dc4badf5c6be5835d6bdd4',
#        '72deb55b6e864b5d58cd2900bf4079b4',
#        '7a5f149ff86cedd8abfdd28358b88786',
#        '7b1e12cfc67be542ac404f3d9389b9dc',
#        '7b4b6c18c831bc54239f663d0e604497',
#        '8145bdb1a51e43529f41a4f640e9a306',
#        '87e27d0359dcbf480739ad0c2000a214',
#        '890600997c60cca3e41236355c65642e',
#        '8a2f954e8d303e73de01bd620b1ef6c3',
#        '8d607031b304748acd198851fca5321c',
#        '95770267429c4b7118a82bb8b4f2be54',
#        '97b18f77e14984e2ed00a5962eb6145d',
#        '97b8982d363b55efc61eae5d969d7f44',
#        '9892e70d668a7287f5460350b8a6afdf',
#        '9b718cc561cecf4da6d0632def573409',
#        '9da3345a6665c45dac22d04f78d8a355',
#        '9fac61d1e1988c53408cfc2578f2c683',
#        'a466c76e072fd634f6d4a8938fb63caa',
#        'a48be9b24719a0473155288a5c081448',
#        'a69272714a8340233730bd697769b261',
#        'a83f772456480ca41ef5fbe62ce70c7e',
#        'ac246b4083eff03543a7d58536808eb4',
#        'acf9fc13f76192889b8ae5c28d229591',
#        'b2b580f1d233c5b3d115028275714306',
#        'b6badbf582ad7c8e52c35cb5308e3ffb',
#        'b7a1056b097e5e604925867c0ca17442',
#        'baa3708b350d01ba0c12fd2a89b1c3d9',
#        'bb4e1b593cc210dec5fdcb0f7eb4739d',
#        'bbdfa92c4ade547643cd69741f736b21',
#        'c09f006fc1ed45361310b19c235dbf72',
#        'c719eacc4252db10ae57c92a8a8e17d2',
#        'c846ca699a9e1d795540ac3f59e72d80',
#        'c8ebe24f264e733f64003130d7d5e18d',
#        'c92a96dcef0009c7d3583cd2e603099c',
#        'c9353934036e5c77258f2b7ab7685e79',
#        'c97b18a3f671fd9bd4648cb84125ac6b',
#        'ca963a5c2830ee97acee003347515654',
#        'd03a92390eb3db203f36d0d89ee9c0b9',
#        'd2bc9ecd1c1dca587901bcc901896076',
#        'd36de5306a05d0cdbd51a7294ac91359',
#        'd508da19217d10b9a4566ef06184b4fd',
#        'd522ea3836b8e1977ab10b3bfeb5dfd1',
#        'db01d0f50dbdc57e0346858ac7be154a',
#        'dc3a96d83623f28fd84bd535e57c146f',
#        'df46ea1ec9250af2cd2f8e48f705ba4a',
#        'e08f26c110e19f7afa4cbe5aed43be4a',
#        'e4ea5ad257a30f4a3c06683e0186bd6d',
#        'e9db074d4b4bb862dde70d545e3ac13f',
#        'ea198bf717f42cdfc94c577faaf39666',
#        'ed95a454eee025e4b93e217ad6a578f1',
#        'efca551b622ff96393fb43947e1aad4b',
#        'f280a671f82eb32b48f00116b8956445',
#        'f959bc122b1ee996f3e12bc61c068ad4',
#        'ff42c1cba89fd3f3a7a6711a11d5576d'], dtype=object)

# %%
GameIDs[55]
# Out:
# 'bb4e1b593cc210dec5fdcb0f7eb4739d'

# %%
PlayByPlay[PlayByPlay['Event_Msg_Type'] == 11]
# Out:
#                                 Game_id  Event_Num  Event_Msg_Type  Period  \
# 6778   3ce947db2df86b08a40b7526e2faaccb        688              11       5
# 13613  72deb55b6e864b5d58cd2900bf4079b4        469              11       3
# 29707  ca963a5c2830ee97acee003347515654        598              11       4
#
#        WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 6778    710270       26            4        0        0        0
# 13613   670240      236            4        0        0        0
# 29707   755580     3300            4        0        0        0
#
#                                 Team_id                           Person1  \
# 6778   cd45058739ed0ac8229849c6249aad48  ef8b068ab7ac9d387b256404acd24cd5
# 13613  8362dfecb7412f12a12713852d2ae566  e814950408915f43de2b079dce7c21c5
# 29707  e2d25dd55740327314a2a0b874621ba8  fe4fc80aa14544264b2eca38dbe85bd1
#
#                                 Person2                           Person3  \
# 6778   0370a0d090da0d0edc6319f120187e0e  8b8d9227a96ad6ed93838617e3a2319a
# 13613  0370a0d090da0d0edc6319f120187e0e  a28c17b37a48e640bfec93966f0b2f91
# 29707  0370a0d090da0d0edc6319f120187e0e  a28c17b37a48e640bfec93966f0b2f91
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 6778              2             5             0             1
# 13613             2             5             0             1
# 29707             2             4             0             1

# %%
game0Lineup = GameLineup[GameLineup['Game_id'] == GameIDs[0]]
game0PlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == GameIDs[0]])
#game0PlayByPlay[(game0PlayByPlay['Event_Msg_Type'] == 3) & (game0PlayByPlay['Option1'] !=1 )]
#game0PlayByPlay[(game0PlayByPlay['Event_Msg_Type'] == 5)]
game0PlayByPlay[10:30]
# Out:
#                              Game_id  Event_Num  Event_Msg_Type  Period  \
# 10  006728e4c10e957011e1f24878e6054a         16               6       1
# 11  006728e4c10e957011e1f24878e6054a         18               3       1
# 12  006728e4c10e957011e1f24878e6054a         19               3       1
# 13  006728e4c10e957011e1f24878e6054a         20               2       1
# 15  006728e4c10e957011e1f24878e6054a         21               4       1
# 14  006728e4c10e957011e1f24878e6054a         22               1       1
# 16  006728e4c10e957011e1f24878e6054a         23               5       1
# 17  006728e4c10e957011e1f24878e6054a         25               2       1
# 18  006728e4c10e957011e1f24878e6054a         26               4       1
# 19  006728e4c10e957011e1f24878e6054a         27               7       1
# 20  006728e4c10e957011e1f24878e6054a         28               1       1
# 21  006728e4c10e957011e1f24878e6054a         29               2       1
# 22  006728e4c10e957011e1f24878e6054a         30               4       1
# 23  006728e4c10e957011e1f24878e6054a         31               1       1
# 24  006728e4c10e957011e1f24878e6054a         32               5       1
# 25  006728e4c10e957011e1f24878e6054a         34               1       1
# 26  006728e4c10e957011e1f24878e6054a         36               9       1
# 27  006728e4c10e957011e1f24878e6054a         37               6       1
# 28  006728e4c10e957011e1f24878e6054a         40               2       1
# 29  006728e4c10e957011e1f24878e6054a         41               4       1
#
#     WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 10   547340     6540            2        0        0        2
# 11   547630     6540           11        1        1        0
# 12   547800     6540           12        1        1        0
# 13   547950     6420            6        2        0        0
# 15   547990     6360            0        0        0        0
# 14   547990     6360           72        2        0        0
# 16   548170     6180            1        1        0        0
# 17   548250     6150            5        2        0        0
# 18   548280     6150            0        0        0        0
# 19   548330     6150            1        0        0        0
# 20   548480     6050           79        2        0        0
# 21   548640     5880            3        2        0        0
# 22   548670     5860            0        0        0        0
# 23   548700     5820           79        2        1        0
# 24   548860     5660            2        1        0        0
# 25   548920     5610           79        3        1        0
# 26   548980     5600            1        0        0        0
# 27   551260     5500            1        0        0        0
# 28   551560     5370            1        3        0        0
# 29   551590     5340            0        0        0        0
#
#                              Team_id                           Person1  \
# 10  01be0ad4af7aeb1f6d2cc2b6b6d6d811  99104de2626f67c1fa2ce70504970c3f
# 11  01be0ad4af7aeb1f6d2cc2b6b6d6d811  8d2127290c94bd41b82a2938734bc750
# 12  01be0ad4af7aeb1f6d2cc2b6b6d6d811  8d2127290c94bd41b82a2938734bc750
# 13  45ba8fc87f55b1191c50c400dc7ed11c  e814950408915f43de2b079dce7c21c5
# 15  45ba8fc87f55b1191c50c400dc7ed11c  99104de2626f67c1fa2ce70504970c3f
# 14  45ba8fc87f55b1191c50c400dc7ed11c  99104de2626f67c1fa2ce70504970c3f
# 16  01be0ad4af7aeb1f6d2cc2b6b6d6d811  8d2127290c94bd41b82a2938734bc750
# 17  45ba8fc87f55b1191c50c400dc7ed11c  e814950408915f43de2b079dce7c21c5
# 18  45ba8fc87f55b1191c50c400dc7ed11c  eb663a4ba8e90722905ef24a17c00df1
# 19  01be0ad4af7aeb1f6d2cc2b6b6d6d811  c9ef395e3fd4c1dda4a4427fd86ec1d6
# 20  01be0ad4af7aeb1f6d2cc2b6b6d6d811  c5dd5b2e3b975f0849d9b74e74125cb9
# 21  45ba8fc87f55b1191c50c400dc7ed11c  99104de2626f67c1fa2ce70504970c3f
# 22  45ba8fc87f55b1191c50c400dc7ed11c  766802a8fda500d7945950de7398c9c6
# 23  01be0ad4af7aeb1f6d2cc2b6b6d6d811  766802a8fda500d7945950de7398c9c6
# 24  45ba8fc87f55b1191c50c400dc7ed11c  48ec4e6c52f418d5ca4ef510ba473ea0
# 25  01be0ad4af7aeb1f6d2cc2b6b6d6d811  c5dd5b2e3b975f0849d9b74e74125cb9
# 26  45ba8fc87f55b1191c50c400dc7ed11c  c9ef395e3fd4c1dda4a4427fd86ec1d6
# 27  45ba8fc87f55b1191c50c400dc7ed11c  618f6d58ab2881152607c2a6e057bc51
# 28  45ba8fc87f55b1191c50c400dc7ed11c  e814950408915f43de2b079dce7c21c5
# 29  45ba8fc87f55b1191c50c400dc7ed11c  99104de2626f67c1fa2ce70504970c3f
#
#                              Person2                           Person3  \
# 10  8d2127290c94bd41b82a2938734bc750  a1277b068e23d54de9770dd59b31879e
# 11  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 12  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 13  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 15  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 14  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 16  48ec4e6c52f418d5ca4ef510ba473ea0  0370a0d090da0d0edc6319f120187e0e
# 17  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 18  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19  0370a0d090da0d0edc6319f120187e0e  a1277b068e23d54de9770dd59b31879e
# 20  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 21  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 22  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 23  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 24  766802a8fda500d7945950de7398c9c6  0370a0d090da0d0edc6319f120187e0e
# 25  766802a8fda500d7945950de7398c9c6  0370a0d090da0d0edc6319f120187e0e
# 26  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 27  e814950408915f43de2b079dce7c21c5  0b1c631effab25d4af2d16fc123c3d31
# 28  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 29  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#     Team_id_type  Person1_type  Person2_type  Person3_type
# 10             2             5             4             1
# 11             2             4             0             0
# 12             2             4             0             0
# 13             3             5             0             0
# 15             3             5             0             0
# 14             3             5             0             0
# 16             2             4             5             0
# 17             3             5             0             0
# 18             3             2             0             0
# 19             2             0             0             1
# 20             2             4             0             0
# 21             3             5             0             0
# 22             3             4             0             0
# 23             2             4             0             0
# 24             3             5             4             0
# 25             2             4             4             0
# 26             3             3             0             0
# 27             3             4             5             1
# 28             3             5             0             0
# 29             3             5             0             0

# %%
game0Teams = list(game0Lineup['Team_id'].unique())
game0Teams
# Out:
# ['01be0ad4af7aeb1f6d2cc2b6b6d6d811', '45ba8fc87f55b1191c50c400dc7ed11c']

# %%
list(GameLineup['Team_id'].unique())
# Out:
# ['01be0ad4af7aeb1f6d2cc2b6b6d6d811',
#  '45ba8fc87f55b1191c50c400dc7ed11c',
#  'cd45058739ed0ac8229849c6249aad48',
#  'b5464c11e1a8a18452a7d2988badfe0c',
#  '5df2526720f9ac092e202de922f5a65f',
#  'e2d25dd55740327314a2a0b874621ba8',
#  '91ea9fc14670a54b9902eb062b416ccf',
#  '8362dfecb7412f12a12713852d2ae566',
#  '0a6fc39f34702cff144525dfd265f8fa',
#  'cff694c8186a4bd377de400e4f60fe47',
#  'cc5e0f4efd0f5410547d4e73f38f7811',
#  'bcdf0d0117f2e3d5afcd70f977eae3d6',
#  '9eaab5de3f7ccd60442845f4e6b70a75',
#  '8e90edc4eb908903bcbb567f92488049',
#  'dc0f916810cb46c22beec67a860e00b4',
#  '012059d397c0b7e5a30a5bb89c0b075e']

# %%
GameLineup[GameLineup['Team_id'] == GameLineup['Team_id'].unique()[0]]['Person_id'].unique()
# Out:
# array(['ae53f8ba6761b64a174051da817785bc',
#        '8d2127290c94bd41b82a2938734bc750',
#        'e816ff284dc3f965b8f3d605a3b91bae',
#        'ed95dff5440fadf3042b5acacea81eed',
#        '2ad626904c8b28cceb8e12c624a84240',
#        'bd45fe7dba52aa2cd00ba80ff107d05b',
#        '766802a8fda500d7945950de7398c9c6',
#        '42e0d7167f04a4ff958c6442da0e6851',
#        'c5dd5b2e3b975f0849d9b74e74125cb9',
#        '5db9c1c8184510fee8161e7fafdc9c49',
#        'f4a5ca938177c407a9dab5412e39498f',
#        'c10b49616a2f4a23607dc1a8be4fde9f',
#        'dd1da128c27db468d95b99b583f8a57d',
#        '618f6d58ab2881152607c2a6e057bc51',
#        'e59b921ab3da55f632bc748beb12805a'], dtype=object)

# %%
eventCodes['Event_Msg_Type_Description'].unique()
# Out:
# array(['Made Shot', 'Missed Shot', 'No Shot', 'Free Throw', 'Rebound',
#        'Turnover', 'Foul', 'Violation', 'Substitution', 'Timeout',
#        'Jump Ball', 'Ejection', 'Start Period', 'End Period',
#        'Validation', 'Memo', 'Flash Stats', 'Supplemental',
#        'Instant Replay', 'Final Box Printed', 'Stoppage'], dtype=object)

# %%
eventCodes['Action_Type_Description'].unique()
# Out:
# array(['No Shot', 'Jump Shot', 'Running Jump Shot', 'Hook Shot',
#        'Tip Shot', 'Layup Shot', 'Driving Layup Shot', 'Dunk Shot',
#        'Slam Dunk Shot', 'Driving Dunk Shot', 'Running Layup Shot',
#        'Alley Oop Layup shot', 'Reverse Layup Shot',
#        'Turnaround Jump Shot', 'Running Dunk Shot', 'Reverse Dunk Shot',
#        'Alley Oop Dunk Shot', 'Running Tip Shot', 'Running Hook Shot',
#        'Driving Hook Shot', 'Turnaround Hook Shot', 'Finger Roll Shot',
#        'Running Finger Roll Shot', 'Driving Finger Roll Shot',
#        'Turnaround Finger Roll Shot', 'Fadeaway Jump Shot',
#        'Follow Up Dunk Shot', 'Jump Hook Shot', 'Jump Bank Shot',
#        'Hook Bank Shot', 'Finger Roll Layup Shot', 'Putback Layup Shot',
#        'Driving Reverse Layup Shot', 'Running Reverse Layup Shot',
#        'Driving Finger Roll Layup Shot', 'Running Finger Roll Layup Shot',
#        'Driving Jump shot', 'Floating Jump shot', 'Pullup Jump shot',
#        'Step Back Jump shot', 'Pullup Bank shot', 'Driving Bank shot',
#        'Fadeaway Bank shot', 'Running Bank shot', 'Turnaround Bank shot',
#        'Turnaround Fadeaway shot', 'Putback Dunk Shot',
#        'Driving Slam Dunk Shot', 'Reverse Slam Dunk Shot',
#        'Running Slam Dunk Shot', 'Putback Reverse Dunk Shot',
#        'Putback Slam Dunk Shot', 'Driving Bank Hook Shot',
#        'Jump Bank Hook Shot', 'Running Bank Hook Shot',
#        'Turnaround Bank Hook Shot', 'Tip Layup Shot',
#        'Cutting Layup Shot', 'Cutting Finger Roll Layup Shot',
#        'Running Alley Oop Layup Shot', 'Driving Floating Jump Shot',
#        'Driving Floating Bank Jump Shot', 'Running Pull-Up Jump Shot',
#        'Step Back Bank Jump Shot', 'Turnaround Fadeaway Bank Jump Shot',
#        'Running Alley Oop Dunk Shot', 'Tip Dunk Shot',
#        'Cutting Dunk Shot', 'Driving Reverse Dunk Shot',
#        'Running Reverse Dunk Shot', nan, 'Free Throw 1 of 1',
#        'Free Throw 1 of 2', 'Free Throw 2 of 2', 'Free Throw 1 of 3',
#        'Free Throw 2 of 3', 'Free Throw 3 of 3', 'Free Throw Technical',
#        'Free Throw Clear Path', 'Free Throw Flagrant 1 of 2',
#        'Free Throw Flagrant 2 of 2', 'Free Throw Flagrant 1 of 1',
#        'Free Throw Technical 1 of 2', 'Free Throw Technical 2 of 2',
#        'Free Throw Clear Path 1 of 2', 'Free Throw Clear Path 2 of 2',
#        'Free Throw Flagrant 1 of 3', 'Free Throw Flagrant 2 of 3',
#        'Free Throw Flagrant 3 of 3', 'Unknown', 'Normal Rebound',
#        'Dead Ball Rebound', 'No Turnover', 'Bad Pass', 'Lost Ball',
#        'Out Of Bounds', 'Traveling', 'Foul', 'Double Dribble',
#        'Discontinue Dribble', '3 Second Violation', '5 Second Violation',
#        '8 Second Violation', 'Shot Clock Turnover', 'Inbound Turnover',
#        'Backcourt Turnover', 'Illegal Pick', 'Offensive Goaltending',
#        'Isolation Violation', 'Lane Violation', 'Jump Ball Violation',
#        'Kicked Ball Violation', 'Illegal Assist Turnover',
#        'Palming Turnover', 'Post Up Turnover', 'Double Personal Turnover',
#        '10 Second Violaton', 'Stolen Pass Turnover',
#        'Opposite Basket Turnover', 'Punched Ball Turnover',
#        'Swinging Elbows Turnover', 'Basket from Below Turnover',
#        'Illegal Screen Turnover', 'Offensive Foul Turnover',
#        '5 Second Inbound Turnover', 'Step Out of Bounds Turnover',
#        'Out of Bounds Lost Ball Turnover', 'Poss Lost Ball Turnover',
#        'Excess Timeout Turnover',
#        'Player Out of Bounds Violation Turnover',
#        'Too Many Players Turnover', 'Out of Bounds - Bad Pass Turnover',
#        'No Foul', 'Personal', 'Shooting', 'Loose Ball', 'Offensive',
#        'Inbound', 'Away From Play', 'Elbow', 'Punching', 'Clear Path',
#        'Double Personal', 'Technical', 'Non-Unsportsmanlike Technical',
#        'Hanging Technical', 'Flagrant Type 1', 'Flagrant Type 2',
#        'Double Technical', 'Defense 3 Second', 'Delay Technical',
#        'Taunting Technical', 'Player Control', 'Indirect Technical',
#        'Excess Timeout Technical', 'Offensive Charge', 'Personal Block',
#        'Personal Take', 'Shooting Block', 'Too Many Players Technical',
#        'No Violation', 'Delay Of Game', 'Defensive Goaltending', 'Lane',
#        'Jump Ball', 'Kicked Ball', 'Double Lane', 'Illegal Defense', ' ',
#        'No Timeout', 'Regular', 'Short', 'Official TV', 'Official',
#        'Advance', 'Reset', 'No Ejection', 'Second Technical',
#        'Second Flagrant Type 1', 'First Flagrant Type 2', 'Other',
#        'Support Ruling', 'Overturn Ruling', 'Altercation Ruling',
#        'No Stoppage', 'Blood Rule', 'Injury', 'Out-of-Bounds',
#        'Court Cleanup', 'Equipment Malfunction',
#        'Other                                   '], dtype=object)

# %%
eventCodes[eventCodes['Event_Msg_Type_Description']== 'End Period']
# Out:
#      Event_Msg_Type  Action_Type Event_Msg_Type_Description  \
# 273              13            0                 End Period
#
#     Action_Type_Description
# 273

# %%
eventCodes[eventCodes['Event_Msg_Type']== 3]
# Out:
#      Event_Msg_Type  Action_Type Event_Msg_Type_Description  \
# 156               3            0                    No Shot
# 157               3           10                 Free Throw
# 158               3           11                 Free Throw
# 159               3           12                 Free Throw
# 160               3           13                 Free Throw
# 161               3           14                 Free Throw
# 162               3           15                 Free Throw
# 163               3           16                 Free Throw
# 164               3           17                 Free Throw
# 165               3           18                 Free Throw
# 166               3           19                 Free Throw
# 167               3           20                 Free Throw
# 168               3           21                 Free Throw
# 169               3           22                 Free Throw
# 170               3           25                 Free Throw
# 171               3           26                 Free Throw
# 172               3           27                 Free Throw
# 173               3           28                 Free Throw
# 174               3           29                 Free Throw
#
#           Action_Type_Description
# 156                           NaN
# 157             Free Throw 1 of 1
# 158             Free Throw 1 of 2
# 159             Free Throw 2 of 2
# 160             Free Throw 1 of 3
# 161             Free Throw 2 of 3
# 162             Free Throw 3 of 3
# 163          Free Throw Technical
# 164         Free Throw Clear Path
# 165    Free Throw Flagrant 1 of 2
# 166    Free Throw Flagrant 2 of 2
# 167    Free Throw Flagrant 1 of 1
# 168   Free Throw Technical 1 of 2
# 169   Free Throw Technical 2 of 2
# 170  Free Throw Clear Path 1 of 2
# 171  Free Throw Clear Path 2 of 2
# 172    Free Throw Flagrant 1 of 3
# 173    Free Throw Flagrant 2 of 3
# 174    Free Throw Flagrant 3 of 3

# %%
type(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-6fac7a639ca6> in <module>()
# ----> 1 type(b)
#
# NameError: name 'b' is not defined

# %%
eventCodes[eventCodes['Event_Msg_Type'] == 1]['Event_Msg_Type_Description'].unique()[0]

# %%
#Creates a dictionary of the format {team1: {player1: [0,0,0], player2: [0,0,0], ...}, team2: {...}, ...}
#The array for each player is [PointsFor, PointsAgainst, Possessions]
teamDict ={team: {} for team in list(GameLineup['Team_id'].unique())}
for team in teamDict.keys():
    players = list(GameLineup[GameLineup['Team_id'] == team]['Person_id'].unique())
    for player in players:
        teamDict[team][player] = np.array([0, 0, 0])

# %%
#Team Dictionary above might not be useful or convenient. 
#Will always access by players and thus requires another list to keep track of what team a player is on
#Instead of its just a full list of players, it doesn't really matter what their associated team is, 
#as long as game lineups tracked

#Also realized format is rating per game so this should be done a per game basis
playerDict = {player: np.array([0,0,0]) for player in list(GameLineup['Person_id'].unique())}

# %%
def readablePlayByPlay(playByPlay, gameLineup, eventCodes):
    """Maps teamIDs to correct player and replaces it with a simple team0 or team1. 
    Also maps event numbers and action to corresponding description, based off eventCodes"""
    gameTeams = list(gameLineup['Team_id'].unique())
    playerList = list(gameLineup['Person_id'].unique())
    
    playByPlay['Event_Msg_Type'] = playByPlay['Event_Msg_Type'].astype(str)
    playByPlay['Action_Type'] = playByPlay['Action_Type'].astype(str)
    
    print('Team0', gameTeams[0])
    print('Team1', gameTeams[1])
    
    for event in playByPlay.itertuples():
        i = getattr(event, 'Index')
        player = getattr(event, 'Person1')
        teamID = getattr(event, 'Team_id')
        
        if teamID not in gameTeams:
            playerTeam = 'Officials'
        else:
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        #print(playerTeam)
        #print(gameTeams)
        
        if playerTeam == gameTeams[0]:
            playByPlay.at[i,'Team_id'] = 'Team0'
        elif playerTeam == gameTeams[1]:
            playByPlay.at[i, 'Team_id'] = 'Team1'
        else:
            playByPlay.at[i, 'Team_id'] = 'Officials'

        
        eventNum = getattr(event, 'Event_Num')
         #Get the event type
        eventMsgType = int(getattr(event, "Event_Msg_Type"))
        actionType = int(getattr(event, 'Action_Type'))
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        playByPlay.at[i, 'Event_Msg_Type'] = eventMsgDescript
        playByPlay.at[i, 'Action_Type'] = actionTypeDescript
    return playByPlay

# %%
j = 0
def addPoints(player, points, team0Lineup, team1Lineup, gameDict, possession):
    #Player is person1 of the event messages. Every teammate gets the points for added and opponents points against
    global j
    #print(j)
    j+=1
    if player in team0Lineup:
        for team0player in team0Lineup:
            #Add points for and off possession
            gameDict[team0player] += np.array([points, 0, possession, 0])
        for team1player in team1Lineup:
            #Add points against and def posession
            gameDict[team1player] += np.array([0, points, 0, possession])
        return
    elif player in team1Lineup:
        for team0player in team0Lineup:
            #Add points against and def possession
            gameDict[team0player] += np.array([0, points, 0, possession])
        for team1player in team1Lineup:
            #Add points for and off possession
            gameDict[team1player] += np.array([points, 0, possession, 0])
        return
    else:
        print("Player not found on either team lineup!")
        print(player)
        print('Team0', team0Lineup)
        print('Team1', team1Lineup)
        return -1
    
def addPossession(team0Lineup, team1Lineup, gameDict):
    """Adds offensive possession to team0Lineup and defensive possession to team1Lineup."""
    for team0player in team0Lineup:
        #Add off possession
        gameDict[team0player] += np.array([0, 0, 1, 0])
    for team1player in team1Lineup:
        #Add def posession
        gameDict[team1player] += np.array([0, 0, 0, 1])
    return

def getPlayerTeam(player, teamID, playerList, gameLineup):
    """Returns the team of the input player (if player is real) otherwise returns teamID"""
    if player not in playerList:
        #Team event
        playerTeam = teamID
    else:
        playerTeam = gameLineup[gameLineup['Person_id'] == player]['Team_id'].values[0]
    return playerTeam

def doSubstitution(player, event, team0Lineup, team1Lineup, verbose):
    leavingPlayer = player
    enteringPlayer = getattr(event, 'Person2')
    if leavingPlayer in team0Lineup:
        team0Lineup.remove(leavingPlayer)
        team0Lineup.append(enteringPlayer)
    else:
        team1Lineup.remove(leavingPlayer)
        team1Lineup.append(enteringPlayer)
            
    if verbose:
        print(enteringPlayer, ' replacing ', leavingPlayer)
        
def doPossessionFix(possessionInfo, team, gameDict, gameTeams, verbose = False):
    eventDescript = possessionInfo['event']
    team0Lineup = possessionInfo['team0']
    team1Lineup = possessionInfo['team1']
    lastTeam = possessionInfo['lastTeam']
    
    if (team not in gameTeams) or (lastTeam not in gameTeams):
        raise Exception('Either {} or {} not a valid team'.format(team, lastTeam))
    
    if (eventDescript == 'Missed Shot') or (eventDescript == 'Technical Free Throw'):
        if verbose:
            print('Missed shot possession fix')
        if lastTeam == team:
            #Offensive rebound on missed shot, do nothing
            if verbose:
                print("Was offensive rebound, don't do anything")
            return
        elif team == gameTeams[0]:
            #Defensive rebound by team0
            addPossession(team1Lineup, team0Lineup, gameDict)
            if verbose:
                print("Add off possession to ", team1Lineup)
                print("Add def possession to ", team0Lineup)
        else:
            #Defensive rebound by team1
            addPossession(team0Lineup, team1Lineup, gameDict)
            if verbose:
                print("Add off possession to ", team0Lineup)
                print("Add def possession to ", team1Lineup)
    elif eventDescript == 'Missed Last Free Throw':
        if verbose:
            print('FT possession fix')
        if lastTeam == team:
            #Offensive rebound, only add to subbed out players
            subbedPlayers0 = possessionInfo['subsTeam0']
            subbedPlayers1 = possessionInfo['subsTeam1']
            
            if (len(subbedPlayers0) > 0) or (len(subbedPlayers1) > 0):
                if team == gameTeams[0]:
                    #team0 grabs offensive rebound
                    addPossession(subbedPlayers0, subbedPlayers1, gameDict)
                    if verbose:
                        print("Add off possession to ", subbedPlayers0)
                        print("Add def possession to ", subbedPlayers1)
                else:
                    addPossession(subbedPlayers1, subbedPlayers0, gameDict)
                    if verbose:
                        print("Add off possession to ", subbedPlayers1)
                        print("Add def possession to ", subbedPlayers0)
        else: #Defensive Rebound
            #Only add possession to those who were on court when foul occured
            ftTeam0Lineup = possessionInfo['ftTeam0']
            ftTeam1Lineup = possessionInfo['ftTeam1']
            
            if team == gameTeams[0]:
                #team0 grabs defensive rebound
                addPossession(ftTeam1Lineup, ftTeam0Lineup, gameDict)
                if verbose:
                    print("Add off possession to ", ftTeam1Lineup)
                    print("Add def possession to ", ftTeam0Lineup)
            else:
                addPossession(ftTeam0Lineup, ftTeam1Lineup, gameDict)
                if verbose:
                    print("Add off possession to ", ftTeam0Lineup)
                    print("Add def possession to ", ftTeam1Lineup)
    else:
        raise Exception('Attempt to fix possession failed, invalid event Descript: {}'.format(eventDescript))
    
    possessionInfo = {'team0': [], 'team1': [], 'ftTeam0': [], 'ftTeam1': [], 'subsTeam0': [], 'subsTeam1': [], 
                                  'event': '', 'lastTeam': ''}
    
def doPossessionFixSub(possessionInfo, team, gameDict, gameTeams, verbose = False):
    """
    Adds possessions to players given by possessionInfo dictionary. 
        Used for when possession unknown (often due to a team rebound).
        
    
    Inputs: 
        possessionInfo: Dictionary containing the relevant information of the events leading to unknown possession.
            'team0' and 'team1' keys correspond to the team0 and team1 lineups. 
            'event' key corresponds to the event (missed shot or free throw)
            'lastTeam' key corresponds to team last known to have possession
            'subbedPlayers0' and 'subbedPlayers1' keys correspond to players subbed out in between 'event' and 
                play where possession becomes known
            'remainingPlayers0' and 'remainingPlayers1' keys typically correspond to players 
                who are still on court after a substitution occurs ie remainingPlayers = teamLineup - subbedInPlayers
                However, currently assuming that all players on court get credited with possession on missed ft 
                so will just be same as teamLineup
        
        team: Team that currently has possession to be compared to lastTeam
        
        gameDict: Dictionary containing all pointsFor/Against and off/defPossessions of each player to be updated
        
        gameTeams: List of both teams playing to be used to check if team0 or 1 has possession
        
        verbose: Optional input, where if True, prints statements describing which players possession added to
        
        """
    eventDescript = possessionInfo['event']
    team0Lineup = possessionInfo['team0']
    team1Lineup = possessionInfo['team1']
    lastTeam = possessionInfo['lastTeam']
    subbedPlayers0 = possessionInfo['subbedPlayers0']
    subbedPlayers1 = possessionInfo['subbedPlayers1']
    
    possessionInfoEmpty = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                           'event': '', 'lastTeam': '', 'subbedPlayers0': [], 'subbedPlayers1': []}
    
    if (team not in gameTeams) or (lastTeam not in gameTeams):
        raise Exception('Either {} or {} not a valid team'.format(team, lastTeam))
    
    if (eventDescript == 'Missed Shot') or (eventDescript == 'Technical Free Throw'):
        if verbose:
            print('Missed shot possession fix')
        if len(subbedPlayers0) + len(subbedPlayers1) > 0:
            #Regardless of who rebounds add possession to players subbed off
            if team == gameTeams[0]:
                #Team0 players who were subbed now on offense (ASSUMES sub happens after rebound)
                addPossession(subbedPlayers0, subbedPlayers1, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers0)
                    print("Add def possession to subbed players", subbedPlayers1)
            else:
                addPossession(subbedPlayers1, subbedPlayers0, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers1)
                    print("Add def possession to subbed players", subbedPlayers0)
        if lastTeam == team:
            #Offensive rebound on missed shot, do nothing except for subbed players
            
            if verbose:
                print("Was offensive rebound, don't do anything for on court players")
            return possessionInfoEmpty
        elif team == gameTeams[0]:
            #Defensive rebound by team0
            addPossession(team1Lineup, team0Lineup, gameDict)
            
            if verbose:
                print("Add off possession to ", team1Lineup)
                print("Add def possession to ", team0Lineup)
        else:
            #Defensive rebound by team1
            addPossession(team0Lineup, team1Lineup, gameDict)

            if verbose:
                print("Add off possession to ", team0Lineup)
                print("Add def possession to ", team1Lineup)
                    
    elif eventDescript == 'Missed Last Free Throw':
        if verbose:
            print('FT possession fix')
        if lastTeam == team:
            #Do nothing, as possession already added to subbed players
            pass
            
        else: #Defensive Rebound
            #Only add possession to those who were on court when foul occured
            ##UPDATE: I believe NBA actually counts it as a possession for all players on court, 
            #so while still labeled remainingPlayers, input in gameRatings function will be teamLineup
            remainingPlayers0 = possessionInfo['remainingPlayers0']
            remainingPlayers1 = possessionInfo['remainingPlayers1']
            
            if team == gameTeams[0]:
                #team0 grabs defensive rebound
                addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers1)
                    print("Add def possession to ", remainingPlayers0)
            else:
                addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers0)
                    print("Add def possession to ", remainingPlayers1)
    else:
        raise Exception('Attempt to fix possession failed, invalid event Descript: {}'.format(eventDescript))
    
    return possessionInfoEmpty

# %%
c = []
c.append('d')
c

# %%
game0 = GameIDs[0]
game0PlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game0])
game0Lineup = GameLineup[GameLineup['Game_id'] == game0]
game0Teams = list(game0Lineup['Team_id'].unique())

#Dictionary of every player (active or inactive for this game)
game0Dict = {player: np.array([0,0,0]) for player in list(game0Lineup['Person_id'].unique())}

#Following are the starting lineups for each time
team0Lineup = list(game0Lineup[(game0Lineup['Period'] ==1) & (game0Lineup['Team_id'] == game0Teams[0])]['Person_id'])
team1Lineup = list(game0Lineup[(game0Lineup['Period'] ==1) & (game0Lineup['Team_id'] == game0Teams[1])]['Person_id'])
ftTeam0Lineup = team0Lineup
ftTeam1Lineup = team1Lineup

# %%
def gameRatings(gamePlayByPlay, gameLineup, eventCodes, verbose = False):
    lastDescript = ''
    counter = 0
    gameTeams = list(gameLineup['Team_id'].unique())
    
    #Create dictionary with keys of each player and value of array([PointsFor,PointsAgainst, OffPossessions, DefPossessions])
    playerList = list(gameLineup['Person_id'].unique())
    gameDict = {player: np.array([0,0,0,0]) for player in playerList}
    
    #List of event numbers to skip (designed for the case where we 'look ahead' at a future rebound due to playbyplay error)
    skipEventNums = []
    
    for event in gamePlayByPlay.itertuples():
        eventNum = getattr(event, 'Event_Num')
         #Get the event type
        eventMsgType = getattr(event, "Event_Msg_Type")
        actionType = getattr(event, 'Action_Type')
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        player = getattr(event, 'Person1') #Player who shoots, rebounds, etc
        if verbose:
            print('Counter', counter)
            print('Event Num', eventNum)
            print(skipEventNums)
            print(eventMsgDescript, 'by', player)
    
        counter += 1
        if eventNum in skipEventNums:
            continue
        

        
        teamID = getattr(event, 'Team_id') #teamID doesn't always correspond to player's team
        playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        PCtime = getattr(event, 'PC_Time')
        period = getattr(event, 'Period')
        #Make sure none of the following gets double counted -- most likely on and-1s
        
        #Substitutions at start of period aren't considered substitution events. Must check game linup explicitly. 
        if eventMsgDescript == 'Start Period':
            period = getattr(event, 'Period')
            team0Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[0])]['Person_id'])
            team1Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[1])]['Person_id'])
            #print(team0Lineup)
            #print(team1Lineup)
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            lastDescript = ''
            unknownRebound = False
            unknownReboundInfo = {'team0': [], 'team1': [], 'ftTeam0': [], 'ftTeam1': [], 'subsTeam0': [], 'subsTeam1': [], 
                                  'event': '', 'lastTeam': ''}
            
            if verbose:
                print(period,' lineup 0:', team0Lineup)
                print(period,' lineup 1:', team1Lineup)
        elif eventMsgDescript == 'End Period':
            if unknownRebound:
                doPossessionFix(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
            lastDescript = ''
            if verbose:
                print(period, 'ended')
        if lastDescript == 'Missed Shot':
            lastDescript = ''
            if eventMsgDescript != 'Rebound':
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at later time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                
                #Check if rebound occurs at later (period and playclock time, arena time does not work!)
                #reboundEvent = gamePlayByPlay[(gamePlayByPlay['Period'] == period) 
                #                              & (gamePlayByPlay['PC_Time'] <= PCtime) 
                #                              & (gamePlayByPlay['Event_Msg_Type'] == 4) 
                #                              & (gamePlayByPlay['WC_Time'] >= WCtime)]
                #reboundEvent = sortedPlayByPlay(reboundEvent)
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[reboundEvent['Event_Msg_Type'] == 4]
                if reboundEvent.empty:
                    print('No rebound at after!')
                    print('Counter', counter-1)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])

            #if player not in lastTeam: #Defensive rebound (for an offensive rebound do nothing)
            
            #Check that if real player (not team rebound) grabbed board, that he is on the court
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Counter', counter-1)
                print('Event num', getattr(event, 'Event_Num'))
                break
                
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
        
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Shot'
                unknownReboundInfo['lastTeam'] = lastTeam
                    
            elif playerTeam != lastTeam:
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    addPossession(team1Lineup, team0Lineup, gameDict)
                else:
                    addPossession(team0Lineup, team1Lineup, gameDict)
                if verbose:
                    print("Defensive Rebound")

            else:
                if verbose:
                    print("Offensive Rebound")
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        elif lastDescript == 'Missed Last Free Throw':
            #Noticed some stoppage (probably clock malfunction after missed shot, the next event was a rebound)
            #if eventMsgDescript == 'Stoppage':
            #    continue
            lastDescript = ''
            if eventMsgDescript != 'Rebound':
                #Does a missed shot that goes out of bounds count as turnover? Don't think so
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at same time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                WCtime = getattr(event, 'WC_Time')
                
                #Check if rebound occurs at same time or after (period and playclock time, arena time does not work!)
                #From the instances where I've noticed an issue, the rebound always occurs after missed shot but not necessarily same time
                #reboundEvent = gamePlayByPlay[(gamePlayByPlay['Period'] == period) 
                #                              & (gamePlayByPlay['PC_Time'] <= PCtime) 
                #                              & (gamePlayByPlay['Event_Msg_Type'] == 4) 
                #                              & (gamePlayByPlay['WC_Time'] >= WCtime)]
                #reboundEvent = sortedPlayByPlay(reboundEvent)
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[reboundEvent['Event_Msg_Type'] == 4]
                if reboundEvent.empty:
                    print('Event num', getattr(event, 'Event_Num'))
                    print('No rebound at same time!')
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])
                
            #There are cases where the substitution event happens after rebound. 
            #In the end does it matter since only people part of ftTeam matter? 
            #Makes attributing possessions to subbed players hard if ignore substitution until after. 
            #Because if a player was subbed off and then an offensive rebound happens, 
            #if events were switched they wouldn't get a possession
            
            if True:#(player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                #Check if players subbed at same time
                
                subEvents = gamePlayByPlay[counter-1:]
                subEvents = subEvents[(subEvents['Event_Msg_Type'] == 8) 
                                    & (subEvents['Period'] == period) 
                                    & (subEvents['PC_Time'] == PCtime)]
                for substitution in subEvents.itertuples():
                    subPlayer = getattr(substitution, 'Person1')
                    subEventNum = getattr(substitution, 'Event_Num')
                    skipEventNums.append(subEventNum)
                    doSubstitution(subPlayer, substitution, team0Lineup, team1Lineup, verbose)
                    if verbose:
                        print('Sub after ft')
                    
                if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                    print('Player not on court', player)
                    print('team0', team0Lineup)
                    print('team1', team1Lineup)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
            
            subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
            subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))

            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Last Free Throw'
                unknownReboundInfo['subsTeam0'] = subbedPlayers0.copy()
                unknownReboundInfo['subsTeam1'] = subbedPlayers1.copy()
                unknownReboundInfo['ftTeam0'] = ftTeam0Lineup.copy()
                unknownReboundInfo['ftTeam1'] = ftTeam1Lineup.copy()
                unknownReboundInfo['lastTeam'] = lastTeam
                
            #Offensive Rebound
            elif playerTeam == lastTeam:
                #Add possession only to the players who were subbed out, if any
                if (len(subbedPlayers0) > 0) or (len(subbedPlayers1) > 0):
                    if playerTeam == gameTeams[0]:
                        #team0 grabs offensive rebound
                        addPossession(subbedPlayers0, subbedPlayers1, gameDict)
                    else:
                        addPossession(subbedPlayers1, subbedPlayers0, gameDict)
                if verbose:
                    print("Offensive Rebound")
 
            else: #Defensive Rebound
                #Only add possession to those who were on court when foul occured
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    addPossession(ftTeam1Lineup, ftTeam0Lineup, gameDict)
                else:
                    addPossession(ftTeam0Lineup, ftTeam1Lineup, gameDict)
                    
                if verbose:
                    print("Defensive Rebound")
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        if eventNum in skipEventNums:
            continue
        
        elif eventMsgDescript == 'Substitution':
            doSubstitution(player, event, team0Lineup, team1Lineup, verbose)
            
        if eventMsgDescript == 'Made Shot':
            if unknownRebound:
                doPossessionFix(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            points = getattr(event, 'Option1')
            
            #Check if and-1. Only checking if fts happen not action type ft 1 out of 1 because possibility of flagrant.
            #This assumes that the ft shot will always be after the made shot in a play by play
            ftEvents = gamePlayByPlay[counter-1:]
            ftEvents = ftEvents[(ftEvents['Event_Msg_Type'] == 3) 
                                    & (ftEvents['Period'] == period) 
                                    & (ftEvents['PC_Time'] == PCtime)]
            # if ft happens then don't count possession, because it will be handled when loop hits that event
            if ftEvents.empty:
                poss = 1
            else:
                poss = 0
            
            addPoints(player,points, team0Lineup, team1Lineup, gameDict, possession= poss)
            if verbose:
                print(player, 'scores', points, 'points')
        elif eventMsgDescript == 'Turnover':
            if unknownRebound:
                doPossessionFix(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
                
            if verbose:
                print(playerTeam, 'turnover')
        elif eventMsgDescript == 'Missed Shot':
            if unknownRebound:
                doPossessionFix(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Check who rebounds in next iteration
            lastDescript = eventMsgDescript
            #player = getattr(event, 'Person1') #Player who misses shot
            if player in team0Lineup:
                #lastTeam = team0Lineup
                lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
            else:
                #lastTeam = team1Lineup
                lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
            if verbose:
                print(player, 'misses shot')

        #Check if Foul (which may or may not lead to free throws), but all free throws come from fouls
        #Important to check if a generic foul and not just shooting fouls, otherwise the free throw lineup will be 'behind'
        #If only looked at shooting fouls - consider situation of substitutions during the game and then a technical foul. 
        #The ft lineup would only be from the previous fts, not the current lineup. 
        elif (eventMsgDescript == 'Foul'):
            #Mistake here before! Working with lists so when teamLineup modified via substitution, 
            #the ftTeamLineup was also modified. Using copy fixes
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            
            if verbose:
                print('Foul on team', playerTeam)

        elif eventMsgDescript == 'Free Throw':
            if unknownRebound:
                doPossessionFix(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            option1 = getattr(event, 'Option1')
            if option1 == 1: #Made Free Throw
                points = 1
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #ActionTypes corresponding to final free throw, so add possession. 
                    #Also update ft lineups to on court lineup. 
                    #CORRECTION I don't think we need to update this because fts only happen after some kind of foul
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=1)
                    #ftTeam0Lineup = team0Lineup
                    #ftTeam1Lineup = team1Lineup
                    if verbose:
                        print('Made final free throw by', player)
                else:
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    if verbose:
                        print('Made free throw by', player)
            else: #Missed FT
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #Missed last free throw for a shooting foul (not technical/flagrant), check who rebounds in next iteration. 
                    lastDescript = 'Missed Last Free Throw'
                    #Offensive rebounds with substitution going to be weird in terms of possessions

                    #Check current lineup, not free throw lineup since current lineup will be the one to rebound
                    if player in team0Lineup:
                        #lastTeam = team0Lineup
                        lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
                    else:
                        #lastTeam = team1Lineup
                        lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
                    if verbose:
                        print('Missed last free throw by', player)
                        print('ftteam1', ftTeam1Lineup)
                else:
                    if verbose:
                        print('Missed free throw by', player)

            #NBA seems to count technical free throws a possession. Delete block below if undesired.
            
            #Check whether was last technical free throw (not flagrant which team keeps possession)
            if (actionType == 16) or (actionType == 22):
                #Use the possessionFix method already implemented and just count this free throw as the 'unknownRebound'
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Technical Free Throw'
                unknownReboundInfo['ftTeam0'] = ftTeam0Lineup.copy()
                unknownReboundInfo['ftTeam1'] = ftTeam1Lineup.copy()
                unknownReboundInfo['lastTeam'] = playerTeam
            #do harder stuff
            
    return gameDict

# %%
def gameRatingsComplete(gamePlayByPlay, gameLineup, eventCodes, verbose = False):
    """Turns a given PlayByPlay log and calculates the number of points and possessions a player is in the game for, 
    both scored by and against the players team. Can be used to calculate offensive and defensive rating defined by 
    offRtg = 100*pointsFor/offPossessions and defRtg = 100*pointsAgainst/defPossesssions
    
    Inputs:
        gamePlayByPlay: A Pandas dataframe object listing the play by play events for a single game. 
            This should be sorted according to the prompt (Period, PC_Time, WC_Time, Event_Num). Taken from Play_by_Play.txt .
        
        gameLineup: A Pandas dataframe of the game lineup for the same gams as the play by play. Taken from Game_Lineup.txt .
        
        eventCodes: Pandas dataframe of the event codes provided by the NBA. Taken from Event_Codes.txt .
        
        verbose: Optional argument. If set to True, prints the current loop counter and a description of each event 
            (made shot, rebound, turnover, etc)
        
    Output:
        gameDict: A dictionary where the keys are each playerID from the gameLineup input, 
            and the value is an array of [pointsFor, pointsAgainst, offPossessions, defPossessions]
    
    """
    
    lastDescript = ''
    counter = 0
    gameTeams = list(gameLineup['Team_id'].unique())
    
    #Create dictionary with keys of each player and value of array([PointsFor, PointsAgainst, OffPossessions, DefPossessions])
    playerList = list(gameLineup['Person_id'].unique())
    gameDict = {player: np.array([0,0,0,0]) for player in playerList}
    
    #List of event numbers to skip 
    #(designed for the case where we 'look ahead' at a future rebound or substitution due to playbyplay error)
    skipEventNums = []
    
    #Keep track of team with possession 
    currPoss = ''
    #Keep track of play clock time (due to weird handling of technical fouls as possessions by NBA) 
    #Initialize to -1 so no accidental equalities
    currTime = -1 
    
    #Added because of cases where made shot with 0 on clock would lead to another possession being added when period ended
    #Unclear if have to take into account other actions at 0
    skipEndPeriod = False
    
    for event in gamePlayByPlay.itertuples():
        
        eventNum = getattr(event, 'Event_Num')
        
         #Get the event type
        eventMsgType = getattr(event, "Event_Msg_Type")
        actionType = getattr(event, 'Action_Type')
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        #Player who shoots, rebounds, etc
        player = getattr(event, 'Person1')
        
        if verbose:
            print('Counter', counter)
            print('Event Num', eventNum)
            print(skipEventNums)
            print(eventMsgDescript, 'by', player)
    
        counter += 1
        if eventNum in skipEventNums:
            continue
        

        
        teamID = getattr(event, 'Team_id') #teamID doesn't always correspond to player's team
        playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        PCtime = getattr(event, 'PC_Time')
        period = getattr(event, 'Period')

     
        if eventMsgDescript == 'Start Period':
            skipEndPeriod = False
            currTime = -1
            currPoss = playerTeam
            #Substitutions at start of period aren't considered substitution events. Must check game linup explicitly.
            team0Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[0])]['Person_id'])
            team1Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[1])]['Person_id'])
            
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            lastDescript = ''
            unknownRebound = False
            unknownReboundInfo = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                                  'subbedPlayers0': [], 'subbedPlayers1': [], 'event': '', 'lastTeam': ''}
            
            if verbose:
                print(period,' lineup 0:', team0Lineup)
                print(period,' lineup 1:', team1Lineup)
        elif eventMsgDescript == 'End Period' and not skipEndPeriod:
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
            lastDescript = ''
            if verbose:
                print(period, 'ended')
        if lastDescript == 'Missed Shot':
            lastDescript = ''
            
            if currTime== 0:
                skipEndPeriod = True
                #Add possession to each player
                if lastTeam == gameTeams[0]:
                    #team0 missed on offense
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                else:
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                continue
            currTime = PCtime
            if eventMsgDescript != 'Rebound':
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at later time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                
                #Check if rebound occurs at later (period and playclock time, arena time does not work!)
                #reboundEvent = gamePlayByPlay[(gamePlayByPlay['Period'] == period) 
                #                              & (gamePlayByPlay['PC_Time'] <= PCtime) 
                #                              & (gamePlayByPlay['Event_Msg_Type'] == 4) 
                #                              & (gamePlayByPlay['WC_Time'] >= WCtime)]
                #reboundEvent = sortedPlayByPlay(reboundEvent)
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & (reboundEvent['Period'] == period)]
                if reboundEvent.empty:
                    print('No rebound after!')
                    print('Counter', counter-1)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])

            #if player not in lastTeam: #Defensive rebound (for an offensive rebound do nothing)
            
            #Check that if real player (not team rebound) grabbed board, that he is on the court
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Counter', counter-1)
                print('Event num', getattr(event, 'Event_Num'))
                break
                
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Shot'
                unknownReboundInfo['lastTeam'] = lastTeam
                    
            elif playerTeam != lastTeam:
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                if verbose:
                    print("Defensive Rebound")

            else:
                if verbose:
                    print("Offensive Rebound")
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
            
        elif lastDescript == 'Missed Last Free Throw':
            #Noticed some stoppage (probably clock malfunction after missed shot, the next event was a rebound)
            #if eventMsgDescript == 'Stoppage':
            #    continue
            lastDescript = ''
            currTime = PCtime
            if eventMsgDescript != 'Rebound':
                #Does a missed shot that goes out of bounds count as turnover? Don't think so
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at same time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                WCtime = getattr(event, 'WC_Time')
                
                #Check if rebound occurs at same time or after (period and playclock time, arena time does not work!)
                #From the instances where I've noticed an issue, the rebound always occurs after missed shot but not necessarily same time
                #reboundEvent = gamePlayByPlay[(gamePlayByPlay['Period'] == period) 
                #                              & (gamePlayByPlay['PC_Time'] <= PCtime) 
                #                              & (gamePlayByPlay['Event_Msg_Type'] == 4) 
                #                              & (gamePlayByPlay['WC_Time'] >= WCtime)]
                #reboundEvent = sortedPlayByPlay(reboundEvent)
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & ((reboundEvent['Period'] == period))]
                if reboundEvent.empty:
                    print('Event num', getattr(event, 'Event_Num'))
                    print('No rebound at same time!')
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])
                
            #There are cases where the substitution event happens after rebound. 
            #In the end does it matter since only people part of ftTeam matter? 
            #Makes attributing possessions to subbed players hard if ignore substitution until after. 
            #Because if a player was subbed off and then an offensive rebound happens, 
            #if events were switched they wouldn't get a possession
            
            if True:#(player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                #Check if players subbed at same time
                
                subEvents = gamePlayByPlay[counter-1:]
                subEvents = subEvents[(subEvents['Event_Msg_Type'] == 8) 
                                    & (subEvents['Period'] == period) 
                                    & (subEvents['PC_Time'] == PCtime)]
                for substitution in subEvents.itertuples():
                    subPlayer = getattr(substitution, 'Person1')
                    subEventNum = getattr(substitution, 'Event_Num')
                    subPlayerTeam = getPlayerTeam(subPlayer, '', playerList, gameLineup)
                    
                    skipEventNums.append(subEventNum)
                    doSubstitution(subPlayer, substitution, team0Lineup, team1Lineup, verbose)
                    if subPlayerTeam == currPoss:
                        #Player subbed out on offense
                        addPossession([subPlayer], [], gameDict)
                    else:
                        addPossession([], [subPlayer], gameDict)
                    if verbose:
                        print('Sub after ft')
                    
                if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                    print('Player not on court', player)
                    print('team0', team0Lineup)
                    print('team1', team1Lineup)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
            
            subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
            subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
            remainingPlayers0 = list(set(ftTeam0Lineup)-set(subbedPlayers0))
            remainingPlayers1 = list(set(ftTeam1Lineup)-set(subbedPlayers1))
            
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Last Free Throw'
                unknownReboundInfo['remainingPlayers0'] = remainingPlayers0.copy()
                unknownReboundInfo['remainingPlayers1'] = remainingPlayers1.copy()

                unknownReboundInfo['lastTeam'] = lastTeam
                
            #Offensive Rebound, no possessions added (already added to subbed players)
            elif playerTeam == lastTeam:
                if verbose:
                    print("Offensive Rebound")
 
            else: #Defensive Rebound
                #Only add possession to those who were on court when foul occured and are still on court
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to remainingPlayers if this is undesired
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    #addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    #addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                    
                if verbose:
                    print("Defensive Rebound")
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        if eventNum in skipEventNums:
            continue
        
        if eventMsgDescript == 'Substitution':
            doSubstitution(player, event, team0Lineup, team1Lineup, verbose)
            
            if unknownRebound:
                if playerTeam == gameTeams[0]:
                    unknownReboundInfo['subbedPlayers0'].append(player)
                elif playerTeam == gameTeams[1]:
                    unknownReboundInfo['subbedPlayers1'].append(player)
            else:
                if playerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([player], [], gameDict)
                else:
                    addPossession([], [player], gameDict)
            
        if eventMsgDescript == 'Made Shot':
            currTime = PCtime
            if PCtime == 0:
                skipEndPeriod = True
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            points = getattr(event, 'Option1')
            
            #Check if and-1. Only checking if fts happen not action type ft 1 out of 1 because possibility of flagrant.
            #This assumes that the ft shot will always be after the made shot in a play by play
            ftEvents = gamePlayByPlay[counter-1:]
            ftEvents = ftEvents[(ftEvents['Event_Msg_Type'] == 3) 
                                    & (ftEvents['Period'] == period) 
                                    & (ftEvents['PC_Time'] == PCtime)]
            # if ft happens then don't count possession, because it will be handled when loop hits that event
            if ftEvents.empty:
                poss = 1
                if playerTeam == gameTeams[0]:
                    currPoss = gameTeams[1]
                else:
                    currPoss = gameTeams[0]
            else:
                poss = 0
            
            addPoints(player,points, team0Lineup, team1Lineup, gameDict, possession= poss)
            if verbose:
                print(player, 'scores', points, 'points')
        elif eventMsgDescript == 'Turnover':
            currTime = PCtime
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
                currPoss = gameTeams[1]
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
                currPoss = gameTeams[0]
                
            if verbose:
                print(playerTeam, 'turnover')
                
        elif eventMsgDescript == 'Missed Shot':
            currTime = PCtime
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Check who rebounds in next iteration
            lastDescript = eventMsgDescript
            #player = getattr(event, 'Person1') #Player who misses shot
            if player in team0Lineup:
                #lastTeam = team0Lineup
                lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
            else:
                #lastTeam = team1Lineup
                lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
            if verbose:
                print(player, 'misses shot')

        #Check if Foul (which may or may not lead to free throws), but all free throws come from fouls
        #Important to check if a generic foul and not just shooting fouls, otherwise the free throw lineup will be 'behind'
        #If only looked at shooting fouls - consider situation of substitutions during the game and then a technical foul. 
        #The ft lineup would only be from the previous fts, not the current lineup. 
        elif (eventMsgDescript == 'Foul'):
            #Mistake here before! Working with lists so when teamLineup modified via substitution, 
            #the ftTeamLineup was also modified. Using copy fixes
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            
            if verbose:
                print('Foul on team', playerTeam)

        elif eventMsgDescript == 'Free Throw':
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            option1 = getattr(event, 'Option1')
            if option1 == 1: #Made Free Throw
                points = 1
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #ActionTypes corresponding to final free throw, so add possession. 
                    subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
                    subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
                    
                    #subbedPlayers already got possession added so only add to remaining players on court
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    remainingPlayers0 = list(set(ftTeam0Lineup) - set(subbedPlayers0))
                    remainingPlayers1 = list(set(ftTeam1Lineup) - set(subbedPlayers1))
                    
                    if playerTeam == gameTeams[0]:
                        addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                        currPoss = gameTeams[1]
                    elif playerTeam == gameTeams[1]:
                        addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                        currPoss = gameTeams[0]
                    else:
                        print('Error: Free throw player not on either team')
                        return
                    #ftTeam0Lineup = team0Lineup
                    #ftTeam1Lineup = team1Lineup
                    if verbose:
                        print('Made final free throw by', player)
                else:
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    if verbose:
                        print('Made free throw by', player)
            else: #Missed FT
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #Missed last free throw for a shooting foul (not technical/flagrant), check who rebounds in next iteration. 
                    lastDescript = 'Missed Last Free Throw'
                    #Offensive rebounds with substitution going to be weird in terms of possessions

                    #Check current lineup, not free throw lineup since current lineup will be the one to rebound
                    if player in team0Lineup:
                        #lastTeam = team0Lineup
                        lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
                    else:
                        #lastTeam = team1Lineup
                        lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
                    if verbose:
                        print('Missed last free throw by', player)
                        print('ftteam1', ftTeam1Lineup)
                else:
                    if verbose:
                        print('Missed free throw by', player)

            #NBA seems to count technical free throws a possession. Delete block below if undesired.
            
            #Check whether was last technical free throw (not flagrant which team keeps possession)
            if (actionType == 16) or (actionType == 22):
                
                
                #Use the possessionFix method already implemented and just count this free throw as the 'unknownRebound'
                #Keeping this block for now, but replacing for now due to what appears to be 
                #tech free throws counting as a change of possession, not just an extra possession. 
                #So if team on offense commits tech that counts as off + def possession
                #then def + off possession for tech ft, and then following possession will be off + def
                if False:
                    unknownRebound = True
                    unknownReboundInfo['team0'] = team0Lineup.copy()
                    unknownReboundInfo['team1'] = team1Lineup.copy()
                    unknownReboundInfo['event'] = 'Technical Free Throw'
                    unknownReboundInfo['remainingPlayers0'] = ftTeam0Lineup.copy()
                    unknownReboundInfo['remainingPlayers1'] = ftTeam1Lineup.copy()
                    #unknownReboundInfo['ftTeam0'] = ftTeam0Lineup.copy()
                    #unknownReboundInfo['ftTeam1'] = ftTeam1Lineup.copy()
                    unknownReboundInfo['lastTeam'] = playerTeam
                    
                #Check if tech committed by team with possession. If so add offensive and defensive possession to both teams 
                #(off from having ball, def from tech shot)
                
                #Also it seems like only if time passed in a given possession does the tech count as a change in possession.
                #Remove currTime != PCtime so all techs treated equally
                if currPoss != playerTeam and currTime != PCtime:
                    addPossession(ftTeam1Lineup, ftTeam0Lineup, gameDict)
                    addPossession(ftTeam0Lineup, ftTeam1Lineup, gameDict)
    return gameDict

# %%
def gameRatingsSubCleaned(gamePlayByPlay, gameLineup, eventCodes, verbose = False):
    """Turns a given PlayByPlay log and calculates the number of points and possessions a player is in the game for, 
    both scored by and against the players team. Can be used to calculate offensive and defensive rating defined by 
    offRtg = 100*pointsFor/offPossessions and defRtg = 100*pointsAgainst/defPossesssions
    
    Inputs:
        gamePlayByPlay: A Pandas dataframe object listing the play by play events for a single game. 
            This should be sorted according to the prompt (Period, PC_Time, WC_Time, Event_Num). Taken from Play_by_Play.txt .
        
        gameLineup: A Pandas dataframe of the game lineup for the same gams as the play by play. Taken from Game_Lineup.txt .
        
        eventCodes: Pandas dataframe of the event codes provided by the NBA. Taken from Event_Codes.txt .
        
        verbose: Optional argument. If set to True, prints the current loop counter and a description of each event 
            (made shot, rebound, turnover, etc)
        
    Output:
        gameDict: A dictionary where the keys are each playerID from the gameLineup input, 
            and the value is an array of [pointsFor, pointsAgainst, offPossessions, defPossessions]
    
    """
    
    lastDescript = ''
    counter = 0
    gameTeams = list(gameLineup['Team_id'].unique())
    
    #Create dictionary with keys of each player and value of array([PointsFor, PointsAgainst, OffPossessions, DefPossessions])
    playerList = list(gameLineup['Person_id'].unique())
    gameDict = {player: np.array([0,0,0,0]) for player in playerList}
    
    #List of event numbers to skip 
    #(designed for the case where we 'look ahead' at a future rebound or substitution due to playbyplay error)
    skipEventNums = []
    
    #Keep track of team with possession 
    currPoss = ''
    #Keep track of play clock time (due to weird handling of technical fouls as possessions by NBA) 
    #Initialize to -1 so no accidental equalities
    currTime = -1 
    
    #Added because of cases where made shot with 0 on clock would lead to another possession being added when period ended
    #Unclear if have to take into account other actions at 0
    skipEndPeriod = False
    
    for event in gamePlayByPlay.itertuples():
        
        eventNum = getattr(event, 'Event_Num')
        
         #Get the event type
        eventMsgType = getattr(event, "Event_Msg_Type")
        actionType = getattr(event, 'Action_Type')
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        #Player who shoots, rebounds, etc
        player = getattr(event, 'Person1')
        
        if verbose:
            print('Counter', counter)
            print('Event Num', eventNum)
            print(skipEventNums)
            print(eventMsgDescript, 'by', player)
    
        counter += 1
        if eventNum in skipEventNums:
            continue
        

        
        teamID = getattr(event, 'Team_id') #teamID doesn't always correspond to player's team
        playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        PCtime = getattr(event, 'PC_Time')
        period = getattr(event, 'Period')

     
        if eventMsgDescript == 'Start Period':
            skipEndPeriod = False
            currTime = -1
            currPoss = playerTeam
            #Substitutions at start of period aren't considered substitution events. Must check game linup explicitly.
            team0Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[0])]['Person_id'])
            team1Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[1])]['Person_id'])

            lastDescript = ''
            
            #Used for cases of a team rebound not assigned to a particular player. The teamID is often wrong, 
            #so when unknownRebound is True, next events are checked to see who has the ball.
            unknownRebound = False
            unknownReboundInfo = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                                  'subbedPlayers0': [], 'subbedPlayers1': [], 'event': '', 'lastTeam': ''}
            
            if verbose:
                print(period,' lineup 0:', team0Lineup)
                print(period,' lineup 1:', team1Lineup)
                
                
        elif eventMsgDescript == 'End Period' and not skipEndPeriod:
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
                
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
            lastDescript = ''
            
            if verbose:
                print(period, 'ended')
                
        if lastDescript == 'Missed Shot':
            #Previous event missed shot, check who rebounded
            
            lastDescript = ''
            
            if currTime== 0:
                #Miss at end of period so skip End Period event otherwise double count of possession
                skipEndPeriod = True
                #Add possession to each player
                if lastTeam == gameTeams[0]:
                    #team0 missed on offense
                    addPossession(team0Lineup, team1Lineup, gameDict)
                else:
                    addPossession(team1Lineup, team0Lineup, gameDict)
                continue
                
            currTime = PCtime
            
            if eventMsgDescript != 'Rebound':
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at later time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                
                #Get all events after current one and check which events correspond to a rebound in same period
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & (reboundEvent['Period'] == period)]
                if reboundEvent.empty:
                    print('No rebound after!')
                    print('Counter', counter-1)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])

            #if player not in lastTeam: #Defensive rebound (for an offensive rebound do nothing)
            
            #Check that if real player (not team rebound) grabbed board, that he is on the court
            #Shouldn't be triggered if parsing done correctly, but good for error checking
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Counter', counter-1)
                print('Event num', getattr(event, 'Event_Num'))
                break
                
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Shot'
                unknownReboundInfo['lastTeam'] = lastTeam
                    
            elif playerTeam != lastTeam:
                #Defensive rebound
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                if verbose:
                    print("Defensive Rebound")

            else:
                if verbose:
                    print("Offensive Rebound")
            #Reset to player of current event for instances where we needed to find next rebound due to wrong order
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
            
        elif lastDescript == 'Missed Last Free Throw':
            #Similar structure as missing last shot, except take into account possibility of substitutions 
            #(important if don't want to give substitutions to player subbed in -- NBA seems to count those)
            lastDescript = ''
            currTime = PCtime
            if eventMsgDescript != 'Rebound':
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at same time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                WCtime = getattr(event, 'WC_Time')
                
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & ((reboundEvent['Period'] == period))]
                if reboundEvent.empty:
                    print('Event num', getattr(event, 'Event_Num'))
                    print('No rebound at same time!')
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])


            #Check if players subbed at same time
            subEvents = gamePlayByPlay[counter-1:]
            subEvents = subEvents[(subEvents['Event_Msg_Type'] == 8) 
                                & (subEvents['Period'] == period) 
                                & (subEvents['PC_Time'] == PCtime)]
            for substitution in subEvents.itertuples():
                subPlayer = getattr(substitution, 'Person1')
                subEventNum = getattr(substitution, 'Event_Num')
                subPlayerTeam = getPlayerTeam(subPlayer, '', playerList, gameLineup)
                    
                skipEventNums.append(subEventNum)
                doSubstitution(subPlayer, substitution, team0Lineup, team1Lineup, verbose)
                if subPlayerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([subPlayer], [], gameDict)
                else:
                    addPossession([], [subPlayer], gameDict)
                if verbose:
                    print('Sub after ft')
                    
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Event num', getattr(event, 'Event_Num'))
                break
            
            subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
            subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
            remainingPlayers0 = list(set(ftTeam0Lineup)-set(subbedPlayers0))
            remainingPlayers1 = list(set(ftTeam1Lineup)-set(subbedPlayers1))
            
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Last Free Throw'
                #unknownReboundInfo['remainingPlayers0'] = remainingPlayers0.copy()
                #unknownReboundInfo['remainingPlayers1'] = remainingPlayers1.copy()
            
                unknownReboundInfo['remainingPlayers0'] = team0Lineup.copy()
                unknownReboundInfo['remainingPlayers1'] = team1Lineup.copy()

                unknownReboundInfo['lastTeam'] = lastTeam
                
            #Offensive Rebound, no possessions added (already added to subbed players)
            elif playerTeam == lastTeam:
                if verbose:
                    print("Offensive Rebound")
 
            else:
                #Only add possession to those who were on court when foul occured and are still on court
            
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    #addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    #addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                    
                if verbose:
                    print("Defensive Rebound")
                    
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        if eventNum in skipEventNums:
            #Check this again because of iteration through substitution events after missed shot or free throw
            continue
        
        if eventMsgDescript == 'Substitution':
            doSubstitution(player, event, team0Lineup, team1Lineup, verbose)
            
            #In case current possession unknown use unknownRebound logic to check next possession and assign correct possessions
            if unknownRebound:
                if playerTeam == gameTeams[0]:
                    unknownReboundInfo['subbedPlayers0'].append(player)
                elif playerTeam == gameTeams[1]:
                    unknownReboundInfo['subbedPlayers1'].append(player)
            else:
                if playerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([player], [], gameDict)
                else:
                    addPossession([], [player], gameDict)
            
        if eventMsgDescript == 'Made Shot':
            currTime = PCtime
            if PCtime == 0:
                skipEndPeriod = True
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            points = getattr(event, 'Option1')
            
            #Check if and-1. Only checking if fts happen not action type ft 1 out of 1 because possibility of flagrant.
            #This assumes that the ft shot will always be after the made shot in a play by play
            ftEvents = gamePlayByPlay[counter-1:]
            ftEvents = ftEvents[(ftEvents['Event_Msg_Type'] == 3) 
                                    & (ftEvents['Period'] == period) 
                                    & (ftEvents['PC_Time'] == PCtime)]
            # if ft happens then don't count possession, because it will be handled when loop hits that event
            if ftEvents.empty:
                poss = 1
                if playerTeam == gameTeams[0]:
                    currPoss = gameTeams[1]
                else:
                    currPoss = gameTeams[0]
            else:
                poss = 0
            
            addPoints(player,points, team0Lineup, team1Lineup, gameDict, possession= poss)
            
            if verbose:
                print(player, 'scores', points, 'points')
                
        elif eventMsgDescript == 'Turnover':
            
            currTime = PCtime
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
                currPoss = gameTeams[1]
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
                currPoss = gameTeams[0]
                
            if verbose:
                print(playerTeam, 'turnover')
                
        elif eventMsgDescript == 'Missed Shot':
            
            currTime = PCtime
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Check who rebounds in next iteration of loop
            lastDescript = eventMsgDescript

            if player in team0Lineup:
                #lastTeam = team0Lineup
                lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
            else:
                #lastTeam = team1Lineup
                lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
            if verbose:
                print(player, 'misses shot')

        #Check if Foul (which may or may not lead to free throws), but all free throws come from fouls
        #Important to check if a generic foul and not just shooting fouls, otherwise the free throw lineup will be 'behind'
        #If only looked at shooting fouls - consider situation of substitutions during the game and then a technical foul. 
        #The ft lineup would only be from the previous fts, not the current lineup. 
        elif (eventMsgDescript == 'Foul'):
            #Make sure to copy lineup not assign, otherwise when lineup changes ftTeamLineup would change
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            
            if verbose:
                print('Foul on team', playerTeam)

        elif eventMsgDescript == 'Free Throw':
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            option1 = getattr(event, 'Option1')
            if option1 == 1: #Made Free Throw
                points = 1
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #ActionTypes corresponding to final free throw, so add possession. 
                    subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
                    subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
                    
                    #subbedPlayers already got possession added so only add to remaining players on court
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    remainingPlayers0 = list(set(ftTeam0Lineup) - set(subbedPlayers0))
                    remainingPlayers1 = list(set(ftTeam1Lineup) - set(subbedPlayers1))
                    
                    if playerTeam == gameTeams[0]:
                        addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                        currPoss = gameTeams[1]
                    elif playerTeam == gameTeams[1]:
                        addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                        currPoss = gameTeams[0]
                    else:
                        print('Error: Free throw player not on either team')
                        return

                    if verbose:
                        print('Made final free throw by', player)
                        
                else:
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    
                    if verbose:
                        print('Made free throw by', player)
                        
            else: #Missed FT
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #Missed last free throw for a shooting foul (not technical/flagrant), check who rebounds in next iteration. 
                    lastDescript = 'Missed Last Free Throw'
                    #Offensive rebounds with substitution going to be weird in terms of possessions

                    #Check current lineup, not free throw lineup since current lineup will be the one to rebound
                    if player in team0Lineup:
                        lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
                    else:
                        lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
                        
                    if verbose:
                        print('Missed last free throw by', player)
                        print('ftteam1', ftTeam1Lineup)
                else:
                    if verbose:
                        print('Missed free throw by', player)

            #NBA seems to count technical free throws a possession. Delete block below if undesired.
            
            #Check whether was last technical free throw (not flagrant which team keeps possession)
            if (actionType == 16) or (actionType == 22):
                
                
                #Use the possessionFix method already implemented and just count this free throw as the 'unknownRebound'
            
                #So if team on offense commits tech that counts as off + def possession
                #then def + off possession for tech ft, and then following possession will be off + def
                if False:
                    unknownRebound = True
                    unknownReboundInfo['team0'] = team0Lineup.copy()
                    unknownReboundInfo['team1'] = team1Lineup.copy()
                    unknownReboundInfo['event'] = 'Technical Free Throw'
                    unknownReboundInfo['remainingPlayers0'] = ftTeam0Lineup.copy()
                    unknownReboundInfo['remainingPlayers1'] = ftTeam1Lineup.copy()
                    unknownReboundInfo['lastTeam'] = playerTeam
                    
                #Check if tech committed by team with possession. If so add offensive and defensive possession to both teams 
                #(off from having ball, def from tech shot)
                
                #Also it seems like only if time passed in a given possession does the tech count as a change in possession.
                #Remove currTime != PCtime so all techs treated equally
                if currPoss != playerTeam and currTime != PCtime:
                    addPossession(ftTeam1Lineup, ftTeam0Lineup, gameDict)
                    addPossession(ftTeam0Lineup, ftTeam1Lineup, gameDict)
    return gameDict

# %%
    dataRows = []
    i = 0
    for game in GameIDs:
        print(i)
        gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
        gameLineup = GameLineup[GameLineup['Game_id'] == game]
        gameDict = gameRatingsSub(gamePlayByPlay, gameLineup, eventCodes)
        playerList = list(gameLineup['Person_id'].unique())

        for player in gameDict.keys():
            dataDict = {'Game_ID': game}
            #Check at least one possession played
            offPossessions = gameDict[player][2]
            defPossessions = gameDict[player][3]

            totalPossessions = offPossessions + defPossessions

            if totalPossessions != 0: 
                #Allowing for possibility of only playing one possession on offense or defense and thus undefined rating
                pointsFor = gameDict[player][0]
                pointsAgainst = gameDict[player][1]
                if offPossessions == 0:
                    offRating = np.nan
                else:
                    offRating = 100*(pointsFor/offPossessions)
                if defPossessions == 0:
                    defRating = np.nan
                else:
                    defRating = 100*(pointsAgainst/defPossessions)
                playerTeam = getPlayerTeam(player, '', playerList, gameLineup)
                dataDict.update({'Player_ID': player, 'Team_ID': playerTeam, 'OffRtg': np.round(offRating,1), 
                                 'DefRtg': np.round(defRating,1), 'OffPossessions': offPossessions, 
                                 'DefPossessions': defPossessions, 'PointsFor': pointsFor, 'PointsAgainst': pointsAgainst})

                dataRows.append(dataDict)
        i+=1
    df = pd.DataFrame(dataRows)
    df= df[['Game_ID', 'Player_ID', 'Team_ID','OffRtg', 'DefRtg', 'OffPossessions', 'DefPossessions', 'PointsFor', 'PointsAgainst']]
    df.to_excel("output3_techs_subbedIn.xlsx", index=False)

# %%
## bug in playbyplay that cant be fixed? Look at gameIDs[3] events 21-23 show missed free throw, rebound, then made free throw?
#Assuming its even ft, ft, rebound it says it was made so how can there be a rebound?
game = GameIDs[41]
gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
gameLineup = GameLineup[GameLineup['Game_id'] == game]
gameDict = gameRatingsSubCleaned(gamePlayByPlay[:], gameLineup, eventCodes, verbose=True)
#gameDict2 = gameRatingsComplete(gamePlayByPlay[:], gameLineup, eventCodes)
# Out:
# Counter 0
# Event Num 2
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 1  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '95920e4bf5b6c15ba8dffbf959b38ba5', '722a380c9b59ef42226e8d392824dcb9', 'ef8b068ab7ac9d387b256404acd24cd5']
# 1  lineup 1: ['3626b893fc73a5cbd67d1ea48a5c7039', 'bfef77a3e57907855444410d490e7bfd', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Counter 1
# Event Num 4
# []
# Jump Ball by bfef77a3e57907855444410d490e7bfd
# Counter 2
# Event Num 7
# []
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 3
# Event Num 9
# []
# Turnover by 722a380c9b59ef42226e8d392824dcb9
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 4
# Event Num 10
# []
# Violation by 22fab2ecad98e9fed46efe57558bc41f
# Counter 5
# Event Num 11
# []
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 6
# Event Num 13
# []
# Foul by 31598ba01a3fff03ed0a87d7dea11dfe
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 7
# Event Num 15
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 8
# Event Num 16
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 9
# Event Num 17
# []
# Turnover by 1a6703883f8f47bb4daf09c03be3bda2
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 10
# Event Num 18
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 11
# Event Num 19
# []
# Violation by bfef77a3e57907855444410d490e7bfd
# Counter 12
# Event Num 20
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 13
# Event Num 21
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 14
# Event Num 23
# []
# Rebound by 722a380c9b59ef42226e8d392824dcb9
# Offensive Rebound
# Counter 15
# Event Num 24
# []
# Made Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 scores 2 points
# Counter 16
# Event Num 25
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 17
# Event Num 26
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 18
# Event Num 27
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 19
# Event Num 28
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 20
# Event Num 29
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 21
# Event Num 31
# []
# Made Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 scores 2 points
# Counter 22
# Event Num 33
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 23
# Event Num 34
# []
# Jump Ball by 1a6703883f8f47bb4daf09c03be3bda2
# Counter 24
# Event Num 37
# []
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 25
# Event Num 39
# []
# Made Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 scores 2 points
# Counter 26
# Event Num 41
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 27
# Event Num 43
# []
# Missed Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 misses shot
# Counter 28
# Event Num 44
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 29
# Event Num 45
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 30
# Event Num 46
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 31
# Event Num 47
# []
# Made Shot by 722a380c9b59ef42226e8d392824dcb9
# Missed shot possession fix
# Add off possession to  ['3626b893fc73a5cbd67d1ea48a5c7039', 'bfef77a3e57907855444410d490e7bfd', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Add def possession to  ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '95920e4bf5b6c15ba8dffbf959b38ba5', '722a380c9b59ef42226e8d392824dcb9', 'ef8b068ab7ac9d387b256404acd24cd5']
# 722a380c9b59ef42226e8d392824dcb9 scores 3 points
# Counter 32
# Event Num 49
# []
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 33
# Event Num 51
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 34
# Event Num 52
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 35
# Event Num 54
# []
# Foul by bfef77a3e57907855444410d490e7bfd
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 36
# Event Num 56
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 37
# Event Num 57
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 38
# Event Num 58
# []
# Made Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a scores 2 points
# Counter 39
# Event Num 59
# []
# Foul by 1a6703883f8f47bb4daf09c03be3bda2
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 40
# Event Num 61
# []
# Free Throw by 7f438c18058290903c46dfe9d71bd68a
# Missed last free throw by 7f438c18058290903c46dfe9d71bd68a
# ftteam1 ['3626b893fc73a5cbd67d1ea48a5c7039', 'bfef77a3e57907855444410d490e7bfd', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Counter 41
# Event Num 62
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Offensive Rebound
# Counter 42
# Event Num 63
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 43
# Event Num 64
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Offensive Rebound
# Counter 44
# Event Num 65
# []
# Missed Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 misses shot
# Counter 45
# Event Num 66
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 46
# Event Num 67
# []
# Turnover by 3626b893fc73a5cbd67d1ea48a5c7039
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 47
# Event Num 69
# []
# Foul by 3626b893fc73a5cbd67d1ea48a5c7039
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 48
# Event Num 71
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 49
# Event Num 72
# []
# Rebound by bfef77a3e57907855444410d490e7bfd
# Defensive Rebound
# Counter 50
# Event Num 73
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 51
# Event Num 75
# []
# Made Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a scores 3 points
# Counter 52
# Event Num 77
# []
# Turnover by 31598ba01a3fff03ed0a87d7dea11dfe
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 53
# Event Num 79
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 54
# Event Num 80
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 55
# Event Num 81
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 56
# Event Num 82
# []
# Rebound by 7f438c18058290903c46dfe9d71bd68a
# Defensive Rebound
# Counter 57
# Event Num 83
# []
# Turnover by 95920e4bf5b6c15ba8dffbf959b38ba5
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 58
# Event Num 84
# []
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 59
# Event Num 86
# []
# Substitution by bfef77a3e57907855444410d490e7bfd
# 3d75035d20b173a867d4bf32c8a58f0b  replacing  bfef77a3e57907855444410d490e7bfd
# Counter 60
# Event Num 87
# []
# Substitution by ef8b068ab7ac9d387b256404acd24cd5
# 1dabb767e07d0aa702ee58d41c15eab1  replacing  ef8b068ab7ac9d387b256404acd24cd5
# Counter 61
# Event Num 90
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 62
# Event Num 91
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 63
# Event Num 92
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 64
# Event Num 93
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Offensive Rebound
# Counter 65
# Event Num 94
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 66
# Event Num 96
# []
# Rebound by 3d75035d20b173a867d4bf32c8a58f0b
# Defensive Rebound
# Counter 67
# Event Num 97
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 68
# Event Num 99
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 69
# Event Num 101
# []
# Made Shot by 3d75035d20b173a867d4bf32c8a58f0b
# 3d75035d20b173a867d4bf32c8a58f0b scores 2 points
# Counter 70
# Event Num 103
# []
# Foul by 3626b893fc73a5cbd67d1ea48a5c7039
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 71
# Event Num 105
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 72
# Event Num 106
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 73
# Event Num 107
# []
# Substitution by 3626b893fc73a5cbd67d1ea48a5c7039
# 52c6125836c465f4ac5232121dacb49d  replacing  3626b893fc73a5cbd67d1ea48a5c7039
# Counter 74
# Event Num 109
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 75
# Event Num 110
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 76
# Event Num 111
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 77
# Event Num 112
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 78
# Event Num 113
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 79
# Event Num 114
# []
# Foul by 3d75035d20b173a867d4bf32c8a58f0b
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 80
# Event Num 116
# []
# Free Throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# Made free throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 81
# Event Num 117
# []
# Substitution by a1591595c04d12e88e3cb427fb667618
# 6f6a807d57aae8f651222523dc82dc35  replacing  a1591595c04d12e88e3cb427fb667618
# Counter 82
# Event Num 119
# []
# Free Throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Made final free throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 83
# Event Num 120
# []
# Missed Shot by 3d75035d20b173a867d4bf32c8a58f0b
# 3d75035d20b173a867d4bf32c8a58f0b misses shot
# Counter 84
# Event Num 121
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 85
# Event Num 122
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 86
# Event Num 124
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 87
# Event Num 125
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 88
# Event Num 126
# []
# Rebound by 6f6a807d57aae8f651222523dc82dc35
# Defensive Rebound
# Counter 89
# Event Num 127
# []
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 90
# Event Num 129
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 91
# Event Num 130
# []
# Substitution by 31598ba01a3fff03ed0a87d7dea11dfe
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  31598ba01a3fff03ed0a87d7dea11dfe
# Counter 92
# Event Num 131
# []
# Substitution by 95920e4bf5b6c15ba8dffbf959b38ba5
# 32c044aa84d75ccd78c3c9f2aeb33bd9  replacing  95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 93
# Event Num 132
# []
# Substitution by 7f438c18058290903c46dfe9d71bd68a
# 942a84f05f4ab956125f68ec0963481f  replacing  7f438c18058290903c46dfe9d71bd68a
# Counter 94
# Event Num 136
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 95
# Event Num 137
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 96
# Event Num 138
# []
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# e49b2cc3f9aacd500b11a35b1c57112d  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 97
# Event Num 140
# []
# Jump Ball by 1a6703883f8f47bb4daf09c03be3bda2
# Counter 98
# Event Num 143
# []
# Turnover by 1a6703883f8f47bb4daf09c03be3bda2
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 99
# Event Num 145
# []
# Foul by 3d75035d20b173a867d4bf32c8a58f0b
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 100
# Event Num 147
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 101
# Event Num 148
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 102
# Event Num 149
# []
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 103
# Event Num 151
# []
# Made Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 scores 2 points
# Counter 104
# Event Num 152
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 105
# Event Num 154
# []
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 106
# Event Num 155
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 107
# Event Num 156
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Offensive Rebound
# Counter 108
# Event Num 157
# []
# Foul by e49b2cc3f9aacd500b11a35b1c57112d
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 109
# Event Num 159
# []
# Substitution by 3d75035d20b173a867d4bf32c8a58f0b
# 3626b893fc73a5cbd67d1ea48a5c7039  replacing  3d75035d20b173a867d4bf32c8a58f0b
# Counter 110
# Event Num 160
# []
# Substitution by 6f6a807d57aae8f651222523dc82dc35
# 31598ba01a3fff03ed0a87d7dea11dfe  replacing  6f6a807d57aae8f651222523dc82dc35
# Counter 111
# Event Num 161
# []
# Substitution by 52c6125836c465f4ac5232121dacb49d
# a1591595c04d12e88e3cb427fb667618  replacing  52c6125836c465f4ac5232121dacb49d
# Counter 112
# Event Num 162
# []
# Substitution by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 7f438c18058290903c46dfe9d71bd68a  replacing  32c044aa84d75ccd78c3c9f2aeb33bd9
# Counter 113
# Event Num 163
# []
# Substitution by e49b2cc3f9aacd500b11a35b1c57112d
# c950aaad2e56c87e9ac7281016d37cb6  replacing  e49b2cc3f9aacd500b11a35b1c57112d
# Counter 114
# Event Num 169
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 115
# Event Num 170
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 116
# Event Num 171
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 1 ended
# Counter 117
# Event Num 180
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 2  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '32c044aa84d75ccd78c3c9f2aeb33bd9', '1dabb767e07d0aa702ee58d41c15eab1', 'e49b2cc3f9aacd500b11a35b1c57112d', '942a84f05f4ab956125f68ec0963481f']
# 2  lineup 1: ['255fe2a8be0ed5c06dd99969ab4fea55', '52c6125836c465f4ac5232121dacb49d', '3626b893fc73a5cbd67d1ea48a5c7039', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Counter 118
# Event Num 181
# []
# Foul by 31598ba01a3fff03ed0a87d7dea11dfe
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 119
# Event Num 183
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 120
# Event Num 184
# []
# Missed Shot by 942a84f05f4ab956125f68ec0963481f
# 942a84f05f4ab956125f68ec0963481f misses shot
# Counter 121
# Event Num 185
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 122
# Event Num 186
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 123
# Event Num 188
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 124
# Event Num 189
# []
# Rebound by 52c6125836c465f4ac5232121dacb49d
# Defensive Rebound
# Counter 125
# Event Num 190
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 126
# Event Num 192
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 127
# Event Num 193
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 128
# Event Num 194
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 129
# Event Num 195
# []
# Made Shot by e49b2cc3f9aacd500b11a35b1c57112d
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# e49b2cc3f9aacd500b11a35b1c57112d scores 2 points
# Counter 130
# Event Num 197
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 131
# Event Num 198
# []
# Missed Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 misses shot
# Counter 132
# Event Num 199
# []
# Rebound by 52c6125836c465f4ac5232121dacb49d
# Offensive Rebound
# Counter 133
# Event Num 200
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 3 points
# Counter 134
# Event Num 202
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 135
# Event Num 203
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Offensive Rebound
# Counter 136
# Event Num 204
# []
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 137
# Event Num 205
# []
# Rebound by 52c6125836c465f4ac5232121dacb49d
# Defensive Rebound
# Counter 138
# Event Num 206
# []
# Turnover by 52c6125836c465f4ac5232121dacb49d
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 139
# Event Num 208
# []
# Foul by 255fe2a8be0ed5c06dd99969ab4fea55
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 140
# Event Num 210
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 141
# Event Num 212
# []
# Rebound by 31598ba01a3fff03ed0a87d7dea11dfe
# Defensive Rebound
# Counter 142
# Event Num 213
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 143
# Event Num 215
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 144
# Event Num 219
# []
# Substitution by e49b2cc3f9aacd500b11a35b1c57112d
# 722a380c9b59ef42226e8d392824dcb9  replacing  e49b2cc3f9aacd500b11a35b1c57112d
# Counter 145
# Event Num 218
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 146
# Event Num 220
# []
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 147
# Event Num 223
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Offensive Rebound
# Counter 148
# Event Num 222
# []
# Turnover by 22fab2ecad98e9fed46efe57558bc41f
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 149
# Event Num 224
# []
# Turnover by 255fe2a8be0ed5c06dd99969ab4fea55
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 150
# Event Num 226
# []
# Made Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 scores 3 points
# Counter 151
# Event Num 228
# []
# Foul by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 152
# Event Num 230
# []
# Instant Replay by a88e6ed67bb789f7782793083a44a693
# Counter 153
# Event Num 231
# []
# Free Throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Missed free throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Counter 154
# Event Num 232
# []
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 155
# Event Num 233
# []
# Substitution by 1dabb767e07d0aa702ee58d41c15eab1
# 95920e4bf5b6c15ba8dffbf959b38ba5  replacing  1dabb767e07d0aa702ee58d41c15eab1
# Counter 156
# Event Num 235
# []
# Free Throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Made final free throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Counter 157
# Event Num 236
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 158
# Event Num 238
# []
# Foul by 255fe2a8be0ed5c06dd99969ab4fea55
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 159
# Event Num 240
# []
# Substitution by 31598ba01a3fff03ed0a87d7dea11dfe
# 1a6703883f8f47bb4daf09c03be3bda2  replacing  31598ba01a3fff03ed0a87d7dea11dfe
# Counter 160
# Event Num 242
# []
# Free Throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Made final free throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 161
# Event Num 243
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 162
# Event Num 244
# []
# Rebound by 255fe2a8be0ed5c06dd99969ab4fea55
# Offensive Rebound
# Counter 163
# Event Num 245
# []
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 164
# Event Num 247
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 165
# Event Num 249
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Offensive Rebound
# Counter 166
# Event Num 250
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 167
# Event Num 251
# []
# Rebound by 255fe2a8be0ed5c06dd99969ab4fea55
# Defensive Rebound
# Counter 168
# Event Num 252
# []
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 169
# Event Num 254
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 170
# Event Num 255
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 171
# Event Num 256
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 172
# Event Num 257
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 173
# Event Num 258
# []
# Substitution by 255fe2a8be0ed5c06dd99969ab4fea55
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  255fe2a8be0ed5c06dd99969ab4fea55
# Counter 174
# Event Num 259
# []
# Substitution by 52c6125836c465f4ac5232121dacb49d
# 31598ba01a3fff03ed0a87d7dea11dfe  replacing  52c6125836c465f4ac5232121dacb49d
# Counter 175
# Event Num 260
# []
# Substitution by 942a84f05f4ab956125f68ec0963481f
# 7f438c18058290903c46dfe9d71bd68a  replacing  942a84f05f4ab956125f68ec0963481f
# Counter 176
# Event Num 261
# []
# Substitution by 32c044aa84d75ccd78c3c9f2aeb33bd9
# ef8b068ab7ac9d387b256404acd24cd5  replacing  32c044aa84d75ccd78c3c9f2aeb33bd9
# Counter 177
# Event Num 266
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 178
# Event Num 267
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 179
# Event Num 270
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 180
# Event Num 271
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 181
# Event Num 272
# []
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 182
# Event Num 274
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 183
# Event Num 275
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Defensive Rebound
# Counter 184
# Event Num 276
# []
# Missed Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 misses shot
# Counter 185
# Event Num 277
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Offensive Rebound
# Counter 186
# Event Num 278
# []
# Foul by 31598ba01a3fff03ed0a87d7dea11dfe
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 187
# Event Num 280
# []
# Free Throw by ef8b068ab7ac9d387b256404acd24cd5
# Missed free throw by ef8b068ab7ac9d387b256404acd24cd5
# Counter 188
# Event Num 281
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 189
# Event Num 282
# []
# Substitution by 0b978fcfa7f2ec839c563a755e345ff8
# bfef77a3e57907855444410d490e7bfd  replacing  0b978fcfa7f2ec839c563a755e345ff8
# Counter 190
# Event Num 284
# []
# Free Throw by ef8b068ab7ac9d387b256404acd24cd5
# Made final free throw by ef8b068ab7ac9d387b256404acd24cd5
# Counter 191
# Event Num 285
# []
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 192
# Event Num 287
# []
# Foul by bfef77a3e57907855444410d490e7bfd
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 193
# Event Num 289
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 194
# Event Num 290
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 195
# Event Num 291
# []
# Substitution by 31598ba01a3fff03ed0a87d7dea11dfe
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  31598ba01a3fff03ed0a87d7dea11dfe
# Counter 196
# Event Num 293
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 197
# Event Num 294
# []
# Missed Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 misses shot
# Counter 198
# Event Num 295
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 199
# Event Num 296
# []
# Turnover by 7f438c18058290903c46dfe9d71bd68a
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 200
# Event Num 297
# []
# Turnover by 1a6703883f8f47bb4daf09c03be3bda2
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 201
# Event Num 299
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 202
# Event Num 300
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 203
# Event Num 301
# []
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 204
# Event Num 303
# []
# Foul by 0b978fcfa7f2ec839c563a755e345ff8
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 205
# Event Num 305
# []
# Free Throw by 722a380c9b59ef42226e8d392824dcb9
# Made free throw by 722a380c9b59ef42226e8d392824dcb9
# Counter 206
# Event Num 308
# []
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 207
# Event Num 309
# []
# Free Throw by 722a380c9b59ef42226e8d392824dcb9
# Made final free throw by 722a380c9b59ef42226e8d392824dcb9
# Counter 208
# Event Num 310
# []
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 209
# Event Num 311
# []
# Rebound by bfef77a3e57907855444410d490e7bfd
# Offensive Rebound
# Counter 210
# Event Num 312
# []
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 211
# Event Num 313
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 212
# Event Num 314
# []
# Made Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 scores 2 points
# Counter 213
# Event Num 316
# []
# Turnover by 3626b893fc73a5cbd67d1ea48a5c7039
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 214
# Event Num 318
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 215
# Event Num 320
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 216
# Event Num 321
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 217
# Event Num 322
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Offensive Rebound
# Counter 218
# Event Num 323
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 219
# Event Num 325
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 220
# Event Num 326
# []
# Foul by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 221
# Event Num 328
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 222
# Event Num 329
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made final free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 223
# Event Num 330
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 224
# Event Num 331
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 225
# Event Num 332
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 226
# Event Num 333
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 227
# Event Num 334
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 228
# Event Num 335
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 229
# Event Num 336
# []
# Substitution by 3626b893fc73a5cbd67d1ea48a5c7039
# 6f6a807d57aae8f651222523dc82dc35  replacing  3626b893fc73a5cbd67d1ea48a5c7039
# Counter 230
# Event Num 338
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 231
# Event Num 339
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 232
# Event Num 340
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 233
# Event Num 341
# []
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 234
# Event Num 343
# []
# Free Throw by 6f6a807d57aae8f651222523dc82dc35
# Missed free throw by 6f6a807d57aae8f651222523dc82dc35
# Counter 235
# Event Num 344
# []
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 236
# Event Num 345
# []
# Substitution by bfef77a3e57907855444410d490e7bfd
# 3d75035d20b173a867d4bf32c8a58f0b  replacing  bfef77a3e57907855444410d490e7bfd
# Counter 237
# Event Num 347
# []
# Free Throw by 6f6a807d57aae8f651222523dc82dc35
# Missed last free throw by 6f6a807d57aae8f651222523dc82dc35
# ftteam1 ['a1591595c04d12e88e3cb427fb667618', '1a6703883f8f47bb4daf09c03be3bda2', 'bfef77a3e57907855444410d490e7bfd', '0b978fcfa7f2ec839c563a755e345ff8', '6f6a807d57aae8f651222523dc82dc35']
# Counter 238
# Event Num 348
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Defensive Rebound
# Counter 239
# Event Num 349
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 2 ended
# Counter 240
# Event Num 356
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 3  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '95920e4bf5b6c15ba8dffbf959b38ba5', '722a380c9b59ef42226e8d392824dcb9', 'ef8b068ab7ac9d387b256404acd24cd5']
# 3  lineup 1: ['3626b893fc73a5cbd67d1ea48a5c7039', 'bfef77a3e57907855444410d490e7bfd', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Counter 241
# Event Num 357
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 242
# Event Num 677
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# Offensive Rebound
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 243
# Event Num 358
# [358]
# Rebound by 722a380c9b59ef42226e8d392824dcb9
# Counter 244
# Event Num 678
# [358]
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Offensive Rebound
# Counter 245
# Event Num 359
# [358]
# Made Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 scores 2 points
# Counter 246
# Event Num 360
# [358]
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 247
# Event Num 361
# [358]
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 248
# Event Num 362
# [358]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 249
# Event Num 363
# [358]
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 250
# Event Num 364
# [358]
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 3 points
# Counter 251
# Event Num 366
# [358]
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 252
# Event Num 368
# [358]
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 253
# Event Num 369
# [358]
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made final free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 254
# Event Num 370
# [358]
# Made Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 scores 2 points
# Counter 255
# Event Num 372
# [358]
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 256
# Event Num 374
# [358]
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 3 points
# Counter 257
# Event Num 376
# [358]
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 3 points
# Counter 258
# Event Num 377
# [358]
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 259
# Event Num 378
# [358]
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 260
# Event Num 379
# [358]
# Foul by ef8b068ab7ac9d387b256404acd24cd5
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 261
# Event Num 381
# [358]
# Free Throw by a1591595c04d12e88e3cb427fb667618
# Missed free throw by a1591595c04d12e88e3cb427fb667618
# Counter 262
# Event Num 382
# [358]
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 263
# Event Num 383
# [358]
# Free Throw by a1591595c04d12e88e3cb427fb667618
# Made final free throw by a1591595c04d12e88e3cb427fb667618
# Counter 264
# Event Num 384
# [358]
# Foul by bfef77a3e57907855444410d490e7bfd
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 265
# Event Num 386
# [358]
# Made Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 scores 3 points
# Counter 266
# Event Num 388
# [358]
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 267
# Event Num 390
# [358]
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 268
# Event Num 392
# [358]
# Free Throw by bfef77a3e57907855444410d490e7bfd
# Missed last free throw by bfef77a3e57907855444410d490e7bfd
# ftteam1 ['3626b893fc73a5cbd67d1ea48a5c7039', 'bfef77a3e57907855444410d490e7bfd', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Counter 269
# Event Num 393
# [358]
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 270
# Event Num 394
# [358]
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 271
# Event Num 395
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 272
# Event Num 396
# [358]
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 273
# Event Num 397
# [358]
# Foul by bfef77a3e57907855444410d490e7bfd
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 274
# Event Num 399
# [358]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 275
# Event Num 400
# [358]
# Rebound by 31598ba01a3fff03ed0a87d7dea11dfe
# Defensive Rebound
# Counter 276
# Event Num 401
# [358]
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 277
# Event Num 402
# [358]
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 3 points
# Counter 278
# Event Num 403
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 279
# Event Num 404
# [358]
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 280
# Event Num 405
# [358]
# Made Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 scores 2 points
# Counter 281
# Event Num 407
# [358]
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 282
# Event Num 408
# [358]
# Instant Replay by 9bd5304205350a87b3c32e2cc5b6a613
# Counter 283
# Event Num 410
# [358]
# Substitution by bfef77a3e57907855444410d490e7bfd
# 3d75035d20b173a867d4bf32c8a58f0b  replacing  bfef77a3e57907855444410d490e7bfd
# Counter 284
# Event Num 413
# [358]
# Made Shot by 3d75035d20b173a867d4bf32c8a58f0b
# 3d75035d20b173a867d4bf32c8a58f0b scores 2 points
# Counter 285
# Event Num 415
# [358]
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 286
# Event Num 417
# [358]
# Free Throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Made free throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 287
# Event Num 418
# [358]
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# 1dabb767e07d0aa702ee58d41c15eab1  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 288
# Event Num 420
# [358]
# Free Throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Made final free throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 289
# Event Num 421
# [358]
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 290
# Event Num 422
# [358]
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 3 points
# Counter 291
# Event Num 424
# [358]
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 292
# Event Num 425
# [358]
# Made Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 scores 2 points
# Counter 293
# Event Num 427
# [358]
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 294
# Event Num 428
# [358]
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 295
# Event Num 429
# [358]
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 296
# Event Num 430
# [358]
# Foul by ef8b068ab7ac9d387b256404acd24cd5
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 297
# Event Num 432
# [358]
# Free Throw by 3d75035d20b173a867d4bf32c8a58f0b
# Missed free throw by 3d75035d20b173a867d4bf32c8a58f0b
# Counter 298
# Event Num 433
# [358]
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 299
# Event Num 434
# [358]
# Free Throw by 3d75035d20b173a867d4bf32c8a58f0b
# Made final free throw by 3d75035d20b173a867d4bf32c8a58f0b
# Counter 300
# Event Num 435
# [358]
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 301
# Event Num 436
# [358]
# Foul by 6cdd2054a7c46a49f7ffa0a3b5e1d517
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 302
# Event Num 437
# [358]
# Free Throw by 1a6703883f8f47bb4daf09c03be3bda2
# Made free throw by 1a6703883f8f47bb4daf09c03be3bda2
# Counter 303
# Event Num 438
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 304
# Event Num 440
# [358]
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 305
# Event Num 441
# [358]
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 306
# Event Num 442
# [358]
# Rebound by 1dabb767e07d0aa702ee58d41c15eab1
# Defensive Rebound
# Counter 307
# Event Num 443
# [358]
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 308
# Event Num 445
# [358]
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 309
# Event Num 446
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 310
# Event Num 447
# [358]
# Rebound by 1dabb767e07d0aa702ee58d41c15eab1
# Defensive Rebound
# Counter 311
# Event Num 448
# [358]
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 312
# Event Num 449
# [358]
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 313
# Event Num 451
# [358]
# Foul by 1a6703883f8f47bb4daf09c03be3bda2
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 314
# Event Num 453
# [358]
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 315
# Event Num 454
# [358]
# Substitution by a1591595c04d12e88e3cb427fb667618
# 255fe2a8be0ed5c06dd99969ab4fea55  replacing  a1591595c04d12e88e3cb427fb667618
# Counter 316
# Event Num 455
# [358]
# Substitution by 1a6703883f8f47bb4daf09c03be3bda2
# 52c6125836c465f4ac5232121dacb49d  replacing  1a6703883f8f47bb4daf09c03be3bda2
# Counter 317
# Event Num 458
# [358]
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 318
# Event Num 459
# [358]
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 319
# Event Num 460
# [358]
# Substitution by ef8b068ab7ac9d387b256404acd24cd5
# 942a84f05f4ab956125f68ec0963481f  replacing  ef8b068ab7ac9d387b256404acd24cd5
# Counter 320
# Event Num 462
# [358]
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed shot possession fix
# Add off possession to subbed players ['ef8b068ab7ac9d387b256404acd24cd5']
# Add def possession to subbed players []
# Was offensive rebound, don't do anything for on court players
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 321
# Event Num 464
# [358]
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 322
# Event Num 465
# [358]
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 323
# Event Num 466
# [358]
# Rebound by 255fe2a8be0ed5c06dd99969ab4fea55
# Defensive Rebound
# Counter 324
# Event Num 467
# [358]
# Turnover by 3626b893fc73a5cbd67d1ea48a5c7039
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 325
# Event Num 469
# [358]
# Foul by 3626b893fc73a5cbd67d1ea48a5c7039
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 326
# Event Num 471
# [358]
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Made free throw by 942a84f05f4ab956125f68ec0963481f
# Counter 327
# Event Num 472
# [358]
# Substitution by 95920e4bf5b6c15ba8dffbf959b38ba5
# 32c044aa84d75ccd78c3c9f2aeb33bd9  replacing  95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 328
# Event Num 474
# [358]
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Made final free throw by 942a84f05f4ab956125f68ec0963481f
# Counter 329
# Event Num 475
# [358]
# Turnover by 31598ba01a3fff03ed0a87d7dea11dfe
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 330
# Event Num 476
# [358]
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 331
# Event Num 477
# [358]
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Offensive Rebound
# Counter 332
# Event Num 478
# [358]
# Foul by 52c6125836c465f4ac5232121dacb49d
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 333
# Event Num 480
# [358]
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Missed free throw by 942a84f05f4ab956125f68ec0963481f
# Counter 334
# Event Num 481
# [358]
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 335
# Event Num 482
# [358]
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Missed last free throw by 942a84f05f4ab956125f68ec0963481f
# ftteam1 ['3626b893fc73a5cbd67d1ea48a5c7039', '31598ba01a3fff03ed0a87d7dea11dfe', '3d75035d20b173a867d4bf32c8a58f0b', '255fe2a8be0ed5c06dd99969ab4fea55', '52c6125836c465f4ac5232121dacb49d']
# Counter 336
# Event Num 483
# [358]
# Rebound by 52c6125836c465f4ac5232121dacb49d
# Defensive Rebound
# Counter 337
# Event Num 484
# [358]
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 338
# Event Num 485
# [358]
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 339
# Event Num 486
# [358]
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 340
# Event Num 487
# [358]
# Rebound by 52c6125836c465f4ac5232121dacb49d
# Defensive Rebound
# Counter 341
# Event Num 488
# [358]
# Made Shot by 255fe2a8be0ed5c06dd99969ab4fea55
# 255fe2a8be0ed5c06dd99969ab4fea55 scores 3 points
# Counter 342
# Event Num 490
# [358]
# Foul by 3d75035d20b173a867d4bf32c8a58f0b
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 343
# Event Num 492
# [358]
# Instant Replay by 05a272a33fbe9bfa320a01e1891572af
# Counter 344
# Event Num 493
# [358]
# Free Throw by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Made final free throw by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Counter 345
# Event Num 495
# [358]
# Substitution by 255fe2a8be0ed5c06dd99969ab4fea55
# a1591595c04d12e88e3cb427fb667618  replacing  255fe2a8be0ed5c06dd99969ab4fea55
# Counter 346
# Event Num 498
# [358]
# Turnover by 942a84f05f4ab956125f68ec0963481f
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 347
# Event Num 499
# [358]
# Substitution by 52c6125836c465f4ac5232121dacb49d
# 1a6703883f8f47bb4daf09c03be3bda2  replacing  52c6125836c465f4ac5232121dacb49d
# Counter 348
# Event Num 569
# [358]
# Substitution by 3d75035d20b173a867d4bf32c8a58f0b
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  3d75035d20b173a867d4bf32c8a58f0b
# Counter 349
# Event Num 503
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 350
# Event Num 504
# [358]
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 351
# Event Num 505
# [358]
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 3 ended
# Counter 352
# Event Num 512
# [358]
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 4  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '32c044aa84d75ccd78c3c9f2aeb33bd9', '1dabb767e07d0aa702ee58d41c15eab1', '722a380c9b59ef42226e8d392824dcb9', '942a84f05f4ab956125f68ec0963481f']
# 4  lineup 1: ['255fe2a8be0ed5c06dd99969ab4fea55', '52c6125836c465f4ac5232121dacb49d', '0b978fcfa7f2ec839c563a755e345ff8', '1a6703883f8f47bb4daf09c03be3bda2', 'a1591595c04d12e88e3cb427fb667618']
# Counter 353
# Event Num 513
# [358]
# Foul by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 354
# Event Num 515
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 355
# Event Num 516
# [358]
# Rebound by a1591595c04d12e88e3cb427fb667618
# Offensive Rebound
# Counter 356
# Event Num 517
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 357
# Event Num 519
# [358]
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 358
# Event Num 520
# [358]
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 359
# Event Num 521
# [358]
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 360
# Event Num 522
# [358]
# Missed Shot by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 32c044aa84d75ccd78c3c9f2aeb33bd9 misses shot
# Counter 361
# Event Num 523
# [358]
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Offensive Rebound
# Counter 362
# Event Num 524
# [358]
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 3 points
# Counter 363
# Event Num 526
# [358]
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 364
# Event Num 527
# [358]
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 365
# Event Num 528
# [358]
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 366
# Event Num 529
# [358]
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 367
# Event Num 531
# [358]
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 368
# Event Num 532
# [358]
# Substitution by 942a84f05f4ab956125f68ec0963481f
# 95920e4bf5b6c15ba8dffbf959b38ba5  replacing  942a84f05f4ab956125f68ec0963481f
# Counter 369
# Event Num 534
# [358]
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 370
# Event Num 536
# [358]
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 371
# Event Num 538
# [358]
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 372
# Event Num 540
# [358]
# Free Throw by 1dabb767e07d0aa702ee58d41c15eab1
# Made free throw by 1dabb767e07d0aa702ee58d41c15eab1
# Counter 373
# Event Num 541
# [358]
# Substitution by 255fe2a8be0ed5c06dd99969ab4fea55
# 3626b893fc73a5cbd67d1ea48a5c7039  replacing  255fe2a8be0ed5c06dd99969ab4fea55
# Counter 374
# Event Num 543
# [358]
# Free Throw by 1dabb767e07d0aa702ee58d41c15eab1
# Made final free throw by 1dabb767e07d0aa702ee58d41c15eab1
# Counter 375
# Event Num 544
# [358]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 376
# Event Num 545
# [358]
# Rebound by a1591595c04d12e88e3cb427fb667618
# Offensive Rebound
# Counter 377
# Event Num 546
# [358]
# Made Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 scores 2 points
# Counter 378
# Event Num 547
# [358]
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 379
# Event Num 548
# [358]
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 380
# Event Num 549
# [358]
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 381
# Event Num 551
# [358]
# Substitution by 0b978fcfa7f2ec839c563a755e345ff8
# 31598ba01a3fff03ed0a87d7dea11dfe  replacing  0b978fcfa7f2ec839c563a755e345ff8
# Counter 382
# Event Num 553
# [358]
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 383
# Event Num 554
# [358]
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed shot possession fix
# Add off possession to subbed players []
# Add def possession to subbed players ['0b978fcfa7f2ec839c563a755e345ff8']
# Was offensive rebound, don't do anything for on court players
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 384
# Event Num 555
# [358]
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 385
# Event Num 556
# [358]
# Substitution by 52c6125836c465f4ac5232121dacb49d
# 6f6a807d57aae8f651222523dc82dc35  replacing  52c6125836c465f4ac5232121dacb49d
# Counter 386
# Event Num 558
# [358]
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 387
# Event Num 559
# [358]
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 388
# Event Num 560
# [358]
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 389
# Event Num 561
# [358]
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 390
# Event Num 562
# [358]
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 391
# Event Num 564
# [358]
# Made Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 scores 2 points
# Counter 392
# Event Num 566
# [358]
# Foul by 1a6703883f8f47bb4daf09c03be3bda2
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 393
# Event Num 568
# [358]
# Turnover by 1a6703883f8f47bb4daf09c03be3bda2
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 394
# Event Num 590
# [358]
# Substitution by 1dabb767e07d0aa702ee58d41c15eab1
# 7f438c18058290903c46dfe9d71bd68a  replacing  1dabb767e07d0aa702ee58d41c15eab1
# Counter 395
# Event Num 571
# [358]
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 396
# Event Num 573
# [358]
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 397
# Event Num 574
# [358]
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 398
# Event Num 575
# [358]
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 399
# Event Num 577
# [358]
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 400
# Event Num 578
# [358]
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 401
# Event Num 579
# [358]
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 402
# Event Num 580
# [358]
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 403
# Event Num 582
# [358]
# Foul by 95920e4bf5b6c15ba8dffbf959b38ba5
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 404
# Event Num 584
# [358]
# Free Throw by 1a6703883f8f47bb4daf09c03be3bda2
# Made final free throw by 1a6703883f8f47bb4daf09c03be3bda2
# Counter 405
# Event Num 585
# [358]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 406
# Event Num 586
# [358]
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 407
# Event Num 587
# [358]
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 408
# Event Num 589
# [358]
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 409
# Event Num 592
# [358]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 410
# Event Num 593
# [358]
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 411
# Event Num 594
# [358]
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 412
# Event Num 595
# [358]
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 413
# Event Num 597
# [358]
# Turnover by 1a6703883f8f47bb4daf09c03be3bda2
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 414
# Event Num 599
# [358]
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 415
# Event Num 600
# [358]
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 416
# Event Num 601
# [358]
# Foul by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 417
# Event Num 603
# [358]
# Free Throw by 6f6a807d57aae8f651222523dc82dc35
# Missed free throw by 6f6a807d57aae8f651222523dc82dc35
# Counter 418
# Event Num 604
# [358]
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 419
# Event Num 605
# [358]
# Substitution by 95920e4bf5b6c15ba8dffbf959b38ba5
# 36fdadf436b164ee29174c8e1fde7271  replacing  95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 420
# Event Num 606
# [358]
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# e49b2cc3f9aacd500b11a35b1c57112d  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 421
# Event Num 607
# [358]
# Substitution by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# c950aaad2e56c87e9ac7281016d37cb6  replacing  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 422
# Event Num 608
# [358]
# Substitution by 7f438c18058290903c46dfe9d71bd68a
# 942a84f05f4ab956125f68ec0963481f  replacing  7f438c18058290903c46dfe9d71bd68a
# Counter 423
# Event Num 613
# [358]
# Free Throw by 6f6a807d57aae8f651222523dc82dc35
# Missed last free throw by 6f6a807d57aae8f651222523dc82dc35
# ftteam1 ['1a6703883f8f47bb4daf09c03be3bda2', 'a1591595c04d12e88e3cb427fb667618', '3626b893fc73a5cbd67d1ea48a5c7039', '31598ba01a3fff03ed0a87d7dea11dfe', '6f6a807d57aae8f651222523dc82dc35']
# Counter 424
# Event Num 614
# [358]
# Rebound by c950aaad2e56c87e9ac7281016d37cb6
# Defensive Rebound
# Counter 425
# Event Num 615
# [358]
# Missed Shot by 36fdadf436b164ee29174c8e1fde7271
# 36fdadf436b164ee29174c8e1fde7271 misses shot
# Counter 426
# Event Num 616
# [358]
# Rebound by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Offensive Rebound
# Counter 427
# Event Num 617
# [358]
# Missed Shot by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 32c044aa84d75ccd78c3c9f2aeb33bd9 misses shot
# Counter 428
# Event Num 619
# [358]
# Rebound by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Offensive Rebound
# Counter 429
# Event Num 620
# [358]
# Missed Shot by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 32c044aa84d75ccd78c3c9f2aeb33bd9 misses shot
# Counter 430
# Event Num 621
# [358]
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 431
# Event Num 622
# [358]
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 432
# Event Num 623
# [358]
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 433
# Event Num 625
# [358]
# Substitution by 31598ba01a3fff03ed0a87d7dea11dfe
# fbcda0bcb861e4726ca8871b8965ede4  replacing  31598ba01a3fff03ed0a87d7dea11dfe
# Counter 434
# Event Num 626
# [358]
# Substitution by a1591595c04d12e88e3cb427fb667618
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  a1591595c04d12e88e3cb427fb667618
# Counter 435
# Event Num 627
# [358]
# Substitution by 1a6703883f8f47bb4daf09c03be3bda2
# 821887f9a002be16b5f79729fae59e01  replacing  1a6703883f8f47bb4daf09c03be3bda2
# Counter 436
# Event Num 628
# [358]
# Substitution by 3626b893fc73a5cbd67d1ea48a5c7039
# 94e99d76e87ee926faab66d382b3a955  replacing  3626b893fc73a5cbd67d1ea48a5c7039
# Counter 437
# Event Num 629
# [358]
# Substitution by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 8c7a7249d80b1489594b3a2a87f3f19d  replacing  32c044aa84d75ccd78c3c9f2aeb33bd9
# Counter 438
# Event Num 635
# [358]
# Substitution by 942a84f05f4ab956125f68ec0963481f
# 619d3e44dc84b366bd685de3e94b3bec  replacing  942a84f05f4ab956125f68ec0963481f
# Counter 439
# Event Num 637
# [358]
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 440
# Event Num 638
# [358]
# Rebound by 94e99d76e87ee926faab66d382b3a955
# Defensive Rebound
# Counter 441
# Event Num 639
# [358]
# Foul by 619d3e44dc84b366bd685de3e94b3bec
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 442
# Event Num 641
# [358]
# Free Throw by 94e99d76e87ee926faab66d382b3a955
# Made free throw by 94e99d76e87ee926faab66d382b3a955
# Counter 443
# Event Num 642
# [358]
# Free Throw by 94e99d76e87ee926faab66d382b3a955
# Made final free throw by 94e99d76e87ee926faab66d382b3a955
# Counter 444
# Event Num 643
# [358]
# Missed Shot by 8c7a7249d80b1489594b3a2a87f3f19d
# 8c7a7249d80b1489594b3a2a87f3f19d misses shot
# Counter 445
# Event Num 645
# [358]
# Rebound by 8c7a7249d80b1489594b3a2a87f3f19d
# Offensive Rebound
# Counter 446
# Event Num 646
# [358]
# Made Shot by 8c7a7249d80b1489594b3a2a87f3f19d
# 8c7a7249d80b1489594b3a2a87f3f19d scores 2 points
# Counter 447
# Event Num 647
# [358]
# Made Shot by fbcda0bcb861e4726ca8871b8965ede4
# fbcda0bcb861e4726ca8871b8965ede4 scores 2 points
# Counter 448
# Event Num 648
# [358]
# Missed Shot by c950aaad2e56c87e9ac7281016d37cb6
# c950aaad2e56c87e9ac7281016d37cb6 misses shot
# Counter 449
# Event Num 649
# [358]
# Rebound by 0b978fcfa7f2ec839c563a755e345ff8
# Defensive Rebound
# Counter 450
# Event Num 650
# [358]
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 451
# Event Num 651
# [358]
# Rebound by 36fdadf436b164ee29174c8e1fde7271
# Defensive Rebound
# Counter 452
# Event Num 652
# [358]
# Made Shot by c950aaad2e56c87e9ac7281016d37cb6
# c950aaad2e56c87e9ac7281016d37cb6 scores 2 points
# Counter 453
# Event Num 654
# [358]
# Violation by 821887f9a002be16b5f79729fae59e01
# Counter 454
# Event Num 655
# [358]
# Missed Shot by 94e99d76e87ee926faab66d382b3a955
# 94e99d76e87ee926faab66d382b3a955 misses shot
# Counter 455
# Event Num 656
# [358]
# Rebound by 94e99d76e87ee926faab66d382b3a955
# Offensive Rebound
# Counter 456
# Event Num 657
# [358]
# Made Shot by 94e99d76e87ee926faab66d382b3a955
# 94e99d76e87ee926faab66d382b3a955 scores 2 points
# Counter 457
# Event Num 658
# [358]
# Turnover by e49b2cc3f9aacd500b11a35b1c57112d
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 458
# Event Num 659
# [358]
# Missed Shot by fbcda0bcb861e4726ca8871b8965ede4
# fbcda0bcb861e4726ca8871b8965ede4 misses shot
# Counter 459
# Event Num 660
# [358]
# Rebound by 8c7a7249d80b1489594b3a2a87f3f19d
# Defensive Rebound
# Counter 460
# Event Num 661
# [358]
# Made Shot by 619d3e44dc84b366bd685de3e94b3bec
# 619d3e44dc84b366bd685de3e94b3bec scores 2 points
# Counter 461
# Event Num 663
# [358]
# Foul by 619d3e44dc84b366bd685de3e94b3bec
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 462
# Event Num 665
# [358]
# Free Throw by 94e99d76e87ee926faab66d382b3a955
# Made free throw by 94e99d76e87ee926faab66d382b3a955
# Counter 463
# Event Num 667
# [358]
# Free Throw by 94e99d76e87ee926faab66d382b3a955
# Made final free throw by 94e99d76e87ee926faab66d382b3a955
# Counter 464
# Event Num 668
# [358]
# Made Shot by 8c7a7249d80b1489594b3a2a87f3f19d
# 8c7a7249d80b1489594b3a2a87f3f19d scores 2 points
# Counter 465
# Event Num 669
# [358]
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 466
# Event Num 670
# [358]
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 467
# Event Num 671
# [358]
# Missed Shot by fbcda0bcb861e4726ca8871b8965ede4
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# fbcda0bcb861e4726ca8871b8965ede4 misses shot
# Counter 468
# Event Num 672
# [358]
# Rebound by e49b2cc3f9aacd500b11a35b1c57112d
# Defensive Rebound
# Counter 469
# Event Num 673
# [358]
# Made Shot by 36fdadf436b164ee29174c8e1fde7271
# 36fdadf436b164ee29174c8e1fde7271 scores 2 points
# Counter 470
# Event Num 675
# [358]
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 4 ended
# Counter 471
# Event Num 0
# [358]
# Final Box Printed by 0370a0d090da0d0edc6319f120187e0e

# %%
compareGameDicts(gameDict, gameDict2)

# %%
gameDict

# %%
gameDict2

# %%
rdPBP = readablePlayByPlay(gamePlayByPlay, gameLineup, eventCodes)
# Out:
# Team0 8362dfecb7412f12a12713852d2ae566
# Team1 cd45058739ed0ac8229849c6249aad48

# %%
rdPBP[320:]
# Out:
#                                 Game_id  Event_Num     Event_Msg_Type  Period  \
# 19108  9892e70d668a7287f5460350b8a6afdf        462           Turnover       3
# 19109  9892e70d668a7287f5460350b8a6afdf        464          Made Shot       3
# 19110  9892e70d668a7287f5460350b8a6afdf        465        Missed Shot       3
# 19111  9892e70d668a7287f5460350b8a6afdf        466            Rebound       3
# 19112  9892e70d668a7287f5460350b8a6afdf        467           Turnover       3
# 19113  9892e70d668a7287f5460350b8a6afdf        469               Foul       3
# 19114  9892e70d668a7287f5460350b8a6afdf        471         Free Throw       3
# 19115  9892e70d668a7287f5460350b8a6afdf        472       Substitution       3
# 19116  9892e70d668a7287f5460350b8a6afdf        474         Free Throw       3
# 19117  9892e70d668a7287f5460350b8a6afdf        475           Turnover       3
# 19118  9892e70d668a7287f5460350b8a6afdf        476        Missed Shot       3
# 19119  9892e70d668a7287f5460350b8a6afdf        477            Rebound       3
# 19120  9892e70d668a7287f5460350b8a6afdf        478               Foul       3
# 19121  9892e70d668a7287f5460350b8a6afdf        480         Free Throw       3
# 19122  9892e70d668a7287f5460350b8a6afdf        481            Rebound       3
# 19123  9892e70d668a7287f5460350b8a6afdf        482         Free Throw       3
# 19124  9892e70d668a7287f5460350b8a6afdf        483            Rebound       3
# 19125  9892e70d668a7287f5460350b8a6afdf        484        Missed Shot       3
# 19126  9892e70d668a7287f5460350b8a6afdf        485            Rebound       3
# 19127  9892e70d668a7287f5460350b8a6afdf        486        Missed Shot       3
# 19128  9892e70d668a7287f5460350b8a6afdf        487            Rebound       3
# 19129  9892e70d668a7287f5460350b8a6afdf        488          Made Shot       3
# 19130  9892e70d668a7287f5460350b8a6afdf        490               Foul       3
# 19131  9892e70d668a7287f5460350b8a6afdf        492     Instant Replay       3
# 19132  9892e70d668a7287f5460350b8a6afdf        493         Free Throw       3
# 19133  9892e70d668a7287f5460350b8a6afdf        495       Substitution       3
# 19134  9892e70d668a7287f5460350b8a6afdf        498           Turnover       3
# 19135  9892e70d668a7287f5460350b8a6afdf        499       Substitution       3
# 19181  9892e70d668a7287f5460350b8a6afdf        569       Substitution       3
# 19136  9892e70d668a7287f5460350b8a6afdf        503        Missed Shot       3
# ...                                 ...        ...                ...     ...
# 19230  9892e70d668a7287f5460350b8a6afdf        641         Free Throw       4
# 19231  9892e70d668a7287f5460350b8a6afdf        642         Free Throw       4
# 19232  9892e70d668a7287f5460350b8a6afdf        643        Missed Shot       4
# 19233  9892e70d668a7287f5460350b8a6afdf        645            Rebound       4
# 19234  9892e70d668a7287f5460350b8a6afdf        646          Made Shot       4
# 19235  9892e70d668a7287f5460350b8a6afdf        647          Made Shot       4
# 19236  9892e70d668a7287f5460350b8a6afdf        648        Missed Shot       4
# 19237  9892e70d668a7287f5460350b8a6afdf        649            Rebound       4
# 19238  9892e70d668a7287f5460350b8a6afdf        650        Missed Shot       4
# 19239  9892e70d668a7287f5460350b8a6afdf        651            Rebound       4
# 19240  9892e70d668a7287f5460350b8a6afdf        652          Made Shot       4
# 19241  9892e70d668a7287f5460350b8a6afdf        654          Violation       4
# 19242  9892e70d668a7287f5460350b8a6afdf        655        Missed Shot       4
# 19244  9892e70d668a7287f5460350b8a6afdf        656            Rebound       4
# 19243  9892e70d668a7287f5460350b8a6afdf        657          Made Shot       4
# 19245  9892e70d668a7287f5460350b8a6afdf        658           Turnover       4
# 19246  9892e70d668a7287f5460350b8a6afdf        659        Missed Shot       4
# 19247  9892e70d668a7287f5460350b8a6afdf        660            Rebound       4
# 19248  9892e70d668a7287f5460350b8a6afdf        661          Made Shot       4
# 19249  9892e70d668a7287f5460350b8a6afdf        663               Foul       4
# 19250  9892e70d668a7287f5460350b8a6afdf        665         Free Throw       4
# 19251  9892e70d668a7287f5460350b8a6afdf        667         Free Throw       4
# 19252  9892e70d668a7287f5460350b8a6afdf        668          Made Shot       4
# 19253  9892e70d668a7287f5460350b8a6afdf        669        Missed Shot       4
# 19254  9892e70d668a7287f5460350b8a6afdf        670            Rebound       4
# 19255  9892e70d668a7287f5460350b8a6afdf        671        Missed Shot       4
# 19256  9892e70d668a7287f5460350b8a6afdf        672            Rebound       4
# 19257  9892e70d668a7287f5460350b8a6afdf        673          Made Shot       4
# 19258  9892e70d668a7287f5460350b8a6afdf        675         End Period       4
# 19259  9892e70d668a7287f5460350b8a6afdf          0  Final Box Printed       4
#
#        WC_Time  PC_Time                        Action_Type  Option1  Option2  \
# 19108   644940     1270                           Bad Pass        1        0
# 19109   645010     1200                   Pullup Jump shot        2        1
# 19110   645160     1030                Step Back Jump shot        2        0
# 19111   645210     1020                            Unknown        0        0
# 19112   645300      900                           Bad Pass        1        0
# 19113   645470      830                           Personal        1        0
# 19114   645670      830                  Free Throw 1 of 2        1        0
# 19115   645790      830                                           0        0
# 19116   645900      830                  Free Throw 2 of 2        1        0
# 19117   646050      710  Out of Bounds - Bad Pass Turnover        0        0
# 19118   646270      579                          Jump Shot        3        0
# 19119   646300      557                            Unknown        0        0
# 19120   646360      557                           Shooting        1        0
# 19121   646520      557                  Free Throw 1 of 2        2        0
# 19122   646520      557                     Normal Rebound        0        0
# 19123   646730      557                  Free Throw 2 of 2        2        0
# 19124   646760      518                            Unknown        0        0
# 19125   646860      420                   Pullup Jump shot        3        0
# 19126   646900      379                            Unknown        0        0
# 19127   647020      268                          Jump Shot        3        0
# 19128   647060      253                            Unknown        0        0
# 19129   647240       46                          Jump Shot        3        0
# 19130   647460       46                            Inbound        0        0
# 19131   647610       46                     Support Ruling        0        0
# 19132   648420       46                  Free Throw 1 of 1        1        0
# 19133   648490       46                                           0        0
# 19134   648640       29  Out of Bounds - Bad Pass Turnover        0        0
# 19135   648750       29                                           0        0
# 19181   660710       29                                           0        0
# 19136   648910       19                          Jump Shot        3        0
# ...        ...      ...                                ...      ...      ...
# 19230   666800     1850                  Free Throw 1 of 2        1        0
# 19231   666940     1850                  Free Throw 2 of 2        1        0
# 19232   667040     1760                 Driving Layup Shot        2        0
# 19233   667080     1750                            Unknown        0        0
# 19234   667090     1700                         Layup Shot        2        0
# 19235   667190     1600                 Driving Layup Shot        2        0
# 19236   667280     1510                   Pullup Jump shot        3        0
# 19237   667320     1500                            Unknown        0        0
# 19238   667490     1300         Driving Floating Jump Shot        2        0
# 19239   667550     1290                            Unknown        0        0
# 19240   667570     1250                 Running Layup Shot        2        1
# 19241   667640     1250              Defensive Goaltending        0        0
# 19242   667840     1060                 Cutting Layup Shot        2        0
# 19244   667900     1050                            Unknown        0        0
# 19243   667900     1050                     Tip Layup Shot        2        0
# 19245   668000      950                          Traveling        0        0
# 19246   668250      810                   Pullup Jump shot        3        0
# 19247   668290      800                            Unknown        0        0
# 19248   668320      750                 Running Layup Shot        2        1
# 19249   668520      600                           Shooting        1        0
# 19250   668770      600                  Free Throw 1 of 2        1        0
# 19251   668940      600                  Free Throw 2 of 2        1        0
# 19252   669030      537                  Running Jump Shot        2        1
# 19253   669230      384                   Pullup Jump shot        3        0
# 19254   669270      374                            Unknown        0        0
# 19255   669440      270                Step Back Jump shot        2        0
# 19256   669490      258                            Unknown        0        0
# 19257   669550      168                  Driving Dunk Shot        2        0
# 19258   669790        0                                           0        0
# 19259   688210        0                                           0        0
#
#        Option3    Team_id                           Person1  \
# 19108        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 19109        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 19110        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 19111        0      Team1  255fe2a8be0ed5c06dd99969ab4fea55
# 19112        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 19113        2      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 19114        0      Team0  942a84f05f4ab956125f68ec0963481f
# 19115        0      Team0  95920e4bf5b6c15ba8dffbf959b38ba5
# 19116        0      Team0  942a84f05f4ab956125f68ec0963481f
# 19117        0      Team1  31598ba01a3fff03ed0a87d7dea11dfe
# 19118        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 19119        0      Team0  942a84f05f4ab956125f68ec0963481f
# 19120        2      Team1  52c6125836c465f4ac5232121dacb49d
# 19121        0      Team0  942a84f05f4ab956125f68ec0963481f
# 19122        0      Team0  22fab2ecad98e9fed46efe57558bc41f
# 19123        0      Team0  942a84f05f4ab956125f68ec0963481f
# 19124        0      Team1  52c6125836c465f4ac5232121dacb49d
# 19125        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 19126        0      Team0  942a84f05f4ab956125f68ec0963481f
# 19127        0      Team0  1dabb767e07d0aa702ee58d41c15eab1
# 19128        0      Team1  52c6125836c465f4ac5232121dacb49d
# 19129        0      Team1  255fe2a8be0ed5c06dd99969ab4fea55
# 19130        1      Team1  3d75035d20b173a867d4bf32c8a58f0b
# 19131        0      Team0  05a272a33fbe9bfa320a01e1891572af
# 19132        0      Team0  32c044aa84d75ccd78c3c9f2aeb33bd9
# 19133        0      Team1  255fe2a8be0ed5c06dd99969ab4fea55
# 19134        0      Team0  942a84f05f4ab956125f68ec0963481f
# 19135        0      Team1  52c6125836c465f4ac5232121dacb49d
# 19181        0      Team1  3d75035d20b173a867d4bf32c8a58f0b
# 19136        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# ...        ...        ...                               ...
# 19230        0      Team1  94e99d76e87ee926faab66d382b3a955
# 19231        0      Team1  94e99d76e87ee926faab66d382b3a955
# 19232        0      Team0  8c7a7249d80b1489594b3a2a87f3f19d
# 19233        0      Team0  8c7a7249d80b1489594b3a2a87f3f19d
# 19234        0      Team0  8c7a7249d80b1489594b3a2a87f3f19d
# 19235        0      Team1  fbcda0bcb861e4726ca8871b8965ede4
# 19236        0      Team0  c950aaad2e56c87e9ac7281016d37cb6
# 19237        0      Team1  0b978fcfa7f2ec839c563a755e345ff8
# 19238        0      Team1  0b978fcfa7f2ec839c563a755e345ff8
# 19239        0      Team0  36fdadf436b164ee29174c8e1fde7271
# 19240        0      Team0  c950aaad2e56c87e9ac7281016d37cb6
# 19241        0      Team1  821887f9a002be16b5f79729fae59e01
# 19242        0      Team1  94e99d76e87ee926faab66d382b3a955
# 19244        0      Team1  94e99d76e87ee926faab66d382b3a955
# 19243        0      Team1  94e99d76e87ee926faab66d382b3a955
# 19245        0      Team0  e49b2cc3f9aacd500b11a35b1c57112d
# 19246        0      Team1  fbcda0bcb861e4726ca8871b8965ede4
# 19247        0      Team0  8c7a7249d80b1489594b3a2a87f3f19d
# 19248        0      Team0  619d3e44dc84b366bd685de3e94b3bec
# 19249        2      Team0  619d3e44dc84b366bd685de3e94b3bec
# 19250        0      Team1  94e99d76e87ee926faab66d382b3a955
# 19251        0      Team1  94e99d76e87ee926faab66d382b3a955
# 19252        0      Team0  8c7a7249d80b1489594b3a2a87f3f19d
# 19253        0      Team1  0b978fcfa7f2ec839c563a755e345ff8
# 19254        0      Team1  f5f0b0fd479d7c889872298f95c3d810
# 19255        0      Team1  fbcda0bcb861e4726ca8871b8965ede4
# 19256        0      Team0  e49b2cc3f9aacd500b11a35b1c57112d
# 19257        0      Team0  36fdadf436b164ee29174c8e1fde7271
# 19258        0      Team1  0370a0d090da0d0edc6319f120187e0e
# 19259        0  Officials  0370a0d090da0d0edc6319f120187e0e
#
#                                 Person2                           Person3  \
# 19108  3d75035d20b173a867d4bf32c8a58f0b  0370a0d090da0d0edc6319f120187e0e
# 19109  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19110  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19111  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19112  95920e4bf5b6c15ba8dffbf959b38ba5  0370a0d090da0d0edc6319f120187e0e
# 19113  942a84f05f4ab956125f68ec0963481f  b72ff0be69b729564593e51b0cccdcff
# 19114  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19115  32c044aa84d75ccd78c3c9f2aeb33bd9  0370a0d090da0d0edc6319f120187e0e
# 19116  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19117  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19118  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19119  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19120  942a84f05f4ab956125f68ec0963481f  3bbe7618e9c2ddc5bd16e54e132bb0e3
# 19121  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19122  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19123  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19124  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19125  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19126  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19127  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19128  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19129  3626b893fc73a5cbd67d1ea48a5c7039  0370a0d090da0d0edc6319f120187e0e
# 19130  fb64ca4b8beaf4c4c6e4575fe2f3abd7  3bbe7618e9c2ddc5bd16e54e132bb0e3
# 19131  0370a0d090da0d0edc6319f120187e0e  3bbe7618e9c2ddc5bd16e54e132bb0e3
# 19132  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19133  a1591595c04d12e88e3cb427fb667618  0370a0d090da0d0edc6319f120187e0e
# 19134  0370a0d090da0d0edc6319f120187e0e  3bbe7618e9c2ddc5bd16e54e132bb0e3
# 19135  1a6703883f8f47bb4daf09c03be3bda2  0370a0d090da0d0edc6319f120187e0e
# 19181  0b978fcfa7f2ec839c563a755e345ff8  0370a0d090da0d0edc6319f120187e0e
# 19136  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# ...                                 ...                               ...
# 19230  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19231  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19232  0370a0d090da0d0edc6319f120187e0e  94e99d76e87ee926faab66d382b3a955
# 19233  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19234  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19235  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19236  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19237  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19238  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19239  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19240  36fdadf436b164ee29174c8e1fde7271  0370a0d090da0d0edc6319f120187e0e
# 19241  0370a0d090da0d0edc6319f120187e0e  3bbe7618e9c2ddc5bd16e54e132bb0e3
# 19242  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19244  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19243  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19245  0370a0d090da0d0edc6319f120187e0e  81efe876f336ab00d7331d21e9ac06dd
# 19246  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19247  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19248  8c7a7249d80b1489594b3a2a87f3f19d  0370a0d090da0d0edc6319f120187e0e
# 19249  94e99d76e87ee926faab66d382b3a955  b72ff0be69b729564593e51b0cccdcff
# 19250  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19251  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19252  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19253  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19254  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19255  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19256  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19257  e49b2cc3f9aacd500b11a35b1c57112d  0370a0d090da0d0edc6319f120187e0e
# 19258  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 19259  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 19108             3             5             4             0
# 19109             2             4             0             0
# 19110             3             5             0             0
# 19111             3             4             0             0
# 19112             2             4             5             0
# 19113             3             4             5             1
# 19114             3             5             0             0
# 19115             3             5             5             0
# 19116             3             5             0             0
# 19117             2             4             0             0
# 19118             3             5             0             0
# 19119             3             5             0             0
# 19120             3             4             5             1
# 19121             3             5             0             0
# 19122             3             3             0             0
# 19123             3             5             0             0
# 19124             3             4             0             0
# 19125             2             4             0             0
# 19126             2             5             0             0
# 19127             3             5             0             0
# 19128             3             4             0             0
# 19129             2             4             4             0
# 19130             3             4             5             1
# 19131             3             0             0             1
# 19132             3             5             0             0
# 19133             2             4             4             0
# 19134             3             5             0             1
# 19135             2             4             4             0
# 19181             2             4             4             0
# 19136             2             4             0             0
# ...             ...           ...           ...           ...
# 19230             2             4             0             0
# 19231             2             4             0             0
# 19232             3             5             0             4
# 19233             3             5             0             0
# 19234             3             5             0             0
# 19235             2             4             0             0
# 19236             3             5             0             0
# 19237             3             4             0             0
# 19238             2             4             0             0
# 19239             2             5             0             0
# 19240             3             5             5             0
# 19241             3             4             0             1
# 19242             2             4             0             0
# 19244             2             4             0             0
# 19243             2             4             0             0
# 19245             3             5             0             1
# 19246             2             4             0             0
# 19247             2             5             0             0
# 19248             3             5             5             0
# 19249             2             5             4             1
# 19250             2             4             0             0
# 19251             2             4             0             0
# 19252             3             5             0             0
# 19253             2             4             0             0
# 19254             2             2             0             0
# 19255             2             4             0             0
# 19256             2             5             0             0
# 19257             3             5             5             0
# 19258             2             0             0             0
# 19259             0             0             0             0
#
# [152 rows x 18 columns]

# %%
def compareGameDicts(gameDict1, gameDict2):
    """Used to compare two gameDicts to see if there are any differences. 
        Typically used when making changes to gameRatings function to determine 
        if it changed any output. Assumes both gameDict have the same exact players (which they should).
    """
    
    for player in gameDict1.keys():
        if not (gameDict1[player] == gameDict2[player]).all():
            return False
    return True

# %%
i = 0
for game in GameIDs:
    print(i)
    gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
    gameLineup = GameLineup[GameLineup['Game_id'] == game]
    gameDict1 = gameRatingsComplete(gamePlayByPlay, gameLineup, eventCodes)
    gameDict2 = gameRatingsSubCleaned(gamePlayByPlay, gameLineup, eventCodes)
    
    print(compareGameDicts(gameDict1, gameDict2))
    
    i += 1

# %%
a = np.array([1,4,2,5])
b = np.array([1,4,3,5])
(a==b).any()

# %%
#General logic

#Have dictionary of dictionaries? {team1: {player1: ,...}, team2: {player1}, ...}
#team1Dict/team2Dict of all players - {player1: [pointsFor, pointsAgainst, possessions], player2...}

#team1List/team2List of players currently in game

#Iterate through every event of playbyplay. Check whether shot made and add points/possession to corresponding For/Against categories
#of players in game. And also check whether defensive rebound/turnover happens and add possession to each player in game

#Special case of free throws where have to track previous players due to substitutions between free throws.
#Hard because for and-1s substitution occurs before free throw. 
#Check if shooting foul? I believe other fouls (technical/flagrant/bonus) substituion occurs after first FT
#See https://official.nba.com/rule-no-3-players-substitutes-and-coaches/ section V.i

#Special case of end to start of next quarter

#Do ejections show up as substitutions afterward?

#What about jump balls?

#Do for every game -> get Off/Def Rating
