# %%
import numpy as np
import pandas as pd

# %%
eventCodes = pd.read_csv('Event_Codes.txt', sep='\t')
#Strip excess whitespace that I noticed in Event Message Type Description
eventCodes['Event_Msg_Type_Description'] = eventCodes['Event_Msg_Type_Description'].map(str.strip)

GameLineup = pd.read_csv('Game_Lineup.txt', sep='\t')
PlayByPlay = pd.read_csv('Play_by_Play.txt', sep='\t')
GameIDs = PlayByPlay['Game_id'].unique()

# %%
def sortedPlayByPlay(PlayByPlay):
    """Returns PlayByPlay with nested sorted given by hackathon pdf file.
    
    Input:
        PlayByPlay: Pandas Dataframe from reading Play_by_Play csv file"""
    return PlayByPlay.sort_values(['Period', 'PC_Time', 'WC_Time', 'Event_Num'], ascending=[True, False, True,True])

# %%
def readablePlayByPlay(playByPlay, gameLineup, eventCodes):
    """Maps teamIDs to correct player and replaces it with a simple team0 or team1. 
    Also maps event numbers and action to corresponding description, based off eventCodes"""
    gameTeams = list(gameLineup['Team_id'].unique())
    playerList = list(gameLineup['Person_id'].unique())
    
    playByPlay['Event_Msg_Type'] = playByPlay['Event_Msg_Type'].astype(str)
    playByPlay['Action_Type'] = playByPlay['Action_Type'].astype(str)
    
    print('Team0', gameTeams[0])
    print('Team1', gameTeams[1])
    
    for event in playByPlay.itertuples():
        i = getattr(event, 'Index')
        player = getattr(event, 'Person1')
        teamID = getattr(event, 'Team_id')
        
        if teamID not in gameTeams:
            playerTeam = 'Officials'
        else:
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        #print(playerTeam)
        #print(gameTeams)
        
        if playerTeam == gameTeams[0]:
            playByPlay.at[i,'Team_id'] = 'Team0'
        elif playerTeam == gameTeams[1]:
            playByPlay.at[i, 'Team_id'] = 'Team1'
        else:
            playByPlay.at[i, 'Team_id'] = 'Officials'

        
        eventNum = getattr(event, 'Event_Num')
         #Get the event type
        eventMsgType = int(getattr(event, "Event_Msg_Type"))
        actionType = int(getattr(event, 'Action_Type'))
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        playByPlay.at[i, 'Event_Msg_Type'] = eventMsgDescript
        playByPlay.at[i, 'Action_Type'] = actionTypeDescript
    return playByPlay

# %%
def addPoints(player, points, team0Lineup, team1Lineup, gameDict, possession):
    #Player is person1 of the event messages. Every teammate gets the points for added and opponents points against
    if player in team0Lineup:
        for team0player in team0Lineup:
            #Add points for and off possession
            gameDict[team0player] += np.array([points, 0, possession, 0])
        for team1player in team1Lineup:
            #Add points against and def posession
            gameDict[team1player] += np.array([0, points, 0, possession])
        return
    elif player in team1Lineup:
        for team0player in team0Lineup:
            #Add points against and def possession
            gameDict[team0player] += np.array([0, points, 0, possession])
        for team1player in team1Lineup:
            #Add points for and off possession
            gameDict[team1player] += np.array([points, 0, possession, 0])
        return
    else:
        print("Player not found on either team lineup!")
        print(player)
        print('Team0', team0Lineup)
        print('Team1', team1Lineup)
        return -1
    
def addPossession(team0Lineup, team1Lineup, gameDict):
    """Adds offensive possession to team0Lineup and defensive possession to team1Lineup."""
    for team0player in team0Lineup:
        #Add off possession
        gameDict[team0player] += np.array([0, 0, 1, 0])
    for team1player in team1Lineup:
        #Add def posession
        gameDict[team1player] += np.array([0, 0, 0, 1])
    return

def getPlayerTeam(player, teamID, playerList, gameLineup):
    """Returns the team of the input player (if player is real) otherwise returns teamID"""
    if player not in playerList:
        #Team event
        playerTeam = teamID
    else:
        playerTeam = gameLineup[gameLineup['Person_id'] == player]['Team_id'].values[0]
    return playerTeam

def doSubstitution(player, event, team0Lineup, team1Lineup, verbose):
    leavingPlayer = player
    enteringPlayer = getattr(event, 'Person2')
    if leavingPlayer in team0Lineup:
        team0Lineup.remove(leavingPlayer)
        team0Lineup.append(enteringPlayer)
    else:
        team1Lineup.remove(leavingPlayer)
        team1Lineup.append(enteringPlayer)
            
    if verbose:
        print(enteringPlayer, ' replacing ', leavingPlayer)

def doPossessionFixSub(possessionInfo, team, gameDict, gameTeams, verbose = False):
    """
    Adds possessions to players given by possessionInfo dictionary. 
        Used for when possession unknown (often due to a team rebound).
        
    
    Inputs: 
        possessionInfo: Dictionary containing the relevant information of the events leading to unknown possession.
            'team0' and 'team1' keys correspond to the team0 and team1 lineups. 
            'event' key corresponds to the event (missed shot or free throw)
            'lastTeam' key corresponds to team last known to have possession
            'subbedPlayers0' and 'subbedPlayers1' keys correspond to players subbed out in between 'event' and 
                play where possession becomes known
            'remainingPlayers0' and 'remainingPlayers1' keys typically correspond to players 
                who are still on court after a substitution occurs ie remainingPlayers = teamLineup - subbedInPlayers
                However, currently assuming that all players on court get credited with possession on missed ft 
                so will just be same as teamLineup
        
        team: Team that currently has possession to be compared to lastTeam
        
        gameDict: Dictionary containing all pointsFor/Against and off/defPossessions of each player to be updated
        
        gameTeams: List of both teams playing to be used to check if team0 or 1 has possession
        
        verbose: Optional input, where if True, prints statements describing which players possession added to
        
        """
    eventDescript = possessionInfo['event']
    team0Lineup = possessionInfo['team0']
    team1Lineup = possessionInfo['team1']
    lastTeam = possessionInfo['lastTeam']
    subbedPlayers0 = possessionInfo['subbedPlayers0']
    subbedPlayers1 = possessionInfo['subbedPlayers1']
    
    possessionInfoEmpty = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                           'event': '', 'lastTeam': '', 'subbedPlayers0': [], 'subbedPlayers1': []}
    
    if (team not in gameTeams) or (lastTeam not in gameTeams):
        raise Exception('Either {} or {} not a valid team'.format(team, lastTeam))
    
    if (eventDescript == 'Missed Shot') or (eventDescript == 'Technical Free Throw'):
        if verbose:
            print('Missed shot possession fix')
        if len(subbedPlayers0) + len(subbedPlayers1) > 0:
            #Regardless of who rebounds add possession to players subbed off
            if team == gameTeams[0]:
                #Team0 players who were subbed now on offense (ASSUMES sub happens after rebound)
                addPossession(subbedPlayers0, subbedPlayers1, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers0)
                    print("Add def possession to subbed players", subbedPlayers1)
            else:
                addPossession(subbedPlayers1, subbedPlayers0, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers1)
                    print("Add def possession to subbed players", subbedPlayers0)
        if lastTeam == team:
            #Offensive rebound on missed shot, do nothing except for subbed players
            
            if verbose:
                print("Was offensive rebound, don't do anything for on court players")
            return possessionInfoEmpty
        elif team == gameTeams[0]:
            #Defensive rebound by team0
            addPossession(team1Lineup, team0Lineup, gameDict)
            
            if verbose:
                print("Add off possession to ", team1Lineup)
                print("Add def possession to ", team0Lineup)
        else:
            #Defensive rebound by team1
            addPossession(team0Lineup, team1Lineup, gameDict)

            if verbose:
                print("Add off possession to ", team0Lineup)
                print("Add def possession to ", team1Lineup)
                    
    elif eventDescript == 'Missed Last Free Throw':
        if verbose:
            print('FT possession fix')
        if lastTeam == team:
            #Do nothing, as possession already added to subbed players
            pass
            
        else: #Defensive Rebound
            #Only add possession to those who were on court when foul occured
            ##UPDATE: I believe NBA actually counts it as a possession for all players on court, 
            #so while still labeled remainingPlayers, input in gameRatings function will be teamLineup
            remainingPlayers0 = possessionInfo['remainingPlayers0']
            remainingPlayers1 = possessionInfo['remainingPlayers1']
            
            if team == gameTeams[0]:
                #team0 grabs defensive rebound
                addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers1)
                    print("Add def possession to ", remainingPlayers0)
            else:
                addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers0)
                    print("Add def possession to ", remainingPlayers1)
    else:
        raise Exception('Attempt to fix possession failed, invalid event Descript: {}'.format(eventDescript))
    
    return possessionInfoEmpty

# %%
def gameRatingsSubCleaned(gamePlayByPlay, gameLineup, eventCodes, verbose = False):
    """Turns a given PlayByPlay log and calculates the number of points and possessions a player is in the game for, 
    both scored by and against the players team. Can be used to calculate offensive and defensive rating defined by 
    offRtg = 100*pointsFor/offPossessions and defRtg = 100*pointsAgainst/defPossesssions
    
    Inputs:
        gamePlayByPlay: A Pandas dataframe object listing the play by play events for a single game. 
            This should be sorted according to the prompt (Period, PC_Time, WC_Time, Event_Num). Taken from Play_by_Play.txt .
        
        gameLineup: A Pandas dataframe of the game lineup for the same gams as the play by play. Taken from Game_Lineup.txt .
        
        eventCodes: Pandas dataframe of the event codes provided by the NBA. Taken from Event_Codes.txt .
        
        verbose: Optional argument. If set to True, prints the current loop counter and a description of each event 
            (made shot, rebound, turnover, etc)
        
    Output:
        gameDict: A dictionary where the keys are each playerID from the gameLineup input, 
            and the value is an array of [pointsFor, pointsAgainst, offPossessions, defPossessions]
    
    """
    
    lastDescript = ''
    counter = 0
    gameTeams = list(gameLineup['Team_id'].unique())
    
    #Create dictionary with keys of each player and value of array([PointsFor, PointsAgainst, OffPossessions, DefPossessions])
    playerList = list(gameLineup['Person_id'].unique())
    gameDict = {player: np.array([0,0,0,0]) for player in playerList}
    
    #List of event numbers to skip 
    #(designed for the case where we 'look ahead' at a future rebound or substitution due to playbyplay error)
    skipEventNums = []
    
    #Keep track of team with possession 
    currPoss = ''
    #Keep track of play clock time (due to weird handling of technical fouls as possessions by NBA) 
    #Initialize to -1 so no accidental equalities
    currTime = -1 
    
    #Added because of cases where made shot with 0 on clock would lead to another possession being added when period ended
    #Unclear if have to take into account other actions at 0
    skipEndPeriod = False
    
    for event in gamePlayByPlay.itertuples():
        
        eventNum = getattr(event, 'Event_Num')
        
         #Get the event type
        eventMsgType = getattr(event, "Event_Msg_Type")
        actionType = getattr(event, 'Action_Type')
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        #Player who shoots, rebounds, etc
        player = getattr(event, 'Person1')
        
        if verbose:
            print('Counter', counter)
            print('Event Num', eventNum)
            print(skipEventNums)
            print(eventMsgDescript, 'by', player)
    
        counter += 1
        if eventNum in skipEventNums:
            continue
        

        
        teamID = getattr(event, 'Team_id') #teamID doesn't always correspond to player's team
        playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        PCtime = getattr(event, 'PC_Time')
        period = getattr(event, 'Period')

     
        if eventMsgDescript == 'Start Period':
            skipEndPeriod = False
            currTime = -1
            currPoss = playerTeam
            #Substitutions at start of period aren't considered substitution events. Must check game linup explicitly.
            team0Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[0])]['Person_id'])
            team1Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[1])]['Person_id'])

            lastDescript = ''
            
            #Used for cases of a team rebound not assigned to a particular player. The teamID is often wrong, 
            #so when unknownRebound is True, next events are checked to see who has the ball.
            unknownRebound = False
            unknownReboundInfo = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                                  'subbedPlayers0': [], 'subbedPlayers1': [], 'event': '', 'lastTeam': ''}
            
            if verbose:
                print(period,' lineup 0:', team0Lineup)
                print(period,' lineup 1:', team1Lineup)
                
                
        elif eventMsgDescript == 'End Period' and not skipEndPeriod:
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
                
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
            lastDescript = ''
            
            if verbose:
                print(period, 'ended')
                
        if lastDescript == 'Missed Shot':
            #Previous event missed shot, check who rebounded
            
            lastDescript = ''
            
            if currTime== 0:
                #Miss at end of period so skip End Period event otherwise double count of possession
                skipEndPeriod = True
                #Add possession to each player
                if lastTeam == gameTeams[0]:
                    #team0 missed on offense
                    addPossession(team0Lineup, team1Lineup, gameDict)
                else:
                    addPossession(team1Lineup, team0Lineup, gameDict)
                continue
                
            currTime = PCtime
            
            if eventMsgDescript != 'Rebound':
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at later time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                
                #Get all events after current one and check which events correspond to a rebound in same period
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & (reboundEvent['Period'] == period)]
                if reboundEvent.empty:
                    print('No rebound after!')
                    print('Counter', counter-1)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])

            #if player not in lastTeam: #Defensive rebound (for an offensive rebound do nothing)
            
            #Check that if real player (not team rebound) grabbed board, that he is on the court
            #Shouldn't be triggered if parsing done correctly, but good for error checking
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Counter', counter-1)
                print('Event num', getattr(event, 'Event_Num'))
                break
                
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Shot'
                unknownReboundInfo['lastTeam'] = lastTeam
                    
            elif playerTeam != lastTeam:
                #Defensive rebound
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                if verbose:
                    print("Defensive Rebound")

            else:
                if verbose:
                    print("Offensive Rebound")
            #Reset to player of current event for instances where we needed to find next rebound due to wrong order
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
            
        elif lastDescript == 'Missed Last Free Throw':
            #Similar structure as missing last shot, except take into account possibility of substitutions 
            #(important if don't want to give substitutions to player subbed in -- NBA seems to count those)
            lastDescript = ''
            currTime = PCtime
            if eventMsgDescript != 'Rebound':
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at same time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                WCtime = getattr(event, 'WC_Time')
                
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & ((reboundEvent['Period'] == period))]
                if reboundEvent.empty:
                    print('Event num', getattr(event, 'Event_Num'))
                    print('No rebound at same time!')
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])


            #Check if players subbed at same time
            subEvents = gamePlayByPlay[counter-1:]
            subEvents = subEvents[(subEvents['Event_Msg_Type'] == 8) 
                                & (subEvents['Period'] == period) 
                                & (subEvents['PC_Time'] == PCtime)]
            for substitution in subEvents.itertuples():
                subPlayer = getattr(substitution, 'Person1')
                subEventNum = getattr(substitution, 'Event_Num')
                subPlayerTeam = getPlayerTeam(subPlayer, '', playerList, gameLineup)
                    
                skipEventNums.append(subEventNum)
                doSubstitution(subPlayer, substitution, team0Lineup, team1Lineup, verbose)
                if subPlayerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([subPlayer], [], gameDict)
                else:
                    addPossession([], [subPlayer], gameDict)
                if verbose:
                    print('Sub after ft')
                    
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Event num', getattr(event, 'Event_Num'))
                break
            
            subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
            subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
            remainingPlayers0 = list(set(ftTeam0Lineup)-set(subbedPlayers0))
            remainingPlayers1 = list(set(ftTeam1Lineup)-set(subbedPlayers1))
            
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Last Free Throw'
                #unknownReboundInfo['remainingPlayers0'] = remainingPlayers0.copy()
                #unknownReboundInfo['remainingPlayers1'] = remainingPlayers1.copy()
            
                unknownReboundInfo['remainingPlayers0'] = team0Lineup.copy()
                unknownReboundInfo['remainingPlayers1'] = team1Lineup.copy()

                unknownReboundInfo['lastTeam'] = lastTeam
                
            #Offensive Rebound, no possessions added (already added to subbed players)
            elif playerTeam == lastTeam:
                if verbose:
                    print("Offensive Rebound")
 
            else:
                #Only add possession to those who were on court when foul occured and are still on court
            
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    #addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    #addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                    
                if verbose:
                    print("Defensive Rebound")
                    
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        if eventNum in skipEventNums:
            #Check this again because of iteration through substitution events after missed shot or free throw
            continue
        
        if eventMsgDescript == 'Substitution':
            doSubstitution(player, event, team0Lineup, team1Lineup, verbose)
            
            #In case current possession unknown use unknownRebound logic to check next possession and assign correct possessions
            if unknownRebound:
                if playerTeam == gameTeams[0]:
                    unknownReboundInfo['subbedPlayers0'].append(player)
                elif playerTeam == gameTeams[1]:
                    unknownReboundInfo['subbedPlayers1'].append(player)
            else:
                if playerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([player], [], gameDict)
                else:
                    addPossession([], [player], gameDict)
            
        if eventMsgDescript == 'Made Shot':
            currTime = PCtime
            if PCtime == 0:
                skipEndPeriod = True
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            points = getattr(event, 'Option1')
            
            #Check if and-1. Only checking if fts happen not action type ft 1 out of 1 because possibility of flagrant.
            #This assumes that the ft shot will always be after the made shot in a play by play
            ftEvents = gamePlayByPlay[counter-1:]
            ftEvents = ftEvents[(ftEvents['Event_Msg_Type'] == 3) 
                                    & (ftEvents['Period'] == period) 
                                    & (ftEvents['PC_Time'] == PCtime)]
            # if ft happens then don't count possession, because it will be handled when loop hits that event
            if ftEvents.empty:
                poss = 1
                if playerTeam == gameTeams[0]:
                    currPoss = gameTeams[1]
                else:
                    currPoss = gameTeams[0]
            else:
                poss = 0
            
            addPoints(player,points, team0Lineup, team1Lineup, gameDict, possession= poss)
            
            if verbose:
                print(player, 'scores', points, 'points')
                
        elif eventMsgDescript == 'Turnover':
            
            currTime = PCtime
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
                currPoss = gameTeams[1]
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
                currPoss = gameTeams[0]
                
            if verbose:
                print(playerTeam, 'turnover')
                
        elif eventMsgDescript == 'Missed Shot':
            
            currTime = PCtime
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Check who rebounds in next iteration of loop
            lastDescript = eventMsgDescript

            if player in team0Lineup:
                #lastTeam = team0Lineup
                lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
            else:
                #lastTeam = team1Lineup
                lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
            if verbose:
                print(player, 'misses shot')

        #Check if Foul (which may or may not lead to free throws), but all free throws come from fouls
        #Important to check if a generic foul and not just shooting fouls, otherwise the free throw lineup will be 'behind'
        #If only looked at shooting fouls - consider situation of substitutions during the game and then a technical foul. 
        #The ft lineup would only be from the previous fts, not the current lineup. 
        elif (eventMsgDescript == 'Foul'):
            #Make sure to copy lineup not assign, otherwise when lineup changes ftTeamLineup would change
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            
            if verbose:
                print('Foul on team', playerTeam)

        elif eventMsgDescript == 'Free Throw':
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            option1 = getattr(event, 'Option1')
            if option1 == 1: #Made Free Throw
                points = 1
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #ActionTypes corresponding to final free throw, so add possession. 
                    subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
                    subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
                    
                    #subbedPlayers already got possession added so only add to remaining players on court
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    remainingPlayers0 = list(set(ftTeam0Lineup) - set(subbedPlayers0))
                    remainingPlayers1 = list(set(ftTeam1Lineup) - set(subbedPlayers1))
                    
                    if playerTeam == gameTeams[0]:
                        addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                        currPoss = gameTeams[1]
                    elif playerTeam == gameTeams[1]:
                        addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                        currPoss = gameTeams[0]
                    else:
                        print('Error: Free throw player not on either team')
                        return

                    if verbose:
                        print('Made final free throw by', player)
                        
                else:
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    
                    if verbose:
                        print('Made free throw by', player)
                        
            else: #Missed FT
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #Missed last free throw for a shooting foul (not technical/flagrant), check who rebounds in next iteration. 
                    lastDescript = 'Missed Last Free Throw'
                    #Offensive rebounds with substitution going to be weird in terms of possessions

                    #Check current lineup, not free throw lineup since current lineup will be the one to rebound
                    if player in team0Lineup:
                        lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
                    else:
                        lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
                        
                    if verbose:
                        print('Missed last free throw by', player)
                        print('ftteam1', ftTeam1Lineup)
                else:
                    if verbose:
                        print('Missed free throw by', player)

            #NBA seems to count technical free throws a possession. Delete block below if undesired.
            
            #Check whether was last technical free throw (not flagrant which team keeps possession)
            if (actionType == 16) or (actionType == 22):
                
                
                #Use the possessionFix method already implemented and just count this free throw as the 'unknownRebound'
            
                #So if team on offense commits tech that counts as off + def possession
                #then def + off possession for tech ft, and then following possession will be off + def
                if False:
                    unknownRebound = True
                    unknownReboundInfo['team0'] = team0Lineup.copy()
                    unknownReboundInfo['team1'] = team1Lineup.copy()
                    unknownReboundInfo['event'] = 'Technical Free Throw'
                    unknownReboundInfo['remainingPlayers0'] = ftTeam0Lineup.copy()
                    unknownReboundInfo['remainingPlayers1'] = ftTeam1Lineup.copy()
                    unknownReboundInfo['lastTeam'] = playerTeam
                    
                #Check if tech committed by team with possession. If so add offensive and defensive possession to both teams 
                #(off from having ball, def from tech shot)
                
                #Also it seems like only if time passed in a given possession does the tech count as a change in possession.
                #Remove currTime != PCtime so all techs treated equally
                if currPoss != playerTeam and currTime != PCtime:
                    addPossession(ftTeam1Lineup, ftTeam0Lineup, gameDict)
                    addPossession(ftTeam0Lineup, ftTeam1Lineup, gameDict)
    return gameDict

# %%
dataRows = []
i = 0
for game in GameIDs:
    print(i)
    gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
    gameLineup = GameLineup[GameLineup['Game_id'] == game]
    gameDict = gameRatingsSub(gamePlayByPlay, gameLineup, eventCodes)
    playerList = list(gameLineup['Person_id'].unique())
    
    for player in gameDict.keys():
        dataDict = {'Game_ID': game}
        #Check at least one possession played
        offPossessions = gameDict[player][2]
        defPossessions = gameDict[player][3]
        
        totalPossessions = offPossessions + defPossessions
        
        if totalPossessions != 0: 
            #Allowing for possibility of only playing one possession on offense or defense and thus undefined rating
            pointsFor = gameDict[player][0]
            pointsAgainst = gameDict[player][1]
            if offPossessions == 0:
                offRating = np.nan
            else:
                offRating = 100*(pointsFor/offPossessions)
            if defPossessions == 0:
                defRating = np.nan
            else:
                defRating = 100*(pointsAgainst/defPossessions)
            playerTeam = getPlayerTeam(player, '', playerList, gameLineup)
            dataDict.update({'Player_ID': player, 'Team_ID': playerTeam, 'OffRtg': np.round(offRating,1), 
                             'DefRtg': np.round(defRating,1), 'OffPossessions': offPossessions, 
                             'DefPossessions': defPossessions, 'PointsFor': pointsFor, 'PointsAgainst': pointsAgainst})
            
            dataRows.append(dataDict)
    i+=1
df = pd.DataFrame(dataRows)
df= df[['Game_ID', 'Player_ID', 'Team_ID','OffRtg', 'DefRtg', 'OffPossessions', 'DefPossessions', 'PointsFor', 'PointsAgainst']]
df.to_excel("GameRatings.xlsx", index=False)

# %%
## bug in playbyplay that cant be fixed? Look at gameIDs[3] events 21-23 show missed free throw, rebound, then made free throw?
#Assuming its even ft, ft, rebound it says it was made so how can there be a rebound?
game = GameIDs[55]
gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
gameLineup = GameLineup[GameLineup['Game_id'] == game]
gameDict = gameRatingsSubCleaned(gamePlayByPlay[:], gameLineup, eventCodes, verbose=True)
# Out:
# Counter 0
# Event Num 2
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 1  lineup 0: ['7dfbb5980c066844384ba7424aceae47', 'ff52c317e26534ae1679da3c917e9fec', '11beb0ae23e6425510297a31fa21881e', '6ad10958a1d4920dccb1daec39bebd6b', '83c15c0962941640faab838a8f6f151d']
# 1  lineup 1: ['f562f72f83b8e06b60ff184531b07056', '23fbda7c31efd6cfa21e3ab6c89d53f3', '0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', '1c5bebebc83437eca5ef0aaf6eabb15a']
# Counter 1
# Event Num 4
# []
# Jump Ball by 83c15c0962941640faab838a8f6f151d
# Counter 2
# Event Num 7
# []
# Made Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 scores 2 points
# Counter 3
# Event Num 8
# []
# Made Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b scores 2 points
# Counter 4
# Event Num 10
# []
# Foul by 2c447ab0a100cb50766552b0f6fadc2d
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 5
# Event Num 12
# []
# Free Throw by 6ad10958a1d4920dccb1daec39bebd6b
# Made final free throw by 6ad10958a1d4920dccb1daec39bebd6b
# Counter 6
# Event Num 13
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 7
# Event Num 15
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 8
# Event Num 16
# []
# Rebound by 0a700ecf0eb76559949f1cb5b69a540b
# Defensive Rebound
# Counter 9
# Event Num 17
# []
# Made Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b scores 2 points
# Counter 10
# Event Num 18
# []
# Missed Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b misses shot
# Counter 11
# Event Num 19
# []
# Rebound by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Defensive Rebound
# Counter 12
# Event Num 20
# []
# Missed Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 misses shot
# Counter 13
# Event Num 21
# []
# Rebound by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 14
# Event Num 22
# []
# Foul by 83c15c0962941640faab838a8f6f151d
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 15
# Event Num 24
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 2c447ab0a100cb50766552b0f6fadc2d scores 3 points
# Counter 16
# Event Num 25
# []
# Foul by 0a700ecf0eb76559949f1cb5b69a540b
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 17
# Event Num 27
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Missed free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 18
# Event Num 28
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 19
# Event Num 29
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made final free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 20
# Event Num 30
# []
# Missed Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a misses shot
# Counter 21
# Event Num 31
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 22
# Event Num 32
# []
# Made Shot by 7dfbb5980c066844384ba7424aceae47
# 7dfbb5980c066844384ba7424aceae47 scores 2 points
# Counter 23
# Event Num 34
# []
# Missed Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d misses shot
# Counter 24
# Event Num 35
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Defensive Rebound
# Counter 25
# Event Num 36
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 26
# Event Num 37
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Defensive Rebound
# Counter 27
# Event Num 38
# []
# Missed Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 misses shot
# Counter 28
# Event Num 39
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 29
# Event Num 40
# []
# Foul by 1c5bebebc83437eca5ef0aaf6eabb15a
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 30
# Event Num 42
# []
# Foul by 0a700ecf0eb76559949f1cb5b69a540b
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 31
# Event Num 44
# []
# Foul by 7dfbb5980c066844384ba7424aceae47
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 32
# Event Num 46
# []
# Turnover by 7dfbb5980c066844384ba7424aceae47
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 33
# Event Num 47
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 34
# Event Num 48
# []
# Rebound by 6ad10958a1d4920dccb1daec39bebd6b
# Defensive Rebound
# Counter 35
# Event Num 49
# []
# Made Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b scores 3 points
# Counter 36
# Event Num 51
# []
# Foul by 11beb0ae23e6425510297a31fa21881e
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 37
# Event Num 53
# []
# Free Throw by 2c447ab0a100cb50766552b0f6fadc2d
# Made free throw by 2c447ab0a100cb50766552b0f6fadc2d
# Counter 38
# Event Num 54
# []
# Free Throw by 2c447ab0a100cb50766552b0f6fadc2d
# Made final free throw by 2c447ab0a100cb50766552b0f6fadc2d
# Counter 39
# Event Num 55
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 40
# Event Num 57
# []
# Foul by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 41
# Event Num 59
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 42
# Event Num 60
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 3 points
# Counter 43
# Event Num 62
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 44
# Event Num 64
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 2 points
# Counter 45
# Event Num 65
# []
# Turnover by ff52c317e26534ae1679da3c917e9fec
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 46
# Event Num 66
# []
# Timeout by 9811289f96c7deb95f04148c206e0b3a
# Counter 47
# Event Num 67
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 48
# Event Num 68
# []
# Rebound by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Offensive Rebound
# Counter 49
# Event Num 69
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 50
# Event Num 70
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 51
# Event Num 71
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Offensive Rebound
# Counter 52
# Event Num 72
# []
# Missed Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 misses shot
# Counter 53
# Event Num 73
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 54
# Event Num 74
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 55
# Event Num 76
# []
# Missed Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d misses shot
# Counter 56
# Event Num 77
# []
# Rebound by 6ad10958a1d4920dccb1daec39bebd6b
# Defensive Rebound
# Counter 57
# Event Num 78
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 58
# Event Num 80
# []
# Timeout by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 59
# Event Num 81
# []
# Substitution by 7dfbb5980c066844384ba7424aceae47
# 90ba0d1de241290df2e124a5e02d68ef  replacing  7dfbb5980c066844384ba7424aceae47
# Counter 60
# Event Num 82
# []
# Substitution by 2c447ab0a100cb50766552b0f6fadc2d
# bbe5cb93ef483ea31d950f6c634837dc  replacing  2c447ab0a100cb50766552b0f6fadc2d
# Counter 61
# Event Num 85
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 62
# Event Num 86
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 63
# Event Num 87
# []
# Rebound by 6ad10958a1d4920dccb1daec39bebd6b
# Defensive Rebound
# Counter 64
# Event Num 88
# []
# Missed Shot by 90ba0d1de241290df2e124a5e02d68ef
# 90ba0d1de241290df2e124a5e02d68ef misses shot
# Counter 65
# Event Num 89
# []
# Rebound by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Defensive Rebound
# Counter 66
# Event Num 90
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 3 points
# Counter 67
# Event Num 92
# []
# Turnover by 83c15c0962941640faab838a8f6f151d
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 68
# Event Num 94
# []
# Made Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 scores 2 points
# Counter 69
# Event Num 95
# []
# Foul by 6ad10958a1d4920dccb1daec39bebd6b
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 70
# Event Num 97
# []
# Turnover by 6ad10958a1d4920dccb1daec39bebd6b
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 71
# Event Num 98
# []
# Instant Replay by 301deb90de3792d0b4ec6bea1edfcbb2
# Counter 72
# Event Num 99
# []
# Substitution by f562f72f83b8e06b60ff184531b07056
# ce3ac26d43af7aa5555535cfed3f48cc  replacing  f562f72f83b8e06b60ff184531b07056
# Counter 73
# Event Num 101
# []
# Turnover by 0a700ecf0eb76559949f1cb5b69a540b
# 91ea9fc14670a54b9902eb062b416ccf turnover
# Counter 74
# Event Num 103
# []
# Foul by 1c5bebebc83437eca5ef0aaf6eabb15a
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 75
# Event Num 105
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made free throw by 83c15c0962941640faab838a8f6f151d
# Counter 76
# Event Num 106
# []
# Substitution by 6ad10958a1d4920dccb1daec39bebd6b
# a3bac86ad549b2f128a62399d73d6299  replacing  6ad10958a1d4920dccb1daec39bebd6b
# Counter 77
# Event Num 107
# []
# Substitution by 23fbda7c31efd6cfa21e3ab6c89d53f3
# bcf50b1e35f187b7c5bc18090cdfb7f6  replacing  23fbda7c31efd6cfa21e3ab6c89d53f3
# Counter 78
# Event Num 108
# []
# Substitution by 1c5bebebc83437eca5ef0aaf6eabb15a
# 687b541bdc76b92b085fc1304f5c1bf1  replacing  1c5bebebc83437eca5ef0aaf6eabb15a
# Counter 79
# Event Num 112
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 80
# Event Num 113
# []
# Missed Shot by bbe5cb93ef483ea31d950f6c634837dc
# bbe5cb93ef483ea31d950f6c634837dc misses shot
# Counter 81
# Event Num 115
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 82
# Event Num 116
# []
# Missed Shot by 90ba0d1de241290df2e124a5e02d68ef
# 90ba0d1de241290df2e124a5e02d68ef misses shot
# Counter 83
# Event Num 117
# []
# Rebound by bbe5cb93ef483ea31d950f6c634837dc
# Defensive Rebound
# Counter 84
# Event Num 118
# []
# Missed Shot by bcf50b1e35f187b7c5bc18090cdfb7f6
# bcf50b1e35f187b7c5bc18090cdfb7f6 misses shot
# Counter 85
# Event Num 120
# []
# Rebound by 90ba0d1de241290df2e124a5e02d68ef
# Defensive Rebound
# Counter 86
# Event Num 121
# []
# Foul by bcf50b1e35f187b7c5bc18090cdfb7f6
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 87
# Event Num 123
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Missed free throw by 83c15c0962941640faab838a8f6f151d
# Counter 88
# Event Num 124
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 89
# Event Num 125
# []
# Substitution by 0a700ecf0eb76559949f1cb5b69a540b
# 2c447ab0a100cb50766552b0f6fadc2d  replacing  0a700ecf0eb76559949f1cb5b69a540b
# Counter 90
# Event Num 127
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 91
# Event Num 128
# []
# Missed Shot by ce3ac26d43af7aa5555535cfed3f48cc
# ce3ac26d43af7aa5555535cfed3f48cc misses shot
# Counter 92
# Event Num 129
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 93
# Event Num 130
# []
# Missed Shot by a3bac86ad549b2f128a62399d73d6299
# a3bac86ad549b2f128a62399d73d6299 misses shot
# Counter 94
# Event Num 131
# []
# Rebound by bcf50b1e35f187b7c5bc18090cdfb7f6
# Defensive Rebound
# Counter 95
# Event Num 132
# []
# Made Shot by 687b541bdc76b92b085fc1304f5c1bf1
# 687b541bdc76b92b085fc1304f5c1bf1 scores 2 points
# Counter 96
# Event Num 133
# []
# Foul by bbe5cb93ef483ea31d950f6c634837dc
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 97
# Event Num 135
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 98
# Event Num 136
# []
# Substitution by 11beb0ae23e6425510297a31fa21881e
# 41c0674725d4cddab004649e9db5a3ce  replacing  11beb0ae23e6425510297a31fa21881e
# Counter 99
# Event Num 138
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made final free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 100
# Event Num 139
# []
# Missed Shot by bbe5cb93ef483ea31d950f6c634837dc
# bbe5cb93ef483ea31d950f6c634837dc misses shot
# Counter 101
# Event Num 141
# []
# Rebound by 41c0674725d4cddab004649e9db5a3ce
# Defensive Rebound
# Counter 102
# Event Num 142
# []
# Turnover by ff52c317e26534ae1679da3c917e9fec
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 103
# Event Num 143
# []
# Substitution by ff52c317e26534ae1679da3c917e9fec
# 7dfbb5980c066844384ba7424aceae47  replacing  ff52c317e26534ae1679da3c917e9fec
# Counter 104
# Event Num 145
# []
# Missed Shot by 687b541bdc76b92b085fc1304f5c1bf1
# 687b541bdc76b92b085fc1304f5c1bf1 misses shot
# Counter 105
# Event Num 146
# []
# Rebound by 7dfbb5980c066844384ba7424aceae47
# Defensive Rebound
# Counter 106
# Event Num 147
# []
# Turnover by 7dfbb5980c066844384ba7424aceae47
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 107
# Event Num 149
# []
# Foul by 90ba0d1de241290df2e124a5e02d68ef
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 108
# Event Num 151
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 109
# Event Num 152
# []
# Made Shot by 90ba0d1de241290df2e124a5e02d68ef
# 90ba0d1de241290df2e124a5e02d68ef scores 3 points
# Counter 110
# Event Num 154
# []
# Missed Shot by ce3ac26d43af7aa5555535cfed3f48cc
# ce3ac26d43af7aa5555535cfed3f48cc misses shot
# Counter 111
# Event Num 155
# []
# Rebound by 7dfbb5980c066844384ba7424aceae47
# Defensive Rebound
# Counter 112
# Event Num 156
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 1 ended
# Counter 113
# Event Num 163
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 2  lineup 0: ['7dfbb5980c066844384ba7424aceae47', 'ff52c317e26534ae1679da3c917e9fec', '11beb0ae23e6425510297a31fa21881e', 'a3bac86ad549b2f128a62399d73d6299', '41c0674725d4cddab004649e9db5a3ce']
# 2  lineup 1: ['bcf50b1e35f187b7c5bc18090cdfb7f6', '0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', 'ce3ac26d43af7aa5555535cfed3f48cc', '687b541bdc76b92b085fc1304f5c1bf1']
# Counter 114
# Event Num 164
# []
# Missed Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e misses shot
# Counter 115
# Event Num 165
# []
# Rebound by bcf50b1e35f187b7c5bc18090cdfb7f6
# Defensive Rebound
# Counter 116
# Event Num 166
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 117
# Event Num 167
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 118
# Event Num 168
# []
# Rebound by bcf50b1e35f187b7c5bc18090cdfb7f6
# Defensive Rebound
# Counter 119
# Event Num 169
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 120
# Event Num 170
# []
# Rebound by 41c0674725d4cddab004649e9db5a3ce
# Defensive Rebound
# Counter 121
# Event Num 171
# []
# Made Shot by a3bac86ad549b2f128a62399d73d6299
# a3bac86ad549b2f128a62399d73d6299 scores 3 points
# Counter 122
# Event Num 173
# []
# Made Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b scores 2 points
# Counter 123
# Event Num 175
# []
# Made Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e scores 2 points
# Counter 124
# Event Num 177
# []
# Missed Shot by 687b541bdc76b92b085fc1304f5c1bf1
# 687b541bdc76b92b085fc1304f5c1bf1 misses shot
# Counter 125
# Event Num 178
# []
# Rebound by 41c0674725d4cddab004649e9db5a3ce
# Defensive Rebound
# Counter 126
# Event Num 179
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 127
# Event Num 180
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 128
# Event Num 181
# []
# Jump Ball by ff52c317e26534ae1679da3c917e9fec
# Counter 129
# Event Num 184
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 130
# Event Num 185
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 131
# Event Num 186
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 132
# Event Num 187
# []
# Foul by 41c0674725d4cddab004649e9db5a3ce
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 133
# Event Num 189
# []
# Substitution by ce3ac26d43af7aa5555535cfed3f48cc
# f562f72f83b8e06b60ff184531b07056  replacing  ce3ac26d43af7aa5555535cfed3f48cc
# Counter 134
# Event Num 191
# []
# Foul by a3bac86ad549b2f128a62399d73d6299
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 135
# Event Num 193
# []
# Free Throw by bcf50b1e35f187b7c5bc18090cdfb7f6
# Missed free throw by bcf50b1e35f187b7c5bc18090cdfb7f6
# Counter 136
# Event Num 194
# []
# Rebound by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 137
# Event Num 195
# []
# Free Throw by bcf50b1e35f187b7c5bc18090cdfb7f6
# Made final free throw by bcf50b1e35f187b7c5bc18090cdfb7f6
# Counter 138
# Event Num 196
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 139
# Event Num 197
# []
# Rebound by bcf50b1e35f187b7c5bc18090cdfb7f6
# Defensive Rebound
# Counter 140
# Event Num 198
# []
# Made Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 scores 2 points
# Counter 141
# Event Num 199
# []
# Turnover by ff52c317e26534ae1679da3c917e9fec
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 142
# Event Num 201
# []
# Made Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 scores 3 points
# Counter 143
# Event Num 203
# []
# Timeout by 9811289f96c7deb95f04148c206e0b3a
# Counter 144
# Event Num 204
# []
# Substitution by 11beb0ae23e6425510297a31fa21881e
# 6ad10958a1d4920dccb1daec39bebd6b  replacing  11beb0ae23e6425510297a31fa21881e
# Counter 145
# Event Num 205
# []
# Substitution by ff52c317e26534ae1679da3c917e9fec
# 83c15c0962941640faab838a8f6f151d  replacing  ff52c317e26534ae1679da3c917e9fec
# Counter 146
# Event Num 208
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 147
# Event Num 209
# []
# Made Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b scores 2 points
# Counter 148
# Event Num 210
# []
# Missed Shot by 687b541bdc76b92b085fc1304f5c1bf1
# 687b541bdc76b92b085fc1304f5c1bf1 misses shot
# Counter 149
# Event Num 211
# []
# Rebound by 7dfbb5980c066844384ba7424aceae47
# Defensive Rebound
# Counter 150
# Event Num 212
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 151
# Event Num 214
# []
# Foul by 83c15c0962941640faab838a8f6f151d
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 152
# Event Num 216
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 153
# Event Num 218
# []
# Foul by 83c15c0962941640faab838a8f6f151d
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 154
# Event Num 220
# []
# Turnover by 83c15c0962941640faab838a8f6f151d
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 155
# Event Num 221
# []
# Substitution by bcf50b1e35f187b7c5bc18090cdfb7f6
# 1c5bebebc83437eca5ef0aaf6eabb15a  replacing  bcf50b1e35f187b7c5bc18090cdfb7f6
# Counter 156
# Event Num 222
# []
# Substitution by 687b541bdc76b92b085fc1304f5c1bf1
# 23fbda7c31efd6cfa21e3ab6c89d53f3  replacing  687b541bdc76b92b085fc1304f5c1bf1
# Counter 157
# Event Num 225
# []
# Missed Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 misses shot
# Counter 158
# Event Num 226
# []
# Rebound by 7dfbb5980c066844384ba7424aceae47
# Defensive Rebound
# Counter 159
# Event Num 227
# []
# Missed Shot by 41c0674725d4cddab004649e9db5a3ce
# 41c0674725d4cddab004649e9db5a3ce misses shot
# Counter 160
# Event Num 228
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Defensive Rebound
# Counter 161
# Event Num 229
# []
# Foul by 6ad10958a1d4920dccb1daec39bebd6b
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 162
# Event Num 231
# []
# Free Throw by 0a700ecf0eb76559949f1cb5b69a540b
# Missed free throw by 0a700ecf0eb76559949f1cb5b69a540b
# Counter 163
# Event Num 232
# []
# Rebound by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 164
# Event Num 233
# []
# Substitution by 41c0674725d4cddab004649e9db5a3ce
# 11beb0ae23e6425510297a31fa21881e  replacing  41c0674725d4cddab004649e9db5a3ce
# Counter 165
# Event Num 235
# []
# Free Throw by 0a700ecf0eb76559949f1cb5b69a540b
# Made final free throw by 0a700ecf0eb76559949f1cb5b69a540b
# Counter 166
# Event Num 236
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 167
# Event Num 238
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 168
# Event Num 239
# []
# Rebound by 7dfbb5980c066844384ba7424aceae47
# Defensive Rebound
# Counter 169
# Event Num 240
# []
# Made Shot by 7dfbb5980c066844384ba7424aceae47
# 7dfbb5980c066844384ba7424aceae47 scores 2 points
# Counter 170
# Event Num 242
# []
# Foul by f562f72f83b8e06b60ff184531b07056
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 171
# Event Num 244
# []
# Free Throw by 7dfbb5980c066844384ba7424aceae47
# Made final free throw by 7dfbb5980c066844384ba7424aceae47
# Counter 172
# Event Num 245
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 173
# Event Num 246
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Offensive Rebound
# Counter 174
# Event Num 247
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 2 points
# Counter 175
# Event Num 249
# []
# Missed Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b misses shot
# Counter 176
# Event Num 250
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Defensive Rebound
# Counter 177
# Event Num 251
# []
# Missed Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d misses shot
# Counter 178
# Event Num 252
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Offensive Rebound
# Counter 179
# Event Num 253
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 180
# Event Num 254
# []
# Foul by 2c447ab0a100cb50766552b0f6fadc2d
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 181
# Event Num 256
# []
# Substitution by 7dfbb5980c066844384ba7424aceae47
# ff52c317e26534ae1679da3c917e9fec  replacing  7dfbb5980c066844384ba7424aceae47
# Counter 182
# Event Num 258
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 183
# Event Num 259
# []
# Timeout by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 184
# Event Num 260
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 3 points
# Counter 185
# Event Num 262
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 186
# Event Num 264
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 187
# Event Num 265
# []
# Turnover by ff52c317e26534ae1679da3c917e9fec
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 188
# Event Num 267
# []
# Foul by 83c15c0962941640faab838a8f6f151d
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 189
# Event Num 269
# []
# Substitution by 83c15c0962941640faab838a8f6f151d
# 41c0674725d4cddab004649e9db5a3ce  replacing  83c15c0962941640faab838a8f6f151d
# Counter 190
# Event Num 271
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 191
# Event Num 272
# []
# Rebound by a3bac86ad549b2f128a62399d73d6299
# Defensive Rebound
# Counter 192
# Event Num 273
# []
# Missed Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e misses shot
# Counter 193
# Event Num 274
# []
# Rebound by a3bac86ad549b2f128a62399d73d6299
# Offensive Rebound
# Counter 194
# Event Num 275
# []
# Turnover by ff52c317e26534ae1679da3c917e9fec
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 195
# Event Num 276
# []
# Turnover by 2c447ab0a100cb50766552b0f6fadc2d
# 91ea9fc14670a54b9902eb062b416ccf turnover
# Counter 196
# Event Num 278
# []
# Foul by 2c447ab0a100cb50766552b0f6fadc2d
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 197
# Event Num 280
# []
# Instant Replay by e20ea50c69ea44842e0af9718fed5f0c
# Counter 198
# Event Num 281
# []
# Foul by 6ad10958a1d4920dccb1daec39bebd6b
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 199
# Event Num 282
# []
# Free Throw by 0a700ecf0eb76559949f1cb5b69a540b
# Made free throw by 0a700ecf0eb76559949f1cb5b69a540b
# Counter 200
# Event Num 283
# []
# Free Throw by 6ad10958a1d4920dccb1daec39bebd6b
# Made free throw by 6ad10958a1d4920dccb1daec39bebd6b
# Counter 201
# Event Num 284
# []
# Free Throw by 6ad10958a1d4920dccb1daec39bebd6b
# Made free throw by 6ad10958a1d4920dccb1daec39bebd6b
# Counter 202
# Event Num 285
# []
# Substitution by a3bac86ad549b2f128a62399d73d6299
# 7dfbb5980c066844384ba7424aceae47  replacing  a3bac86ad549b2f128a62399d73d6299
# Counter 203
# Event Num 287
# []
# Made Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b scores 2 points
# Counter 204
# Event Num 288
# []
# Foul by 41c0674725d4cddab004649e9db5a3ce
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 205
# Event Num 290
# []
# Free Throw by 0a700ecf0eb76559949f1cb5b69a540b
# Made free throw by 0a700ecf0eb76559949f1cb5b69a540b
# Counter 206
# Event Num 291
# []
# Substitution by 2c447ab0a100cb50766552b0f6fadc2d
# bbe5cb93ef483ea31d950f6c634837dc  replacing  2c447ab0a100cb50766552b0f6fadc2d
# Counter 207
# Event Num 293
# []
# Free Throw by 0a700ecf0eb76559949f1cb5b69a540b
# Made final free throw by 0a700ecf0eb76559949f1cb5b69a540b
# Counter 208
# Event Num 294
# []
# Foul by f562f72f83b8e06b60ff184531b07056
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 209
# Event Num 296
# []
# Free Throw by 41c0674725d4cddab004649e9db5a3ce
# Made free throw by 41c0674725d4cddab004649e9db5a3ce
# Counter 210
# Event Num 297
# []
# Substitution by 6ad10958a1d4920dccb1daec39bebd6b
# 90ba0d1de241290df2e124a5e02d68ef  replacing  6ad10958a1d4920dccb1daec39bebd6b
# Counter 211
# Event Num 298
# []
# Substitution by bbe5cb93ef483ea31d950f6c634837dc
# 2c447ab0a100cb50766552b0f6fadc2d  replacing  bbe5cb93ef483ea31d950f6c634837dc
# Counter 212
# Event Num 301
# []
# Free Throw by 41c0674725d4cddab004649e9db5a3ce
# Missed last free throw by 41c0674725d4cddab004649e9db5a3ce
# ftteam1 ['0a700ecf0eb76559949f1cb5b69a540b', 'f562f72f83b8e06b60ff184531b07056', '1c5bebebc83437eca5ef0aaf6eabb15a', '23fbda7c31efd6cfa21e3ab6c89d53f3', 'bbe5cb93ef483ea31d950f6c634837dc']
# Counter 213
# Event Num 302
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Defensive Rebound
# Counter 214
# Event Num 303
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 215
# Event Num 305
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 216
# Event Num 306
# []
# Rebound by 0a700ecf0eb76559949f1cb5b69a540b
# Defensive Rebound
# Counter 217
# Event Num 307
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 2 points
# Counter 218
# Event Num 309
# []
# Foul by 1c5bebebc83437eca5ef0aaf6eabb15a
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 219
# Event Num 311
# []
# Free Throw by 41c0674725d4cddab004649e9db5a3ce
# Made free throw by 41c0674725d4cddab004649e9db5a3ce
# Counter 220
# Event Num 312
# []
# Substitution by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 687b541bdc76b92b085fc1304f5c1bf1  replacing  23fbda7c31efd6cfa21e3ab6c89d53f3
# Counter 221
# Event Num 313
# []
# Substitution by 1c5bebebc83437eca5ef0aaf6eabb15a
# bcf50b1e35f187b7c5bc18090cdfb7f6  replacing  1c5bebebc83437eca5ef0aaf6eabb15a
# Counter 222
# Event Num 316
# []
# Free Throw by 41c0674725d4cddab004649e9db5a3ce
# Made final free throw by 41c0674725d4cddab004649e9db5a3ce
# Counter 223
# Event Num 317
# []
# Made Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 scores 2 points
# Counter 224
# Event Num 319
# []
# Made Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e scores 2 points
# Counter 225
# Event Num 321
# []
# Missed Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 misses shot
# Counter 226
# Event Num 322
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 227
# Event Num 324
# []
# Foul by 687b541bdc76b92b085fc1304f5c1bf1
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 228
# Event Num 327
# []
# Foul by 7dfbb5980c066844384ba7424aceae47
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 229
# Event Num 335
# []
# Instant Replay by 63ecace96228f09fcd4b07de08b8fc37
# Counter 230
# Event Num 329
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Missed shot possession fix
# Add off possession to  ['0a700ecf0eb76559949f1cb5b69a540b', 'f562f72f83b8e06b60ff184531b07056', '2c447ab0a100cb50766552b0f6fadc2d', '687b541bdc76b92b085fc1304f5c1bf1', 'bcf50b1e35f187b7c5bc18090cdfb7f6']
# Add def possession to  ['11beb0ae23e6425510297a31fa21881e', 'ff52c317e26534ae1679da3c917e9fec', '41c0674725d4cddab004649e9db5a3ce', '7dfbb5980c066844384ba7424aceae47', '90ba0d1de241290df2e124a5e02d68ef']
# Made free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 231
# Event Num 330
# []
# Substitution by f562f72f83b8e06b60ff184531b07056
# ce3ac26d43af7aa5555535cfed3f48cc  replacing  f562f72f83b8e06b60ff184531b07056
# Counter 232
# Event Num 332
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Missed last free throw by ff52c317e26534ae1679da3c917e9fec
# ftteam1 ['0a700ecf0eb76559949f1cb5b69a540b', 'f562f72f83b8e06b60ff184531b07056', '2c447ab0a100cb50766552b0f6fadc2d', '687b541bdc76b92b085fc1304f5c1bf1', 'bcf50b1e35f187b7c5bc18090cdfb7f6']
# Counter 233
# Event Num 333
# []
# Rebound by bcf50b1e35f187b7c5bc18090cdfb7f6
# Defensive Rebound
# Counter 234
# Event Num 334
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 2 ended
# Counter 235
# Event Num 346
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 3  lineup 0: ['7dfbb5980c066844384ba7424aceae47', 'ff52c317e26534ae1679da3c917e9fec', '11beb0ae23e6425510297a31fa21881e', '6ad10958a1d4920dccb1daec39bebd6b', '83c15c0962941640faab838a8f6f151d']
# 3  lineup 1: ['f562f72f83b8e06b60ff184531b07056', '23fbda7c31efd6cfa21e3ab6c89d53f3', '0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', '1c5bebebc83437eca5ef0aaf6eabb15a']
# Counter 236
# Event Num 347
# []
# Missed Shot by 7dfbb5980c066844384ba7424aceae47
# 7dfbb5980c066844384ba7424aceae47 misses shot
# Counter 237
# Event Num 348
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Defensive Rebound
# Counter 238
# Event Num 349
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 239
# Event Num 350
# []
# Foul by 11beb0ae23e6425510297a31fa21881e
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 240
# Event Num 352
# []
# Free Throw by 2c447ab0a100cb50766552b0f6fadc2d
# Missed last free throw by 2c447ab0a100cb50766552b0f6fadc2d
# ftteam1 ['f562f72f83b8e06b60ff184531b07056', '23fbda7c31efd6cfa21e3ab6c89d53f3', '0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', '1c5bebebc83437eca5ef0aaf6eabb15a']
# Counter 241
# Event Num 353
# []
# Rebound by 7dfbb5980c066844384ba7424aceae47
# Defensive Rebound
# Counter 242
# Event Num 354
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 243
# Event Num 355
# []
# Made Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b scores 2 points
# Counter 244
# Event Num 356
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 245
# Event Num 359
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 246
# Event Num 360
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Defensive Rebound
# Counter 247
# Event Num 361
# []
# Foul by 2c447ab0a100cb50766552b0f6fadc2d
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 248
# Event Num 363
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 249
# Event Num 364
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made final free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 250
# Event Num 365
# []
# Missed Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d misses shot
# Counter 251
# Event Num 366
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 252
# Event Num 367
# []
# Missed Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b misses shot
# Counter 253
# Event Num 368
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Defensive Rebound
# Counter 254
# Event Num 369
# []
# Jump Ball by 6ad10958a1d4920dccb1daec39bebd6b
# Counter 255
# Event Num 372
# []
# Turnover by f562f72f83b8e06b60ff184531b07056
# 91ea9fc14670a54b9902eb062b416ccf turnover
# Counter 256
# Event Num 374
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 257
# Event Num 376
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 258
# Event Num 377
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 259
# Event Num 378
# []
# Foul by 1c5bebebc83437eca5ef0aaf6eabb15a
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 260
# Event Num 380
# []
# Foul by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 261
# Event Num 382
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Missed shot possession fix
# Add off possession to  ['f562f72f83b8e06b60ff184531b07056', '23fbda7c31efd6cfa21e3ab6c89d53f3', '0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', '1c5bebebc83437eca5ef0aaf6eabb15a']
# Add def possession to  ['7dfbb5980c066844384ba7424aceae47', 'ff52c317e26534ae1679da3c917e9fec', '11beb0ae23e6425510297a31fa21881e', '6ad10958a1d4920dccb1daec39bebd6b', '83c15c0962941640faab838a8f6f151d']
# Made free throw by 83c15c0962941640faab838a8f6f151d
# Counter 262
# Event Num 383
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 263
# Event Num 384
# []
# Made Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b scores 2 points
# Counter 264
# Event Num 385
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 3 points
# Counter 265
# Event Num 387
# []
# Timeout by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 266
# Event Num 388
# []
# Turnover by f562f72f83b8e06b60ff184531b07056
# 91ea9fc14670a54b9902eb062b416ccf turnover
# Counter 267
# Event Num 390
# []
# Missed Shot by 7dfbb5980c066844384ba7424aceae47
# 7dfbb5980c066844384ba7424aceae47 misses shot
# Counter 268
# Event Num 391
# []
# Rebound by 0a700ecf0eb76559949f1cb5b69a540b
# Defensive Rebound
# Counter 269
# Event Num 392
# []
# Missed Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 misses shot
# Counter 270
# Event Num 393
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Offensive Rebound
# Counter 271
# Event Num 394
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 272
# Event Num 395
# []
# Missed Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e misses shot
# Counter 273
# Event Num 396
# []
# Rebound by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Defensive Rebound
# Counter 274
# Event Num 397
# []
# Missed Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d misses shot
# Counter 275
# Event Num 398
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 276
# Event Num 399
# []
# Made Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e scores 2 points
# Counter 277
# Event Num 401
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 278
# Event Num 402
# []
# Rebound by 7dfbb5980c066844384ba7424aceae47
# Defensive Rebound
# Counter 279
# Event Num 403
# []
# Made Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e scores 3 points
# Counter 280
# Event Num 404
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 3 points
# Counter 281
# Event Num 406
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 282
# Event Num 408
# []
# Foul by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 283
# Event Num 410
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 284
# Event Num 411
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 285
# Event Num 412
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 286
# Event Num 413
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 287
# Event Num 414
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 288
# Event Num 415
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Defensive Rebound
# Counter 289
# Event Num 416
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 290
# Event Num 417
# []
# Rebound by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Defensive Rebound
# Counter 291
# Event Num 418
# []
# Foul by ff52c317e26534ae1679da3c917e9fec
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 292
# Event Num 420
# []
# Substitution by 7dfbb5980c066844384ba7424aceae47
# a3bac86ad549b2f128a62399d73d6299  replacing  7dfbb5980c066844384ba7424aceae47
# Counter 293
# Event Num 421
# []
# Substitution by 6ad10958a1d4920dccb1daec39bebd6b
# 90ba0d1de241290df2e124a5e02d68ef  replacing  6ad10958a1d4920dccb1daec39bebd6b
# Counter 294
# Event Num 422
# []
# Substitution by f562f72f83b8e06b60ff184531b07056
# ce3ac26d43af7aa5555535cfed3f48cc  replacing  f562f72f83b8e06b60ff184531b07056
# Counter 295
# Event Num 426
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 296
# Event Num 427
# []
# Foul by 90ba0d1de241290df2e124a5e02d68ef
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 297
# Event Num 429
# []
# Free Throw by 2c447ab0a100cb50766552b0f6fadc2d
# Made final free throw by 2c447ab0a100cb50766552b0f6fadc2d
# Counter 298
# Event Num 430
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 299
# Event Num 432
# []
# Foul by 90ba0d1de241290df2e124a5e02d68ef
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 300
# Event Num 434
# []
# Substitution by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 687b541bdc76b92b085fc1304f5c1bf1  replacing  23fbda7c31efd6cfa21e3ab6c89d53f3
# Counter 301
# Event Num 435
# []
# Substitution by 1c5bebebc83437eca5ef0aaf6eabb15a
# bcf50b1e35f187b7c5bc18090cdfb7f6  replacing  1c5bebebc83437eca5ef0aaf6eabb15a
# Counter 302
# Event Num 438
# []
# Missed Shot by 687b541bdc76b92b085fc1304f5c1bf1
# 687b541bdc76b92b085fc1304f5c1bf1 misses shot
# Counter 303
# Event Num 439
# []
# Rebound by ff52c317e26534ae1679da3c917e9fec
# Defensive Rebound
# Counter 304
# Event Num 440
# []
# Foul by 687b541bdc76b92b085fc1304f5c1bf1
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 305
# Event Num 442
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made free throw by 83c15c0962941640faab838a8f6f151d
# Counter 306
# Event Num 443
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Missed last free throw by 83c15c0962941640faab838a8f6f151d
# ftteam1 ['0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', 'ce3ac26d43af7aa5555535cfed3f48cc', '687b541bdc76b92b085fc1304f5c1bf1', 'bcf50b1e35f187b7c5bc18090cdfb7f6']
# Counter 307
# Event Num 444
# []
# Rebound by 687b541bdc76b92b085fc1304f5c1bf1
# Defensive Rebound
# Counter 308
# Event Num 445
# []
# Missed Shot by 687b541bdc76b92b085fc1304f5c1bf1
# 687b541bdc76b92b085fc1304f5c1bf1 misses shot
# Counter 309
# Event Num 447
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 310
# Event Num 448
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 3 points
# Counter 311
# Event Num 450
# []
# Timeout by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 312
# Event Num 451
# []
# Substitution by 11beb0ae23e6425510297a31fa21881e
# 41c0674725d4cddab004649e9db5a3ce  replacing  11beb0ae23e6425510297a31fa21881e
# Counter 313
# Event Num 453
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 314
# Event Num 454
# []
# Rebound by a3bac86ad549b2f128a62399d73d6299
# Defensive Rebound
# Counter 315
# Event Num 455
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 316
# Event Num 456
# []
# Rebound by 2c447ab0a100cb50766552b0f6fadc2d
# Defensive Rebound
# Counter 317
# Event Num 457
# []
# Made Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b scores 3 points
# Counter 318
# Event Num 459
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 319
# Event Num 460
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Offensive Rebound
# Counter 320
# Event Num 461
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 321
# Event Num 462
# []
# Made Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b scores 2 points
# Counter 322
# Event Num 463
# []
# Foul by ce3ac26d43af7aa5555535cfed3f48cc
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 323
# Event Num 465
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 324
# Event Num 466
# []
# Substitution by ce3ac26d43af7aa5555535cfed3f48cc
# bbe5cb93ef483ea31d950f6c634837dc  replacing  ce3ac26d43af7aa5555535cfed3f48cc
# Counter 325
# Event Num 468
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made final free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 326
# Event Num 469
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 327
# Event Num 470
# []
# Foul by 41c0674725d4cddab004649e9db5a3ce
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 328
# Event Num 472
# []
# Substitution by ff52c317e26534ae1679da3c917e9fec
# 7dfbb5980c066844384ba7424aceae47  replacing  ff52c317e26534ae1679da3c917e9fec
# Counter 329
# Event Num 474
# []
# Free Throw by 2c447ab0a100cb50766552b0f6fadc2d
# Made final free throw by 2c447ab0a100cb50766552b0f6fadc2d
# Counter 330
# Event Num 475
# []
# Made Shot by 7dfbb5980c066844384ba7424aceae47
# 7dfbb5980c066844384ba7424aceae47 scores 2 points
# Counter 331
# Event Num 476
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 332
# Event Num 477
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 333
# Event Num 479
# []
# Made Shot by bbe5cb93ef483ea31d950f6c634837dc
# bbe5cb93ef483ea31d950f6c634837dc scores 3 points
# Counter 334
# Event Num 481
# []
# Made Shot by 41c0674725d4cddab004649e9db5a3ce
# 41c0674725d4cddab004649e9db5a3ce scores 3 points
# Counter 335
# Event Num 483
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 336
# Event Num 484
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Defensive Rebound
# Counter 337
# Event Num 486
# []
# Foul by bcf50b1e35f187b7c5bc18090cdfb7f6
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 338
# Event Num 488
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made free throw by 83c15c0962941640faab838a8f6f151d
# Counter 339
# Event Num 489
# []
# Substitution by bcf50b1e35f187b7c5bc18090cdfb7f6
# 1c5bebebc83437eca5ef0aaf6eabb15a  replacing  bcf50b1e35f187b7c5bc18090cdfb7f6
# Counter 340
# Event Num 490
# []
# Substitution by 687b541bdc76b92b085fc1304f5c1bf1
# 23fbda7c31efd6cfa21e3ab6c89d53f3  replacing  687b541bdc76b92b085fc1304f5c1bf1
# Counter 341
# Event Num 493
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 342
# Event Num 494
# []
# Foul by 90ba0d1de241290df2e124a5e02d68ef
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 343
# Event Num 496
# []
# Free Throw by 2c447ab0a100cb50766552b0f6fadc2d
# Made free throw by 2c447ab0a100cb50766552b0f6fadc2d
# Counter 344
# Event Num 497
# []
# Substitution by 90ba0d1de241290df2e124a5e02d68ef
# 6ad10958a1d4920dccb1daec39bebd6b  replacing  90ba0d1de241290df2e124a5e02d68ef
# Counter 345
# Event Num 499
# []
# Free Throw by 2c447ab0a100cb50766552b0f6fadc2d
# Made final free throw by 2c447ab0a100cb50766552b0f6fadc2d
# Counter 346
# Event Num 500
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 347
# Event Num 501
# []
# Jump Ball by 83c15c0962941640faab838a8f6f151d
# Counter 348
# Event Num 504
# []
# Missed Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b misses shot
# Counter 349
# Event Num 505
# []
# Rebound by 41c0674725d4cddab004649e9db5a3ce
# Offensive Rebound
# Counter 350
# Event Num 506
# []
# Missed Shot by 7dfbb5980c066844384ba7424aceae47
# 7dfbb5980c066844384ba7424aceae47 misses shot
# Counter 351
# Event Num 508
# []
# Rebound by bbe5cb93ef483ea31d950f6c634837dc
# Defensive Rebound
# Counter 352
# Event Num 509
# []
# Turnover by bbe5cb93ef483ea31d950f6c634837dc
# 91ea9fc14670a54b9902eb062b416ccf turnover
# Counter 353
# Event Num 511
# []
# Missed Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b misses shot
# Counter 354
# Event Num 512
# []
# Rebound by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 355
# Event Num 515
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# Missed shot possession fix
# Add off possession to  ['83c15c0962941640faab838a8f6f151d', 'a3bac86ad549b2f128a62399d73d6299', '41c0674725d4cddab004649e9db5a3ce', '7dfbb5980c066844384ba7424aceae47', '6ad10958a1d4920dccb1daec39bebd6b']
# Add def possession to  ['0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', 'bbe5cb93ef483ea31d950f6c634837dc', '1c5bebebc83437eca5ef0aaf6eabb15a', '23fbda7c31efd6cfa21e3ab6c89d53f3']
# 3 ended
# Counter 356
# Event Num 522
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 4  lineup 0: ['7dfbb5980c066844384ba7424aceae47', 'ff52c317e26534ae1679da3c917e9fec', '11beb0ae23e6425510297a31fa21881e', '6ad10958a1d4920dccb1daec39bebd6b', '41c0674725d4cddab004649e9db5a3ce']
# 4  lineup 1: ['f562f72f83b8e06b60ff184531b07056', '23fbda7c31efd6cfa21e3ab6c89d53f3', '0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', '1c5bebebc83437eca5ef0aaf6eabb15a']
# Counter 357
# Event Num 523
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 358
# Event Num 524
# []
# Missed Shot by 11beb0ae23e6425510297a31fa21881e
# 11beb0ae23e6425510297a31fa21881e misses shot
# Counter 359
# Event Num 525
# []
# Rebound by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Defensive Rebound
# Counter 360
# Event Num 526
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 3 points
# Counter 361
# Event Num 528
# []
# Made Shot by 6ad10958a1d4920dccb1daec39bebd6b
# 6ad10958a1d4920dccb1daec39bebd6b scores 2 points
# Counter 362
# Event Num 530
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 363
# Event Num 532
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 364
# Event Num 533
# []
# Made Shot by f562f72f83b8e06b60ff184531b07056
# f562f72f83b8e06b60ff184531b07056 scores 2 points
# Counter 365
# Event Num 535
# []
# Turnover by 41c0674725d4cddab004649e9db5a3ce
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 366
# Event Num 537
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 367
# Event Num 539
# []
# Timeout by 9811289f96c7deb95f04148c206e0b3a
# Counter 368
# Event Num 540
# []
# Substitution by 41c0674725d4cddab004649e9db5a3ce
# 83c15c0962941640faab838a8f6f151d  replacing  41c0674725d4cddab004649e9db5a3ce
# Counter 369
# Event Num 542
# []
# Missed Shot by 7dfbb5980c066844384ba7424aceae47
# 7dfbb5980c066844384ba7424aceae47 misses shot
# Counter 370
# Event Num 543
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Offensive Rebound
# Counter 371
# Event Num 544
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 372
# Event Num 545
# []
# Rebound by 0a700ecf0eb76559949f1cb5b69a540b
# Defensive Rebound
# Counter 373
# Event Num 546
# []
# Missed Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a misses shot
# Counter 374
# Event Num 548
# []
# Rebound by 1c5bebebc83437eca5ef0aaf6eabb15a
# Offensive Rebound
# Counter 375
# Event Num 549
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 2 points
# Counter 376
# Event Num 550
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 377
# Event Num 551
# []
# Rebound by f562f72f83b8e06b60ff184531b07056
# Defensive Rebound
# Counter 378
# Event Num 552
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 379
# Event Num 553
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 380
# Event Num 554
# []
# Foul by 11beb0ae23e6425510297a31fa21881e
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 381
# Event Num 556
# []
# Substitution by 7dfbb5980c066844384ba7424aceae47
# a3bac86ad549b2f128a62399d73d6299  replacing  7dfbb5980c066844384ba7424aceae47
# Counter 382
# Event Num 558
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 383
# Event Num 559
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 384
# Event Num 560
# []
# Foul by 83c15c0962941640faab838a8f6f151d
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 385
# Event Num 562
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 386
# Event Num 563
# []
# Rebound by ff52c317e26534ae1679da3c917e9fec
# Defensive Rebound
# Counter 387
# Event Num 564
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 388
# Event Num 565
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Offensive Rebound
# Counter 389
# Event Num 566
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 390
# Event Num 567
# []
# Timeout by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 391
# Event Num 568
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 3 points
# Counter 392
# Event Num 570
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 393
# Event Num 571
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 394
# Event Num 572
# []
# Missed Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a misses shot
# Counter 395
# Event Num 574
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Defensive Rebound
# Counter 396
# Event Num 575
# []
# Turnover by ff52c317e26534ae1679da3c917e9fec
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 397
# Event Num 577
# []
# Missed Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b misses shot
# Counter 398
# Event Num 578
# []
# Rebound by a3bac86ad549b2f128a62399d73d6299
# Defensive Rebound
# Counter 399
# Event Num 579
# []
# Turnover by 11beb0ae23e6425510297a31fa21881e
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 400
# Event Num 581
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 401
# Event Num 582
# []
# Turnover by ff52c317e26534ae1679da3c917e9fec
# b5464c11e1a8a18452a7d2988badfe0c turnover
# Counter 402
# Event Num 584
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 2 points
# Counter 403
# Event Num 585
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 404
# Event Num 587
# []
# Foul by 0a700ecf0eb76559949f1cb5b69a540b
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 405
# Event Num 589
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 406
# Event Num 590
# []
# Made Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a scores 2 points
# Counter 407
# Event Num 591
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 3 points
# Counter 408
# Event Num 593
# []
# Made Shot by 0a700ecf0eb76559949f1cb5b69a540b
# 0a700ecf0eb76559949f1cb5b69a540b scores 2 points
# Counter 409
# Event Num 594
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 410
# Event Num 595
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 411
# Event Num 596
# []
# Foul by f562f72f83b8e06b60ff184531b07056
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 412
# Event Num 598
# []
# Substitution by a3bac86ad549b2f128a62399d73d6299
# 7dfbb5980c066844384ba7424aceae47  replacing  a3bac86ad549b2f128a62399d73d6299
# Counter 413
# Event Num 600
# []
# Foul by 23fbda7c31efd6cfa21e3ab6c89d53f3
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 414
# Event Num 603
# []
# Foul by f562f72f83b8e06b60ff184531b07056
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 415
# Event Num 605
# []
# Free Throw by 11beb0ae23e6425510297a31fa21881e
# Missed shot possession fix
# Add off possession to subbed players ['a3bac86ad549b2f128a62399d73d6299']
# Add def possession to subbed players []
# Was offensive rebound, don't do anything for on court players
# Missed free throw by 11beb0ae23e6425510297a31fa21881e
# Counter 416
# Event Num 606
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 417
# Event Num 607
# []
# Free Throw by 11beb0ae23e6425510297a31fa21881e
# Made final free throw by 11beb0ae23e6425510297a31fa21881e
# Counter 418
# Event Num 608
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 419
# Event Num 609
# []
# Missed Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec misses shot
# Counter 420
# Event Num 610
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Offensive Rebound
# Counter 421
# Event Num 611
# []
# Made Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d scores 2 points
# Counter 422
# Event Num 612
# []
# Foul by 7dfbb5980c066844384ba7424aceae47
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 423
# Event Num 614
# []
# Free Throw by f562f72f83b8e06b60ff184531b07056
# Made free throw by f562f72f83b8e06b60ff184531b07056
# Counter 424
# Event Num 615
# []
# Timeout by 9811289f96c7deb95f04148c206e0b3a
# Counter 425
# Event Num 616
# []
# Free Throw by f562f72f83b8e06b60ff184531b07056
# Made final free throw by f562f72f83b8e06b60ff184531b07056
# Counter 426
# Event Num 617
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 3 points
# Counter 427
# Event Num 619
# []
# Foul by 6ad10958a1d4920dccb1daec39bebd6b
# Foul on team b5464c11e1a8a18452a7d2988badfe0c
# Counter 428
# Event Num 621
# []
# Missed Shot by 1c5bebebc83437eca5ef0aaf6eabb15a
# 1c5bebebc83437eca5ef0aaf6eabb15a misses shot
# Counter 429
# Event Num 622
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 430
# Event Num 623
# []
# Foul by 1c5bebebc83437eca5ef0aaf6eabb15a
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 431
# Event Num 625
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Missed shot possession fix
# Add off possession to  ['f562f72f83b8e06b60ff184531b07056', '23fbda7c31efd6cfa21e3ab6c89d53f3', '0a700ecf0eb76559949f1cb5b69a540b', '2c447ab0a100cb50766552b0f6fadc2d', '1c5bebebc83437eca5ef0aaf6eabb15a']
# Add def possession to  ['ff52c317e26534ae1679da3c917e9fec', '11beb0ae23e6425510297a31fa21881e', '6ad10958a1d4920dccb1daec39bebd6b', '83c15c0962941640faab838a8f6f151d', '7dfbb5980c066844384ba7424aceae47']
# Made free throw by 83c15c0962941640faab838a8f6f151d
# Counter 432
# Event Num 626
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 433
# Event Num 627
# []
# Missed Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d misses shot
# Counter 434
# Event Num 628
# []
# Rebound by 83c15c0962941640faab838a8f6f151d
# Defensive Rebound
# Counter 435
# Event Num 629
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 436
# Event Num 630
# []
# Rebound by 0a700ecf0eb76559949f1cb5b69a540b
# Defensive Rebound
# Counter 437
# Event Num 631
# []
# Made Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 scores 2 points
# Counter 438
# Event Num 632
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 439
# Event Num 634
# []
# Rebound by ff52c317e26534ae1679da3c917e9fec
# Offensive Rebound
# Counter 440
# Event Num 635
# []
# Missed Shot by 83c15c0962941640faab838a8f6f151d
# 83c15c0962941640faab838a8f6f151d misses shot
# Counter 441
# Event Num 636
# []
# Rebound by 2c447ab0a100cb50766552b0f6fadc2d
# Defensive Rebound
# Counter 442
# Event Num 637
# []
# Turnover by 2c447ab0a100cb50766552b0f6fadc2d
# 91ea9fc14670a54b9902eb062b416ccf turnover
# Counter 443
# Event Num 638
# []
# Instant Replay by a3801b904a10b622331b97394eebcb4e
# Counter 444
# Event Num 639
# []
# Foul by 1c5bebebc83437eca5ef0aaf6eabb15a
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 445
# Event Num 641
# []
# Substitution by 1c5bebebc83437eca5ef0aaf6eabb15a
# 687b541bdc76b92b085fc1304f5c1bf1  replacing  1c5bebebc83437eca5ef0aaf6eabb15a
# Counter 446
# Event Num 643
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Missed free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 447
# Event Num 644
# []
# Rebound by 9811289f96c7deb95f04148c206e0b3a
# Counter 448
# Event Num 645
# []
# Free Throw by ff52c317e26534ae1679da3c917e9fec
# Made final free throw by ff52c317e26534ae1679da3c917e9fec
# Counter 449
# Event Num 646
# []
# Made Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d scores 2 points
# Counter 450
# Event Num 648
# []
# Substitution by 687b541bdc76b92b085fc1304f5c1bf1
# ce3ac26d43af7aa5555535cfed3f48cc  replacing  687b541bdc76b92b085fc1304f5c1bf1
# Counter 451
# Event Num 650
# []
# Instant Replay by b005e593a20bcdd4b1d04021af9accff
# Counter 452
# Event Num 651
# []
# Made Shot by ff52c317e26534ae1679da3c917e9fec
# ff52c317e26534ae1679da3c917e9fec scores 2 points
# Counter 453
# Event Num 652
# []
# Timeout by e9ed8a6685a60e2416cd81bf874cffb1
# Counter 454
# Event Num 653
# []
# Substitution by ce3ac26d43af7aa5555535cfed3f48cc
# 687b541bdc76b92b085fc1304f5c1bf1  replacing  ce3ac26d43af7aa5555535cfed3f48cc
# Counter 455
# Event Num 655
# []
# Missed Shot by 23fbda7c31efd6cfa21e3ab6c89d53f3
# 23fbda7c31efd6cfa21e3ab6c89d53f3 misses shot
# Counter 456
# Event Num 657
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 457
# Event Num 658
# []
# Foul by 2c447ab0a100cb50766552b0f6fadc2d
# Foul on team 91ea9fc14670a54b9902eb062b416ccf
# Counter 458
# Event Num 660
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made free throw by 83c15c0962941640faab838a8f6f151d
# Counter 459
# Event Num 661
# []
# Substitution by 687b541bdc76b92b085fc1304f5c1bf1
# ce3ac26d43af7aa5555535cfed3f48cc  replacing  687b541bdc76b92b085fc1304f5c1bf1
# Counter 460
# Event Num 663
# []
# Free Throw by 83c15c0962941640faab838a8f6f151d
# Made final free throw by 83c15c0962941640faab838a8f6f151d
# Counter 461
# Event Num 664
# []
# Missed Shot by 2c447ab0a100cb50766552b0f6fadc2d
# 2c447ab0a100cb50766552b0f6fadc2d misses shot
# Counter 462
# Event Num 665
# []
# Rebound by 11beb0ae23e6425510297a31fa21881e
# Defensive Rebound
# Counter 463
# Event Num 666
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 4 ended
# Counter 464
# Event Num 0
# []
# Final Box Printed by 0370a0d090da0d0edc6319f120187e0e

# %%
gameDict
# Out:
# {'0b978fcfa7f2ec839c563a755e345ff8': array([8, 4, 6, 5]),
#  '14de632b07100527b0ced12fd4eeffb7': array([0, 0, 0, 0]),
#  '18a823379f2bf4e4be8b419698cde91c': array([0, 0, 0, 0]),
#  '1a6703883f8f47bb4daf09c03be3bda2': array([26, 21, 20, 20]),
#  '1dabb767e07d0aa702ee58d41c15eab1': array([12, 10,  9,  9]),
#  '255fe2a8be0ed5c06dd99969ab4fea55': array([0, 0, 0, 0]),
#  '31598ba01a3fff03ed0a87d7dea11dfe': array([13,  5,  9,  9]),
#  '32c044aa84d75ccd78c3c9f2aeb33bd9': array([2, 5, 4, 5]),
#  '3626b893fc73a5cbd67d1ea48a5c7039': array([34, 25, 24, 24]),
#  '36fdadf436b164ee29174c8e1fde7271': array([12, 10,  9,  9]),
#  '3d75035d20b173a867d4bf32c8a58f0b': array([12, 12, 11, 10]),
#  '52c6125836c465f4ac5232121dacb49d': array([8, 4, 6, 5]),
#  '619d3e44dc84b366bd685de3e94b3bec': array([0, 0, 0, 0]),
#  '6f6a807d57aae8f651222523dc82dc35': array([0, 0, 0, 0]),
#  '722a380c9b59ef42226e8d392824dcb9': array([13, 24, 16, 16]),
#  '7f438c18058290903c46dfe9d71bd68a': array([23, 29, 20, 20]),
#  '821887f9a002be16b5f79729fae59e01': array([0, 0, 0, 0]),
#  '8c7a7249d80b1489594b3a2a87f3f19d': array([0, 0, 0, 0]),
#  '942a84f05f4ab956125f68ec0963481f': array([0, 0, 1, 1]),
#  '94e99d76e87ee926faab66d382b3a955': array([0, 0, 0, 0]),
#  '95920e4bf5b6c15ba8dffbf959b38ba5': array([25, 34, 24, 25]),
#  'a1591595c04d12e88e3cb427fb667618': array([26, 21, 19, 19]),
#  'bfef77a3e57907855444410d490e7bfd': array([22, 13, 15, 14]),
#  'c950aaad2e56c87e9ac7281016d37cb6': array([0, 0, 0, 0]),
#  'e49b2cc3f9aacd500b11a35b1c57112d': array([0, 0, 0, 0]),
#  'ef8b068ab7ac9d387b256404acd24cd5': array([13, 24, 16, 16]),
#  'f3d6e924c2736c9e5771b0784e31c2df': array([0, 0, 0, 0]),
#  'fb64ca4b8beaf4c4c6e4575fe2f3abd7': array([25, 34, 24, 24]),
#  'fbcda0bcb861e4726ca8871b8965ede4': array([0, 0, 0, 0]),
#  'ff59dc439c6c323320bc355afe884fcb': array([21, 20, 16, 16])}

# %%
rdPBP = readablePlayByPlay(gamePlayByPlay, gameLineup, eventCodes)
# Out:
# Team0 b5464c11e1a8a18452a7d2988badfe0c
# Team1 91ea9fc14670a54b9902eb062b416ccf

# %%
rdPBP[235:356]
# Out:
#                                 Game_id  Event_Num Event_Msg_Type  Period  \
# 25475  bb4e1b593cc210dec5fdcb0f7eb4739d        346   Start Period       3
# 25476  bb4e1b593cc210dec5fdcb0f7eb4739d        347    Missed Shot       3
# 25477  bb4e1b593cc210dec5fdcb0f7eb4739d        348        Rebound       3
# 25478  bb4e1b593cc210dec5fdcb0f7eb4739d        349      Made Shot       3
# 25479  bb4e1b593cc210dec5fdcb0f7eb4739d        350           Foul       3
# 25480  bb4e1b593cc210dec5fdcb0f7eb4739d        352     Free Throw       3
# 25481  bb4e1b593cc210dec5fdcb0f7eb4739d        353        Rebound       3
# 25482  bb4e1b593cc210dec5fdcb0f7eb4739d        354      Made Shot       3
# 25483  bb4e1b593cc210dec5fdcb0f7eb4739d        355      Made Shot       3
# 25484  bb4e1b593cc210dec5fdcb0f7eb4739d        356      Made Shot       3
# 25485  bb4e1b593cc210dec5fdcb0f7eb4739d        359    Missed Shot       3
# 25486  bb4e1b593cc210dec5fdcb0f7eb4739d        360        Rebound       3
# 25487  bb4e1b593cc210dec5fdcb0f7eb4739d        361           Foul       3
# 25488  bb4e1b593cc210dec5fdcb0f7eb4739d        363     Free Throw       3
# 25489  bb4e1b593cc210dec5fdcb0f7eb4739d        364     Free Throw       3
# 25490  bb4e1b593cc210dec5fdcb0f7eb4739d        365    Missed Shot       3
# 25491  bb4e1b593cc210dec5fdcb0f7eb4739d        366        Rebound       3
# 25492  bb4e1b593cc210dec5fdcb0f7eb4739d        367    Missed Shot       3
# 25493  bb4e1b593cc210dec5fdcb0f7eb4739d        368        Rebound       3
# 25495  bb4e1b593cc210dec5fdcb0f7eb4739d        369      Jump Ball       3
# 25494  bb4e1b593cc210dec5fdcb0f7eb4739d        372       Turnover       3
# 25496  bb4e1b593cc210dec5fdcb0f7eb4739d        374      Made Shot       3
# 25497  bb4e1b593cc210dec5fdcb0f7eb4739d        376    Missed Shot       3
# 25498  bb4e1b593cc210dec5fdcb0f7eb4739d        377        Rebound       3
# 25499  bb4e1b593cc210dec5fdcb0f7eb4739d        378           Foul       3
# 25500  bb4e1b593cc210dec5fdcb0f7eb4739d        380           Foul       3
# 25501  bb4e1b593cc210dec5fdcb0f7eb4739d        382     Free Throw       3
# 25502  bb4e1b593cc210dec5fdcb0f7eb4739d        383     Free Throw       3
# 25503  bb4e1b593cc210dec5fdcb0f7eb4739d        384      Made Shot       3
# 25504  bb4e1b593cc210dec5fdcb0f7eb4739d        385      Made Shot       3
# ...                                 ...        ...            ...     ...
# 25566  bb4e1b593cc210dec5fdcb0f7eb4739d        469      Made Shot       3
# 25567  bb4e1b593cc210dec5fdcb0f7eb4739d        470           Foul       3
# 25568  bb4e1b593cc210dec5fdcb0f7eb4739d        472   Substitution       3
# 25569  bb4e1b593cc210dec5fdcb0f7eb4739d        474     Free Throw       3
# 25570  bb4e1b593cc210dec5fdcb0f7eb4739d        475      Made Shot       3
# 25571  bb4e1b593cc210dec5fdcb0f7eb4739d        476      Made Shot       3
# 25572  bb4e1b593cc210dec5fdcb0f7eb4739d        477      Made Shot       3
# 25573  bb4e1b593cc210dec5fdcb0f7eb4739d        479      Made Shot       3
# 25574  bb4e1b593cc210dec5fdcb0f7eb4739d        481      Made Shot       3
# 25575  bb4e1b593cc210dec5fdcb0f7eb4739d        483    Missed Shot       3
# 25576  bb4e1b593cc210dec5fdcb0f7eb4739d        484        Rebound       3
# 25577  bb4e1b593cc210dec5fdcb0f7eb4739d        486           Foul       3
# 25578  bb4e1b593cc210dec5fdcb0f7eb4739d        488     Free Throw       3
# 25580  bb4e1b593cc210dec5fdcb0f7eb4739d        489   Substitution       3
# 25579  bb4e1b593cc210dec5fdcb0f7eb4739d        490   Substitution       3
# 25581  bb4e1b593cc210dec5fdcb0f7eb4739d        493     Free Throw       3
# 25582  bb4e1b593cc210dec5fdcb0f7eb4739d        494           Foul       3
# 25583  bb4e1b593cc210dec5fdcb0f7eb4739d        496     Free Throw       3
# 25584  bb4e1b593cc210dec5fdcb0f7eb4739d        497   Substitution       3
# 25585  bb4e1b593cc210dec5fdcb0f7eb4739d        499     Free Throw       3
# 25586  bb4e1b593cc210dec5fdcb0f7eb4739d        500       Stoppage       3
# 25587  bb4e1b593cc210dec5fdcb0f7eb4739d        501      Jump Ball       3
# 25588  bb4e1b593cc210dec5fdcb0f7eb4739d        504    Missed Shot       3
# 25589  bb4e1b593cc210dec5fdcb0f7eb4739d        505        Rebound       3
# 25590  bb4e1b593cc210dec5fdcb0f7eb4739d        506    Missed Shot       3
# 25591  bb4e1b593cc210dec5fdcb0f7eb4739d        508        Rebound       3
# 25592  bb4e1b593cc210dec5fdcb0f7eb4739d        509       Turnover       3
# 25593  bb4e1b593cc210dec5fdcb0f7eb4739d        511    Missed Shot       3
# 25594  bb4e1b593cc210dec5fdcb0f7eb4739d        512        Rebound       3
# 25595  bb4e1b593cc210dec5fdcb0f7eb4739d        515     End Period       3
#
#        WC_Time  PC_Time                 Action_Type  Option1  Option2  \
# 25475   525230     7200                                    0        0
# 25476   525400     7020  Driving Reverse Layup Shot        2        0
# 25477   525430     7000                     Unknown        0        0
# 25478   525630     6840          Floating Jump shot        2        0
# 25479   525680     6840                    Shooting        0        0
# 25480   525970     6840           Free Throw 1 of 1        2        0
# 25481   525980     6790                     Unknown        0        0
# 25482   526060     6710          Reverse Layup Shot        2        0
# 25483   526260     6500          Driving Layup Shot        2        0
# 25484   526320     6440                  Layup Shot        2        0
# 25485   526560     6210                   Jump Shot        3        0
# 25486   526610     6160                     Unknown        0        0
# 25487   526710     6090                    Shooting        0        0
# 25488   526880     6090           Free Throw 1 of 2        1        0
# 25489   527040     6090           Free Throw 2 of 2        1        0
# 25490   527300     5860                   Jump Shot        3        0
# 25491   527330     5810                     Unknown        0        0
# 25492   527380     5770                   Jump Shot        3        1
# 25493   527420     5740                     Unknown        0        0
# 25495   527900     5620                                    0        0
# 25494   527900     5620                   Lost Ball        1        0
# 25496   527940     5570                  Layup Shot        2        0
# 25497   528060     5450                   Jump Shot        3        0
# 25498   528150     5430                     Unknown        0        0
# 25499   528160     5430                  Loose Ball        0        0
# 25500   528530     5240                    Shooting        0        0
# 25501   528750     5240           Free Throw 1 of 2        1        0
# 25502   528880     5240           Free Throw 2 of 2        1        0
# 25503   529030     5120  Driving Reverse Layup Shot        2        0
# 25504   529170     4970                   Jump Shot        3        0
# ...        ...      ...                         ...      ...      ...
# 25566   539570     1390                   Jump Shot        2        0
# 25567   539640     1390                    Shooting        1        0
# 25568   539730     1390                                    0        0
# 25569   539880     1390           Free Throw 1 of 1        1        0
# 25570   540020     1260          Driving Layup Shot        2        0
# 25571   540100     1180          Driving Layup Shot        2        0
# 25572   540220     1070                   Jump Shot        2        0
# 25573   540380      900                   Jump Shot        3        0
# 25574   540570      720                   Jump Shot        3        0
# 25575   540710      594          Reverse Layup Shot        2        0
# 25576   540740      594                     Unknown        0        0
# 25577   540830      594                    Personal        1        0
# 25578   541050      594           Free Throw 1 of 2        1        0
# 25580   541110      594                                    0        0
# 25579   541110      594                                    0        0
# 25581   541370      594           Free Throw 2 of 2        1        0
# 25582   541510      531                    Personal        1        0
# 25583   541790      531           Free Throw 1 of 2        1        0
# 25584   541810      531                                    0        0
# 25585   542000      531           Free Throw 2 of 2        1        0
# 25586   542160      418               Out-of-Bounds        0        0
# 25587   542640      361                                    0        0
# 25588   542670      333                   Jump Shot        2        0
# 25589   542710      291                     Unknown        0        0
# 25590   542910       89                   Jump Shot        3        0
# 25591   542970       32                     Unknown        0        0
# 25592   542990       14                    Bad Pass        1        0
# 25593   543110       11          Floating Jump shot        2        0
# 25594   543130        1                     Unknown        0        0
# 25595   543480        0                                    0        0
#
#        Option3 Team_id                           Person1  \
# 25475        0   Team0  0370a0d090da0d0edc6319f120187e0e
# 25476        0   Team0  7dfbb5980c066844384ba7424aceae47
# 25477        0   Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25478        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25479        1   Team0  11beb0ae23e6425510297a31fa21881e
# 25480        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25481        0   Team0  7dfbb5980c066844384ba7424aceae47
# 25482        0   Team0  ff52c317e26534ae1679da3c917e9fec
# 25483        0   Team1  0a700ecf0eb76559949f1cb5b69a540b
# 25484        0   Team0  83c15c0962941640faab838a8f6f151d
# 25485        0   Team1  23fbda7c31efd6cfa21e3ab6c89d53f3
# 25486        0   Team0  83c15c0962941640faab838a8f6f151d
# 25487        2   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25488        0   Team0  ff52c317e26534ae1679da3c917e9fec
# 25489        0   Team0  ff52c317e26534ae1679da3c917e9fec
# 25490        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25491        0   Team0  11beb0ae23e6425510297a31fa21881e
# 25492        0   Team0  6ad10958a1d4920dccb1daec39bebd6b
# 25493        0   Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25495        0   Team0  6ad10958a1d4920dccb1daec39bebd6b
# 25494        0   Team1  f562f72f83b8e06b60ff184531b07056
# 25496        0   Team0  ff52c317e26534ae1679da3c917e9fec
# 25497        0   Team1  0a700ecf0eb76559949f1cb5b69a540b
# 25498        0   Team1  9811289f96c7deb95f04148c206e0b3a
# 25499        0   Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25500        2   Team1  23fbda7c31efd6cfa21e3ab6c89d53f3
# 25501        0   Team0  83c15c0962941640faab838a8f6f151d
# 25502        0   Team0  83c15c0962941640faab838a8f6f151d
# 25503        0   Team1  0a700ecf0eb76559949f1cb5b69a540b
# 25504        0   Team0  83c15c0962941640faab838a8f6f151d
# ...        ...     ...                               ...
# 25566        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25567        1   Team0  41c0674725d4cddab004649e9db5a3ce
# 25568        0   Team0  ff52c317e26534ae1679da3c917e9fec
# 25569        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25570        0   Team0  7dfbb5980c066844384ba7424aceae47
# 25571        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25572        0   Team0  83c15c0962941640faab838a8f6f151d
# 25573        0   Team1  bbe5cb93ef483ea31d950f6c634837dc
# 25574        0   Team0  41c0674725d4cddab004649e9db5a3ce
# 25575        0   Team1  0a700ecf0eb76559949f1cb5b69a540b
# 25576        0   Team0  83c15c0962941640faab838a8f6f151d
# 25577        2   Team1  bcf50b1e35f187b7c5bc18090cdfb7f6
# 25578        0   Team0  83c15c0962941640faab838a8f6f151d
# 25580        0   Team1  bcf50b1e35f187b7c5bc18090cdfb7f6
# 25579        0   Team1  687b541bdc76b92b085fc1304f5c1bf1
# 25581        0   Team0  83c15c0962941640faab838a8f6f151d
# 25582        2   Team0  90ba0d1de241290df2e124a5e02d68ef
# 25583        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25584        0   Team0  90ba0d1de241290df2e124a5e02d68ef
# 25585        0   Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25586        0   Team0  0370a0d090da0d0edc6319f120187e0e
# 25587        0   Team0  83c15c0962941640faab838a8f6f151d
# 25588        0   Team0  6ad10958a1d4920dccb1daec39bebd6b
# 25589        0   Team0  41c0674725d4cddab004649e9db5a3ce
# 25590        0   Team0  7dfbb5980c066844384ba7424aceae47
# 25591        0   Team1  bbe5cb93ef483ea31d950f6c634837dc
# 25592        0   Team1  bbe5cb93ef483ea31d950f6c634837dc
# 25593        0   Team0  6ad10958a1d4920dccb1daec39bebd6b
# 25594        0   Team0  e9ed8a6685a60e2416cd81bf874cffb1
# 25595        0   Team1  0370a0d090da0d0edc6319f120187e0e
#
#                                 Person2                           Person3  \
# 25475  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25476  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25477  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25478  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25479  2c447ab0a100cb50766552b0f6fadc2d  5201a0c1055bebf092c5ce178e5c7863
# 25480  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25481  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25482  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25483  2c447ab0a100cb50766552b0f6fadc2d  0370a0d090da0d0edc6319f120187e0e
# 25484  ff52c317e26534ae1679da3c917e9fec  0370a0d090da0d0edc6319f120187e0e
# 25485  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25486  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25487  ff52c317e26534ae1679da3c917e9fec  5201a0c1055bebf092c5ce178e5c7863
# 25488  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25489  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25490  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25491  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25492  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25493  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25495  f562f72f83b8e06b60ff184531b07056  7dfbb5980c066844384ba7424aceae47
# 25494  6ad10958a1d4920dccb1daec39bebd6b  0370a0d090da0d0edc6319f120187e0e
# 25496  7dfbb5980c066844384ba7424aceae47  0370a0d090da0d0edc6319f120187e0e
# 25497  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25498  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25499  83c15c0962941640faab838a8f6f151d  227d578f7628770519b586873c704e07
# 25500  83c15c0962941640faab838a8f6f151d  5201a0c1055bebf092c5ce178e5c7863
# 25501  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25502  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25503  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25504  7dfbb5980c066844384ba7424aceae47  0370a0d090da0d0edc6319f120187e0e
# ...                                 ...                               ...
# 25566  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25567  2c447ab0a100cb50766552b0f6fadc2d  5201a0c1055bebf092c5ce178e5c7863
# 25568  7dfbb5980c066844384ba7424aceae47  0370a0d090da0d0edc6319f120187e0e
# 25569  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25570  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25571  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25572  7dfbb5980c066844384ba7424aceae47  0370a0d090da0d0edc6319f120187e0e
# 25573  687b541bdc76b92b085fc1304f5c1bf1  0370a0d090da0d0edc6319f120187e0e
# 25574  7dfbb5980c066844384ba7424aceae47  0370a0d090da0d0edc6319f120187e0e
# 25575  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25576  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25577  83c15c0962941640faab838a8f6f151d  227d578f7628770519b586873c704e07
# 25578  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25580  1c5bebebc83437eca5ef0aaf6eabb15a  0370a0d090da0d0edc6319f120187e0e
# 25579  23fbda7c31efd6cfa21e3ab6c89d53f3  0370a0d090da0d0edc6319f120187e0e
# 25581  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25582  2c447ab0a100cb50766552b0f6fadc2d  5201a0c1055bebf092c5ce178e5c7863
# 25583  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25584  6ad10958a1d4920dccb1daec39bebd6b  0370a0d090da0d0edc6319f120187e0e
# 25585  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25586  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25587  23fbda7c31efd6cfa21e3ab6c89d53f3  7dfbb5980c066844384ba7424aceae47
# 25588  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25589  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25590  0370a0d090da0d0edc6319f120187e0e  1c5bebebc83437eca5ef0aaf6eabb15a
# 25591  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25592  6ad10958a1d4920dccb1daec39bebd6b  0370a0d090da0d0edc6319f120187e0e
# 25593  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25594  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25595  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 25475             2             0             0             0
# 25476             2             4             0             0
# 25477             2             5             0             0
# 25478             3             5             0             0
# 25479             3             4             5             1
# 25480             3             5             0             0
# 25481             3             4             0             0
# 25482             2             4             0             0
# 25483             3             5             5             0
# 25484             2             4             4             0
# 25485             3             5             0             0
# 25486             3             4             0             0
# 25487             2             5             4             1
# 25488             2             4             0             0
# 25489             2             4             0             0
# 25490             3             5             0             0
# 25491             3             4             0             0
# 25492             2             4             0             0
# 25493             2             5             0             0
# 25495             2             4             5             4
# 25494             3             5             4             0
# 25496             2             4             4             0
# 25497             3             5             0             0
# 25498             3             2             0             0
# 25499             2             5             4             1
# 25500             2             5             4             1
# 25501             2             4             0             0
# 25502             2             4             0             0
# 25503             3             5             0             0
# 25504             2             4             4             0
# ...             ...           ...           ...           ...
# 25566             3             5             0             0
# 25567             3             4             5             1
# 25568             3             4             4             0
# 25569             3             5             0             0
# 25570             2             4             0             0
# 25571             3             5             0             0
# 25572             2             4             4             0
# 25573             3             5             5             0
# 25574             2             4             4             0
# 25575             3             5             0             0
# 25576             3             4             0             0
# 25577             2             5             4             1
# 25578             2             4             0             0
# 25580             2             5             5             0
# 25579             2             5             5             0
# 25581             2             4             0             0
# 25582             3             4             5             1
# 25583             3             5             0             0
# 25584             3             4             4             0
# 25585             3             5             0             0
# 25586             2             0             0             0
# 25587             2             4             5             4
# 25588             2             4             0             0
# 25589             2             4             0             0
# 25590             2             4             0             5
# 25591             2             5             0             0
# 25592             3             5             4             0
# 25593             2             4             0             0
# 25594             2             3             0             0
# 25595             3             0             0             0
#
# [121 rows x 18 columns]

# %%
rdPBP[420:]
# Out:
#                                 Game_id  Event_Num     Event_Msg_Type  Period  \
# 25661  bb4e1b593cc210dec5fdcb0f7eb4739d        610            Rebound       4
# 25660  bb4e1b593cc210dec5fdcb0f7eb4739d        611          Made Shot       4
# 25662  bb4e1b593cc210dec5fdcb0f7eb4739d        612               Foul       4
# 25663  bb4e1b593cc210dec5fdcb0f7eb4739d        614         Free Throw       4
# 25664  bb4e1b593cc210dec5fdcb0f7eb4739d        615            Timeout       4
# 25665  bb4e1b593cc210dec5fdcb0f7eb4739d        616         Free Throw       4
# 25666  bb4e1b593cc210dec5fdcb0f7eb4739d        617          Made Shot       4
# 25667  bb4e1b593cc210dec5fdcb0f7eb4739d        619               Foul       4
# 25668  bb4e1b593cc210dec5fdcb0f7eb4739d        621        Missed Shot       4
# 25669  bb4e1b593cc210dec5fdcb0f7eb4739d        622            Rebound       4
# 25670  bb4e1b593cc210dec5fdcb0f7eb4739d        623               Foul       4
# 25671  bb4e1b593cc210dec5fdcb0f7eb4739d        625         Free Throw       4
# 25672  bb4e1b593cc210dec5fdcb0f7eb4739d        626         Free Throw       4
# 25673  bb4e1b593cc210dec5fdcb0f7eb4739d        627        Missed Shot       4
# 25674  bb4e1b593cc210dec5fdcb0f7eb4739d        628            Rebound       4
# 25675  bb4e1b593cc210dec5fdcb0f7eb4739d        629        Missed Shot       4
# 25676  bb4e1b593cc210dec5fdcb0f7eb4739d        630            Rebound       4
# 25677  bb4e1b593cc210dec5fdcb0f7eb4739d        631          Made Shot       4
# 25678  bb4e1b593cc210dec5fdcb0f7eb4739d        632        Missed Shot       4
# 25679  bb4e1b593cc210dec5fdcb0f7eb4739d        634            Rebound       4
# 25680  bb4e1b593cc210dec5fdcb0f7eb4739d        635        Missed Shot       4
# 25681  bb4e1b593cc210dec5fdcb0f7eb4739d        636            Rebound       4
# 25682  bb4e1b593cc210dec5fdcb0f7eb4739d        637           Turnover       4
# 25683  bb4e1b593cc210dec5fdcb0f7eb4739d        638     Instant Replay       4
# 25684  bb4e1b593cc210dec5fdcb0f7eb4739d        639               Foul       4
# 25685  bb4e1b593cc210dec5fdcb0f7eb4739d        641       Substitution       4
# 25687  bb4e1b593cc210dec5fdcb0f7eb4739d        643         Free Throw       4
# 25686  bb4e1b593cc210dec5fdcb0f7eb4739d        644            Rebound       4
# 25688  bb4e1b593cc210dec5fdcb0f7eb4739d        645         Free Throw       4
# 25689  bb4e1b593cc210dec5fdcb0f7eb4739d        646          Made Shot       4
# 25690  bb4e1b593cc210dec5fdcb0f7eb4739d        648       Substitution       4
# 25691  bb4e1b593cc210dec5fdcb0f7eb4739d        650     Instant Replay       4
# 25692  bb4e1b593cc210dec5fdcb0f7eb4739d        651          Made Shot       4
# 25693  bb4e1b593cc210dec5fdcb0f7eb4739d        652            Timeout       4
# 25694  bb4e1b593cc210dec5fdcb0f7eb4739d        653       Substitution       4
# 25695  bb4e1b593cc210dec5fdcb0f7eb4739d        655        Missed Shot       4
# 25696  bb4e1b593cc210dec5fdcb0f7eb4739d        657            Rebound       4
# 25697  bb4e1b593cc210dec5fdcb0f7eb4739d        658               Foul       4
# 25698  bb4e1b593cc210dec5fdcb0f7eb4739d        660         Free Throw       4
# 25699  bb4e1b593cc210dec5fdcb0f7eb4739d        661       Substitution       4
# 25700  bb4e1b593cc210dec5fdcb0f7eb4739d        663         Free Throw       4
# 25701  bb4e1b593cc210dec5fdcb0f7eb4739d        664        Missed Shot       4
# 25702  bb4e1b593cc210dec5fdcb0f7eb4739d        665            Rebound       4
# 25703  bb4e1b593cc210dec5fdcb0f7eb4739d        666         End Period       4
# 25704  bb4e1b593cc210dec5fdcb0f7eb4739d          0  Final Box Printed       4
#
#        WC_Time  PC_Time                  Action_Type  Option1  Option2  \
# 25661   557280     1920                      Unknown        0        0
# 25660   557280     1920            Putback Dunk Shot        2        0
# 25662   557350     1880                     Shooting        0        0
# 25663   557590     1880            Free Throw 1 of 2        1        0
# 25664   557680     1880                      Regular        0        0
# 25665   558730     1880            Free Throw 2 of 2        1        0
# 25666   558840     1720                    Jump Shot        3        0
# 25667   559080     1550                     Personal        0        0
# 25668   559320     1490                   Layup Shot        2        0
# 25669   559350     1490                      Unknown        0        0
# 25670   559360     1490                   Loose Ball        1        0
# 25671   559830     1490            Free Throw 1 of 2        1        0
# 25672   560000     1490            Free Throw 2 of 2        1        0
# 25673   560200     1390             Pullup Jump shot        2        0
# 25674   560230     1350                      Unknown        0        0
# 25675   560360     1220           Fadeaway Jump Shot        2        0
# 25676   560400     1180                      Unknown        0        0
# 25677   560530     1060           Driving Layup Shot        2        0
# 25678   560670      930           Floating Jump shot        2        0
# 25679   560700      900                      Unknown        0        0
# 25680   560720      880                    Jump Shot        3        0
# 25681   560760      860                      Unknown        0        0
# 25682   560850      860  Step Out of Bounds Turnover        0        0
# 25683   560880      860               Support Ruling        0        0
# 25684   562190      690                     Shooting        1        0
# 25685   562590      690                                     0        0
# 25687   562980      690            Free Throw 1 of 2        2        0
# 25686   562980      690               Normal Rebound        0        0
# 25688   563110      690            Free Throw 2 of 2        1        0
# 25689   563230      600           Driving Layup Shot        2        0
# 25690   563510      474                                     0        0
# 25691   563560      474              Overturn Ruling        0        0
# 25692   564810      404             Pullup Jump shot        2        0
# 25693   564870      404                      Regular        0        0
# 25694   565620      404                                     0        0
# 25695   565920      308                    Jump Shot        3        0
# 25696   565970      256                      Unknown        0        0
# 25697   566040      209                Personal Take        1        0
# 25698   566300      209            Free Throw 1 of 2        1        0
# 25699   566320      209                                     0        0
# 25700   566490      209            Free Throw 2 of 2        1        0
# 25701   566590      131           Driving Layup Shot        2        0
# 25702   566630       94                      Unknown        0        0
# 25703   566760        0                                     0        0
# 25704   570330        0                                     0        0
#
#        Option3    Team_id                           Person1  \
# 25661        0      Team0  83c15c0962941640faab838a8f6f151d
# 25660        0      Team0  83c15c0962941640faab838a8f6f151d
# 25662        2      Team0  7dfbb5980c066844384ba7424aceae47
# 25663        0      Team1  f562f72f83b8e06b60ff184531b07056
# 25664        0      Team1  9811289f96c7deb95f04148c206e0b3a
# 25665        0      Team1  f562f72f83b8e06b60ff184531b07056
# 25666        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25667        0      Team0  6ad10958a1d4920dccb1daec39bebd6b
# 25668        0      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25669        0      Team1  9811289f96c7deb95f04148c206e0b3a
# 25670        2      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25671        0      Team0  83c15c0962941640faab838a8f6f151d
# 25672        0      Team0  83c15c0962941640faab838a8f6f151d
# 25673        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25674        0      Team0  83c15c0962941640faab838a8f6f151d
# 25675        0      Team0  83c15c0962941640faab838a8f6f151d
# 25676        0      Team1  0a700ecf0eb76559949f1cb5b69a540b
# 25677        0      Team1  23fbda7c31efd6cfa21e3ab6c89d53f3
# 25678        0      Team0  83c15c0962941640faab838a8f6f151d
# 25679        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25680        0      Team0  83c15c0962941640faab838a8f6f151d
# 25681        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25682        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25683        0      Team0  a3801b904a10b622331b97394eebcb4e
# 25684        2      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25685        0      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25687        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25686        0      Team0  9811289f96c7deb95f04148c206e0b3a
# 25688        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25689        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25690        0      Team1  687b541bdc76b92b085fc1304f5c1bf1
# 25691        0      Team0  b005e593a20bcdd4b1d04021af9accff
# 25692        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25693        0      Team1  e9ed8a6685a60e2416cd81bf874cffb1
# 25694        0      Team1  ce3ac26d43af7aa5555535cfed3f48cc
# 25695        0      Team1  23fbda7c31efd6cfa21e3ab6c89d53f3
# 25696        0      Team0  11beb0ae23e6425510297a31fa21881e
# 25697        2      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25698        0      Team0  83c15c0962941640faab838a8f6f151d
# 25699        0      Team1  687b541bdc76b92b085fc1304f5c1bf1
# 25700        0      Team0  83c15c0962941640faab838a8f6f151d
# 25701        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25702        0      Team0  11beb0ae23e6425510297a31fa21881e
# 25703        0      Team0  0370a0d090da0d0edc6319f120187e0e
# 25704        0  Officials  0370a0d090da0d0edc6319f120187e0e
#
#                                 Person2                           Person3  \
# 25661  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25660  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25662  f562f72f83b8e06b60ff184531b07056  5201a0c1055bebf092c5ce178e5c7863
# 25663  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25664  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25665  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25666  7dfbb5980c066844384ba7424aceae47  0370a0d090da0d0edc6319f120187e0e
# 25667  2c447ab0a100cb50766552b0f6fadc2d  227d578f7628770519b586873c704e07
# 25668  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25669  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25670  83c15c0962941640faab838a8f6f151d  a2e5a2de2ee7fe3b5ba9be7caa05fba8
# 25671  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25672  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25673  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25674  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25675  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25676  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25677  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25678  0370a0d090da0d0edc6319f120187e0e  1c5bebebc83437eca5ef0aaf6eabb15a
# 25679  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25680  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25681  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25682  0370a0d090da0d0edc6319f120187e0e  5201a0c1055bebf092c5ce178e5c7863
# 25683  0370a0d090da0d0edc6319f120187e0e  227d578f7628770519b586873c704e07
# 25684  ff52c317e26534ae1679da3c917e9fec  227d578f7628770519b586873c704e07
# 25685  687b541bdc76b92b085fc1304f5c1bf1  0370a0d090da0d0edc6319f120187e0e
# 25687  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25686  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25688  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25689  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25690  ce3ac26d43af7aa5555535cfed3f48cc  0370a0d090da0d0edc6319f120187e0e
# 25691  0370a0d090da0d0edc6319f120187e0e  a2e5a2de2ee7fe3b5ba9be7caa05fba8
# 25692  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25693  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25694  687b541bdc76b92b085fc1304f5c1bf1  0370a0d090da0d0edc6319f120187e0e
# 25695  0370a0d090da0d0edc6319f120187e0e  83c15c0962941640faab838a8f6f151d
# 25696  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25697  83c15c0962941640faab838a8f6f151d  5201a0c1055bebf092c5ce178e5c7863
# 25698  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25699  ce3ac26d43af7aa5555535cfed3f48cc  0370a0d090da0d0edc6319f120187e0e
# 25700  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25701  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25702  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25703  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25704  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 25661             2             4             0             0
# 25660             2             4             0             0
# 25662             3             4             5             1
# 25663             3             5             0             0
# 25664             3             2             0             0
# 25665             3             5             0             0
# 25666             2             4             4             0
# 25667             3             4             5             1
# 25668             3             5             0             0
# 25669             3             2             0             0
# 25670             2             5             4             1
# 25671             2             4             0             0
# 25672             2             4             0             0
# 25673             3             5             0             0
# 25674             3             4             0             0
# 25675             2             4             0             0
# 25676             2             5             0             0
# 25677             3             5             0             0
# 25678             2             4             0             5
# 25679             2             4             0             0
# 25680             2             4             0             0
# 25681             2             5             0             0
# 25682             3             5             0             1
# 25683             2             0             0             1
# 25684             2             5             4             1
# 25685             2             5             5             0
# 25687             2             4             0             0
# 25686             2             2             0             0
# 25688             2             4             0             0
# 25689             3             5             0             0
# 25690             2             5             5             0
# 25691             2             0             0             1
# 25692             2             4             0             0
# 25693             3             3             0             0
# 25694             3             5             5             0
# 25695             3             5             0             4
# 25696             3             4             0             0
# 25697             2             5             4             1
# 25698             2             4             0             0
# 25699             2             5             5             0
# 25700             2             4             0             0
# 25701             3             5             0             0
# 25702             3             4             0             0
# 25703             2             0             0             0
# 25704             0             0             0             0

# %%
np.round(100*21.0/16, 2)
# Out:
# 131.25
