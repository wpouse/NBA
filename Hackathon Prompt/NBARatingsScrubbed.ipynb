# %%
import numpy as np
import pandas as pd

# %%
eventCodes = pd.read_csv('Event_Codes.txt', sep='\t')
#Strip excess whitespace that I noticed in Event Message Type Description
eventCodes['Event_Msg_Type_Description'] = eventCodes['Event_Msg_Type_Description'].map(str.strip)

GameLineup = pd.read_csv('Game_Lineup.txt', sep='\t')
PlayByPlay = pd.read_csv('Play_by_Play.txt', sep='\t')
GameIDs = PlayByPlay['Game_id'].unique()

# %%
def sortedPlayByPlay(PlayByPlay):
    """Returns PlayByPlay with nested sorted given by hackathon pdf file.
    
    Input:
        PlayByPlay: Pandas Dataframe from reading Play_by_Play csv file"""
    return PlayByPlay.sort_values(['Period', 'PC_Time', 'WC_Time', 'Event_Num'], ascending=[True, False, True,True])

# %%
def readablePlayByPlay(playByPlay, gameLineup, eventCodes):
    """Maps teamIDs to correct player and replaces it with a simple team0 or team1. 
    Also maps event numbers and action to corresponding description, based off eventCodes"""
    gameTeams = list(gameLineup['Team_id'].unique())
    playerList = list(gameLineup['Person_id'].unique())
    
    playByPlay['Event_Msg_Type'] = playByPlay['Event_Msg_Type'].astype(str)
    playByPlay['Action_Type'] = playByPlay['Action_Type'].astype(str)
    
    print('Team0', gameTeams[0])
    print('Team1', gameTeams[1])
    
    for event in playByPlay.itertuples():
        i = getattr(event, 'Index')
        player = getattr(event, 'Person1')
        teamID = getattr(event, 'Team_id')
        
        if teamID not in gameTeams:
            playerTeam = 'Officials'
        else:
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        #print(playerTeam)
        #print(gameTeams)
        
        if playerTeam == gameTeams[0]:
            playByPlay.at[i,'Team_id'] = 'Team0'
        elif playerTeam == gameTeams[1]:
            playByPlay.at[i, 'Team_id'] = 'Team1'
        else:
            playByPlay.at[i, 'Team_id'] = 'Officials'

        
        eventNum = getattr(event, 'Event_Num')
         #Get the event type
        eventMsgType = int(getattr(event, "Event_Msg_Type"))
        actionType = int(getattr(event, 'Action_Type'))
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        playByPlay.at[i, 'Event_Msg_Type'] = eventMsgDescript
        playByPlay.at[i, 'Action_Type'] = actionTypeDescript
    return playByPlay

# %%
def addPoints(player, points, team0Lineup, team1Lineup, gameDict, possession):
    #Player is person1 of the event messages. Every teammate gets the points for added and opponents points against
    if player in team0Lineup:
        for team0player in team0Lineup:
            #Add points for and off possession
            gameDict[team0player] += np.array([points, 0, possession, 0])
        for team1player in team1Lineup:
            #Add points against and def posession
            gameDict[team1player] += np.array([0, points, 0, possession])
        return
    elif player in team1Lineup:
        for team0player in team0Lineup:
            #Add points against and def possession
            gameDict[team0player] += np.array([0, points, 0, possession])
        for team1player in team1Lineup:
            #Add points for and off possession
            gameDict[team1player] += np.array([points, 0, possession, 0])
        return
    else:
        print("Player not found on either team lineup!")
        print(player)
        print('Team0', team0Lineup)
        print('Team1', team1Lineup)
        return -1
    
def addPossession(team0Lineup, team1Lineup, gameDict):
    """Adds offensive possession to team0Lineup and defensive possession to team1Lineup."""
    for team0player in team0Lineup:
        #Add off possession
        gameDict[team0player] += np.array([0, 0, 1, 0])
    for team1player in team1Lineup:
        #Add def posession
        gameDict[team1player] += np.array([0, 0, 0, 1])
    return

def getPlayerTeam(player, teamID, playerList, gameLineup):
    """Returns the team of the input player (if player is real) otherwise returns teamID"""
    if player not in playerList:
        #Team event
        playerTeam = teamID
    else:
        playerTeam = gameLineup[gameLineup['Person_id'] == player]['Team_id'].values[0]
    return playerTeam

def doSubstitution(player, event, team0Lineup, team1Lineup, verbose):
    leavingPlayer = player
    enteringPlayer = getattr(event, 'Person2')
    if leavingPlayer in team0Lineup:
        team0Lineup.remove(leavingPlayer)
        team0Lineup.append(enteringPlayer)
    else:
        team1Lineup.remove(leavingPlayer)
        team1Lineup.append(enteringPlayer)
            
    if verbose:
        print(enteringPlayer, ' replacing ', leavingPlayer)

def doPossessionFixSub(possessionInfo, team, gameDict, gameTeams, verbose = False):
    """
    Adds possessions to players given by possessionInfo dictionary. 
        Used for when possession unknown (often due to a team rebound).
        
    
    Inputs: 
        possessionInfo: Dictionary containing the relevant information of the events leading to unknown possession.
            'team0' and 'team1' keys correspond to the team0 and team1 lineups. 
            'event' key corresponds to the event (missed shot or free throw)
            'lastTeam' key corresponds to team last known to have possession
            'subbedPlayers0' and 'subbedPlayers1' keys correspond to players subbed out in between 'event' and 
                play where possession becomes known
            'remainingPlayers0' and 'remainingPlayers1' keys typically correspond to players 
                who are still on court after a substitution occurs ie remainingPlayers = teamLineup - subbedInPlayers
                However, currently assuming that all players on court get credited with possession on missed ft 
                so will just be same as teamLineup
        
        team: Team that currently has possession to be compared to lastTeam
        
        gameDict: Dictionary containing all pointsFor/Against and off/defPossessions of each player to be updated
        
        gameTeams: List of both teams playing to be used to check if team0 or 1 has possession
        
        verbose: Optional input, where if True, prints statements describing which players possession added to
        
        """
    eventDescript = possessionInfo['event']
    team0Lineup = possessionInfo['team0']
    team1Lineup = possessionInfo['team1']
    lastTeam = possessionInfo['lastTeam']
    subbedPlayers0 = possessionInfo['subbedPlayers0']
    subbedPlayers1 = possessionInfo['subbedPlayers1']
    
    possessionInfoEmpty = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                           'event': '', 'lastTeam': '', 'subbedPlayers0': [], 'subbedPlayers1': []}
    
    if (team not in gameTeams) or (lastTeam not in gameTeams):
        raise Exception('Either {} or {} not a valid team'.format(team, lastTeam))
    
    if (eventDescript == 'Missed Shot') or (eventDescript == 'Technical Free Throw'):
        if verbose:
            print('Missed shot possession fix')
        if len(subbedPlayers0) + len(subbedPlayers1) > 0:
            #Regardless of who rebounds add possession to players subbed off
            if team == gameTeams[0]:
                #Team0 players who were subbed now on offense (ASSUMES sub happens after rebound)
                addPossession(subbedPlayers0, subbedPlayers1, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers0)
                    print("Add def possession to subbed players", subbedPlayers1)
            else:
                addPossession(subbedPlayers1, subbedPlayers0, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers1)
                    print("Add def possession to subbed players", subbedPlayers0)
        if lastTeam == team:
            #Offensive rebound on missed shot, do nothing except for subbed players
            
            if verbose:
                print("Was offensive rebound, don't do anything for on court players")
            return possessionInfoEmpty
        elif team == gameTeams[0]:
            #Defensive rebound by team0
            addPossession(team1Lineup, team0Lineup, gameDict)
            
            if verbose:
                print("Add off possession to ", team1Lineup)
                print("Add def possession to ", team0Lineup)
        else:
            #Defensive rebound by team1
            addPossession(team0Lineup, team1Lineup, gameDict)

            if verbose:
                print("Add off possession to ", team0Lineup)
                print("Add def possession to ", team1Lineup)
                    
    elif eventDescript == 'Missed Last Free Throw':
        if verbose:
            print('FT possession fix')
        if lastTeam == team:
            #Do nothing, as possession already added to subbed players
            pass
            
        else: #Defensive Rebound
            #Only add possession to those who were on court when foul occured
            ##UPDATE: I believe NBA actually counts it as a possession for all players on court, 
            #so while still labeled remainingPlayers, input in gameRatings function will be teamLineup
            remainingPlayers0 = possessionInfo['remainingPlayers0']
            remainingPlayers1 = possessionInfo['remainingPlayers1']
            
            if team == gameTeams[0]:
                #team0 grabs defensive rebound
                addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers1)
                    print("Add def possession to ", remainingPlayers0)
            else:
                addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers0)
                    print("Add def possession to ", remainingPlayers1)
    else:
        raise Exception('Attempt to fix possession failed, invalid event Descript: {}'.format(eventDescript))
    
    return possessionInfoEmpty

# %%
def gameRatingsSubCleaned(gamePlayByPlay, gameLineup, eventCodes, verbose = False):
    """Turns a given PlayByPlay log and calculates the number of points and possessions a player is in the game for, 
    both scored by and against the players team. Can be used to calculate offensive and defensive rating defined by 
    offRtg = 100*pointsFor/offPossessions and defRtg = 100*pointsAgainst/defPossesssions
    
    Inputs:
        gamePlayByPlay: A Pandas dataframe object listing the play by play events for a single game. 
            This should be sorted according to the prompt (Period, PC_Time, WC_Time, Event_Num). Taken from Play_by_Play.txt .
        
        gameLineup: A Pandas dataframe of the game lineup for the same gams as the play by play. Taken from Game_Lineup.txt .
        
        eventCodes: Pandas dataframe of the event codes provided by the NBA. Taken from Event_Codes.txt .
        
        verbose: Optional argument. If set to True, prints the current loop counter and a description of each event 
            (made shot, rebound, turnover, etc)
        
    Output:
        gameDict: A dictionary where the keys are each playerID from the gameLineup input, 
            and the value is an array of [pointsFor, pointsAgainst, offPossessions, defPossessions]
    
    """
    
    lastDescript = ''
    counter = 0
    gameTeams = list(gameLineup['Team_id'].unique())
    
    #Create dictionary with keys of each player and value of array([PointsFor, PointsAgainst, OffPossessions, DefPossessions])
    playerList = list(gameLineup['Person_id'].unique())
    gameDict = {player: np.array([0,0,0,0]) for player in playerList}
    
    #List of event numbers to skip 
    #(designed for the case where we 'look ahead' at a future rebound or substitution due to playbyplay error)
    skipEventNums = []
    
    #Keep track of team with possession 
    currPoss = ''
    #Keep track of play clock time (due to weird handling of technical fouls as possessions by NBA) 
    #Initialize to -1 so no accidental equalities
    currTime = -1 
    
    #Added because of cases where made shot with 0 on clock would lead to another possession being added when period ended
    #Unclear if have to take into account other actions at 0
    skipEndPeriod = False
    
    for event in gamePlayByPlay.itertuples():
        
        eventNum = getattr(event, 'Event_Num')
        
         #Get the event type
        eventMsgType = getattr(event, "Event_Msg_Type")
        actionType = getattr(event, 'Action_Type')
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        #Player who shoots, rebounds, etc
        player = getattr(event, 'Person1')
        
        if verbose:
            print('Counter', counter)
            print('Event Num', eventNum)
            print(skipEventNums)
            print(eventMsgDescript, 'by', player)
    
        counter += 1
        if eventNum in skipEventNums:
            continue
        

        
        teamID = getattr(event, 'Team_id') #teamID doesn't always correspond to player's team
        playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        PCtime = getattr(event, 'PC_Time')
        period = getattr(event, 'Period')

     
        if eventMsgDescript == 'Start Period':
            skipEndPeriod = False
            currTime = -1
            currPoss = playerTeam
            #Substitutions at start of period aren't considered substitution events. Must check game linup explicitly.
            team0Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[0])]['Person_id'])
            team1Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[1])]['Person_id'])

            lastDescript = ''
            
            #Used for cases of a team rebound not assigned to a particular player. The teamID is often wrong, 
            #so when unknownRebound is True, next events are checked to see who has the ball.
            unknownRebound = False
            unknownReboundInfo = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                                  'subbedPlayers0': [], 'subbedPlayers1': [], 'event': '', 'lastTeam': ''}
            
            if verbose:
                print(period,' lineup 0:', team0Lineup)
                print(period,' lineup 1:', team1Lineup)
                
                
        elif eventMsgDescript == 'End Period' and not skipEndPeriod:
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
                
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
            lastDescript = ''
            
            if verbose:
                print(period, 'ended')
                
        if lastDescript == 'Missed Shot':
            #Previous event missed shot, check who rebounded
            
            lastDescript = ''
            
            if currTime== 0:
                #Miss at end of period so skip End Period event otherwise double count of possession
                skipEndPeriod = True
                #Add possession to each player
                if lastTeam == gameTeams[0]:
                    #team0 missed on offense
                    addPossession(team0Lineup, team1Lineup, gameDict)
                else:
                    addPossession(team1Lineup, team0Lineup, gameDict)
                continue
                
            currTime = PCtime
            
            if eventMsgDescript != 'Rebound':
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at later time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                
                #Get all events after current one and check which events correspond to a rebound in same period
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & (reboundEvent['Period'] == period)]
                if reboundEvent.empty:
                    print('No rebound after!')
                    print('Counter', counter-1)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])

            #if player not in lastTeam: #Defensive rebound (for an offensive rebound do nothing)
            
            #Check that if real player (not team rebound) grabbed board, that he is on the court
            #Shouldn't be triggered if parsing done correctly, but good for error checking
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Counter', counter-1)
                print('Event num', getattr(event, 'Event_Num'))
                break
                
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Shot'
                unknownReboundInfo['lastTeam'] = lastTeam
                    
            elif playerTeam != lastTeam:
                #Defensive rebound
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                if verbose:
                    print("Defensive Rebound")

            else:
                if verbose:
                    print("Offensive Rebound")
            #Reset to player of current event for instances where we needed to find next rebound due to wrong order
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
            
        elif lastDescript == 'Missed Last Free Throw':
            #Similar structure as missing last shot, except take into account possibility of substitutions 
            #(important if don't want to give substitutions to player subbed in -- NBA seems to count those)
            lastDescript = ''
            currTime = PCtime
            if eventMsgDescript != 'Rebound':
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at same time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                WCtime = getattr(event, 'WC_Time')
                
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & ((reboundEvent['Period'] == period))]
                if reboundEvent.empty:
                    print('Event num', getattr(event, 'Event_Num'))
                    print('No rebound at same time!')
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])


            #Check if players subbed at same time
            subEvents = gamePlayByPlay[counter-1:]
            subEvents = subEvents[(subEvents['Event_Msg_Type'] == 8) 
                                & (subEvents['Period'] == period) 
                                & (subEvents['PC_Time'] == PCtime)]
            for substitution in subEvents.itertuples():
                subPlayer = getattr(substitution, 'Person1')
                subEventNum = getattr(substitution, 'Event_Num')
                subPlayerTeam = getPlayerTeam(subPlayer, '', playerList, gameLineup)
                    
                skipEventNums.append(subEventNum)
                doSubstitution(subPlayer, substitution, team0Lineup, team1Lineup, verbose)
                if subPlayerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([subPlayer], [], gameDict)
                else:
                    addPossession([], [subPlayer], gameDict)
                if verbose:
                    print('Sub after ft')
                    
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Event num', getattr(event, 'Event_Num'))
                break
            
            subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
            subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
            remainingPlayers0 = list(set(ftTeam0Lineup)-set(subbedPlayers0))
            remainingPlayers1 = list(set(ftTeam1Lineup)-set(subbedPlayers1))
            
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Last Free Throw'
                #unknownReboundInfo['remainingPlayers0'] = remainingPlayers0.copy()
                #unknownReboundInfo['remainingPlayers1'] = remainingPlayers1.copy()
            
                unknownReboundInfo['remainingPlayers0'] = team0Lineup.copy()
                unknownReboundInfo['remainingPlayers1'] = team1Lineup.copy()

                unknownReboundInfo['lastTeam'] = lastTeam
                
            #Offensive Rebound, no possessions added (already added to subbed players)
            elif playerTeam == lastTeam:
                if verbose:
                    print("Offensive Rebound")
 
            else:
                #Only add possession to those who were on court when foul occured and are still on court
            
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    #addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    #addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                    
                if verbose:
                    print("Defensive Rebound")
                    
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        if eventNum in skipEventNums:
            #Check this again because of iteration through substitution events after missed shot or free throw
            continue
        
        if eventMsgDescript == 'Substitution':
            doSubstitution(player, event, team0Lineup, team1Lineup, verbose)
            
            #In case current possession unknown use unknownRebound logic to check next possession and assign correct possessions
            if unknownRebound:
                if playerTeam == gameTeams[0]:
                    unknownReboundInfo['subbedPlayers0'].append(player)
                elif playerTeam == gameTeams[1]:
                    unknownReboundInfo['subbedPlayers1'].append(player)
            else:
                if playerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([player], [], gameDict)
                else:
                    addPossession([], [player], gameDict)
            
        if eventMsgDescript == 'Made Shot':
            currTime = PCtime
            if PCtime == 0:
                skipEndPeriod = True
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            points = getattr(event, 'Option1')
            
            #Check if and-1. Only checking if fts happen not action type ft 1 out of 1 because possibility of flagrant.
            #This assumes that the ft shot will always be after the made shot in a play by play
            ftEvents = gamePlayByPlay[counter-1:]
            ftEvents = ftEvents[(ftEvents['Event_Msg_Type'] == 3) 
                                    & (ftEvents['Period'] == period) 
                                    & (ftEvents['PC_Time'] == PCtime)]
            # if ft happens then don't count possession, because it will be handled when loop hits that event
            if ftEvents.empty:
                poss = 1
                if playerTeam == gameTeams[0]:
                    currPoss = gameTeams[1]
                else:
                    currPoss = gameTeams[0]
            else:
                poss = 0
            
            addPoints(player,points, team0Lineup, team1Lineup, gameDict, possession= poss)
            
            if verbose:
                print(player, 'scores', points, 'points')
                
        elif eventMsgDescript == 'Turnover':
            
            currTime = PCtime
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
                currPoss = gameTeams[1]
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
                currPoss = gameTeams[0]
                
            if verbose:
                print(playerTeam, 'turnover')
                
        elif eventMsgDescript == 'Missed Shot':
            
            currTime = PCtime
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Check who rebounds in next iteration of loop
            lastDescript = eventMsgDescript

            if player in team0Lineup:
                #lastTeam = team0Lineup
                lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
            else:
                #lastTeam = team1Lineup
                lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
            if verbose:
                print(player, 'misses shot')

        #Check if Foul (which may or may not lead to free throws), but all free throws come from fouls
        #Important to check if a generic foul and not just shooting fouls, otherwise the free throw lineup will be 'behind'
        #If only looked at shooting fouls - consider situation of substitutions during the game and then a technical foul. 
        #The ft lineup would only be from the previous fts, not the current lineup. 
        elif (eventMsgDescript == 'Foul'):
            #Make sure to copy lineup not assign, otherwise when lineup changes ftTeamLineup would change
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            
            if verbose:
                print('Foul on team', playerTeam)

        elif eventMsgDescript == 'Free Throw':
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            option1 = getattr(event, 'Option1')
            if option1 == 1: #Made Free Throw
                points = 1
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #ActionTypes corresponding to final free throw, so add possession. 
                    subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
                    subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
                    
                    #subbedPlayers already got possession added so only add to remaining players on court
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    remainingPlayers0 = list(set(ftTeam0Lineup) - set(subbedPlayers0))
                    remainingPlayers1 = list(set(ftTeam1Lineup) - set(subbedPlayers1))
                    
                    if playerTeam == gameTeams[0]:
                        addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                        currPoss = gameTeams[1]
                    elif playerTeam == gameTeams[1]:
                        addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                        currPoss = gameTeams[0]
                    else:
                        print('Error: Free throw player not on either team')
                        return

                    if verbose:
                        print('Made final free throw by', player)
                        
                else:
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    
                    if verbose:
                        print('Made free throw by', player)
                        
            else: #Missed FT
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #Missed last free throw for a shooting foul (not technical/flagrant), check who rebounds in next iteration. 
                    lastDescript = 'Missed Last Free Throw'
                    #Offensive rebounds with substitution going to be weird in terms of possessions

                    #Check current lineup, not free throw lineup since current lineup will be the one to rebound
                    if player in team0Lineup:
                        lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
                    else:
                        lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
                        
                    if verbose:
                        print('Missed last free throw by', player)
                        print('ftteam1', ftTeam1Lineup)
                else:
                    if verbose:
                        print('Missed free throw by', player)

            #NBA seems to count technical free throws a possession. Delete block below if undesired.
            
            #Check whether was last technical free throw (not flagrant which team keeps possession)
            if (actionType == 16) or (actionType == 22):
                
                
                #Use the possessionFix method already implemented and just count this free throw as the 'unknownRebound'
            
                #So if team on offense commits tech that counts as off + def possession
                #then def + off possession for tech ft, and then following possession will be off + def
                if False:
                    unknownRebound = True
                    unknownReboundInfo['team0'] = team0Lineup.copy()
                    unknownReboundInfo['team1'] = team1Lineup.copy()
                    unknownReboundInfo['event'] = 'Technical Free Throw'
                    unknownReboundInfo['remainingPlayers0'] = ftTeam0Lineup.copy()
                    unknownReboundInfo['remainingPlayers1'] = ftTeam1Lineup.copy()
                    unknownReboundInfo['lastTeam'] = playerTeam
                    
                #Check if tech committed by team with possession. If so add offensive and defensive possession to both teams 
                #(off from having ball, def from tech shot)
                
                #Also it seems like only if time passed in a given possession does the tech count as a change in possession.
                #Remove currTime != PCtime so all techs treated equally
                if currPoss != playerTeam and currTime != PCtime:
                    addPossession(ftTeam1Lineup, ftTeam0Lineup, gameDict)
                    addPossession(ftTeam0Lineup, ftTeam1Lineup, gameDict)
    return gameDict

# %%
dataRows = []
i = 0
for game in GameIDs:
    print(i)
    gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
    gameLineup = GameLineup[GameLineup['Game_id'] == game]
    gameDict = gameRatingsSub(gamePlayByPlay, gameLineup, eventCodes)
    playerList = list(gameLineup['Person_id'].unique())
    
    for player in gameDict.keys():
        dataDict = {'Game_ID': game}
        #Check at least one possession played
        offPossessions = gameDict[player][2]
        defPossessions = gameDict[player][3]
        
        totalPossessions = offPossessions + defPossessions
        
        if totalPossessions != 0: 
            #Allowing for possibility of only playing one possession on offense or defense and thus undefined rating
            pointsFor = gameDict[player][0]
            pointsAgainst = gameDict[player][1]
            if offPossessions == 0:
                offRating = np.nan
            else:
                offRating = 100*(pointsFor/offPossessions)
            if defPossessions == 0:
                defRating = np.nan
            else:
                defRating = 100*(pointsAgainst/defPossessions)
            playerTeam = getPlayerTeam(player, '', playerList, gameLineup)
            dataDict.update({'Player_ID': player, 'Team_ID': playerTeam, 'OffRtg': np.round(offRating,1), 
                             'DefRtg': np.round(defRating,1), 'OffPossessions': offPossessions, 
                             'DefPossessions': defPossessions, 'PointsFor': pointsFor, 'PointsAgainst': pointsAgainst})
            
            dataRows.append(dataDict)
    i+=1
df = pd.DataFrame(dataRows)
df= df[['Game_ID', 'Player_ID', 'Team_ID','OffRtg', 'DefRtg', 'OffPossessions', 'DefPossessions', 'PointsFor', 'PointsAgainst']]
df.to_excel("GameRatings.xlsx", index=False)

# %%
## bug in playbyplay that cant be fixed? Look at gameIDs[3] events 21-23 show missed free throw, rebound, then made free throw?
#Assuming its even ft, ft, rebound it says it was made so how can there be a rebound?
game = GameIDs[11]
gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
gameLineup = GameLineup[GameLineup['Game_id'] == game]
gameDict = gameRatingsSubCleaned(gamePlayByPlay[:], gameLineup, eventCodes, verbose=True)
# Out:
# Counter 0
# Event Num 2
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 1  lineup 0: ['f1970daaab6bd4c23edea9c6e4305b12', '3fa713b9a00c76b7b09419786eaf79e0', '2d4ae904a46dd8141197a4bdbcbcebea', '86f33f0bc083cd2e9c543c4631d5690b', 'd32d7f7ead681a3c45ac0401b025169b']
# 1  lineup 1: ['ade82b71d52bf8ebd00f724b25c87e95', '7a1c1f680a11456d505f05fa70712213', '16d76c912992709c8be29b896b8f9417', '2ffe19dc39838eaa55a52d7b2fbd687c', '682ee02d38c947defb4cf5e30fba6f96']
# Counter 1
# Event Num 4
# []
# Jump Ball by 682ee02d38c947defb4cf5e30fba6f96
# Counter 2
# Event Num 7
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 3
# Event Num 8
# []
# Rebound by 16d76c912992709c8be29b896b8f9417
# Defensive Rebound
# Counter 4
# Event Num 9
# []
# Missed Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 misses shot
# Counter 5
# Event Num 10
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 6
# Event Num 11
# []
# Missed Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b misses shot
# Counter 7
# Event Num 12
# []
# Rebound by 2ffe19dc39838eaa55a52d7b2fbd687c
# Defensive Rebound
# Counter 8
# Event Num 13
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 9
# Event Num 14
# []
# Rebound by 2d4ae904a46dd8141197a4bdbcbcebea
# Defensive Rebound
# Counter 10
# Event Num 15
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 11
# Event Num 17
# []
# Foul by 86f33f0bc083cd2e9c543c4631d5690b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 12
# Event Num 19
# []
# Made Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 scores 3 points
# Counter 13
# Event Num 21
# []
# Made Shot by 3fa713b9a00c76b7b09419786eaf79e0
# 3fa713b9a00c76b7b09419786eaf79e0 scores 2 points
# Counter 14
# Event Num 22
# []
# Missed Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 misses shot
# Counter 15
# Event Num 23
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 16
# Event Num 24
# []
# Made Shot by 3fa713b9a00c76b7b09419786eaf79e0
# 3fa713b9a00c76b7b09419786eaf79e0 scores 2 points
# Counter 17
# Event Num 26
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 18
# Event Num 27
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 19
# Event Num 29
# []
# Rebound by 1f67aefd482a400ad8efa1f751128efb
# Counter 20
# Event Num 30
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 3 points
# Counter 21
# Event Num 31
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 22
# Event Num 32
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 23
# Event Num 33
# []
# Missed Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 misses shot
# Counter 24
# Event Num 35
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 25
# Event Num 36
# []
# Missed Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b misses shot
# Counter 26
# Event Num 38
# []
# Rebound by 2ffe19dc39838eaa55a52d7b2fbd687c
# Defensive Rebound
# Counter 27
# Event Num 39
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 28
# Event Num 41
# []
# Missed Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea misses shot
# Counter 29
# Event Num 42
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 30
# Event Num 43
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 31
# Event Num 44
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 32
# Event Num 45
# []
# Missed Shot by 3fa713b9a00c76b7b09419786eaf79e0
# 3fa713b9a00c76b7b09419786eaf79e0 misses shot
# Counter 33
# Event Num 46
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 34
# Event Num 47
# []
# Made Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 scores 2 points
# Counter 35
# Event Num 49
# []
# Made Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 scores 3 points
# Counter 36
# Event Num 51
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 37
# Event Num 52
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 38
# Event Num 53
# []
# Made Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 scores 3 points
# Counter 39
# Event Num 54
# []
# Timeout by 1f67aefd482a400ad8efa1f751128efb
# Counter 40
# Event Num 55
# []
# Instant Replay by 17f8fc22abaa6303b0e8e5d5debf1ed2
# Counter 41
# Event Num 56
# []
# Substitution by 7a1c1f680a11456d505f05fa70712213
# 758bfe4f98e1d0fc26ef37ef7f9688e4  replacing  7a1c1f680a11456d505f05fa70712213
# Counter 42
# Event Num 57
# []
# Substitution by 16d76c912992709c8be29b896b8f9417
# 71646c64f62c2748740c45b469e0d611  replacing  16d76c912992709c8be29b896b8f9417
# Counter 43
# Event Num 60
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 44
# Event Num 62
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 45
# Event Num 64
# []
# Rebound by 758bfe4f98e1d0fc26ef37ef7f9688e4
# Defensive Rebound
# Counter 46
# Event Num 65
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 47
# Event Num 67
# []
# Made Shot by 3fa713b9a00c76b7b09419786eaf79e0
# 3fa713b9a00c76b7b09419786eaf79e0 scores 2 points
# Counter 48
# Event Num 68
# []
# Missed Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 misses shot
# Counter 49
# Event Num 69
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 50
# Event Num 70
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 51
# Event Num 71
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 52
# Event Num 72
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 53
# Event Num 74
# []
# Timeout by aa557e7793b0037e089d5425fa9f1636
# Counter 54
# Event Num 75
# []
# Substitution by 682ee02d38c947defb4cf5e30fba6f96
# 59c61598abe68e36e2a0f6b24f5344a9  replacing  682ee02d38c947defb4cf5e30fba6f96
# Counter 55
# Event Num 76
# []
# Substitution by f1970daaab6bd4c23edea9c6e4305b12
# a0a99aa6dcb9947e8501d3c17e89cf01  replacing  f1970daaab6bd4c23edea9c6e4305b12
# Counter 56
# Event Num 79
# []
# Made Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea scores 2 points
# Counter 57
# Event Num 81
# []
# Missed Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 misses shot
# Counter 58
# Event Num 82
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 59
# Event Num 83
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 3 points
# Counter 60
# Event Num 85
# []
# Made Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 scores 3 points
# Counter 61
# Event Num 87
# []
# Foul by 2ffe19dc39838eaa55a52d7b2fbd687c
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 62
# Event Num 89
# []
# Substitution by ade82b71d52bf8ebd00f724b25c87e95
# ffc3716da11461d5337f42c2e9590797  replacing  ade82b71d52bf8ebd00f724b25c87e95
# Counter 63
# Event Num 90
# []
# Substitution by d32d7f7ead681a3c45ac0401b025169b
# 661390debadbc4b6d53f7d1883cdd279  replacing  d32d7f7ead681a3c45ac0401b025169b
# Counter 64
# Event Num 93
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 65
# Event Num 94
# []
# Rebound by 59c61598abe68e36e2a0f6b24f5344a9
# Defensive Rebound
# Counter 66
# Event Num 95
# []
# Missed Shot by 758bfe4f98e1d0fc26ef37ef7f9688e4
# 758bfe4f98e1d0fc26ef37ef7f9688e4 misses shot
# Counter 67
# Event Num 96
# []
# Rebound by 661390debadbc4b6d53f7d1883cdd279
# Defensive Rebound
# Counter 68
# Event Num 97
# []
# Made Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea scores 2 points
# Counter 69
# Event Num 98
# []
# Foul by 661390debadbc4b6d53f7d1883cdd279
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 70
# Event Num 100
# []
# Free Throw by 71646c64f62c2748740c45b469e0d611
# Made free throw by 71646c64f62c2748740c45b469e0d611
# Counter 71
# Event Num 101
# []
# Substitution by 2ffe19dc39838eaa55a52d7b2fbd687c
# 7a1c1f680a11456d505f05fa70712213  replacing  2ffe19dc39838eaa55a52d7b2fbd687c
# Counter 72
# Event Num 102
# []
# Substitution by 2d4ae904a46dd8141197a4bdbcbcebea
# bce6c859f6e409e45c3665c11e202ca9  replacing  2d4ae904a46dd8141197a4bdbcbcebea
# Counter 73
# Event Num 105
# []
# Free Throw by 71646c64f62c2748740c45b469e0d611
# Made final free throw by 71646c64f62c2748740c45b469e0d611
# Counter 74
# Event Num 106
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 75
# Event Num 108
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 76
# Event Num 109
# []
# Foul by 71646c64f62c2748740c45b469e0d611
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 77
# Event Num 111
# []
# Free Throw by 86f33f0bc083cd2e9c543c4631d5690b
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# Missed free throw by 86f33f0bc083cd2e9c543c4631d5690b
# Counter 78
# Event Num 112
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 79
# Event Num 113
# []
# Free Throw by 86f33f0bc083cd2e9c543c4631d5690b
# Missed last free throw by 86f33f0bc083cd2e9c543c4631d5690b
# ftteam1 ['758bfe4f98e1d0fc26ef37ef7f9688e4', '71646c64f62c2748740c45b469e0d611', '59c61598abe68e36e2a0f6b24f5344a9', 'ffc3716da11461d5337f42c2e9590797', '7a1c1f680a11456d505f05fa70712213']
# Counter 80
# Event Num 114
# []
# Rebound by ffc3716da11461d5337f42c2e9590797
# Defensive Rebound
# Counter 81
# Event Num 115
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 82
# Event Num 116
# []
# Substitution by a0a99aa6dcb9947e8501d3c17e89cf01
# f1970daaab6bd4c23edea9c6e4305b12  replacing  a0a99aa6dcb9947e8501d3c17e89cf01
# Counter 83
# Event Num 118
# []
# Foul by 3fa713b9a00c76b7b09419786eaf79e0
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 84
# Event Num 120
# []
# Missed Shot by 59c61598abe68e36e2a0f6b24f5344a9
# 59c61598abe68e36e2a0f6b24f5344a9 misses shot
# Counter 85
# Event Num 121
# []
# Rebound by 59c61598abe68e36e2a0f6b24f5344a9
# Offensive Rebound
# Counter 86
# Event Num 122
# []
# Made Shot by 59c61598abe68e36e2a0f6b24f5344a9
# 59c61598abe68e36e2a0f6b24f5344a9 scores 2 points
# Counter 87
# Event Num 123
# []
# Made Shot by 3fa713b9a00c76b7b09419786eaf79e0
# 3fa713b9a00c76b7b09419786eaf79e0 scores 2 points
# Counter 88
# Event Num 124
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 89
# Event Num 125
# []
# Rebound by 758bfe4f98e1d0fc26ef37ef7f9688e4
# Offensive Rebound
# Counter 90
# Event Num 126
# []
# Made Shot by 758bfe4f98e1d0fc26ef37ef7f9688e4
# 758bfe4f98e1d0fc26ef37ef7f9688e4 scores 2 points
# Counter 91
# Event Num 127
# []
# Missed Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 misses shot
# Counter 92
# Event Num 128
# []
# Rebound by 661390debadbc4b6d53f7d1883cdd279
# Offensive Rebound
# Counter 93
# Event Num 129
# []
# Missed Shot by 661390debadbc4b6d53f7d1883cdd279
# 661390debadbc4b6d53f7d1883cdd279 misses shot
# Counter 94
# Event Num 130
# []
# Rebound by ffc3716da11461d5337f42c2e9590797
# Defensive Rebound
# Counter 95
# Event Num 131
# []
# Missed Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 misses shot
# Counter 96
# Event Num 132
# []
# Rebound by 661390debadbc4b6d53f7d1883cdd279
# Defensive Rebound
# Counter 97
# Event Num 133
# []
# Made Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b scores 2 points
# Counter 98
# Event Num 135
# []
# Foul by 59c61598abe68e36e2a0f6b24f5344a9
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 99
# Event Num 137
# []
# Substitution by 3fa713b9a00c76b7b09419786eaf79e0
# 5b0d8dd8f942cf81c88a4ab317b20fc5  replacing  3fa713b9a00c76b7b09419786eaf79e0
# Counter 100
# Event Num 139
# []
# Free Throw by 86f33f0bc083cd2e9c543c4631d5690b
# Made final free throw by 86f33f0bc083cd2e9c543c4631d5690b
# Counter 101
# Event Num 140
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 102
# Event Num 141
# []
# Rebound by 5b0d8dd8f942cf81c88a4ab317b20fc5
# Defensive Rebound
# Counter 103
# Event Num 142
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 104
# Event Num 143
# []
# Substitution by 661390debadbc4b6d53f7d1883cdd279
# d32d7f7ead681a3c45ac0401b025169b  replacing  661390debadbc4b6d53f7d1883cdd279
# Counter 105
# Event Num 145
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 106
# Event Num 146
# []
# Rebound by 7a1c1f680a11456d505f05fa70712213
# Defensive Rebound
# Counter 107
# Event Num 147
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 108
# Event Num 148
# []
# Rebound by 1f67aefd482a400ad8efa1f751128efb
# Counter 109
# Event Num 149
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# Counter 110
# Event Num 158
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 2  lineup 0: ['bce6c859f6e409e45c3665c11e202ca9', 'e51630054008b5867f9fe3e04d1dd016', 'f1970daaab6bd4c23edea9c6e4305b12', '2d4ae904a46dd8141197a4bdbcbcebea', '661390debadbc4b6d53f7d1883cdd279']
# 2  lineup 1: ['7a1c1f680a11456d505f05fa70712213', 'ffc3716da11461d5337f42c2e9590797', '71646c64f62c2748740c45b469e0d611', '758bfe4f98e1d0fc26ef37ef7f9688e4', '682ee02d38c947defb4cf5e30fba6f96']
# Counter 111
# Event Num 159
# []
# Foul by f1970daaab6bd4c23edea9c6e4305b12
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 112
# Event Num 161
# []
# Substitution by 758bfe4f98e1d0fc26ef37ef7f9688e4
# 16d76c912992709c8be29b896b8f9417  replacing  758bfe4f98e1d0fc26ef37ef7f9688e4
# Counter 113
# Event Num 162
# []
# Substitution by 661390debadbc4b6d53f7d1883cdd279
# d32d7f7ead681a3c45ac0401b025169b  replacing  661390debadbc4b6d53f7d1883cdd279
# Counter 114
# Event Num 165
# []
# Made Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 scores 3 points
# Counter 115
# Event Num 167
# []
# Foul by ffc3716da11461d5337f42c2e9590797
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 116
# Event Num 169
# []
# Free Throw by d32d7f7ead681a3c45ac0401b025169b
# Made free throw by d32d7f7ead681a3c45ac0401b025169b
# Counter 117
# Event Num 170
# []
# Free Throw by d32d7f7ead681a3c45ac0401b025169b
# Made final free throw by d32d7f7ead681a3c45ac0401b025169b
# Counter 118
# Event Num 171
# []
# Missed Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 misses shot
# Counter 119
# Event Num 172
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 120
# Event Num 173
# []
# Made Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea scores 2 points
# Counter 121
# Event Num 175
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 122
# Event Num 177
# []
# Made Shot by e51630054008b5867f9fe3e04d1dd016
# e51630054008b5867f9fe3e04d1dd016 scores 3 points
# Counter 123
# Event Num 179
# []
# Made Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 scores 2 points
# Counter 124
# Event Num 181
# []
# Foul by e51630054008b5867f9fe3e04d1dd016
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 125
# Event Num 183
# []
# Free Throw by 71646c64f62c2748740c45b469e0d611
# Made final free throw by 71646c64f62c2748740c45b469e0d611
# Counter 126
# Event Num 184
# []
# Foul by 71646c64f62c2748740c45b469e0d611
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 127
# Event Num 186
# []
# Free Throw by e51630054008b5867f9fe3e04d1dd016
# Made free throw by e51630054008b5867f9fe3e04d1dd016
# Counter 128
# Event Num 187
# []
# Free Throw by e51630054008b5867f9fe3e04d1dd016
# Made final free throw by e51630054008b5867f9fe3e04d1dd016
# Counter 129
# Event Num 188
# []
# Missed Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 misses shot
# Counter 130
# Event Num 189
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Offensive Rebound
# Counter 131
# Event Num 190
# []
# Made Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 scores 3 points
# Counter 132
# Event Num 192
# []
# Made Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 scores 2 points
# Counter 133
# Event Num 193
# []
# Missed Shot by ffc3716da11461d5337f42c2e9590797
# ffc3716da11461d5337f42c2e9590797 misses shot
# Counter 134
# Event Num 194
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 135
# Event Num 195
# []
# Made Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea scores 2 points
# Counter 136
# Event Num 197
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 137
# Event Num 198
# []
# Rebound by f1970daaab6bd4c23edea9c6e4305b12
# Defensive Rebound
# Counter 138
# Event Num 199
# []
# Made Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 scores 2 points
# Counter 139
# Event Num 200
# []
# Missed Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 misses shot
# Counter 140
# Event Num 201
# []
# Rebound by 71646c64f62c2748740c45b469e0d611
# Offensive Rebound
# Counter 141
# Event Num 202
# []
# Foul by e51630054008b5867f9fe3e04d1dd016
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 142
# Event Num 204
# []
# Free Throw by 71646c64f62c2748740c45b469e0d611
# Made free throw by 71646c64f62c2748740c45b469e0d611
# Counter 143
# Event Num 205
# []
# Substitution by ffc3716da11461d5337f42c2e9590797
# ade82b71d52bf8ebd00f724b25c87e95  replacing  ffc3716da11461d5337f42c2e9590797
# Counter 144
# Event Num 207
# []
# Free Throw by 71646c64f62c2748740c45b469e0d611
# Missed last free throw by 71646c64f62c2748740c45b469e0d611
# ftteam1 ['7a1c1f680a11456d505f05fa70712213', 'ffc3716da11461d5337f42c2e9590797', '71646c64f62c2748740c45b469e0d611', '682ee02d38c947defb4cf5e30fba6f96', '16d76c912992709c8be29b896b8f9417']
# Counter 145
# Event Num 208
# []
# Rebound by 2d4ae904a46dd8141197a4bdbcbcebea
# Defensive Rebound
# Counter 146
# Event Num 209
# []
# Foul by 16d76c912992709c8be29b896b8f9417
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 147
# Event Num 211
# []
# Substitution by 71646c64f62c2748740c45b469e0d611
# 2ffe19dc39838eaa55a52d7b2fbd687c  replacing  71646c64f62c2748740c45b469e0d611
# Counter 148
# Event Num 213
# []
# Missed Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b misses shot
# Counter 149
# Event Num 214
# []
# Rebound by ade82b71d52bf8ebd00f724b25c87e95
# Defensive Rebound
# Counter 150
# Event Num 215
# []
# Missed Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 misses shot
# Counter 151
# Event Num 216
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 152
# Event Num 217
# []
# Turnover by f1970daaab6bd4c23edea9c6e4305b12
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 153
# Event Num 218
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 154
# Event Num 219
# []
# Rebound by 2d4ae904a46dd8141197a4bdbcbcebea
# Defensive Rebound
# Counter 155
# Event Num 220
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 3 points
# Counter 156
# Event Num 222
# []
# Turnover by 2ffe19dc39838eaa55a52d7b2fbd687c
# 5df2526720f9ac092e202de922f5a65f turnover
# Counter 157
# Event Num 223
# []
# Timeout by 1f67aefd482a400ad8efa1f751128efb
# Counter 158
# Event Num 224
# []
# Substitution by 7a1c1f680a11456d505f05fa70712213
# 71646c64f62c2748740c45b469e0d611  replacing  7a1c1f680a11456d505f05fa70712213
# Counter 159
# Event Num 226
# []
# Made Shot by e51630054008b5867f9fe3e04d1dd016
# e51630054008b5867f9fe3e04d1dd016 scores 3 points
# Counter 160
# Event Num 228
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 161
# Event Num 229
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Offensive Rebound
# Counter 162
# Event Num 230
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 163
# Event Num 231
# []
# Missed Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea misses shot
# Counter 164
# Event Num 232
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 165
# Event Num 233
# []
# Turnover by 2ffe19dc39838eaa55a52d7b2fbd687c
# 5df2526720f9ac092e202de922f5a65f turnover
# Counter 166
# Event Num 235
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 2 points
# Counter 167
# Event Num 237
# []
# Made Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 scores 3 points
# Counter 168
# Event Num 239
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 169
# Event Num 240
# []
# Foul by d32d7f7ead681a3c45ac0401b025169b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 170
# Event Num 242
# []
# Free Throw by ade82b71d52bf8ebd00f724b25c87e95
# Made free throw by ade82b71d52bf8ebd00f724b25c87e95
# Counter 171
# Event Num 243
# []
# Substitution by 682ee02d38c947defb4cf5e30fba6f96
# 7a1c1f680a11456d505f05fa70712213  replacing  682ee02d38c947defb4cf5e30fba6f96
# Counter 172
# Event Num 244
# []
# Substitution by 2d4ae904a46dd8141197a4bdbcbcebea
# 86f33f0bc083cd2e9c543c4631d5690b  replacing  2d4ae904a46dd8141197a4bdbcbcebea
# Counter 173
# Event Num 247
# []
# Free Throw by ade82b71d52bf8ebd00f724b25c87e95
# Made final free throw by ade82b71d52bf8ebd00f724b25c87e95
# Counter 174
# Event Num 248
# []
# Turnover by bce6c859f6e409e45c3665c11e202ca9
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 175
# Event Num 250
# []
# Made Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 scores 3 points
# Counter 176
# Event Num 252
# []
# Timeout by aa557e7793b0037e089d5425fa9f1636
# Counter 177
# Event Num 253
# []
# Foul by d32d7f7ead681a3c45ac0401b025169b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 178
# Event Num 255
# []
# Turnover by d32d7f7ead681a3c45ac0401b025169b
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 179
# Event Num 256
# []
# Made Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 scores 3 points
# Counter 180
# Event Num 258
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 181
# Event Num 259
# []
# Substitution by bce6c859f6e409e45c3665c11e202ca9
# 2d4ae904a46dd8141197a4bdbcbcebea  replacing  bce6c859f6e409e45c3665c11e202ca9
# Counter 182
# Event Num 261
# []
# Missed Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea misses shot
# Counter 183
# Event Num 262
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Offensive Rebound
# Counter 184
# Event Num 263
# []
# Missed Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b misses shot
# Counter 185
# Event Num 264
# []
# Rebound by 16d76c912992709c8be29b896b8f9417
# Defensive Rebound
# Counter 186
# Event Num 265
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 187
# Event Num 266
# []
# Rebound by 2ffe19dc39838eaa55a52d7b2fbd687c
# Offensive Rebound
# Counter 188
# Event Num 267
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 189
# Event Num 268
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 190
# Event Num 269
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# Missed shot possession fix
# Add off possession to  ['16d76c912992709c8be29b896b8f9417', 'ade82b71d52bf8ebd00f724b25c87e95', '2ffe19dc39838eaa55a52d7b2fbd687c', '71646c64f62c2748740c45b469e0d611', '7a1c1f680a11456d505f05fa70712213']
# Add def possession to  ['e51630054008b5867f9fe3e04d1dd016', 'f1970daaab6bd4c23edea9c6e4305b12', 'd32d7f7ead681a3c45ac0401b025169b', '86f33f0bc083cd2e9c543c4631d5690b', '2d4ae904a46dd8141197a4bdbcbcebea']
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 191
# Event Num 270
# []
# Missed Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 misses shot
# Counter 192
# Event Num 271
# []
# Rebound by f1970daaab6bd4c23edea9c6e4305b12
# Defensive Rebound
# Counter 193
# Event Num 272
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 194
# Event Num 274
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 2 points
# Counter 195
# Event Num 275
# []
# Made Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 scores 3 points
# Counter 196
# Event Num 277
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 197
# Event Num 278
# []
# Rebound by 2d4ae904a46dd8141197a4bdbcbcebea
# Defensive Rebound
# Counter 198
# Event Num 279
# []
# Foul by ade82b71d52bf8ebd00f724b25c87e95
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 199
# Event Num 281
# []
# Free Throw by f1970daaab6bd4c23edea9c6e4305b12
# Missed free throw by f1970daaab6bd4c23edea9c6e4305b12
# Counter 200
# Event Num 282
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 201
# Event Num 283
# []
# Substitution by 16d76c912992709c8be29b896b8f9417
# 682ee02d38c947defb4cf5e30fba6f96  replacing  16d76c912992709c8be29b896b8f9417
# Counter 202
# Event Num 284
# []
# Substitution by d32d7f7ead681a3c45ac0401b025169b
# 661390debadbc4b6d53f7d1883cdd279  replacing  d32d7f7ead681a3c45ac0401b025169b
# Counter 203
# Event Num 287
# []
# Free Throw by f1970daaab6bd4c23edea9c6e4305b12
# Made final free throw by f1970daaab6bd4c23edea9c6e4305b12
# Counter 204
# Event Num 288
# []
# Made Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 scores 2 points
# Counter 205
# Event Num 289
# []
# Missed Shot by e51630054008b5867f9fe3e04d1dd016
# e51630054008b5867f9fe3e04d1dd016 misses shot
# Counter 206
# Event Num 291
# []
# Rebound by 2ffe19dc39838eaa55a52d7b2fbd687c
# Defensive Rebound
# Counter 207
# Event Num 292
# []
# Foul by f1970daaab6bd4c23edea9c6e4305b12
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 208
# Event Num 294
# []
# Instant Replay by 0c741cb7e14988aa77147e5469428dd1
# Counter 209
# Event Num 295
# []
# Substitution by 661390debadbc4b6d53f7d1883cdd279
# d32d7f7ead681a3c45ac0401b025169b  replacing  661390debadbc4b6d53f7d1883cdd279
# Counter 210
# Event Num 297
# []
# Free Throw by 682ee02d38c947defb4cf5e30fba6f96
# Missed free throw by 682ee02d38c947defb4cf5e30fba6f96
# Counter 211
# Event Num 298
# []
# Rebound by 1f67aefd482a400ad8efa1f751128efb
# Counter 212
# Event Num 299
# []
# Free Throw by 682ee02d38c947defb4cf5e30fba6f96
# Made final free throw by 682ee02d38c947defb4cf5e30fba6f96
# Counter 213
# Event Num 300
# []
# Missed Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b misses shot
# Counter 214
# Event Num 301
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 215
# Event Num 302
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 2 ended
# Counter 216
# Event Num 307
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 3  lineup 0: ['f1970daaab6bd4c23edea9c6e4305b12', '3fa713b9a00c76b7b09419786eaf79e0', '2d4ae904a46dd8141197a4bdbcbcebea', '86f33f0bc083cd2e9c543c4631d5690b', 'd32d7f7ead681a3c45ac0401b025169b']
# 3  lineup 1: ['ade82b71d52bf8ebd00f724b25c87e95', '7a1c1f680a11456d505f05fa70712213', '16d76c912992709c8be29b896b8f9417', '2ffe19dc39838eaa55a52d7b2fbd687c', '682ee02d38c947defb4cf5e30fba6f96']
# Counter 217
# Event Num 308
# []
# Made Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 scores 2 points
# Counter 218
# Event Num 309
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 219
# Event Num 311
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 220
# Event Num 312
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 221
# Event Num 313
# []
# Missed Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea misses shot
# Counter 222
# Event Num 314
# []
# Rebound by ade82b71d52bf8ebd00f724b25c87e95
# Defensive Rebound
# Counter 223
# Event Num 315
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 3 points
# Counter 224
# Event Num 317
# []
# Foul by 2ffe19dc39838eaa55a52d7b2fbd687c
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 225
# Event Num 319
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 226
# Event Num 320
# []
# Rebound by ade82b71d52bf8ebd00f724b25c87e95
# Defensive Rebound
# Counter 227
# Event Num 321
# []
# Made Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 scores 3 points
# Counter 228
# Event Num 323
# []
# Missed Shot by 3fa713b9a00c76b7b09419786eaf79e0
# 3fa713b9a00c76b7b09419786eaf79e0 misses shot
# Counter 229
# Event Num 324
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 230
# Event Num 325
# []
# Made Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 scores 2 points
# Counter 231
# Event Num 326
# []
# Timeout by aa557e7793b0037e089d5425fa9f1636
# Counter 232
# Event Num 327
# []
# Foul by 16d76c912992709c8be29b896b8f9417
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 233
# Event Num 329
# []
# Free Throw by d32d7f7ead681a3c45ac0401b025169b
# Made free throw by d32d7f7ead681a3c45ac0401b025169b
# Counter 234
# Event Num 330
# []
# Free Throw by d32d7f7ead681a3c45ac0401b025169b
# Made final free throw by d32d7f7ead681a3c45ac0401b025169b
# Counter 235
# Event Num 331
# []
# Turnover by 16d76c912992709c8be29b896b8f9417
# 5df2526720f9ac092e202de922f5a65f turnover
# Counter 236
# Event Num 332
# []
# Foul by 682ee02d38c947defb4cf5e30fba6f96
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 237
# Event Num 334
# []
# Free Throw by f1970daaab6bd4c23edea9c6e4305b12
# Missed free throw by f1970daaab6bd4c23edea9c6e4305b12
# Counter 238
# Event Num 335
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 239
# Event Num 336
# []
# Free Throw by f1970daaab6bd4c23edea9c6e4305b12
# Made final free throw by f1970daaab6bd4c23edea9c6e4305b12
# Counter 240
# Event Num 337
# []
# Turnover by 2ffe19dc39838eaa55a52d7b2fbd687c
# 5df2526720f9ac092e202de922f5a65f turnover
# Counter 241
# Event Num 339
# []
# Missed Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea misses shot
# Counter 242
# Event Num 341
# []
# Rebound by 1f67aefd482a400ad8efa1f751128efb
# Counter 243
# Event Num 342
# []
# Foul by d32d7f7ead681a3c45ac0401b025169b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 244
# Event Num 344
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# Missed shot possession fix
# Add off possession to  ['f1970daaab6bd4c23edea9c6e4305b12', '3fa713b9a00c76b7b09419786eaf79e0', '2d4ae904a46dd8141197a4bdbcbcebea', '86f33f0bc083cd2e9c543c4631d5690b', 'd32d7f7ead681a3c45ac0401b025169b']
# Add def possession to  ['ade82b71d52bf8ebd00f724b25c87e95', '7a1c1f680a11456d505f05fa70712213', '16d76c912992709c8be29b896b8f9417', '2ffe19dc39838eaa55a52d7b2fbd687c', '682ee02d38c947defb4cf5e30fba6f96']
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 245
# Event Num 345
# []
# Rebound by 86f33f0bc083cd2e9c543c4631d5690b
# Defensive Rebound
# Counter 246
# Event Num 346
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 247
# Event Num 347
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 248
# Event Num 348
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 249
# Event Num 349
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 250
# Event Num 350
# []
# Made Shot by 3fa713b9a00c76b7b09419786eaf79e0
# 3fa713b9a00c76b7b09419786eaf79e0 scores 2 points
# Counter 251
# Event Num 352
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 3 points
# Counter 252
# Event Num 354
# []
# Turnover by d32d7f7ead681a3c45ac0401b025169b
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 253
# Event Num 355
# []
# Substitution by 7a1c1f680a11456d505f05fa70712213
# 71646c64f62c2748740c45b469e0d611  replacing  7a1c1f680a11456d505f05fa70712213
# Counter 254
# Event Num 357
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 2 points
# Counter 255
# Event Num 358
# []
# Timeout by aa557e7793b0037e089d5425fa9f1636
# Counter 256
# Event Num 359
# []
# Foul by 16d76c912992709c8be29b896b8f9417
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 257
# Event Num 361
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 258
# Event Num 362
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 259
# Event Num 363
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 3 points
# Counter 260
# Event Num 364
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 261
# Event Num 365
# []
# Foul by 86f33f0bc083cd2e9c543c4631d5690b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 262
# Event Num 367
# []
# Violation by d32d7f7ead681a3c45ac0401b025169b
# Counter 263
# Event Num 368
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 264
# Event Num 370
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 265
# Event Num 371
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 266
# Event Num 372
# []
# Missed Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 misses shot
# Counter 267
# Event Num 373
# []
# Rebound by 2d4ae904a46dd8141197a4bdbcbcebea
# Defensive Rebound
# Counter 268
# Event Num 374
# []
# Missed Shot by 2d4ae904a46dd8141197a4bdbcbcebea
# 2d4ae904a46dd8141197a4bdbcbcebea misses shot
# Counter 269
# Event Num 375
# []
# Rebound by 16d76c912992709c8be29b896b8f9417
# Defensive Rebound
# Counter 270
# Event Num 376
# []
# Missed Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 misses shot
# Counter 271
# Event Num 377
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Offensive Rebound
# Counter 272
# Event Num 378
# []
# Missed Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 misses shot
# Counter 273
# Event Num 379
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Offensive Rebound
# Counter 274
# Event Num 380
# []
# Made Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 scores 3 points
# Counter 275
# Event Num 382
# []
# Turnover by aa557e7793b0037e089d5425fa9f1636
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 276
# Event Num 383
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 277
# Event Num 384
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 278
# Event Num 385
# []
# Substitution by f1970daaab6bd4c23edea9c6e4305b12
# a0a99aa6dcb9947e8501d3c17e89cf01  replacing  f1970daaab6bd4c23edea9c6e4305b12
# Counter 279
# Event Num 387
# []
# Turnover by 86f33f0bc083cd2e9c543c4631d5690b
# Missed shot possession fix
# Add off possession to subbed players ['f1970daaab6bd4c23edea9c6e4305b12']
# Add def possession to subbed players []
# Add off possession to  ['ade82b71d52bf8ebd00f724b25c87e95', '16d76c912992709c8be29b896b8f9417', '2ffe19dc39838eaa55a52d7b2fbd687c', '682ee02d38c947defb4cf5e30fba6f96', '71646c64f62c2748740c45b469e0d611']
# Add def possession to  ['f1970daaab6bd4c23edea9c6e4305b12', '3fa713b9a00c76b7b09419786eaf79e0', '2d4ae904a46dd8141197a4bdbcbcebea', '86f33f0bc083cd2e9c543c4631d5690b', 'd32d7f7ead681a3c45ac0401b025169b']
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 280
# Event Num 389
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 2 points
# Counter 281
# Event Num 390
# []
# Foul by 86f33f0bc083cd2e9c543c4631d5690b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 282
# Event Num 392
# []
# Substitution by ade82b71d52bf8ebd00f724b25c87e95
# 59c61598abe68e36e2a0f6b24f5344a9  replacing  ade82b71d52bf8ebd00f724b25c87e95
# Counter 283
# Event Num 393
# []
# Substitution by 682ee02d38c947defb4cf5e30fba6f96
# 7a1c1f680a11456d505f05fa70712213  replacing  682ee02d38c947defb4cf5e30fba6f96
# Counter 284
# Event Num 394
# []
# Substitution by d32d7f7ead681a3c45ac0401b025169b
# 661390debadbc4b6d53f7d1883cdd279  replacing  d32d7f7ead681a3c45ac0401b025169b
# Counter 285
# Event Num 398
# []
# Free Throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Made final free throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Counter 286
# Event Num 399
# []
# Foul by 71646c64f62c2748740c45b469e0d611
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 287
# Event Num 401
# []
# Free Throw by 86f33f0bc083cd2e9c543c4631d5690b
# Missed free throw by 86f33f0bc083cd2e9c543c4631d5690b
# Counter 288
# Event Num 402
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 289
# Event Num 403
# []
# Free Throw by 86f33f0bc083cd2e9c543c4631d5690b
# Made free throw by 86f33f0bc083cd2e9c543c4631d5690b
# Counter 290
# Event Num 404
# []
# Substitution by 2d4ae904a46dd8141197a4bdbcbcebea
# bce6c859f6e409e45c3665c11e202ca9  replacing  2d4ae904a46dd8141197a4bdbcbcebea
# Counter 291
# Event Num 406
# []
# Free Throw by 86f33f0bc083cd2e9c543c4631d5690b
# Made final free throw by 86f33f0bc083cd2e9c543c4631d5690b
# Counter 292
# Event Num 407
# []
# Made Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 scores 3 points
# Counter 293
# Event Num 409
# []
# Foul by bce6c859f6e409e45c3665c11e202ca9
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 294
# Event Num 411
# []
# Turnover by bce6c859f6e409e45c3665c11e202ca9
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 295
# Event Num 412
# []
# Foul by bce6c859f6e409e45c3665c11e202ca9
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 296
# Event Num 413
# []
# Instant Replay by c655e33acd106a68f92bb61e8124bcf7
# Counter 297
# Event Num 414
# []
# Free Throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Made free throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Counter 298
# Event Num 415
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 299
# Event Num 416
# []
# Rebound by a0a99aa6dcb9947e8501d3c17e89cf01
# Defensive Rebound
# Counter 300
# Event Num 417
# []
# Made Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b scores 2 points
# Counter 301
# Event Num 418
# []
# Foul by 3fa713b9a00c76b7b09419786eaf79e0
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 302
# Event Num 420
# []
# Free Throw by 59c61598abe68e36e2a0f6b24f5344a9
# Missed free throw by 59c61598abe68e36e2a0f6b24f5344a9
# Counter 303
# Event Num 421
# []
# Rebound by 1f67aefd482a400ad8efa1f751128efb
# Counter 304
# Event Num 422
# []
# Substitution by 16d76c912992709c8be29b896b8f9417
# 758bfe4f98e1d0fc26ef37ef7f9688e4  replacing  16d76c912992709c8be29b896b8f9417
# Counter 305
# Event Num 423
# []
# Substitution by 2ffe19dc39838eaa55a52d7b2fbd687c
# ffc3716da11461d5337f42c2e9590797  replacing  2ffe19dc39838eaa55a52d7b2fbd687c
# Counter 306
# Event Num 426
# []
# Free Throw by 59c61598abe68e36e2a0f6b24f5344a9
# Missed last free throw by 59c61598abe68e36e2a0f6b24f5344a9
# ftteam1 ['16d76c912992709c8be29b896b8f9417', '2ffe19dc39838eaa55a52d7b2fbd687c', '71646c64f62c2748740c45b469e0d611', '59c61598abe68e36e2a0f6b24f5344a9', '7a1c1f680a11456d505f05fa70712213']
# Counter 307
# Event Num 427
# []
# Rebound by 3fa713b9a00c76b7b09419786eaf79e0
# Defensive Rebound
# Counter 308
# Event Num 428
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 309
# Event Num 429
# []
# Rebound by 3fa713b9a00c76b7b09419786eaf79e0
# Offensive Rebound
# Counter 310
# Event Num 430
# []
# Missed Shot by a0a99aa6dcb9947e8501d3c17e89cf01
# a0a99aa6dcb9947e8501d3c17e89cf01 misses shot
# Counter 311
# Event Num 431
# []
# Rebound by 758bfe4f98e1d0fc26ef37ef7f9688e4
# Defensive Rebound
# Counter 312
# Event Num 432
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 313
# Event Num 433
# []
# Rebound by 86f33f0bc083cd2e9c543c4631d5690b
# Defensive Rebound
# Counter 314
# Event Num 434
# []
# Made Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b scores 2 points
# Counter 315
# Event Num 435
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 316
# Event Num 436
# []
# Rebound by 1f67aefd482a400ad8efa1f751128efb
# Counter 317
# Event Num 437
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# Counter 318
# Event Num 444
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 4  lineup 0: ['bce6c859f6e409e45c3665c11e202ca9', 'e51630054008b5867f9fe3e04d1dd016', '5b0d8dd8f942cf81c88a4ab317b20fc5', '661390debadbc4b6d53f7d1883cdd279', 'a0a99aa6dcb9947e8501d3c17e89cf01']
# 4  lineup 1: ['59c61598abe68e36e2a0f6b24f5344a9', 'ade82b71d52bf8ebd00f724b25c87e95', '7a1c1f680a11456d505f05fa70712213', '71646c64f62c2748740c45b469e0d611', '758bfe4f98e1d0fc26ef37ef7f9688e4']
# Counter 319
# Event Num 445
# []
# Missed Shot by e51630054008b5867f9fe3e04d1dd016
# e51630054008b5867f9fe3e04d1dd016 misses shot
# Counter 320
# Event Num 446
# []
# Rebound by 7a1c1f680a11456d505f05fa70712213
# Defensive Rebound
# Counter 321
# Event Num 447
# []
# Made Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 scores 2 points
# Counter 322
# Event Num 449
# []
# Missed Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 misses shot
# Counter 323
# Event Num 450
# []
# Rebound by 7a1c1f680a11456d505f05fa70712213
# Defensive Rebound
# Counter 324
# Event Num 451
# []
# Missed Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 misses shot
# Counter 325
# Event Num 452
# []
# Rebound by a0a99aa6dcb9947e8501d3c17e89cf01
# Defensive Rebound
# Counter 326
# Event Num 453
# []
# Missed Shot by 661390debadbc4b6d53f7d1883cdd279
# 661390debadbc4b6d53f7d1883cdd279 misses shot
# Counter 327
# Event Num 454
# []
# Rebound by 7a1c1f680a11456d505f05fa70712213
# Defensive Rebound
# Counter 328
# Event Num 455
# []
# Made Shot by 758bfe4f98e1d0fc26ef37ef7f9688e4
# 758bfe4f98e1d0fc26ef37ef7f9688e4 scores 3 points
# Counter 329
# Event Num 457
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 2 points
# Counter 330
# Event Num 458
# []
# Made Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 scores 2 points
# Counter 331
# Event Num 459
# []
# Timeout by aa557e7793b0037e089d5425fa9f1636
# Counter 332
# Event Num 460
# []
# Substitution by 758bfe4f98e1d0fc26ef37ef7f9688e4
# 2ffe19dc39838eaa55a52d7b2fbd687c  replacing  758bfe4f98e1d0fc26ef37ef7f9688e4
# Counter 333
# Event Num 461
# []
# Substitution by a0a99aa6dcb9947e8501d3c17e89cf01
# f1970daaab6bd4c23edea9c6e4305b12  replacing  a0a99aa6dcb9947e8501d3c17e89cf01
# Counter 334
# Event Num 462
# []
# Substitution by 661390debadbc4b6d53f7d1883cdd279
# d32d7f7ead681a3c45ac0401b025169b  replacing  661390debadbc4b6d53f7d1883cdd279
# Counter 335
# Event Num 463
# []
# Substitution by 5b0d8dd8f942cf81c88a4ab317b20fc5
# 86f33f0bc083cd2e9c543c4631d5690b  replacing  5b0d8dd8f942cf81c88a4ab317b20fc5
# Counter 336
# Event Num 468
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 2 points
# Counter 337
# Event Num 470
# []
# Foul by 86f33f0bc083cd2e9c543c4631d5690b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 338
# Event Num 472
# []
# Free Throw by 71646c64f62c2748740c45b469e0d611
# Made free throw by 71646c64f62c2748740c45b469e0d611
# Counter 339
# Event Num 473
# []
# Substitution by 59c61598abe68e36e2a0f6b24f5344a9
# 682ee02d38c947defb4cf5e30fba6f96  replacing  59c61598abe68e36e2a0f6b24f5344a9
# Counter 340
# Event Num 475
# []
# Free Throw by 71646c64f62c2748740c45b469e0d611
# Made final free throw by 71646c64f62c2748740c45b469e0d611
# Counter 341
# Event Num 476
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 342
# Event Num 478
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 343
# Event Num 479
# []
# Rebound by bce6c859f6e409e45c3665c11e202ca9
# Defensive Rebound
# Counter 344
# Event Num 480
# []
# Foul by ade82b71d52bf8ebd00f724b25c87e95
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 345
# Event Num 482
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 346
# Event Num 483
# []
# Rebound by aa557e7793b0037e089d5425fa9f1636
# Counter 347
# Event Num 484
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 348
# Event Num 485
# []
# Rebound by f1970daaab6bd4c23edea9c6e4305b12
# Offensive Rebound
# Counter 349
# Event Num 486
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 350
# Event Num 488
# []
# Rebound by f1970daaab6bd4c23edea9c6e4305b12
# Offensive Rebound
# Counter 351
# Event Num 489
# []
# Missed Shot by e51630054008b5867f9fe3e04d1dd016
# e51630054008b5867f9fe3e04d1dd016 misses shot
# Counter 352
# Event Num 490
# []
# Rebound by ade82b71d52bf8ebd00f724b25c87e95
# Defensive Rebound
# Counter 353
# Event Num 491
# []
# Missed Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 misses shot
# Counter 354
# Event Num 492
# []
# Rebound by bce6c859f6e409e45c3665c11e202ca9
# Defensive Rebound
# Counter 355
# Event Num 493
# []
# Missed Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b misses shot
# Counter 356
# Event Num 494
# []
# Rebound by 7a1c1f680a11456d505f05fa70712213
# Defensive Rebound
# Counter 357
# Event Num 495
# []
# Made Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 scores 2 points
# Counter 358
# Event Num 496
# []
# Made Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 scores 2 points
# Counter 359
# Event Num 497
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 360
# Event Num 499
# []
# Foul by ade82b71d52bf8ebd00f724b25c87e95
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 361
# Event Num 501
# []
# Timeout by 1f67aefd482a400ad8efa1f751128efb
# Counter 362
# Event Num 502
# []
# Substitution by 7a1c1f680a11456d505f05fa70712213
# 16d76c912992709c8be29b896b8f9417  replacing  7a1c1f680a11456d505f05fa70712213
# Counter 363
# Event Num 504
# []
# Made Shot by e51630054008b5867f9fe3e04d1dd016
# e51630054008b5867f9fe3e04d1dd016 scores 2 points
# Counter 364
# Event Num 506
# []
# Made Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c scores 2 points
# Counter 365
# Event Num 507
# []
# Missed Shot by f1970daaab6bd4c23edea9c6e4305b12
# f1970daaab6bd4c23edea9c6e4305b12 misses shot
# Counter 366
# Event Num 508
# []
# Rebound by 682ee02d38c947defb4cf5e30fba6f96
# Defensive Rebound
# Counter 367
# Event Num 509
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 368
# Event Num 511
# []
# Foul by e51630054008b5867f9fe3e04d1dd016
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 369
# Event Num 513
# []
# Free Throw by 682ee02d38c947defb4cf5e30fba6f96
# Made final free throw by 682ee02d38c947defb4cf5e30fba6f96
# Counter 370
# Event Num 514
# []
# Made Shot by d32d7f7ead681a3c45ac0401b025169b
# d32d7f7ead681a3c45ac0401b025169b scores 2 points
# Counter 371
# Event Num 516
# []
# Foul by d32d7f7ead681a3c45ac0401b025169b
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 372
# Event Num 518
# []
# Free Throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Made free throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Counter 373
# Event Num 519
# []
# Free Throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Made final free throw by 2ffe19dc39838eaa55a52d7b2fbd687c
# Counter 374
# Event Num 520
# []
# Foul by ade82b71d52bf8ebd00f724b25c87e95
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 375
# Event Num 522
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 2 points
# Counter 376
# Event Num 523
# []
# Made Shot by 71646c64f62c2748740c45b469e0d611
# 71646c64f62c2748740c45b469e0d611 scores 3 points
# Counter 377
# Event Num 525
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 3 points
# Counter 378
# Event Num 527
# []
# Missed Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 misses shot
# Counter 379
# Event Num 529
# []
# Rebound by d32d7f7ead681a3c45ac0401b025169b
# Defensive Rebound
# Counter 380
# Event Num 530
# []
# Made Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b scores 3 points
# Counter 381
# Event Num 532
# []
# Timeout by 1f67aefd482a400ad8efa1f751128efb
# Counter 382
# Event Num 533
# []
# Instant Replay by 95bc7573315e75c5dc1b0d99fff15fc6
# Counter 383
# Event Num 534
# []
# Substitution by 71646c64f62c2748740c45b469e0d611
# 7a1c1f680a11456d505f05fa70712213  replacing  71646c64f62c2748740c45b469e0d611
# Counter 384
# Event Num 536
# []
# Made Shot by 16d76c912992709c8be29b896b8f9417
# 16d76c912992709c8be29b896b8f9417 scores 3 points
# Counter 385
# Event Num 538
# []
# Missed Shot by e51630054008b5867f9fe3e04d1dd016
# e51630054008b5867f9fe3e04d1dd016 misses shot
# Counter 386
# Event Num 539
# []
# Rebound by 2ffe19dc39838eaa55a52d7b2fbd687c
# Defensive Rebound
# Counter 387
# Event Num 540
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 388
# Event Num 542
# []
# Foul by f1970daaab6bd4c23edea9c6e4305b12
# Foul on team cff694c8186a4bd377de400e4f60fe47
# Counter 389
# Event Num 544
# []
# Substitution by f1970daaab6bd4c23edea9c6e4305b12
# 661390debadbc4b6d53f7d1883cdd279  replacing  f1970daaab6bd4c23edea9c6e4305b12
# Counter 390
# Event Num 545
# []
# Substitution by d32d7f7ead681a3c45ac0401b025169b
# a0a99aa6dcb9947e8501d3c17e89cf01  replacing  d32d7f7ead681a3c45ac0401b025169b
# Counter 391
# Event Num 548
# []
# Free Throw by 682ee02d38c947defb4cf5e30fba6f96
# Missed last free throw by 682ee02d38c947defb4cf5e30fba6f96
# ftteam1 ['ade82b71d52bf8ebd00f724b25c87e95', '2ffe19dc39838eaa55a52d7b2fbd687c', '682ee02d38c947defb4cf5e30fba6f96', '16d76c912992709c8be29b896b8f9417', '7a1c1f680a11456d505f05fa70712213']
# Counter 392
# Event Num 549
# []
# Rebound by 661390debadbc4b6d53f7d1883cdd279
# Defensive Rebound
# Counter 393
# Event Num 550
# []
# Foul by 16d76c912992709c8be29b896b8f9417
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 394
# Event Num 552
# []
# Free Throw by bce6c859f6e409e45c3665c11e202ca9
# Made free throw by bce6c859f6e409e45c3665c11e202ca9
# Counter 395
# Event Num 553
# []
# Free Throw by bce6c859f6e409e45c3665c11e202ca9
# Made final free throw by bce6c859f6e409e45c3665c11e202ca9
# Counter 396
# Event Num 554
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 397
# Event Num 556
# []
# Made Shot by 86f33f0bc083cd2e9c543c4631d5690b
# 86f33f0bc083cd2e9c543c4631d5690b scores 2 points
# Counter 398
# Event Num 557
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 399
# Event Num 558
# []
# Missed Shot by 2ffe19dc39838eaa55a52d7b2fbd687c
# 2ffe19dc39838eaa55a52d7b2fbd687c misses shot
# Counter 400
# Event Num 559
# []
# Rebound by 86f33f0bc083cd2e9c543c4631d5690b
# Defensive Rebound
# Counter 401
# Event Num 560
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 2 points
# Counter 402
# Event Num 562
# []
# Made Shot by 7a1c1f680a11456d505f05fa70712213
# 7a1c1f680a11456d505f05fa70712213 scores 2 points
# Counter 403
# Event Num 563
# []
# Turnover by 86f33f0bc083cd2e9c543c4631d5690b
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 404
# Event Num 565
# []
# Made Shot by 682ee02d38c947defb4cf5e30fba6f96
# 682ee02d38c947defb4cf5e30fba6f96 scores 2 points
# Counter 405
# Event Num 567
# []
# Made Shot by bce6c859f6e409e45c3665c11e202ca9
# bce6c859f6e409e45c3665c11e202ca9 scores 2 points
# Counter 406
# Event Num 569
# []
# Missed Shot by ade82b71d52bf8ebd00f724b25c87e95
# ade82b71d52bf8ebd00f724b25c87e95 misses shot
# Counter 407
# Event Num 570
# []
# Rebound by 86f33f0bc083cd2e9c543c4631d5690b
# Defensive Rebound
# Counter 408
# Event Num 571
# []
# Foul by 7a1c1f680a11456d505f05fa70712213
# Foul on team 5df2526720f9ac092e202de922f5a65f
# Counter 409
# Event Num 573
# []
# Substitution by 7a1c1f680a11456d505f05fa70712213
# 3d784b11288b827cbd97d6dbcd6602ec  replacing  7a1c1f680a11456d505f05fa70712213
# Counter 410
# Event Num 574
# []
# Substitution by 16d76c912992709c8be29b896b8f9417
# ffc3716da11461d5337f42c2e9590797  replacing  16d76c912992709c8be29b896b8f9417
# Counter 411
# Event Num 575
# []
# Substitution by 2ffe19dc39838eaa55a52d7b2fbd687c
# 745fd2a3e78aaceb805e7bc19cf5f126  replacing  2ffe19dc39838eaa55a52d7b2fbd687c
# Counter 412
# Event Num 576
# []
# Substitution by 682ee02d38c947defb4cf5e30fba6f96
# 24e7fa348c6b922fe075358bdabc0b29  replacing  682ee02d38c947defb4cf5e30fba6f96
# Counter 413
# Event Num 581
# []
# Free Throw by e51630054008b5867f9fe3e04d1dd016
# Made free throw by e51630054008b5867f9fe3e04d1dd016
# Counter 414
# Event Num 582
# []
# Substitution by 86f33f0bc083cd2e9c543c4631d5690b
# df04a338c0749cef4022674be6803411  replacing  86f33f0bc083cd2e9c543c4631d5690b
# Counter 415
# Event Num 584
# []
# Free Throw by e51630054008b5867f9fe3e04d1dd016
# Made final free throw by e51630054008b5867f9fe3e04d1dd016
# Counter 416
# Event Num 585
# []
# Made Shot by ffc3716da11461d5337f42c2e9590797
# ffc3716da11461d5337f42c2e9590797 scores 3 points
# Counter 417
# Event Num 587
# []
# Turnover by bce6c859f6e409e45c3665c11e202ca9
# cff694c8186a4bd377de400e4f60fe47 turnover
# Counter 418
# Event Num 588
# []
# Turnover by 1f67aefd482a400ad8efa1f751128efb
# 5df2526720f9ac092e202de922f5a65f turnover
# Counter 419
# Event Num 589
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 4 ended
# Counter 420
# Event Num 0
# []
# Final Box Printed by 0370a0d090da0d0edc6319f120187e0e

# %%
gameDict
# Out:
# {'01e5ad8b6847aa68c70fe1acc54a884d': array([0, 0, 0, 0]),
#  '053f6b9f70bbc1116e3af3c8a2ecdbe6': array([0, 0, 0, 0]),
#  '16d76c912992709c8be29b896b8f9417': array([88, 80, 64, 64]),
#  '24e7fa348c6b922fe075358bdabc0b29': array([3, 0, 2, 2]),
#  '2d4ae904a46dd8141197a4bdbcbcebea': array([65, 71, 56, 57]),
#  '2ffe19dc39838eaa55a52d7b2fbd687c': array([96, 80, 71, 71]),
#  '3d784b11288b827cbd97d6dbcd6602ec': array([3, 0, 2, 2]),
#  '3fa713b9a00c76b7b09419786eaf79e0': array([41, 55, 43, 43]),
#  '49399a850e5eedd6953e506218ebd4b2': array([0, 0, 0, 0]),
#  '59c61598abe68e36e2a0f6b24f5344a9': array([22, 22, 19, 19]),
#  '5a634567f5022bf46e1c990096fceb9f': array([0, 0, 0, 0]),
#  '5b0d8dd8f942cf81c88a4ab317b20fc5': array([2, 7, 6, 6]),
#  '661390debadbc4b6d53f7d1883cdd279': array([25, 29, 26, 26]),
#  '682ee02d38c947defb4cf5e30fba6f96': array([89, 74, 65, 64]),
#  '71646c64f62c2748740c45b469e0d611': array([85, 72, 61, 59]),
#  '745fd2a3e78aaceb805e7bc19cf5f126': array([3, 0, 2, 2]),
#  '758bfe4f98e1d0fc26ef37ef7f9688e4': array([22, 18, 21, 19]),
#  '7a1c1f680a11456d505f05fa70712213': array([78, 74, 68, 68]),
#  '86f33f0bc083cd2e9c543c4631d5690b': array([77, 93, 71, 71]),
#  'a0a99aa6dcb9947e8501d3c17e89cf01': array([25, 28, 24, 23]),
#  'ade82b71d52bf8ebd00f724b25c87e95': array([100,  76,  73,  73]),
#  'bce6c859f6e409e45c3665c11e202ca9': array([64, 70, 50, 50]),
#  'cf76849b2d40cd089fa8fe823846b717': array([0, 0, 0, 0]),
#  'd1159a16ddc833d8787756a5b90b9141': array([0, 0, 0, 0]),
#  'd32d7f7ead681a3c45ac0401b025169b': array([79, 93, 68, 68]),
#  'df04a338c0749cef4022674be6803411': array([0, 3, 2, 2]),
#  'e51630054008b5867f9fe3e04d1dd016': array([63, 67, 47, 47]),
#  'f1970daaab6bd4c23edea9c6e4305b12': array([79, 94, 70, 71]),
#  'f53d9aa67d5fed6677cf8d57a4707485': array([0, 0, 0, 0]),
#  'ffc3716da11461d5337f42c2e9590797': array([21, 24, 20, 18])}

# %%
rdPBP = readablePlayByPlay(gamePlayByPlay, gameLineup, eventCodes)
# Out:
# Team0 cff694c8186a4bd377de400e4f60fe47
# Team1 5df2526720f9ac092e202de922f5a65f

# %%
gamePlayByPlay[318:]
# Out:
#                                Game_id  Event_Num  Event_Msg_Type  Period  \
# 5320  394fd09c602f2cfe11644107673ae1c1        444              12       4
# 5321  394fd09c602f2cfe11644107673ae1c1        445               2       4
# 5322  394fd09c602f2cfe11644107673ae1c1        446               4       4
# 5323  394fd09c602f2cfe11644107673ae1c1        447               1       4
# 5324  394fd09c602f2cfe11644107673ae1c1        449               2       4
# 5325  394fd09c602f2cfe11644107673ae1c1        450               4       4
# 5326  394fd09c602f2cfe11644107673ae1c1        451               2       4
# 5327  394fd09c602f2cfe11644107673ae1c1        452               4       4
# 5328  394fd09c602f2cfe11644107673ae1c1        453               2       4
# 5329  394fd09c602f2cfe11644107673ae1c1        454               4       4
# 5330  394fd09c602f2cfe11644107673ae1c1        455               1       4
# 5331  394fd09c602f2cfe11644107673ae1c1        457               1       4
# 5332  394fd09c602f2cfe11644107673ae1c1        458               1       4
# 5333  394fd09c602f2cfe11644107673ae1c1        459               9       4
# 5334  394fd09c602f2cfe11644107673ae1c1        460               8       4
# 5336  394fd09c602f2cfe11644107673ae1c1        461               8       4
# 5337  394fd09c602f2cfe11644107673ae1c1        462               8       4
# 5335  394fd09c602f2cfe11644107673ae1c1        463               8       4
# 5338  394fd09c602f2cfe11644107673ae1c1        468               1       4
# 5339  394fd09c602f2cfe11644107673ae1c1        470               6       4
# 5340  394fd09c602f2cfe11644107673ae1c1        472               3       4
# 5341  394fd09c602f2cfe11644107673ae1c1        473               8       4
# 5342  394fd09c602f2cfe11644107673ae1c1        475               3       4
# 5343  394fd09c602f2cfe11644107673ae1c1        476               1       4
# 5344  394fd09c602f2cfe11644107673ae1c1        478               2       4
# 5345  394fd09c602f2cfe11644107673ae1c1        479               4       4
# 5346  394fd09c602f2cfe11644107673ae1c1        480               6       4
# 5347  394fd09c602f2cfe11644107673ae1c1        482               2       4
# 5348  394fd09c602f2cfe11644107673ae1c1        483               4       4
# 5349  394fd09c602f2cfe11644107673ae1c1        484               2       4
# ...                                ...        ...             ...     ...
# 5393  394fd09c602f2cfe11644107673ae1c1        548               3       4
# 5394  394fd09c602f2cfe11644107673ae1c1        549               4       4
# 5395  394fd09c602f2cfe11644107673ae1c1        550               6       4
# 5396  394fd09c602f2cfe11644107673ae1c1        552               3       4
# 5397  394fd09c602f2cfe11644107673ae1c1        553               3       4
# 5398  394fd09c602f2cfe11644107673ae1c1        554               1       4
# 5399  394fd09c602f2cfe11644107673ae1c1        556               1       4
# 5400  394fd09c602f2cfe11644107673ae1c1        557              20       4
# 5401  394fd09c602f2cfe11644107673ae1c1        558               2       4
# 5402  394fd09c602f2cfe11644107673ae1c1        559               4       4
# 5403  394fd09c602f2cfe11644107673ae1c1        560               1       4
# 5404  394fd09c602f2cfe11644107673ae1c1        562               1       4
# 5405  394fd09c602f2cfe11644107673ae1c1        563               5       4
# 5406  394fd09c602f2cfe11644107673ae1c1        565               1       4
# 5407  394fd09c602f2cfe11644107673ae1c1        567               1       4
# 5408  394fd09c602f2cfe11644107673ae1c1        569               2       4
# 5409  394fd09c602f2cfe11644107673ae1c1        570               4       4
# 5410  394fd09c602f2cfe11644107673ae1c1        571               6       4
# 5414  394fd09c602f2cfe11644107673ae1c1        573               8       4
# 5412  394fd09c602f2cfe11644107673ae1c1        574               8       4
# 5413  394fd09c602f2cfe11644107673ae1c1        575               8       4
# 5411  394fd09c602f2cfe11644107673ae1c1        576               8       4
# 5415  394fd09c602f2cfe11644107673ae1c1        581               3       4
# 5416  394fd09c602f2cfe11644107673ae1c1        582               8       4
# 5417  394fd09c602f2cfe11644107673ae1c1        584               3       4
# 5418  394fd09c602f2cfe11644107673ae1c1        585               1       4
# 5419  394fd09c602f2cfe11644107673ae1c1        587               5       4
# 5420  394fd09c602f2cfe11644107673ae1c1        588               5       4
# 5421  394fd09c602f2cfe11644107673ae1c1        589              13       4
# 5422  394fd09c602f2cfe11644107673ae1c1          0              16       4
#
#       WC_Time  PC_Time  Action_Type  Option1  Option2  Option3  \
# 5320   706770     7200            0        0        0        0
# 5321   707010     6950           98        2        0        0
# 5322   707020     6930            0        0        0        0
# 5323   707060     6910           41        2        1        0
# 5324   707280     6680           79        3        0        0
# 5325   707300     6670            0        0        0        0
# 5326   707440     6530            1        3        0        0
# 5327   707460     6520            0        0        0        0
# 5328   707610     6370            1        2        0        0
# 5329   707630     6360            0        0        0        0
# 5330   707850     6110            1        3        0        0
# 5331   708060     5900          101        2        0        0
# 5332   708190     5780           79        2        0        0
# 5333   708260     5770            1        0        0        0
# 5334   709080     5770            0        0        0        0
# 5336   709080     5770            0        0        0        0
# 5337   709080     5770            0        0        0        0
# 5335   709080     5770            0        0        0        0
# 5338   710440     5690           79        2        0        0
# 5339   710670     5490            2        0        0        2
# 5340   710940     5490           11        1        0        0
# 5341   710950     5490            0        0        0        0
# 5342   711130     5490           12        1        0        0
# 5343   711270     5370           58        2        0        0
# 5344   711550     5100           63        2        0        0
# 5345   711570     5090            0        0        0        0
# 5346   711610     5050            1        0        0        0
# 5347   711860     4950           86        2        0        0
# 5348   711890     4940            0        0        0        0
# 5349   712200     4820          101        2        0        0
# ...       ...      ...          ...      ...      ...      ...
# 5393   719850     1990           10        2        0        0
# 5394   719860     1990            0        0        0        0
# 5395   719980     1870            2        0        0        2
# 5396   720490     1870           11        1        0        0
# 5397   720500     1870           12        1        0        0
# 5398   720590     1710           52        2        0        0
# 5399   720710     1590           79        2        0        0
# 5400   720920     1410            3        0        0        0
# 5401   721120     1330            1        3        0        0
# 5402   721150     1330            0        0        0        0
# 5403   721170     1280           98        2        1        0
# 5404   721410     1050           79        2        0        0
# 5405   721570      930            2        1        0        0
# 5406   721770      740          108        2        0        0
# 5407   721860      700            1        2        0        0
# 5408   722070      512            1        3        0        0
# 5409   722090      500            0        0        0        0
# 5410   722140      467           28        1        0        2
# 5414   722310      467            0        0        0        0
# 5412   722310      467            0        0        0        0
# 5413   722310      467            0        0        0        0
# 5411   722310      467            0        0        0        0
# 5415   722510      467           11        1        0        0
# 5416   722530      467            0        0        0        0
# 5417   722710      467           12        1        0        0
# 5418   722910      304            1        3        0        0
# 5419   723000      268           45        0        0        0
# 5420   723320       28           11        0        0        0
# 5421   723550        0            0        0        0        0
# 5422   723610        0            0        0        0        0
#
#                                Team_id                           Person1  \
# 5320  cff694c8186a4bd377de400e4f60fe47  0370a0d090da0d0edc6319f120187e0e
# 5321  cff694c8186a4bd377de400e4f60fe47  e51630054008b5867f9fe3e04d1dd016
# 5322  cff694c8186a4bd377de400e4f60fe47  7a1c1f680a11456d505f05fa70712213
# 5323  5df2526720f9ac092e202de922f5a65f  71646c64f62c2748740c45b469e0d611
# 5324  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5325  cff694c8186a4bd377de400e4f60fe47  7a1c1f680a11456d505f05fa70712213
# 5326  5df2526720f9ac092e202de922f5a65f  7a1c1f680a11456d505f05fa70712213
# 5327  5df2526720f9ac092e202de922f5a65f  a0a99aa6dcb9947e8501d3c17e89cf01
# 5328  cff694c8186a4bd377de400e4f60fe47  661390debadbc4b6d53f7d1883cdd279
# 5329  cff694c8186a4bd377de400e4f60fe47  7a1c1f680a11456d505f05fa70712213
# 5330  5df2526720f9ac092e202de922f5a65f  758bfe4f98e1d0fc26ef37ef7f9688e4
# 5331  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5332  5df2526720f9ac092e202de922f5a65f  7a1c1f680a11456d505f05fa70712213
# 5333  cff694c8186a4bd377de400e4f60fe47  aa557e7793b0037e089d5425fa9f1636
# 5334  cff694c8186a4bd377de400e4f60fe47  758bfe4f98e1d0fc26ef37ef7f9688e4
# 5336  cff694c8186a4bd377de400e4f60fe47  a0a99aa6dcb9947e8501d3c17e89cf01
# 5337  cff694c8186a4bd377de400e4f60fe47  661390debadbc4b6d53f7d1883cdd279
# 5335  cff694c8186a4bd377de400e4f60fe47  5b0d8dd8f942cf81c88a4ab317b20fc5
# 5338  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5339  5df2526720f9ac092e202de922f5a65f  86f33f0bc083cd2e9c543c4631d5690b
# 5340  5df2526720f9ac092e202de922f5a65f  71646c64f62c2748740c45b469e0d611
# 5341  5df2526720f9ac092e202de922f5a65f  59c61598abe68e36e2a0f6b24f5344a9
# 5342  5df2526720f9ac092e202de922f5a65f  71646c64f62c2748740c45b469e0d611
# 5343  cff694c8186a4bd377de400e4f60fe47  d32d7f7ead681a3c45ac0401b025169b
# 5344  5df2526720f9ac092e202de922f5a65f  2ffe19dc39838eaa55a52d7b2fbd687c
# 5345  5df2526720f9ac092e202de922f5a65f  bce6c859f6e409e45c3665c11e202ca9
# 5346  cff694c8186a4bd377de400e4f60fe47  ade82b71d52bf8ebd00f724b25c87e95
# 5347  cff694c8186a4bd377de400e4f60fe47  86f33f0bc083cd2e9c543c4631d5690b
# 5348  cff694c8186a4bd377de400e4f60fe47  aa557e7793b0037e089d5425fa9f1636
# 5349  cff694c8186a4bd377de400e4f60fe47  f1970daaab6bd4c23edea9c6e4305b12
# ...                                ...                               ...
# 5393  5df2526720f9ac092e202de922f5a65f  682ee02d38c947defb4cf5e30fba6f96
# 5394  5df2526720f9ac092e202de922f5a65f  661390debadbc4b6d53f7d1883cdd279
# 5395  cff694c8186a4bd377de400e4f60fe47  16d76c912992709c8be29b896b8f9417
# 5396  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5397  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5398  5df2526720f9ac092e202de922f5a65f  682ee02d38c947defb4cf5e30fba6f96
# 5399  cff694c8186a4bd377de400e4f60fe47  86f33f0bc083cd2e9c543c4631d5690b
# 5400  5df2526720f9ac092e202de922f5a65f  0370a0d090da0d0edc6319f120187e0e
# 5401  5df2526720f9ac092e202de922f5a65f  2ffe19dc39838eaa55a52d7b2fbd687c
# 5402  5df2526720f9ac092e202de922f5a65f  86f33f0bc083cd2e9c543c4631d5690b
# 5403  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5404  5df2526720f9ac092e202de922f5a65f  7a1c1f680a11456d505f05fa70712213
# 5405  cff694c8186a4bd377de400e4f60fe47  86f33f0bc083cd2e9c543c4631d5690b
# 5406  5df2526720f9ac092e202de922f5a65f  682ee02d38c947defb4cf5e30fba6f96
# 5407  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5408  5df2526720f9ac092e202de922f5a65f  ade82b71d52bf8ebd00f724b25c87e95
# 5409  5df2526720f9ac092e202de922f5a65f  86f33f0bc083cd2e9c543c4631d5690b
# 5410  cff694c8186a4bd377de400e4f60fe47  7a1c1f680a11456d505f05fa70712213
# 5414  cff694c8186a4bd377de400e4f60fe47  7a1c1f680a11456d505f05fa70712213
# 5412  cff694c8186a4bd377de400e4f60fe47  16d76c912992709c8be29b896b8f9417
# 5413  cff694c8186a4bd377de400e4f60fe47  2ffe19dc39838eaa55a52d7b2fbd687c
# 5411  cff694c8186a4bd377de400e4f60fe47  682ee02d38c947defb4cf5e30fba6f96
# 5415  cff694c8186a4bd377de400e4f60fe47  e51630054008b5867f9fe3e04d1dd016
# 5416  cff694c8186a4bd377de400e4f60fe47  86f33f0bc083cd2e9c543c4631d5690b
# 5417  cff694c8186a4bd377de400e4f60fe47  e51630054008b5867f9fe3e04d1dd016
# 5418  5df2526720f9ac092e202de922f5a65f  ffc3716da11461d5337f42c2e9590797
# 5419  cff694c8186a4bd377de400e4f60fe47  bce6c859f6e409e45c3665c11e202ca9
# 5420  5df2526720f9ac092e202de922f5a65f  1f67aefd482a400ad8efa1f751128efb
# 5421  cff694c8186a4bd377de400e4f60fe47  0370a0d090da0d0edc6319f120187e0e
# 5422  1473d70e5646a26de3c52aa1abd85b1f  0370a0d090da0d0edc6319f120187e0e
#
#                                Person2                           Person3  \
# 5320  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5321  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5322  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5323  7a1c1f680a11456d505f05fa70712213  0370a0d090da0d0edc6319f120187e0e
# 5324  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5325  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5326  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5327  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5328  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5329  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5330  7a1c1f680a11456d505f05fa70712213  0370a0d090da0d0edc6319f120187e0e
# 5331  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5332  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5333  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5334  2ffe19dc39838eaa55a52d7b2fbd687c  0370a0d090da0d0edc6319f120187e0e
# 5336  f1970daaab6bd4c23edea9c6e4305b12  0370a0d090da0d0edc6319f120187e0e
# 5337  d32d7f7ead681a3c45ac0401b025169b  0370a0d090da0d0edc6319f120187e0e
# 5335  86f33f0bc083cd2e9c543c4631d5690b  0370a0d090da0d0edc6319f120187e0e
# 5338  f1970daaab6bd4c23edea9c6e4305b12  0370a0d090da0d0edc6319f120187e0e
# 5339  71646c64f62c2748740c45b469e0d611  96a5a2607526673603df5c2aec94f8ee
# 5340  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5341  682ee02d38c947defb4cf5e30fba6f96  0370a0d090da0d0edc6319f120187e0e
# 5342  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5343  e51630054008b5867f9fe3e04d1dd016  0370a0d090da0d0edc6319f120187e0e
# 5344  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5345  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5346  bce6c859f6e409e45c3665c11e202ca9  96a5a2607526673603df5c2aec94f8ee
# 5347  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5348  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5349  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# ...                                ...                               ...
# 5393  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5394  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5395  bce6c859f6e409e45c3665c11e202ca9  96a5a2607526673603df5c2aec94f8ee
# 5396  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5397  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5398  2ffe19dc39838eaa55a52d7b2fbd687c  0370a0d090da0d0edc6319f120187e0e
# 5399  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5400  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5401  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5402  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5403  a0a99aa6dcb9947e8501d3c17e89cf01  0370a0d090da0d0edc6319f120187e0e
# 5404  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5405  2ffe19dc39838eaa55a52d7b2fbd687c  0370a0d090da0d0edc6319f120187e0e
# 5406  7a1c1f680a11456d505f05fa70712213  0370a0d090da0d0edc6319f120187e0e
# 5407  a0a99aa6dcb9947e8501d3c17e89cf01  0370a0d090da0d0edc6319f120187e0e
# 5408  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5409  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5410  e51630054008b5867f9fe3e04d1dd016  a1277b068e23d54de9770dd59b31879e
# 5414  3d784b11288b827cbd97d6dbcd6602ec  0370a0d090da0d0edc6319f120187e0e
# 5412  ffc3716da11461d5337f42c2e9590797  0370a0d090da0d0edc6319f120187e0e
# 5413  745fd2a3e78aaceb805e7bc19cf5f126  0370a0d090da0d0edc6319f120187e0e
# 5411  24e7fa348c6b922fe075358bdabc0b29  0370a0d090da0d0edc6319f120187e0e
# 5415  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5416  df04a338c0749cef4022674be6803411  0370a0d090da0d0edc6319f120187e0e
# 5417  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5418  3d784b11288b827cbd97d6dbcd6602ec  0370a0d090da0d0edc6319f120187e0e
# 5419  0370a0d090da0d0edc6319f120187e0e  a1277b068e23d54de9770dd59b31879e
# 5420  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5421  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5422  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#       Team_id_type  Person1_type  Person2_type  Person3_type
# 5320             3             0             0             0
# 5321             3             5             0             0
# 5322             3             4             0             0
# 5323             2             4             4             0
# 5324             3             5             0             0
# 5325             3             4             0             0
# 5326             2             4             0             0
# 5327             2             5             0             0
# 5328             3             5             0             0
# 5329             3             4             0             0
# 5330             2             4             4             0
# 5331             3             5             0             0
# 5332             2             4             0             0
# 5333             3             3             0             0
# 5334             3             4             4             0
# 5336             3             5             5             0
# 5337             3             5             5             0
# 5335             3             5             5             0
# 5338             3             5             5             0
# 5339             2             5             4             1
# 5340             2             4             0             0
# 5341             2             4             4             0
# 5342             2             4             0             0
# 5343             3             5             5             0
# 5344             2             4             0             0
# 5345             2             5             0             0
# 5346             3             4             5             1
# 5347             3             5             0             0
# 5348             3             3             0             0
# 5349             3             5             0             0
# ...            ...           ...           ...           ...
# 5393             2             4             0             0
# 5394             2             5             0             0
# 5395             3             4             5             1
# 5396             3             5             0             0
# 5397             3             5             0             0
# 5398             2             4             4             0
# 5399             3             5             0             0
# 5400             2             0             0             0
# 5401             2             4             0             0
# 5402             2             5             0             0
# 5403             3             5             5             0
# 5404             2             4             0             0
# 5405             3             5             4             0
# 5406             2             4             4             0
# 5407             3             5             5             0
# 5408             2             4             0             0
# 5409             2             5             0             0
# 5410             3             4             5             1
# 5414             3             4             4             0
# 5412             3             4             4             0
# 5413             3             4             4             0
# 5411             3             4             4             0
# 5415             3             5             0             0
# 5416             3             5             5             0
# 5417             3             5             0             0
# 5418             2             4             4             0
# 5419             3             5             0             1
# 5420             2             2             0             0
# 5421             3             0             0             0
# 5422             0             0             0             0
#
# [103 rows x 18 columns]

# %%
rdPBP[318:]
# Out:
#                                Game_id  Event_Num     Event_Msg_Type  Period  \
# 5320  394fd09c602f2cfe11644107673ae1c1        444       Start Period       4
# 5321  394fd09c602f2cfe11644107673ae1c1        445        Missed Shot       4
# 5322  394fd09c602f2cfe11644107673ae1c1        446            Rebound       4
# 5323  394fd09c602f2cfe11644107673ae1c1        447          Made Shot       4
# 5324  394fd09c602f2cfe11644107673ae1c1        449        Missed Shot       4
# 5325  394fd09c602f2cfe11644107673ae1c1        450            Rebound       4
# 5326  394fd09c602f2cfe11644107673ae1c1        451        Missed Shot       4
# 5327  394fd09c602f2cfe11644107673ae1c1        452            Rebound       4
# 5328  394fd09c602f2cfe11644107673ae1c1        453        Missed Shot       4
# 5329  394fd09c602f2cfe11644107673ae1c1        454            Rebound       4
# 5330  394fd09c602f2cfe11644107673ae1c1        455          Made Shot       4
# 5331  394fd09c602f2cfe11644107673ae1c1        457          Made Shot       4
# 5332  394fd09c602f2cfe11644107673ae1c1        458          Made Shot       4
# 5333  394fd09c602f2cfe11644107673ae1c1        459            Timeout       4
# 5334  394fd09c602f2cfe11644107673ae1c1        460       Substitution       4
# 5336  394fd09c602f2cfe11644107673ae1c1        461       Substitution       4
# 5337  394fd09c602f2cfe11644107673ae1c1        462       Substitution       4
# 5335  394fd09c602f2cfe11644107673ae1c1        463       Substitution       4
# 5338  394fd09c602f2cfe11644107673ae1c1        468          Made Shot       4
# 5339  394fd09c602f2cfe11644107673ae1c1        470               Foul       4
# 5340  394fd09c602f2cfe11644107673ae1c1        472         Free Throw       4
# 5341  394fd09c602f2cfe11644107673ae1c1        473       Substitution       4
# 5342  394fd09c602f2cfe11644107673ae1c1        475         Free Throw       4
# 5343  394fd09c602f2cfe11644107673ae1c1        476          Made Shot       4
# 5344  394fd09c602f2cfe11644107673ae1c1        478        Missed Shot       4
# 5345  394fd09c602f2cfe11644107673ae1c1        479            Rebound       4
# 5346  394fd09c602f2cfe11644107673ae1c1        480               Foul       4
# 5347  394fd09c602f2cfe11644107673ae1c1        482        Missed Shot       4
# 5348  394fd09c602f2cfe11644107673ae1c1        483            Rebound       4
# 5349  394fd09c602f2cfe11644107673ae1c1        484        Missed Shot       4
# ...                                ...        ...                ...     ...
# 5393  394fd09c602f2cfe11644107673ae1c1        548         Free Throw       4
# 5394  394fd09c602f2cfe11644107673ae1c1        549            Rebound       4
# 5395  394fd09c602f2cfe11644107673ae1c1        550               Foul       4
# 5396  394fd09c602f2cfe11644107673ae1c1        552         Free Throw       4
# 5397  394fd09c602f2cfe11644107673ae1c1        553         Free Throw       4
# 5398  394fd09c602f2cfe11644107673ae1c1        554          Made Shot       4
# 5399  394fd09c602f2cfe11644107673ae1c1        556          Made Shot       4
# 5400  394fd09c602f2cfe11644107673ae1c1        557           Stoppage       4
# 5401  394fd09c602f2cfe11644107673ae1c1        558        Missed Shot       4
# 5402  394fd09c602f2cfe11644107673ae1c1        559            Rebound       4
# 5403  394fd09c602f2cfe11644107673ae1c1        560          Made Shot       4
# 5404  394fd09c602f2cfe11644107673ae1c1        562          Made Shot       4
# 5405  394fd09c602f2cfe11644107673ae1c1        563           Turnover       4
# 5406  394fd09c602f2cfe11644107673ae1c1        565          Made Shot       4
# 5407  394fd09c602f2cfe11644107673ae1c1        567          Made Shot       4
# 5408  394fd09c602f2cfe11644107673ae1c1        569        Missed Shot       4
# 5409  394fd09c602f2cfe11644107673ae1c1        570            Rebound       4
# 5410  394fd09c602f2cfe11644107673ae1c1        571               Foul       4
# 5414  394fd09c602f2cfe11644107673ae1c1        573       Substitution       4
# 5412  394fd09c602f2cfe11644107673ae1c1        574       Substitution       4
# 5413  394fd09c602f2cfe11644107673ae1c1        575       Substitution       4
# 5411  394fd09c602f2cfe11644107673ae1c1        576       Substitution       4
# 5415  394fd09c602f2cfe11644107673ae1c1        581         Free Throw       4
# 5416  394fd09c602f2cfe11644107673ae1c1        582       Substitution       4
# 5417  394fd09c602f2cfe11644107673ae1c1        584         Free Throw       4
# 5418  394fd09c602f2cfe11644107673ae1c1        585          Made Shot       4
# 5419  394fd09c602f2cfe11644107673ae1c1        587           Turnover       4
# 5420  394fd09c602f2cfe11644107673ae1c1        588           Turnover       4
# 5421  394fd09c602f2cfe11644107673ae1c1        589         End Period       4
# 5422  394fd09c602f2cfe11644107673ae1c1          0  Final Box Printed       4
#
#       WC_Time  PC_Time                        Action_Type  Option1  Option2  \
# 5320   706770     7200                                           0        0
# 5321   707010     6950                 Cutting Layup Shot        2        0
# 5322   707020     6930                            Unknown        0        0
# 5323   707060     6910                 Running Layup Shot        2        1
# 5324   707280     6680                   Pullup Jump shot        3        0
# 5325   707300     6670                            Unknown        0        0
# 5326   707440     6530                          Jump Shot        3        0
# 5327   707460     6520                            Unknown        0        0
# 5328   707610     6370                          Jump Shot        2        0
# 5329   707630     6360                            Unknown        0        0
# 5330   707850     6110                          Jump Shot        3        0
# 5331   708060     5900         Driving Floating Jump Shot        2        0
# 5332   708190     5780                   Pullup Jump shot        2        0
# 5333   708260     5770                            Regular        0        0
# 5334   709080     5770                                           0        0
# 5336   709080     5770                                           0        0
# 5337   709080     5770                                           0        0
# 5335   709080     5770                                           0        0
# 5338   710440     5690                   Pullup Jump shot        2        0
# 5339   710670     5490                           Shooting        0        0
# 5340   710940     5490                  Free Throw 1 of 2        1        0
# 5341   710950     5490                                           0        0
# 5342   711130     5490                  Free Throw 2 of 2        1        0
# 5343   711270     5370               Turnaround Hook Shot        2        0
# 5344   711550     5100                 Fadeaway Jump Shot        2        0
# 5345   711570     5090                            Unknown        0        0
# 5346   711610     5050                           Personal        0        0
# 5347   711860     4950           Turnaround Fadeaway shot        2        0
# 5348   711890     4940                            Unknown        0        0
# 5349   712200     4820         Driving Floating Jump Shot        2        0
# ...       ...      ...                                ...      ...      ...
# 5393   719850     1990                  Free Throw 1 of 1        2        0
# 5394   719860     1990                            Unknown        0        0
# 5395   719980     1870                           Shooting        0        0
# 5396   720490     1870                  Free Throw 1 of 2        1        0
# 5397   720500     1870                  Free Throw 2 of 2        1        0
# 5398   720590     1710                Alley Oop Dunk Shot        2        0
# 5399   720710     1590                   Pullup Jump shot        2        0
# 5400   720920     1410                      Out-of-Bounds        0        0
# 5401   721120     1330                          Jump Shot        3        0
# 5402   721150     1330                            Unknown        0        0
# 5403   721170     1280                 Cutting Layup Shot        2        1
# 5404   721410     1050                   Pullup Jump shot        2        0
# 5405   721570      930                          Lost Ball        1        0
# 5406   721770      740                  Cutting Dunk Shot        2        0
# 5407   721860      700                          Jump Shot        2        0
# 5408   722070      512                          Jump Shot        3        0
# 5409   722090      500                            Unknown        0        0
# 5410   722140      467                      Personal Take        1        0
# 5414   722310      467                                           0        0
# 5412   722310      467                                           0        0
# 5413   722310      467                                           0        0
# 5411   722310      467                                           0        0
# 5415   722510      467                  Free Throw 1 of 2        1        0
# 5416   722530      467                                           0        0
# 5417   722710      467                  Free Throw 2 of 2        1        0
# 5418   722910      304                          Jump Shot        3        0
# 5419   723000      268  Out of Bounds - Bad Pass Turnover        0        0
# 5420   723320       28                Shot Clock Turnover        0        0
# 5421   723550        0                                           0        0
# 5422   723610        0                                           0        0
#
#       Option3    Team_id                           Person1  \
# 5320        0      Team0  0370a0d090da0d0edc6319f120187e0e
# 5321        0      Team0  e51630054008b5867f9fe3e04d1dd016
# 5322        0      Team1  7a1c1f680a11456d505f05fa70712213
# 5323        0      Team1  71646c64f62c2748740c45b469e0d611
# 5324        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5325        0      Team1  7a1c1f680a11456d505f05fa70712213
# 5326        0      Team1  7a1c1f680a11456d505f05fa70712213
# 5327        0      Team0  a0a99aa6dcb9947e8501d3c17e89cf01
# 5328        0      Team0  661390debadbc4b6d53f7d1883cdd279
# 5329        0      Team1  7a1c1f680a11456d505f05fa70712213
# 5330        0      Team1  758bfe4f98e1d0fc26ef37ef7f9688e4
# 5331        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5332        0      Team1  7a1c1f680a11456d505f05fa70712213
# 5333        0      Team0  aa557e7793b0037e089d5425fa9f1636
# 5334        0      Team1  758bfe4f98e1d0fc26ef37ef7f9688e4
# 5336        0      Team0  a0a99aa6dcb9947e8501d3c17e89cf01
# 5337        0      Team0  661390debadbc4b6d53f7d1883cdd279
# 5335        0      Team0  5b0d8dd8f942cf81c88a4ab317b20fc5
# 5338        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5339        2      Team0  86f33f0bc083cd2e9c543c4631d5690b
# 5340        0      Team1  71646c64f62c2748740c45b469e0d611
# 5341        0      Team1  59c61598abe68e36e2a0f6b24f5344a9
# 5342        0      Team1  71646c64f62c2748740c45b469e0d611
# 5343        0      Team0  d32d7f7ead681a3c45ac0401b025169b
# 5344        0      Team1  2ffe19dc39838eaa55a52d7b2fbd687c
# 5345        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5346        0      Team1  ade82b71d52bf8ebd00f724b25c87e95
# 5347        0      Team0  86f33f0bc083cd2e9c543c4631d5690b
# 5348        0      Team0  aa557e7793b0037e089d5425fa9f1636
# 5349        0      Team0  f1970daaab6bd4c23edea9c6e4305b12
# ...       ...        ...                               ...
# 5393        0      Team1  682ee02d38c947defb4cf5e30fba6f96
# 5394        0      Team0  661390debadbc4b6d53f7d1883cdd279
# 5395        2      Team1  16d76c912992709c8be29b896b8f9417
# 5396        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5397        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5398        0      Team1  682ee02d38c947defb4cf5e30fba6f96
# 5399        0      Team0  86f33f0bc083cd2e9c543c4631d5690b
# 5400        0      Team1  0370a0d090da0d0edc6319f120187e0e
# 5401        0      Team1  2ffe19dc39838eaa55a52d7b2fbd687c
# 5402        0      Team0  86f33f0bc083cd2e9c543c4631d5690b
# 5403        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5404        0      Team1  7a1c1f680a11456d505f05fa70712213
# 5405        0      Team0  86f33f0bc083cd2e9c543c4631d5690b
# 5406        0      Team1  682ee02d38c947defb4cf5e30fba6f96
# 5407        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5408        0      Team1  ade82b71d52bf8ebd00f724b25c87e95
# 5409        0      Team0  86f33f0bc083cd2e9c543c4631d5690b
# 5410        2      Team1  7a1c1f680a11456d505f05fa70712213
# 5414        0      Team1  7a1c1f680a11456d505f05fa70712213
# 5412        0      Team1  16d76c912992709c8be29b896b8f9417
# 5413        0      Team1  2ffe19dc39838eaa55a52d7b2fbd687c
# 5411        0      Team1  682ee02d38c947defb4cf5e30fba6f96
# 5415        0      Team0  e51630054008b5867f9fe3e04d1dd016
# 5416        0      Team0  86f33f0bc083cd2e9c543c4631d5690b
# 5417        0      Team0  e51630054008b5867f9fe3e04d1dd016
# 5418        0      Team1  ffc3716da11461d5337f42c2e9590797
# 5419        0      Team0  bce6c859f6e409e45c3665c11e202ca9
# 5420        0      Team1  1f67aefd482a400ad8efa1f751128efb
# 5421        0      Team0  0370a0d090da0d0edc6319f120187e0e
# 5422        0  Officials  0370a0d090da0d0edc6319f120187e0e
#
#                                Person2                           Person3  \
# 5320  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5321  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5322  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5323  7a1c1f680a11456d505f05fa70712213  0370a0d090da0d0edc6319f120187e0e
# 5324  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5325  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5326  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5327  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5328  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5329  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5330  7a1c1f680a11456d505f05fa70712213  0370a0d090da0d0edc6319f120187e0e
# 5331  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5332  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5333  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5334  2ffe19dc39838eaa55a52d7b2fbd687c  0370a0d090da0d0edc6319f120187e0e
# 5336  f1970daaab6bd4c23edea9c6e4305b12  0370a0d090da0d0edc6319f120187e0e
# 5337  d32d7f7ead681a3c45ac0401b025169b  0370a0d090da0d0edc6319f120187e0e
# 5335  86f33f0bc083cd2e9c543c4631d5690b  0370a0d090da0d0edc6319f120187e0e
# 5338  f1970daaab6bd4c23edea9c6e4305b12  0370a0d090da0d0edc6319f120187e0e
# 5339  71646c64f62c2748740c45b469e0d611  96a5a2607526673603df5c2aec94f8ee
# 5340  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5341  682ee02d38c947defb4cf5e30fba6f96  0370a0d090da0d0edc6319f120187e0e
# 5342  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5343  e51630054008b5867f9fe3e04d1dd016  0370a0d090da0d0edc6319f120187e0e
# 5344  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5345  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5346  bce6c859f6e409e45c3665c11e202ca9  96a5a2607526673603df5c2aec94f8ee
# 5347  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5348  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5349  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# ...                                ...                               ...
# 5393  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5394  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5395  bce6c859f6e409e45c3665c11e202ca9  96a5a2607526673603df5c2aec94f8ee
# 5396  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5397  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5398  2ffe19dc39838eaa55a52d7b2fbd687c  0370a0d090da0d0edc6319f120187e0e
# 5399  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5400  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5401  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5402  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5403  a0a99aa6dcb9947e8501d3c17e89cf01  0370a0d090da0d0edc6319f120187e0e
# 5404  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5405  2ffe19dc39838eaa55a52d7b2fbd687c  0370a0d090da0d0edc6319f120187e0e
# 5406  7a1c1f680a11456d505f05fa70712213  0370a0d090da0d0edc6319f120187e0e
# 5407  a0a99aa6dcb9947e8501d3c17e89cf01  0370a0d090da0d0edc6319f120187e0e
# 5408  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5409  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5410  e51630054008b5867f9fe3e04d1dd016  a1277b068e23d54de9770dd59b31879e
# 5414  3d784b11288b827cbd97d6dbcd6602ec  0370a0d090da0d0edc6319f120187e0e
# 5412  ffc3716da11461d5337f42c2e9590797  0370a0d090da0d0edc6319f120187e0e
# 5413  745fd2a3e78aaceb805e7bc19cf5f126  0370a0d090da0d0edc6319f120187e0e
# 5411  24e7fa348c6b922fe075358bdabc0b29  0370a0d090da0d0edc6319f120187e0e
# 5415  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5416  df04a338c0749cef4022674be6803411  0370a0d090da0d0edc6319f120187e0e
# 5417  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5418  3d784b11288b827cbd97d6dbcd6602ec  0370a0d090da0d0edc6319f120187e0e
# 5419  0370a0d090da0d0edc6319f120187e0e  a1277b068e23d54de9770dd59b31879e
# 5420  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5421  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 5422  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#       Team_id_type  Person1_type  Person2_type  Person3_type
# 5320             3             0             0             0
# 5321             3             5             0             0
# 5322             3             4             0             0
# 5323             2             4             4             0
# 5324             3             5             0             0
# 5325             3             4             0             0
# 5326             2             4             0             0
# 5327             2             5             0             0
# 5328             3             5             0             0
# 5329             3             4             0             0
# 5330             2             4             4             0
# 5331             3             5             0             0
# 5332             2             4             0             0
# 5333             3             3             0             0
# 5334             3             4             4             0
# 5336             3             5             5             0
# 5337             3             5             5             0
# 5335             3             5             5             0
# 5338             3             5             5             0
# 5339             2             5             4             1
# 5340             2             4             0             0
# 5341             2             4             4             0
# 5342             2             4             0             0
# 5343             3             5             5             0
# 5344             2             4             0             0
# 5345             2             5             0             0
# 5346             3             4             5             1
# 5347             3             5             0             0
# 5348             3             3             0             0
# 5349             3             5             0             0
# ...            ...           ...           ...           ...
# 5393             2             4             0             0
# 5394             2             5             0             0
# 5395             3             4             5             1
# 5396             3             5             0             0
# 5397             3             5             0             0
# 5398             2             4             4             0
# 5399             3             5             0             0
# 5400             2             0             0             0
# 5401             2             4             0             0
# 5402             2             5             0             0
# 5403             3             5             5             0
# 5404             2             4             0             0
# 5405             3             5             4             0
# 5406             2             4             4             0
# 5407             3             5             5             0
# 5408             2             4             0             0
# 5409             2             5             0             0
# 5410             3             4             5             1
# 5414             3             4             4             0
# 5412             3             4             4             0
# 5413             3             4             4             0
# 5411             3             4             4             0
# 5415             3             5             0             0
# 5416             3             5             5             0
# 5417             3             5             0             0
# 5418             2             4             4             0
# 5419             3             5             0             1
# 5420             2             2             0             0
# 5421             3             0             0             0
# 5422             0             0             0             0
#
# [103 rows x 18 columns]

# %%
rdPBP[420:]
# Out:
#                                 Game_id  Event_Num     Event_Msg_Type  Period  \
# 25661  bb4e1b593cc210dec5fdcb0f7eb4739d        610            Rebound       4
# 25660  bb4e1b593cc210dec5fdcb0f7eb4739d        611          Made Shot       4
# 25662  bb4e1b593cc210dec5fdcb0f7eb4739d        612               Foul       4
# 25663  bb4e1b593cc210dec5fdcb0f7eb4739d        614         Free Throw       4
# 25664  bb4e1b593cc210dec5fdcb0f7eb4739d        615            Timeout       4
# 25665  bb4e1b593cc210dec5fdcb0f7eb4739d        616         Free Throw       4
# 25666  bb4e1b593cc210dec5fdcb0f7eb4739d        617          Made Shot       4
# 25667  bb4e1b593cc210dec5fdcb0f7eb4739d        619               Foul       4
# 25668  bb4e1b593cc210dec5fdcb0f7eb4739d        621        Missed Shot       4
# 25669  bb4e1b593cc210dec5fdcb0f7eb4739d        622            Rebound       4
# 25670  bb4e1b593cc210dec5fdcb0f7eb4739d        623               Foul       4
# 25671  bb4e1b593cc210dec5fdcb0f7eb4739d        625         Free Throw       4
# 25672  bb4e1b593cc210dec5fdcb0f7eb4739d        626         Free Throw       4
# 25673  bb4e1b593cc210dec5fdcb0f7eb4739d        627        Missed Shot       4
# 25674  bb4e1b593cc210dec5fdcb0f7eb4739d        628            Rebound       4
# 25675  bb4e1b593cc210dec5fdcb0f7eb4739d        629        Missed Shot       4
# 25676  bb4e1b593cc210dec5fdcb0f7eb4739d        630            Rebound       4
# 25677  bb4e1b593cc210dec5fdcb0f7eb4739d        631          Made Shot       4
# 25678  bb4e1b593cc210dec5fdcb0f7eb4739d        632        Missed Shot       4
# 25679  bb4e1b593cc210dec5fdcb0f7eb4739d        634            Rebound       4
# 25680  bb4e1b593cc210dec5fdcb0f7eb4739d        635        Missed Shot       4
# 25681  bb4e1b593cc210dec5fdcb0f7eb4739d        636            Rebound       4
# 25682  bb4e1b593cc210dec5fdcb0f7eb4739d        637           Turnover       4
# 25683  bb4e1b593cc210dec5fdcb0f7eb4739d        638     Instant Replay       4
# 25684  bb4e1b593cc210dec5fdcb0f7eb4739d        639               Foul       4
# 25685  bb4e1b593cc210dec5fdcb0f7eb4739d        641       Substitution       4
# 25687  bb4e1b593cc210dec5fdcb0f7eb4739d        643         Free Throw       4
# 25686  bb4e1b593cc210dec5fdcb0f7eb4739d        644            Rebound       4
# 25688  bb4e1b593cc210dec5fdcb0f7eb4739d        645         Free Throw       4
# 25689  bb4e1b593cc210dec5fdcb0f7eb4739d        646          Made Shot       4
# 25690  bb4e1b593cc210dec5fdcb0f7eb4739d        648       Substitution       4
# 25691  bb4e1b593cc210dec5fdcb0f7eb4739d        650     Instant Replay       4
# 25692  bb4e1b593cc210dec5fdcb0f7eb4739d        651          Made Shot       4
# 25693  bb4e1b593cc210dec5fdcb0f7eb4739d        652            Timeout       4
# 25694  bb4e1b593cc210dec5fdcb0f7eb4739d        653       Substitution       4
# 25695  bb4e1b593cc210dec5fdcb0f7eb4739d        655        Missed Shot       4
# 25696  bb4e1b593cc210dec5fdcb0f7eb4739d        657            Rebound       4
# 25697  bb4e1b593cc210dec5fdcb0f7eb4739d        658               Foul       4
# 25698  bb4e1b593cc210dec5fdcb0f7eb4739d        660         Free Throw       4
# 25699  bb4e1b593cc210dec5fdcb0f7eb4739d        661       Substitution       4
# 25700  bb4e1b593cc210dec5fdcb0f7eb4739d        663         Free Throw       4
# 25701  bb4e1b593cc210dec5fdcb0f7eb4739d        664        Missed Shot       4
# 25702  bb4e1b593cc210dec5fdcb0f7eb4739d        665            Rebound       4
# 25703  bb4e1b593cc210dec5fdcb0f7eb4739d        666         End Period       4
# 25704  bb4e1b593cc210dec5fdcb0f7eb4739d          0  Final Box Printed       4
#
#        WC_Time  PC_Time                  Action_Type  Option1  Option2  \
# 25661   557280     1920                      Unknown        0        0
# 25660   557280     1920            Putback Dunk Shot        2        0
# 25662   557350     1880                     Shooting        0        0
# 25663   557590     1880            Free Throw 1 of 2        1        0
# 25664   557680     1880                      Regular        0        0
# 25665   558730     1880            Free Throw 2 of 2        1        0
# 25666   558840     1720                    Jump Shot        3        0
# 25667   559080     1550                     Personal        0        0
# 25668   559320     1490                   Layup Shot        2        0
# 25669   559350     1490                      Unknown        0        0
# 25670   559360     1490                   Loose Ball        1        0
# 25671   559830     1490            Free Throw 1 of 2        1        0
# 25672   560000     1490            Free Throw 2 of 2        1        0
# 25673   560200     1390             Pullup Jump shot        2        0
# 25674   560230     1350                      Unknown        0        0
# 25675   560360     1220           Fadeaway Jump Shot        2        0
# 25676   560400     1180                      Unknown        0        0
# 25677   560530     1060           Driving Layup Shot        2        0
# 25678   560670      930           Floating Jump shot        2        0
# 25679   560700      900                      Unknown        0        0
# 25680   560720      880                    Jump Shot        3        0
# 25681   560760      860                      Unknown        0        0
# 25682   560850      860  Step Out of Bounds Turnover        0        0
# 25683   560880      860               Support Ruling        0        0
# 25684   562190      690                     Shooting        1        0
# 25685   562590      690                                     0        0
# 25687   562980      690            Free Throw 1 of 2        2        0
# 25686   562980      690               Normal Rebound        0        0
# 25688   563110      690            Free Throw 2 of 2        1        0
# 25689   563230      600           Driving Layup Shot        2        0
# 25690   563510      474                                     0        0
# 25691   563560      474              Overturn Ruling        0        0
# 25692   564810      404             Pullup Jump shot        2        0
# 25693   564870      404                      Regular        0        0
# 25694   565620      404                                     0        0
# 25695   565920      308                    Jump Shot        3        0
# 25696   565970      256                      Unknown        0        0
# 25697   566040      209                Personal Take        1        0
# 25698   566300      209            Free Throw 1 of 2        1        0
# 25699   566320      209                                     0        0
# 25700   566490      209            Free Throw 2 of 2        1        0
# 25701   566590      131           Driving Layup Shot        2        0
# 25702   566630       94                      Unknown        0        0
# 25703   566760        0                                     0        0
# 25704   570330        0                                     0        0
#
#        Option3    Team_id                           Person1  \
# 25661        0      Team0  83c15c0962941640faab838a8f6f151d
# 25660        0      Team0  83c15c0962941640faab838a8f6f151d
# 25662        2      Team0  7dfbb5980c066844384ba7424aceae47
# 25663        0      Team1  f562f72f83b8e06b60ff184531b07056
# 25664        0      Team1  9811289f96c7deb95f04148c206e0b3a
# 25665        0      Team1  f562f72f83b8e06b60ff184531b07056
# 25666        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25667        0      Team0  6ad10958a1d4920dccb1daec39bebd6b
# 25668        0      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25669        0      Team1  9811289f96c7deb95f04148c206e0b3a
# 25670        2      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25671        0      Team0  83c15c0962941640faab838a8f6f151d
# 25672        0      Team0  83c15c0962941640faab838a8f6f151d
# 25673        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25674        0      Team0  83c15c0962941640faab838a8f6f151d
# 25675        0      Team0  83c15c0962941640faab838a8f6f151d
# 25676        0      Team1  0a700ecf0eb76559949f1cb5b69a540b
# 25677        0      Team1  23fbda7c31efd6cfa21e3ab6c89d53f3
# 25678        0      Team0  83c15c0962941640faab838a8f6f151d
# 25679        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25680        0      Team0  83c15c0962941640faab838a8f6f151d
# 25681        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25682        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25683        0      Team0  a3801b904a10b622331b97394eebcb4e
# 25684        2      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25685        0      Team1  1c5bebebc83437eca5ef0aaf6eabb15a
# 25687        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25686        0      Team0  9811289f96c7deb95f04148c206e0b3a
# 25688        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25689        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25690        0      Team1  687b541bdc76b92b085fc1304f5c1bf1
# 25691        0      Team0  b005e593a20bcdd4b1d04021af9accff
# 25692        0      Team0  ff52c317e26534ae1679da3c917e9fec
# 25693        0      Team1  e9ed8a6685a60e2416cd81bf874cffb1
# 25694        0      Team1  ce3ac26d43af7aa5555535cfed3f48cc
# 25695        0      Team1  23fbda7c31efd6cfa21e3ab6c89d53f3
# 25696        0      Team0  11beb0ae23e6425510297a31fa21881e
# 25697        2      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25698        0      Team0  83c15c0962941640faab838a8f6f151d
# 25699        0      Team1  687b541bdc76b92b085fc1304f5c1bf1
# 25700        0      Team0  83c15c0962941640faab838a8f6f151d
# 25701        0      Team1  2c447ab0a100cb50766552b0f6fadc2d
# 25702        0      Team0  11beb0ae23e6425510297a31fa21881e
# 25703        0      Team0  0370a0d090da0d0edc6319f120187e0e
# 25704        0  Officials  0370a0d090da0d0edc6319f120187e0e
#
#                                 Person2                           Person3  \
# 25661  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25660  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25662  f562f72f83b8e06b60ff184531b07056  5201a0c1055bebf092c5ce178e5c7863
# 25663  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25664  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25665  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25666  7dfbb5980c066844384ba7424aceae47  0370a0d090da0d0edc6319f120187e0e
# 25667  2c447ab0a100cb50766552b0f6fadc2d  227d578f7628770519b586873c704e07
# 25668  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25669  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25670  83c15c0962941640faab838a8f6f151d  a2e5a2de2ee7fe3b5ba9be7caa05fba8
# 25671  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25672  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25673  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25674  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25675  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25676  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25677  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25678  0370a0d090da0d0edc6319f120187e0e  1c5bebebc83437eca5ef0aaf6eabb15a
# 25679  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25680  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25681  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25682  0370a0d090da0d0edc6319f120187e0e  5201a0c1055bebf092c5ce178e5c7863
# 25683  0370a0d090da0d0edc6319f120187e0e  227d578f7628770519b586873c704e07
# 25684  ff52c317e26534ae1679da3c917e9fec  227d578f7628770519b586873c704e07
# 25685  687b541bdc76b92b085fc1304f5c1bf1  0370a0d090da0d0edc6319f120187e0e
# 25687  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25686  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25688  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25689  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25690  ce3ac26d43af7aa5555535cfed3f48cc  0370a0d090da0d0edc6319f120187e0e
# 25691  0370a0d090da0d0edc6319f120187e0e  a2e5a2de2ee7fe3b5ba9be7caa05fba8
# 25692  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25693  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25694  687b541bdc76b92b085fc1304f5c1bf1  0370a0d090da0d0edc6319f120187e0e
# 25695  0370a0d090da0d0edc6319f120187e0e  83c15c0962941640faab838a8f6f151d
# 25696  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25697  83c15c0962941640faab838a8f6f151d  5201a0c1055bebf092c5ce178e5c7863
# 25698  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25699  ce3ac26d43af7aa5555535cfed3f48cc  0370a0d090da0d0edc6319f120187e0e
# 25700  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25701  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25702  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25703  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25704  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 25661             2             4             0             0
# 25660             2             4             0             0
# 25662             3             4             5             1
# 25663             3             5             0             0
# 25664             3             2             0             0
# 25665             3             5             0             0
# 25666             2             4             4             0
# 25667             3             4             5             1
# 25668             3             5             0             0
# 25669             3             2             0             0
# 25670             2             5             4             1
# 25671             2             4             0             0
# 25672             2             4             0             0
# 25673             3             5             0             0
# 25674             3             4             0             0
# 25675             2             4             0             0
# 25676             2             5             0             0
# 25677             3             5             0             0
# 25678             2             4             0             5
# 25679             2             4             0             0
# 25680             2             4             0             0
# 25681             2             5             0             0
# 25682             3             5             0             1
# 25683             2             0             0             1
# 25684             2             5             4             1
# 25685             2             5             5             0
# 25687             2             4             0             0
# 25686             2             2             0             0
# 25688             2             4             0             0
# 25689             3             5             0             0
# 25690             2             5             5             0
# 25691             2             0             0             1
# 25692             2             4             0             0
# 25693             3             3             0             0
# 25694             3             5             5             0
# 25695             3             5             0             4
# 25696             3             4             0             0
# 25697             2             5             4             1
# 25698             2             4             0             0
# 25699             2             5             5             0
# 25700             2             4             0             0
# 25701             3             5             0             0
# 25702             3             4             0             0
# 25703             2             0             0             0
# 25704             0             0             0             0

# %%
np.round(100*21.0/16, 2)
# Out:
# 131.25

# %%
rdPBPsmall = rdPBP[419:424]
rdPBPsmall
# Out:
#                                 Game_id  Event_Num Event_Msg_Type  Period  \
# 25659  bb4e1b593cc210dec5fdcb0f7eb4739d        609    Missed Shot       4
# 25661  bb4e1b593cc210dec5fdcb0f7eb4739d        610        Rebound       4
# 25660  bb4e1b593cc210dec5fdcb0f7eb4739d        611      Made Shot       4
# 25662  bb4e1b593cc210dec5fdcb0f7eb4739d        612           Foul       4
# 25663  bb4e1b593cc210dec5fdcb0f7eb4739d        614     Free Throw       4
#
#        WC_Time  PC_Time         Action_Type  Option1  Option2  Option3  \
# 25659   557230     1970  Floating Jump shot        2        0        0
# 25661   557280     1920             Unknown        0        0        0
# 25660   557280     1920   Putback Dunk Shot        2        0        0
# 25662   557350     1880            Shooting        0        0        2
# 25663   557590     1880   Free Throw 1 of 2        1        0        0
#
#       Team_id                           Person1  \
# 25659   Team0  ff52c317e26534ae1679da3c917e9fec
# 25661   Team0  83c15c0962941640faab838a8f6f151d
# 25660   Team0  83c15c0962941640faab838a8f6f151d
# 25662   Team0  7dfbb5980c066844384ba7424aceae47
# 25663   Team1  f562f72f83b8e06b60ff184531b07056
#
#                                 Person2                           Person3  \
# 25659  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25661  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25660  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25662  f562f72f83b8e06b60ff184531b07056  5201a0c1055bebf092c5ce178e5c7863
# 25663  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 25659             2             4             0             0
# 25661             2             4             0             0
# 25660             2             4             0             0
# 25662             3             4             5             1
# 25663             3             5             0             0

# %%
rdPBPsmallReb = rdPBPsmall.iloc[1]
for play in rdPBPsmall.itertuples():
    if getattr(play, 'Event_Num') == rdPBPsmallReb['Event_Num']:
        print('hi')
    else:
        print('no')
# Out:
# no
# hi
# no
# no
# no

# %%
ser = (rdPBPsmall['Event_Num'] == rdPBPsmallReb['Event_Num'])
np.where(ser.values == True)[0][0]
# Out:
# 1

# %%
for p in rdPBPsmall[5:].itertuples():
    print('d')
