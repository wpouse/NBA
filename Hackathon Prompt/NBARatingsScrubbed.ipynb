# %%
import numpy as np
import pandas as pd

# %%
eventCodes = pd.read_csv('Event_Codes.txt', sep='\t')
#Strip excess whitespace that I noticed in Event Message Type Description
eventCodes['Event_Msg_Type_Description'] = eventCodes['Event_Msg_Type_Description'].map(str.strip)

GameLineup = pd.read_csv('Game_Lineup.txt', sep='\t')
PlayByPlay = pd.read_csv('Play_by_Play.txt', sep='\t')
GameIDs = PlayByPlay['Game_id'].unique()

# %%
def sortedPlayByPlay(PlayByPlay):
    """Returns PlayByPlay with nested sorted given by hackathon pdf file.
    
    Input:
        PlayByPlay: Pandas Dataframe from reading Play_by_Play csv file"""
    return PlayByPlay.sort_values(['Period', 'PC_Time', 'WC_Time', 'Event_Num'], ascending=[True, False, True,True])

# %%
def readablePlayByPlay(playByPlay, gameLineup, eventCodes):
    """Maps teamIDs to correct player and replaces it with a simple team0 or team1. 
    Also maps event numbers and action to corresponding description, based off eventCodes"""
    gameTeams = list(gameLineup['Team_id'].unique())
    playerList = list(gameLineup['Person_id'].unique())
    
    playByPlay['Event_Msg_Type'] = playByPlay['Event_Msg_Type'].astype(str)
    playByPlay['Action_Type'] = playByPlay['Action_Type'].astype(str)
    
    print('Team0', gameTeams[0])
    print('Team1', gameTeams[1])
    
    for event in playByPlay.itertuples():
        i = getattr(event, 'Index')
        player = getattr(event, 'Person1')
        teamID = getattr(event, 'Team_id')
        
        if teamID not in gameTeams:
            playerTeam = 'Officials'
        else:
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        #print(playerTeam)
        #print(gameTeams)
        
        if playerTeam == gameTeams[0]:
            playByPlay.at[i,'Team_id'] = 'Team0'
        elif playerTeam == gameTeams[1]:
            playByPlay.at[i, 'Team_id'] = 'Team1'
        else:
            playByPlay.at[i, 'Team_id'] = 'Officials'

        
        eventNum = getattr(event, 'Event_Num')
         #Get the event type
        eventMsgType = int(getattr(event, "Event_Msg_Type"))
        actionType = int(getattr(event, 'Action_Type'))
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        playByPlay.at[i, 'Event_Msg_Type'] = eventMsgDescript
        playByPlay.at[i, 'Action_Type'] = actionTypeDescript
    return playByPlay

# %%
def addPoints(player, points, team0Lineup, team1Lineup, gameDict, possession):
    #Player is person1 of the event messages. Every teammate gets the points for added and opponents points against
    if player in team0Lineup:
        for team0player in team0Lineup:
            #Add points for and off possession
            gameDict[team0player] += np.array([points, 0, possession, 0])
        for team1player in team1Lineup:
            #Add points against and def posession
            gameDict[team1player] += np.array([0, points, 0, possession])
        return
    elif player in team1Lineup:
        for team0player in team0Lineup:
            #Add points against and def possession
            gameDict[team0player] += np.array([0, points, 0, possession])
        for team1player in team1Lineup:
            #Add points for and off possession
            gameDict[team1player] += np.array([points, 0, possession, 0])
        return
    else:
        print("Player not found on either team lineup!")
        print(player)
        print('Team0', team0Lineup)
        print('Team1', team1Lineup)
        return -1
    
def addPossession(team0Lineup, team1Lineup, gameDict):
    """Adds offensive possession to team0Lineup and defensive possession to team1Lineup."""
    for team0player in team0Lineup:
        #Add off possession
        gameDict[team0player] += np.array([0, 0, 1, 0])
    for team1player in team1Lineup:
        #Add def posession
        gameDict[team1player] += np.array([0, 0, 0, 1])
    return

def getPlayerTeam(player, teamID, playerList, gameLineup):
    """Returns the team of the input player (if player is real) otherwise returns teamID"""
    if player not in playerList:
        #Team event
        playerTeam = teamID
    else:
        playerTeam = gameLineup[gameLineup['Person_id'] == player]['Team_id'].values[0]
    return playerTeam

def doSubstitution(player, event, team0Lineup, team1Lineup, verbose):
    leavingPlayer = player
    enteringPlayer = getattr(event, 'Person2')
    if leavingPlayer in team0Lineup:
        team0Lineup.remove(leavingPlayer)
        team0Lineup.append(enteringPlayer)
    else:
        team1Lineup.remove(leavingPlayer)
        team1Lineup.append(enteringPlayer)
            
    if verbose:
        print(enteringPlayer, ' replacing ', leavingPlayer)

def doPossessionFixSub(possessionInfo, team, gameDict, gameTeams, verbose = False):
    """
    Adds possessions to players given by possessionInfo dictionary. 
        Used for when possession unknown (often due to a team rebound).
        
    
    Inputs: 
        possessionInfo: Dictionary containing the relevant information of the events leading to unknown possession.
            'team0' and 'team1' keys correspond to the team0 and team1 lineups. 
            'event' key corresponds to the event (missed shot or free throw)
            'lastTeam' key corresponds to team last known to have possession
            'subbedPlayers0' and 'subbedPlayers1' keys correspond to players subbed out in between 'event' and 
                play where possession becomes known
            'remainingPlayers0' and 'remainingPlayers1' keys typically correspond to players 
                who are still on court after a substitution occurs ie remainingPlayers = teamLineup - subbedInPlayers
                However, currently assuming that all players on court get credited with possession on missed ft 
                so will just be same as teamLineup
        
        team: Team that currently has possession to be compared to lastTeam
        
        gameDict: Dictionary containing all pointsFor/Against and off/defPossessions of each player to be updated
        
        gameTeams: List of both teams playing to be used to check if team0 or 1 has possession
        
        verbose: Optional input, where if True, prints statements describing which players possession added to
        
        """
    eventDescript = possessionInfo['event']
    team0Lineup = possessionInfo['team0']
    team1Lineup = possessionInfo['team1']
    lastTeam = possessionInfo['lastTeam']
    subbedPlayers0 = possessionInfo['subbedPlayers0']
    subbedPlayers1 = possessionInfo['subbedPlayers1']
    
    possessionInfoEmpty = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                           'event': '', 'lastTeam': '', 'subbedPlayers0': [], 'subbedPlayers1': []}
    
    if (team not in gameTeams) or (lastTeam not in gameTeams):
        raise Exception('Either {} or {} not a valid team'.format(team, lastTeam))
    
    if (eventDescript == 'Missed Shot') or (eventDescript == 'Technical Free Throw'):
        if verbose:
            print('Missed shot possession fix')
        if len(subbedPlayers0) + len(subbedPlayers1) > 0:
            #Regardless of who rebounds add possession to players subbed off
            if team == gameTeams[0]:
                #Team0 players who were subbed now on offense (ASSUMES sub happens after rebound)
                addPossession(subbedPlayers0, subbedPlayers1, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers0)
                    print("Add def possession to subbed players", subbedPlayers1)
            else:
                addPossession(subbedPlayers1, subbedPlayers0, gameDict)
                if verbose:
                    print("Add off possession to subbed players", subbedPlayers1)
                    print("Add def possession to subbed players", subbedPlayers0)
        if lastTeam == team:
            #Offensive rebound on missed shot, do nothing except for subbed players
            
            if verbose:
                print("Was offensive rebound, don't do anything for on court players")
            return possessionInfoEmpty
        elif team == gameTeams[0]:
            #Defensive rebound by team0
            addPossession(team1Lineup, team0Lineup, gameDict)
            
            if verbose:
                print("Add off possession to ", team1Lineup)
                print("Add def possession to ", team0Lineup)
        else:
            #Defensive rebound by team1
            addPossession(team0Lineup, team1Lineup, gameDict)

            if verbose:
                print("Add off possession to ", team0Lineup)
                print("Add def possession to ", team1Lineup)
                    
    elif eventDescript == 'Missed Last Free Throw':
        if verbose:
            print('FT possession fix')
        if lastTeam == team:
            #Do nothing, as possession already added to subbed players
            pass
            
        else: #Defensive Rebound
            #Only add possession to those who were on court when foul occured
            ##UPDATE: I believe NBA actually counts it as a possession for all players on court, 
            #so while still labeled remainingPlayers, input in gameRatings function will be teamLineup
            remainingPlayers0 = possessionInfo['remainingPlayers0']
            remainingPlayers1 = possessionInfo['remainingPlayers1']
            
            if team == gameTeams[0]:
                #team0 grabs defensive rebound
                addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers1)
                    print("Add def possession to ", remainingPlayers0)
            else:
                addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                if verbose:
                    print("Add off possession to ", remainingPlayers0)
                    print("Add def possession to ", remainingPlayers1)
    else:
        raise Exception('Attempt to fix possession failed, invalid event Descript: {}'.format(eventDescript))
    
    return possessionInfoEmpty

# %%
def gameRatingsSubCleaned(gamePlayByPlay, gameLineup, eventCodes, verbose = False):
    """Turns a given PlayByPlay log and calculates the number of points and possessions a player is in the game for, 
    both scored by and against the players team. Can be used to calculate offensive and defensive rating defined by 
    offRtg = 100*pointsFor/offPossessions and defRtg = 100*pointsAgainst/defPossesssions
    
    Inputs:
        gamePlayByPlay: A Pandas dataframe object listing the play by play events for a single game. 
            This should be sorted according to the prompt (Period, PC_Time, WC_Time, Event_Num). Taken from Play_by_Play.txt .
        
        gameLineup: A Pandas dataframe of the game lineup for the same gams as the play by play. Taken from Game_Lineup.txt .
        
        eventCodes: Pandas dataframe of the event codes provided by the NBA. Taken from Event_Codes.txt .
        
        verbose: Optional argument. If set to True, prints the current loop counter and a description of each event 
            (made shot, rebound, turnover, etc)
        
    Output:
        gameDict: A dictionary where the keys are each playerID from the gameLineup input, 
            and the value is an array of [pointsFor, pointsAgainst, offPossessions, defPossessions]
    
    """
    
    lastDescript = ''
    counter = 0
    gameTeams = list(gameLineup['Team_id'].unique())
    
    #Create dictionary with keys of each player and value of array([PointsFor, PointsAgainst, OffPossessions, DefPossessions])
    playerList = list(gameLineup['Person_id'].unique())
    gameDict = {player: np.array([0,0,0,0]) for player in playerList}
    
    #List of event numbers to skip 
    #(designed for the case where we 'look ahead' at a future rebound or substitution due to playbyplay error)
    skipEventNums = []
    
    #Keep track of team with possession 
    currPoss = ''
    #Keep track of play clock time (due to weird handling of technical fouls as possessions by NBA) 
    #Initialize to -1 so no accidental equalities
    currTime = -1 
    
    #Added because of cases where made shot with 0 on clock would lead to another possession being added when period ended
    #Unclear if have to take into account other actions at 0
    skipEndPeriod = False
    
    for event in gamePlayByPlay.itertuples():
        
        eventNum = getattr(event, 'Event_Num')
        
         #Get the event type
        eventMsgType = getattr(event, "Event_Msg_Type")
        actionType = getattr(event, 'Action_Type')
        
        #Turn the event type and action type into a description
        #First find corresponding row in eventCodes file
        eventCode = eventCodes[(eventCodes['Event_Msg_Type'] == eventMsgType) & (eventCodes['Action_Type'] == actionType)]

        #Description should be unique based off ID, so just get first element of list created
        eventMsgDescript = list(eventCode['Event_Msg_Type_Description'].unique())[0]
        actionTypeDescript = list(eventCode['Action_Type_Description'].unique())[0]
        
        #Player who shoots, rebounds, etc
        player = getattr(event, 'Person1')
        
        if verbose:
            print('Counter', counter)
            print('Event Num', eventNum)
            print(skipEventNums)
            print(eventMsgDescript, 'by', player)
    
        counter += 1
        if eventNum in skipEventNums:
            continue
        

        
        teamID = getattr(event, 'Team_id') #teamID doesn't always correspond to player's team
        playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        PCtime = getattr(event, 'PC_Time')
        period = getattr(event, 'Period')

     
        if eventMsgDescript == 'Start Period':
            skipEndPeriod = False
            currTime = -1
            currPoss = playerTeam
            #Substitutions at start of period aren't considered substitution events. Must check game linup explicitly.
            team0Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[0])]['Person_id'])
            team1Lineup = list(gameLineup[(gameLineup['Period'] == period) 
                                          & (gameLineup['Team_id'] == gameTeams[1])]['Person_id'])

            lastDescript = ''
            
            #Used for cases of a team rebound not assigned to a particular player. The teamID is often wrong, 
            #so when unknownRebound is True, next events are checked to see who has the ball.
            unknownRebound = False
            unknownReboundInfo = {'team0': [], 'team1': [], 'remainingPlayers0': [], 'remainingPlayers1': [], 
                                  'subbedPlayers0': [], 'subbedPlayers1': [], 'event': '', 'lastTeam': ''}
            
            if verbose:
                print(period,' lineup 0:', team0Lineup)
                print(period,' lineup 1:', team1Lineup)
                
                
        elif eventMsgDescript == 'End Period' and not skipEndPeriod:
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
                
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
            lastDescript = ''
            
            if verbose:
                print(period, 'ended')
                
        if lastDescript == 'Missed Shot':
            #Previous event missed shot, check who rebounded
            
            lastDescript = ''
            
            if currTime== 0:
                #Miss at end of period so skip End Period event otherwise double count of possession
                skipEndPeriod = True
                #Add possession to each player
                if lastTeam == gameTeams[0]:
                    #team0 missed on offense
                    addPossession(team0Lineup, team1Lineup, gameDict)
                else:
                    addPossession(team1Lineup, team0Lineup, gameDict)
                continue
                
            currTime = PCtime
            
            if eventMsgDescript != 'Rebound':
                
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at later time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                
                #Get all events after current one and check which events correspond to a rebound in same period
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & (reboundEvent['Period'] == period)]
                if reboundEvent.empty:
                    print('No rebound after!')
                    print('Counter', counter-1)
                    print('Event num', getattr(event, 'Event_Num'))
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])

            #if player not in lastTeam: #Defensive rebound (for an offensive rebound do nothing)
            
            #Check that if real player (not team rebound) grabbed board, that he is on the court
            #Shouldn't be triggered if parsing done correctly, but good for error checking
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Counter', counter-1)
                print('Event num', getattr(event, 'Event_Num'))
                break
                
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Shot'
                unknownReboundInfo['lastTeam'] = lastTeam
                    
            elif playerTeam != lastTeam:
                #Defensive rebound
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                if verbose:
                    print("Defensive Rebound")

            else:
                if verbose:
                    print("Offensive Rebound")
            #Reset to player of current event for instances where we needed to find next rebound due to wrong order
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
            
        elif lastDescript == 'Missed Last Free Throw':
            #Similar structure as missing last shot, except take into account possibility of substitutions 
            #(important if don't want to give substitutions to player subbed in -- NBA seems to count those)
            lastDescript = ''
            currTime = PCtime
            if eventMsgDescript != 'Rebound':
                #Errors in playbyplay sometimes lead to the wrong order if two things happen at same playclock time
                #Check other events at same time to see if rebound occurs
                
                PCtime = getattr(event, 'PC_Time')
                period = getattr(event, 'Period')
                WCtime = getattr(event, 'WC_Time')
                
                reboundEvent = gamePlayByPlay[counter-1:]
                reboundEvent = reboundEvent[(reboundEvent['Event_Msg_Type'] == 4) & ((reboundEvent['Period'] == period))]
                if reboundEvent.empty:
                    print('Event num', getattr(event, 'Event_Num'))
                    print('No rebound at same time!')
                    break
                #Get first instance of rebound
                player = reboundEvent['Person1'].values[0]
                playerTeam = getPlayerTeam(player, reboundEvent['Team_id'].values[0], playerList, gameLineup)
                
                #Make sure to skip this rebound event
                skipEventNums.append(reboundEvent['Event_Num'].values[0])


            #Check if players subbed at same time
            subEvents = gamePlayByPlay[counter-1:]
            subEvents = subEvents[(subEvents['Event_Msg_Type'] == 8) 
                                & (subEvents['Period'] == period) 
                                & (subEvents['PC_Time'] == PCtime)]
            for substitution in subEvents.itertuples():
                subPlayer = getattr(substitution, 'Person1')
                subEventNum = getattr(substitution, 'Event_Num')
                subPlayerTeam = getPlayerTeam(subPlayer, '', playerList, gameLineup)
                    
                skipEventNums.append(subEventNum)
                doSubstitution(subPlayer, substitution, team0Lineup, team1Lineup, verbose)
                if subPlayerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([subPlayer], [], gameDict)
                else:
                    addPossession([], [subPlayer], gameDict)
                if verbose:
                    print('Sub after ft')
                    
            if (player not in team0Lineup) and (player not in team1Lineup) and (player in playerList):
                print('Player not on court', player)
                print('team0', team0Lineup)
                print('team1', team1Lineup)
                print('Event num', getattr(event, 'Event_Num'))
                break
            
            subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
            subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
            remainingPlayers0 = list(set(ftTeam0Lineup)-set(subbedPlayers0))
            remainingPlayers1 = list(set(ftTeam1Lineup)-set(subbedPlayers1))
            
            if player not in playerList:
                #Team rebound, but the teamID might be messed up so don't add possession yet
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                
                unknownRebound = True
                unknownReboundInfo['team0'] = team0Lineup.copy()
                unknownReboundInfo['team1'] = team1Lineup.copy()
                unknownReboundInfo['event'] = 'Missed Last Free Throw'
                #unknownReboundInfo['remainingPlayers0'] = remainingPlayers0.copy()
                #unknownReboundInfo['remainingPlayers1'] = remainingPlayers1.copy()
            
                unknownReboundInfo['remainingPlayers0'] = team0Lineup.copy()
                unknownReboundInfo['remainingPlayers1'] = team1Lineup.copy()

                unknownReboundInfo['lastTeam'] = lastTeam
                
            #Offensive Rebound, no possessions added (already added to subbed players)
            elif playerTeam == lastTeam:
                if verbose:
                    print("Offensive Rebound")
 
            else:
                #Only add possession to those who were on court when foul occured and are still on court
            
                #UPDATE: I believe NBA counts players being subbed in on a missed last free throw as part of that possession
                #so just add possession to team lineup. Change back to teamLineup back to remainingPlayers if this is undesired
                if playerTeam == gameTeams[0]:
                    #team0 grabs defensive rebound
                    #addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                    addPossession(team1Lineup, team0Lineup, gameDict)
                    currPoss = gameTeams[0]
                else:
                    #addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                    addPossession(team0Lineup, team1Lineup, gameDict)
                    currPoss = gameTeams[1]
                    
                if verbose:
                    print("Defensive Rebound")
                    
            #Reset to player of current event
            player = getattr(event, 'Person1')
            playerTeam = getPlayerTeam(player, teamID, playerList, gameLineup)
        
        if eventNum in skipEventNums:
            #Check this again because of iteration through substitution events after missed shot or free throw
            continue
        
        if eventMsgDescript == 'Substitution':
            doSubstitution(player, event, team0Lineup, team1Lineup, verbose)
            
            #In case current possession unknown use unknownRebound logic to check next possession and assign correct possessions
            if unknownRebound:
                if playerTeam == gameTeams[0]:
                    unknownReboundInfo['subbedPlayers0'].append(player)
                elif playerTeam == gameTeams[1]:
                    unknownReboundInfo['subbedPlayers1'].append(player)
            else:
                if playerTeam == currPoss:
                    #Player subbed out on offense
                    addPossession([player], [], gameDict)
                else:
                    addPossession([], [player], gameDict)
            
        if eventMsgDescript == 'Made Shot':
            currTime = PCtime
            if PCtime == 0:
                skipEndPeriod = True
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            points = getattr(event, 'Option1')
            
            #Check if and-1. Only checking if fts happen not action type ft 1 out of 1 because possibility of flagrant.
            #This assumes that the ft shot will always be after the made shot in a play by play
            ftEvents = gamePlayByPlay[counter-1:]
            ftEvents = ftEvents[(ftEvents['Event_Msg_Type'] == 3) 
                                    & (ftEvents['Period'] == period) 
                                    & (ftEvents['PC_Time'] == PCtime)]
            # if ft happens then don't count possession, because it will be handled when loop hits that event
            if ftEvents.empty:
                poss = 1
                if playerTeam == gameTeams[0]:
                    currPoss = gameTeams[1]
                else:
                    currPoss = gameTeams[0]
            else:
                poss = 0
            
            addPoints(player,points, team0Lineup, team1Lineup, gameDict, possession= poss)
            
            if verbose:
                print(player, 'scores', points, 'points')
                
        elif eventMsgDescript == 'Turnover':
            
            currTime = PCtime
            
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Add possession to each player
            if playerTeam == gameTeams[0]:
                #team0 on offense
                addPossession(team0Lineup, team1Lineup, gameDict)
                currPoss = gameTeams[1]
            else:
                addPossession(team1Lineup, team0Lineup, gameDict)
                currPoss = gameTeams[0]
                
            if verbose:
                print(playerTeam, 'turnover')
                
        elif eventMsgDescript == 'Missed Shot':
            
            currTime = PCtime
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            #Check who rebounds in next iteration of loop
            lastDescript = eventMsgDescript

            if player in team0Lineup:
                #lastTeam = team0Lineup
                lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
            else:
                #lastTeam = team1Lineup
                lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
            if verbose:
                print(player, 'misses shot')

        #Check if Foul (which may or may not lead to free throws), but all free throws come from fouls
        #Important to check if a generic foul and not just shooting fouls, otherwise the free throw lineup will be 'behind'
        #If only looked at shooting fouls - consider situation of substitutions during the game and then a technical foul. 
        #The ft lineup would only be from the previous fts, not the current lineup. 
        elif (eventMsgDescript == 'Foul'):
            #Make sure to copy lineup not assign, otherwise when lineup changes ftTeamLineup would change
            ftTeam0Lineup = team0Lineup.copy()
            ftTeam1Lineup = team1Lineup.copy()
            
            if verbose:
                print('Foul on team', playerTeam)

        elif eventMsgDescript == 'Free Throw':
            if unknownRebound:
                unknownReboundInfo = doPossessionFixSub(unknownReboundInfo, playerTeam, gameDict, gameTeams, verbose)
                unknownRebound = False
            
            option1 = getattr(event, 'Option1')
            if option1 == 1: #Made Free Throw
                points = 1
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #ActionTypes corresponding to final free throw, so add possession. 
                    subbedPlayers0 = list(set(ftTeam0Lineup) - set(team0Lineup))
                    subbedPlayers1 = list(set(ftTeam1Lineup) - set(team1Lineup))
                    
                    #subbedPlayers already got possession added so only add to remaining players on court
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    remainingPlayers0 = list(set(ftTeam0Lineup) - set(subbedPlayers0))
                    remainingPlayers1 = list(set(ftTeam1Lineup) - set(subbedPlayers1))
                    
                    if playerTeam == gameTeams[0]:
                        addPossession(remainingPlayers0, remainingPlayers1, gameDict)
                        currPoss = gameTeams[1]
                    elif playerTeam == gameTeams[1]:
                        addPossession(remainingPlayers1, remainingPlayers0, gameDict)
                        currPoss = gameTeams[0]
                    else:
                        print('Error: Free throw player not on either team')
                        return

                    if verbose:
                        print('Made final free throw by', player)
                        
                else:
                    addPoints(player, points, ftTeam0Lineup, ftTeam1Lineup, gameDict, possession=0)
                    
                    if verbose:
                        print('Made free throw by', player)
                        
            else: #Missed FT
                if (actionType == 10) or (actionType == 12) or (actionType == 15):
                    #Missed last free throw for a shooting foul (not technical/flagrant), check who rebounds in next iteration. 
                    lastDescript = 'Missed Last Free Throw'
                    #Offensive rebounds with substitution going to be weird in terms of possessions

                    #Check current lineup, not free throw lineup since current lineup will be the one to rebound
                    if player in team0Lineup:
                        lastTeam = getPlayerTeam(team0Lineup[0], '', playerList, gameLineup)
                    else:
                        lastTeam = getPlayerTeam(team1Lineup[0], '', playerList, gameLineup)
                        
                    if verbose:
                        print('Missed last free throw by', player)
                        print('ftteam1', ftTeam1Lineup)
                else:
                    if verbose:
                        print('Missed free throw by', player)

            #NBA seems to count technical free throws a possession. Delete block below if undesired.
            
            #Check whether was last technical free throw (not flagrant which team keeps possession)
            if (actionType == 16) or (actionType == 22):
                
                
                #Use the possessionFix method already implemented and just count this free throw as the 'unknownRebound'
            
                #So if team on offense commits tech that counts as off + def possession
                #then def + off possession for tech ft, and then following possession will be off + def
                if False:
                    unknownRebound = True
                    unknownReboundInfo['team0'] = team0Lineup.copy()
                    unknownReboundInfo['team1'] = team1Lineup.copy()
                    unknownReboundInfo['event'] = 'Technical Free Throw'
                    unknownReboundInfo['remainingPlayers0'] = ftTeam0Lineup.copy()
                    unknownReboundInfo['remainingPlayers1'] = ftTeam1Lineup.copy()
                    unknownReboundInfo['lastTeam'] = playerTeam
                    
                #Check if tech committed by team with possession. If so add offensive and defensive possession to both teams 
                #(off from having ball, def from tech shot)
                
                #Also it seems like only if time passed in a given possession does the tech count as a change in possession.
                #Remove currTime != PCtime so all techs treated equally
                if currPoss != playerTeam and currTime != PCtime:
                    addPossession(ftTeam1Lineup, ftTeam0Lineup, gameDict)
                    addPossession(ftTeam0Lineup, ftTeam1Lineup, gameDict)
    return gameDict

# %%
dataRows = []
i = 0
for game in GameIDs:
    print(i)
    gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
    gameLineup = GameLineup[GameLineup['Game_id'] == game]
    gameDict = gameRatingsSub(gamePlayByPlay, gameLineup, eventCodes)
    playerList = list(gameLineup['Person_id'].unique())
    
    for player in gameDict.keys():
        dataDict = {'Game_ID': game}
        #Check at least one possession played
        offPossessions = gameDict[player][2]
        defPossessions = gameDict[player][3]
        
        totalPossessions = offPossessions + defPossessions
        
        if totalPossessions != 0: 
            #Allowing for possibility of only playing one possession on offense or defense and thus undefined rating
            pointsFor = gameDict[player][0]
            pointsAgainst = gameDict[player][1]
            if offPossessions == 0:
                offRating = np.nan
            else:
                offRating = 100*(pointsFor/offPossessions)
            if defPossessions == 0:
                defRating = np.nan
            else:
                defRating = 100*(pointsAgainst/defPossessions)
            playerTeam = getPlayerTeam(player, '', playerList, gameLineup)
            dataDict.update({'Player_ID': player, 'Team_ID': playerTeam, 'OffRtg': np.round(offRating,1), 
                             'DefRtg': np.round(defRating,1), 'OffPossessions': offPossessions, 
                             'DefPossessions': defPossessions, 'PointsFor': pointsFor, 'PointsAgainst': pointsAgainst})
            
            dataRows.append(dataDict)
    i+=1
df = pd.DataFrame(dataRows)
df= df[['Game_ID', 'Player_ID', 'Team_ID','OffRtg', 'DefRtg', 'OffPossessions', 'DefPossessions', 'PointsFor', 'PointsAgainst']]
df.to_excel("GameRatings.xlsx", index=False)

# %%
## bug in playbyplay that cant be fixed? Look at gameIDs[3] events 21-23 show missed free throw, rebound, then made free throw?
#Assuming its even ft, ft, rebound it says it was made so how can there be a rebound?
game = GameIDs[14]
gamePlayByPlay= sortedPlayByPlay(PlayByPlay[PlayByPlay['Game_id'] == game])
gameLineup = GameLineup[GameLineup['Game_id'] == game]
gameDict = gameRatingsSubCleaned(gamePlayByPlay[:], gameLineup, eventCodes, verbose=True)
# Out:
# Counter 0
# Event Num 2
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 1  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '95920e4bf5b6c15ba8dffbf959b38ba5', '722a380c9b59ef42226e8d392824dcb9', 'ef8b068ab7ac9d387b256404acd24cd5']
# 1  lineup 1: ['3626b893fc73a5cbd67d1ea48a5c7039', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618', '6f6a807d57aae8f651222523dc82dc35']
# Counter 1
# Event Num 4
# []
# Jump Ball by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 2
# Event Num 7
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 3
# Event Num 8
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 4
# Event Num 9
# []
# Turnover by a1591595c04d12e88e3cb427fb667618
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 5
# Event Num 11
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 6
# Event Num 12
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 7
# Event Num 13
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 8
# Event Num 14
# []
# Made Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a scores 2 points
# Counter 9
# Event Num 15
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 10
# Event Num 16
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Defensive Rebound
# Counter 11
# Event Num 17
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 12
# Event Num 18
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 13
# Event Num 19
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 14
# Event Num 20
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 15
# Event Num 22
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 16
# Event Num 23
# []
# Foul by ef8b068ab7ac9d387b256404acd24cd5
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 17
# Event Num 25
# []
# Free Throw by 1a6703883f8f47bb4daf09c03be3bda2
# Made final free throw by 1a6703883f8f47bb4daf09c03be3bda2
# Counter 18
# Event Num 26
# []
# Foul by 3626b893fc73a5cbd67d1ea48a5c7039
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 19
# Event Num 28
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 20
# Event Num 29
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 21
# Event Num 30
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 22
# Event Num 32
# []
# Turnover by 7f438c18058290903c46dfe9d71bd68a
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 23
# Event Num 34
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 24
# Event Num 36
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 25
# Event Num 38
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 26
# Event Num 39
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 27
# Event Num 40
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 28
# Event Num 41
# []
# Foul by 31598ba01a3fff03ed0a87d7dea11dfe
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 29
# Event Num 43
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 3 points
# Counter 30
# Event Num 44
# []
# Missed Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 misses shot
# Counter 31
# Event Num 45
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 32
# Event Num 46
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 33
# Event Num 47
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 34
# Event Num 48
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 35
# Event Num 50
# []
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 36
# Event Num 52
# []
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 37
# Event Num 54
# []
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 38
# Event Num 55
# []
# Substitution by 6f6a807d57aae8f651222523dc82dc35
# 3d75035d20b173a867d4bf32c8a58f0b  replacing  6f6a807d57aae8f651222523dc82dc35
# Counter 39
# Event Num 57
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 40
# Event Num 58
# []
# Made Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a scores 3 points
# Counter 41
# Event Num 60
# []
# Foul by 7f438c18058290903c46dfe9d71bd68a
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 42
# Event Num 62
# []
# Substitution by 31598ba01a3fff03ed0a87d7dea11dfe
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  31598ba01a3fff03ed0a87d7dea11dfe
# Counter 43
# Event Num 64
# []
# Made Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 scores 2 points
# Counter 44
# Event Num 66
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 45
# Event Num 67
# []
# Made Shot by 3d75035d20b173a867d4bf32c8a58f0b
# 3d75035d20b173a867d4bf32c8a58f0b scores 2 points
# Counter 46
# Event Num 69
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 47
# Event Num 70
# []
# Foul by 3d75035d20b173a867d4bf32c8a58f0b
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 48
# Event Num 72
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 49
# Event Num 73
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 50
# Event Num 74
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 51
# Event Num 75
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 52
# Event Num 76
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 53
# Event Num 78
# []
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 54
# Event Num 79
# []
# Made Shot by 0b978fcfa7f2ec839c563a755e345ff8
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 0b978fcfa7f2ec839c563a755e345ff8 scores 2 points
# Counter 55
# Event Num 81
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 56
# Event Num 82
# []
# Rebound by 7f438c18058290903c46dfe9d71bd68a
# Offensive Rebound
# Counter 57
# Event Num 83
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 58
# Event Num 85
# []
# Foul by 0b978fcfa7f2ec839c563a755e345ff8
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 59
# Event Num 87
# []
# Free Throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Made final free throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 60
# Event Num 88
# []
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 61
# Event Num 90
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 62
# Event Num 91
# []
# Substitution by ef8b068ab7ac9d387b256404acd24cd5
# 1dabb767e07d0aa702ee58d41c15eab1  replacing  ef8b068ab7ac9d387b256404acd24cd5
# Counter 63
# Event Num 93
# []
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# e49b2cc3f9aacd500b11a35b1c57112d  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 64
# Event Num 95
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made final free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 65
# Event Num 96
# []
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 66
# Event Num 97
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 67
# Event Num 98
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 68
# Event Num 99
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 69
# Event Num 100
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# Missed shot possession fix
# Add off possession to  ['3626b893fc73a5cbd67d1ea48a5c7039', '1a6703883f8f47bb4daf09c03be3bda2', 'a1591595c04d12e88e3cb427fb667618', '3d75035d20b173a867d4bf32c8a58f0b', '0b978fcfa7f2ec839c563a755e345ff8']
# Add def possession to  ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '95920e4bf5b6c15ba8dffbf959b38ba5', '1dabb767e07d0aa702ee58d41c15eab1', 'e49b2cc3f9aacd500b11a35b1c57112d']
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 70
# Event Num 101
# []
# Rebound by 3d75035d20b173a867d4bf32c8a58f0b
# Defensive Rebound
# Counter 71
# Event Num 102
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 72
# Event Num 103
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 73
# Event Num 105
# []
# Made Shot by 3d75035d20b173a867d4bf32c8a58f0b
# 3d75035d20b173a867d4bf32c8a58f0b scores 2 points
# Counter 74
# Event Num 107
# []
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 75
# Event Num 109
# []
# Free Throw by 7f438c18058290903c46dfe9d71bd68a
# Made free throw by 7f438c18058290903c46dfe9d71bd68a
# Counter 76
# Event Num 110
# []
# Substitution by 1a6703883f8f47bb4daf09c03be3bda2
# 52c6125836c465f4ac5232121dacb49d  replacing  1a6703883f8f47bb4daf09c03be3bda2
# Counter 77
# Event Num 112
# []
# Free Throw by 7f438c18058290903c46dfe9d71bd68a
# Made final free throw by 7f438c18058290903c46dfe9d71bd68a
# Counter 78
# Event Num 113
# []
# Turnover by 3626b893fc73a5cbd67d1ea48a5c7039
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 79
# Event Num 115
# []
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 80
# Event Num 116
# []
# Rebound by 52c6125836c465f4ac5232121dacb49d
# Defensive Rebound
# Counter 81
# Event Num 117
# []
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 82
# Event Num 118
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 83
# Event Num 119
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 84
# Event Num 120
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 85
# Event Num 121
# []
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 86
# Event Num 123
# []
# Made Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d scores 2 points
# Counter 87
# Event Num 135
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 88
# Event Num 137
# []
# Rebound by e49b2cc3f9aacd500b11a35b1c57112d
# Defensive Rebound
# Counter 89
# Event Num 127
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 90
# Event Num 129
# []
# Rebound by 7f438c18058290903c46dfe9d71bd68a
# Offensive Rebound
# Counter 91
# Event Num 130
# []
# Turnover by e49b2cc3f9aacd500b11a35b1c57112d
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 92
# Event Num 132
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 93
# Event Num 133
# []
# Rebound by 7f438c18058290903c46dfe9d71bd68a
# Defensive Rebound
# Counter 94
# Event Num 134
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 1 ended
# Counter 95
# Event Num 150
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 2  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '32c044aa84d75ccd78c3c9f2aeb33bd9', '1dabb767e07d0aa702ee58d41c15eab1', 'e49b2cc3f9aacd500b11a35b1c57112d', '942a84f05f4ab956125f68ec0963481f']
# 2  lineup 1: ['255fe2a8be0ed5c06dd99969ab4fea55', '52c6125836c465f4ac5232121dacb49d', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', '821887f9a002be16b5f79729fae59e01']
# Counter 96
# Event Num 151
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 97
# Event Num 152
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 98
# Event Num 153
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 99
# Event Num 154
# []
# Foul by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 100
# Event Num 156
# []
# Free Throw by 821887f9a002be16b5f79729fae59e01
# Made free throw by 821887f9a002be16b5f79729fae59e01
# Counter 101
# Event Num 157
# []
# Free Throw by 821887f9a002be16b5f79729fae59e01
# Made final free throw by 821887f9a002be16b5f79729fae59e01
# Counter 102
# Event Num 158
# []
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 103
# Event Num 160
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 104
# Event Num 161
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 105
# Event Num 163
# []
# Foul by 52c6125836c465f4ac5232121dacb49d
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 106
# Event Num 164
# []
# Free Throw by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Missed free throw by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Counter 107
# Event Num 165
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 108
# Event Num 166
# []
# Made Shot by 942a84f05f4ab956125f68ec0963481f
# 942a84f05f4ab956125f68ec0963481f scores 2 points
# Counter 109
# Event Num 167
# []
# Turnover by 255fe2a8be0ed5c06dd99969ab4fea55
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 110
# Event Num 169
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 111
# Event Num 170
# []
# Made Shot by 255fe2a8be0ed5c06dd99969ab4fea55
# 255fe2a8be0ed5c06dd99969ab4fea55 scores 2 points
# Counter 112
# Event Num 172
# []
# Missed Shot by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 32c044aa84d75ccd78c3c9f2aeb33bd9 misses shot
# Counter 113
# Event Num 173
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 114
# Event Num 174
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 115
# Event Num 175
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 116
# Event Num 176
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 117
# Event Num 177
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 118
# Event Num 178
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Offensive Rebound
# Counter 119
# Event Num 179
# []
# Made Shot by 942a84f05f4ab956125f68ec0963481f
# 942a84f05f4ab956125f68ec0963481f scores 2 points
# Counter 120
# Event Num 180
# []
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 121
# Event Num 182
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 122
# Event Num 183
# []
# Substitution by 1a6703883f8f47bb4daf09c03be3bda2
# 3626b893fc73a5cbd67d1ea48a5c7039  replacing  1a6703883f8f47bb4daf09c03be3bda2
# Counter 123
# Event Num 184
# []
# Substitution by 821887f9a002be16b5f79729fae59e01
# a1591595c04d12e88e3cb427fb667618  replacing  821887f9a002be16b5f79729fae59e01
# Counter 124
# Event Num 187
# []
# Made Shot by 942a84f05f4ab956125f68ec0963481f
# 942a84f05f4ab956125f68ec0963481f scores 2 points
# Counter 125
# Event Num 189
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 126
# Event Num 190
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 127
# Event Num 191
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 128
# Event Num 192
# []
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 129
# Event Num 193
# []
# Substitution by 255fe2a8be0ed5c06dd99969ab4fea55
# 3d75035d20b173a867d4bf32c8a58f0b  replacing  255fe2a8be0ed5c06dd99969ab4fea55
# Counter 130
# Event Num 194
# []
# Substitution by 52c6125836c465f4ac5232121dacb49d
# 1a6703883f8f47bb4daf09c03be3bda2  replacing  52c6125836c465f4ac5232121dacb49d
# Counter 131
# Event Num 197
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 132
# Event Num 198
# []
# Rebound by 1dabb767e07d0aa702ee58d41c15eab1
# Defensive Rebound
# Counter 133
# Event Num 199
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 134
# Event Num 201
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 135
# Event Num 203
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 136
# Event Num 204
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Offensive Rebound
# Counter 137
# Event Num 205
# []
# Missed Shot by 942a84f05f4ab956125f68ec0963481f
# 942a84f05f4ab956125f68ec0963481f misses shot
# Counter 138
# Event Num 206
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Offensive Rebound
# Counter 139
# Event Num 207
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 140
# Event Num 208
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 141
# Event Num 209
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 142
# Event Num 211
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 143
# Event Num 212
# []
# Substitution by e49b2cc3f9aacd500b11a35b1c57112d
# 95920e4bf5b6c15ba8dffbf959b38ba5  replacing  e49b2cc3f9aacd500b11a35b1c57112d
# Counter 144
# Event Num 213
# []
# Substitution by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 722a380c9b59ef42226e8d392824dcb9  replacing  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 145
# Event Num 216
# []
# Made Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 scores 3 points
# Counter 146
# Event Num 218
# []
# Turnover by a1591595c04d12e88e3cb427fb667618
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 147
# Event Num 220
# []
# Made Shot by 942a84f05f4ab956125f68ec0963481f
# 942a84f05f4ab956125f68ec0963481f scores 2 points
# Counter 148
# Event Num 222
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 149
# Event Num 223
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 150
# Event Num 224
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 151
# Event Num 226
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 152
# Event Num 228
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 153
# Event Num 229
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 154
# Event Num 230
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 155
# Event Num 231
# []
# Turnover by 95920e4bf5b6c15ba8dffbf959b38ba5
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 156
# Event Num 233
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 157
# Event Num 234
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 158
# Event Num 235
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 159
# Event Num 236
# []
# Rebound by 31598ba01a3fff03ed0a87d7dea11dfe
# Defensive Rebound
# Counter 160
# Event Num 237
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 161
# Event Num 238
# []
# Rebound by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Defensive Rebound
# Counter 162
# Event Num 242
# []
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 163
# Event Num 244
# []
# Substitution by 3d75035d20b173a867d4bf32c8a58f0b
# 6f6a807d57aae8f651222523dc82dc35  replacing  3d75035d20b173a867d4bf32c8a58f0b
# Counter 164
# Event Num 245
# []
# Substitution by 32c044aa84d75ccd78c3c9f2aeb33bd9
# fb64ca4b8beaf4c4c6e4575fe2f3abd7  replacing  32c044aa84d75ccd78c3c9f2aeb33bd9
# Counter 165
# Event Num 246
# []
# Substitution by 1dabb767e07d0aa702ee58d41c15eab1
# 7f438c18058290903c46dfe9d71bd68a  replacing  1dabb767e07d0aa702ee58d41c15eab1
# Counter 166
# Event Num 250
# []
# Turnover by 22fab2ecad98e9fed46efe57558bc41f
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 167
# Event Num 251
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 168
# Event Num 252
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 169
# Event Num 253
# []
# Turnover by 7f438c18058290903c46dfe9d71bd68a
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 170
# Event Num 255
# []
# Stoppage by 0370a0d090da0d0edc6319f120187e0e
# Counter 171
# Event Num 256
# []
# Substitution by 6f6a807d57aae8f651222523dc82dc35
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  6f6a807d57aae8f651222523dc82dc35
# Counter 172
# Event Num 257
# []
# Substitution by 942a84f05f4ab956125f68ec0963481f
# ef8b068ab7ac9d387b256404acd24cd5  replacing  942a84f05f4ab956125f68ec0963481f
# Counter 173
# Event Num 260
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 3 points
# Counter 174
# Event Num 262
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 175
# Event Num 263
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Offensive Rebound
# Counter 176
# Event Num 264
# []
# Missed Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 misses shot
# Counter 177
# Event Num 265
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Offensive Rebound
# Counter 178
# Event Num 266
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 179
# Event Num 267
# []
# Made Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 scores 2 points
# Counter 180
# Event Num 269
# []
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 181
# Event Num 271
# []
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# 1dabb767e07d0aa702ee58d41c15eab1  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 182
# Event Num 273
# []
# Free Throw by a1591595c04d12e88e3cb427fb667618
# Made final free throw by a1591595c04d12e88e3cb427fb667618
# Counter 183
# Event Num 274
# []
# Turnover by ef8b068ab7ac9d387b256404acd24cd5
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 184
# Event Num 276
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 185
# Event Num 278
# []
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 186
# Event Num 280
# []
# Substitution by a1591595c04d12e88e3cb427fb667618
# bfef77a3e57907855444410d490e7bfd  replacing  a1591595c04d12e88e3cb427fb667618
# Counter 187
# Event Num 282
# []
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 188
# Event Num 283
# []
# Free Throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Made free throw by 95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 189
# Event Num 284
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 190
# Event Num 285
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 191
# Event Num 286
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 192
# Event Num 287
# []
# Rebound by 7f438c18058290903c46dfe9d71bd68a
# Defensive Rebound
# Counter 193
# Event Num 288
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 194
# Event Num 289
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 195
# Event Num 290
# []
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 196
# Event Num 291
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Defensive Rebound
# Counter 197
# Event Num 292
# []
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 198
# Event Num 293
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 199
# Event Num 294
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 200
# Event Num 296
# []
# Instant Replay by 035f7f0d15cef3182c61a8d7fbbf59ad
# Counter 201
# Event Num 297
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 2 ended
# Counter 202
# Event Num 302
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 3  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '95920e4bf5b6c15ba8dffbf959b38ba5', '722a380c9b59ef42226e8d392824dcb9', 'ef8b068ab7ac9d387b256404acd24cd5']
# 3  lineup 1: ['3626b893fc73a5cbd67d1ea48a5c7039', 'bfef77a3e57907855444410d490e7bfd', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Counter 203
# Event Num 303
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 204
# Event Num 305
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 205
# Event Num 306
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Offensive Rebound
# Counter 206
# Event Num 328
# []
# Missed Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 misses shot
# Counter 207
# Event Num 330
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 208
# Event Num 309
# []
# Made Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 scores 2 points
# Counter 209
# Event Num 310
# []
# Made Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 scores 3 points
# Counter 210
# Event Num 311
# []
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 211
# Event Num 313
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 212
# Event Num 314
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 213
# Event Num 315
# []
# Made Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd scores 2 points
# Counter 214
# Event Num 317
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 215
# Event Num 318
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 216
# Event Num 319
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 217
# Event Num 320
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Defensive Rebound
# Counter 218
# Event Num 321
# []
# Foul by 31598ba01a3fff03ed0a87d7dea11dfe
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 219
# Event Num 323
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 220
# Event Num 324
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 221
# Event Num 325
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 222
# Event Num 327
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 223
# Event Num 331
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 224
# Event Num 332
# []
# Rebound by ef8b068ab7ac9d387b256404acd24cd5
# Offensive Rebound
# Counter 225
# Event Num 333
# []
# Missed Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 misses shot
# Counter 226
# Event Num 335
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 227
# Event Num 336
# []
# Turnover by 1a6703883f8f47bb4daf09c03be3bda2
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 228
# Event Num 337
# []
# Made Shot by ef8b068ab7ac9d387b256404acd24cd5
# ef8b068ab7ac9d387b256404acd24cd5 scores 2 points
# Counter 229
# Event Num 339
# []
# Missed Shot by bfef77a3e57907855444410d490e7bfd
# bfef77a3e57907855444410d490e7bfd misses shot
# Counter 230
# Event Num 340
# []
# Rebound by 722a380c9b59ef42226e8d392824dcb9
# Defensive Rebound
# Counter 231
# Event Num 341
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 232
# Event Num 342
# []
# Rebound by bfef77a3e57907855444410d490e7bfd
# Defensive Rebound
# Counter 233
# Event Num 343
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 234
# Event Num 344
# []
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 235
# Event Num 345
# []
# Foul by ef8b068ab7ac9d387b256404acd24cd5
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 236
# Event Num 347
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 237
# Event Num 349
# []
# Foul by 1a6703883f8f47bb4daf09c03be3bda2
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 238
# Event Num 351
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 239
# Event Num 352
# []
# Substitution by bfef77a3e57907855444410d490e7bfd
# 6f6a807d57aae8f651222523dc82dc35  replacing  bfef77a3e57907855444410d490e7bfd
# Counter 240
# Event Num 354
# []
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 241
# Event Num 355
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 242
# Event Num 356
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 243
# Event Num 357
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 244
# Event Num 368
# []
# Instant Replay by bf0da1b311f7619970cb629cba3cdb93
# Counter 245
# Event Num 358
# []
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 246
# Event Num 360
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 247
# Event Num 361
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 248
# Event Num 362
# []
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed shot possession fix
# Add off possession to  ['3626b893fc73a5cbd67d1ea48a5c7039', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618', '6f6a807d57aae8f651222523dc82dc35']
# Add def possession to  ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '95920e4bf5b6c15ba8dffbf959b38ba5', '722a380c9b59ef42226e8d392824dcb9', 'ef8b068ab7ac9d387b256404acd24cd5']
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 249
# Event Num 364
# []
# Missed Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 misses shot
# Counter 250
# Event Num 365
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 251
# Event Num 366
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 3 points
# Counter 252
# Event Num 367
# []
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 253
# Event Num 370
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 254
# Event Num 371
# []
# Rebound by 6f6a807d57aae8f651222523dc82dc35
# Offensive Rebound
# Counter 255
# Event Num 372
# []
# Made Shot by 6f6a807d57aae8f651222523dc82dc35
# 6f6a807d57aae8f651222523dc82dc35 scores 2 points
# Counter 256
# Event Num 373
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 257
# Event Num 374
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 258
# Event Num 375
# []
# Foul by 6f6a807d57aae8f651222523dc82dc35
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 259
# Event Num 377
# []
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# 1dabb767e07d0aa702ee58d41c15eab1  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 260
# Event Num 379
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed shot possession fix
# Add off possession to subbed players ['722a380c9b59ef42226e8d392824dcb9']
# Add def possession to subbed players []
# Was offensive rebound, don't do anything for on court players
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 261
# Event Num 381
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Offensive Rebound
# Counter 262
# Event Num 382
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 263
# Event Num 383
# []
# Missed Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe misses shot
# Counter 264
# Event Num 384
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 265
# Event Num 385
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 3 points
# Counter 266
# Event Num 386
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 267
# Event Num 387
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 268
# Event Num 388
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 269
# Event Num 389
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 270
# Event Num 390
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 271
# Event Num 391
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 272
# Event Num 392
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 273
# Event Num 393
# []
# Foul by 6f6a807d57aae8f651222523dc82dc35
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 274
# Event Num 395
# []
# Substitution by ef8b068ab7ac9d387b256404acd24cd5
# 942a84f05f4ab956125f68ec0963481f  replacing  ef8b068ab7ac9d387b256404acd24cd5
# Counter 275
# Event Num 397
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed shot possession fix
# Add off possession to subbed players ['ef8b068ab7ac9d387b256404acd24cd5']
# Add def possession to subbed players []
# Was offensive rebound, don't do anything for on court players
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 276
# Event Num 398
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Offensive Rebound
# Counter 277
# Event Num 399
# []
# Missed Shot by 942a84f05f4ab956125f68ec0963481f
# 942a84f05f4ab956125f68ec0963481f misses shot
# Counter 278
# Event Num 401
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 279
# Event Num 402
# []
# Foul by 942a84f05f4ab956125f68ec0963481f
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 280
# Event Num 404
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 281
# Event Num 405
# []
# Substitution by 1a6703883f8f47bb4daf09c03be3bda2
# 52c6125836c465f4ac5232121dacb49d  replacing  1a6703883f8f47bb4daf09c03be3bda2
# Counter 282
# Event Num 407
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made final free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 283
# Event Num 408
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 284
# Event Num 410
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 285
# Event Num 411
# []
# Turnover by 1dabb767e07d0aa702ee58d41c15eab1
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 286
# Event Num 413
# []
# Missed Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 misses shot
# Counter 287
# Event Num 414
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 288
# Event Num 415
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 289
# Event Num 416
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 290
# Event Num 417
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 291
# Event Num 419
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 292
# Event Num 420
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 293
# Event Num 421
# []
# Made Shot by 6f6a807d57aae8f651222523dc82dc35
# 6f6a807d57aae8f651222523dc82dc35 scores 2 points
# Counter 294
# Event Num 423
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 295
# Event Num 424
# []
# Substitution by 31598ba01a3fff03ed0a87d7dea11dfe
# 3d75035d20b173a867d4bf32c8a58f0b  replacing  31598ba01a3fff03ed0a87d7dea11dfe
# Counter 296
# Event Num 425
# []
# Substitution by a1591595c04d12e88e3cb427fb667618
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  a1591595c04d12e88e3cb427fb667618
# Counter 297
# Event Num 426
# []
# Substitution by 7f438c18058290903c46dfe9d71bd68a
# 32c044aa84d75ccd78c3c9f2aeb33bd9  replacing  7f438c18058290903c46dfe9d71bd68a
# Counter 298
# Event Num 427
# []
# Substitution by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# e49b2cc3f9aacd500b11a35b1c57112d  replacing  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 299
# Event Num 432
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 300
# Event Num 433
# []
# Made Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 scores 2 points
# Counter 301
# Event Num 435
# []
# Foul by 3626b893fc73a5cbd67d1ea48a5c7039
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 302
# Event Num 437
# []
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Missed free throw by 942a84f05f4ab956125f68ec0963481f
# Counter 303
# Event Num 438
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 304
# Event Num 439
# []
# Substitution by 95920e4bf5b6c15ba8dffbf959b38ba5
# 7f438c18058290903c46dfe9d71bd68a  replacing  95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 305
# Event Num 441
# []
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Made final free throw by 942a84f05f4ab956125f68ec0963481f
# Counter 306
# Event Num 442
# []
# Missed Shot by 0b978fcfa7f2ec839c563a755e345ff8
# 0b978fcfa7f2ec839c563a755e345ff8 misses shot
# Counter 307
# Event Num 443
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 308
# Event Num 444
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 309
# Event Num 445
# []
# Rebound by 3d75035d20b173a867d4bf32c8a58f0b
# Defensive Rebound
# Counter 310
# Event Num 446
# []
# Missed Shot by 3d75035d20b173a867d4bf32c8a58f0b
# 3d75035d20b173a867d4bf32c8a58f0b misses shot
# Counter 311
# Event Num 447
# []
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 312
# Event Num 448
# []
# End Period by 0370a0d090da0d0edc6319f120187e0e
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# 3 ended
# Counter 313
# Event Num 455
# []
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 4  lineup 0: ['32c044aa84d75ccd78c3c9f2aeb33bd9', '7f438c18058290903c46dfe9d71bd68a', '1dabb767e07d0aa702ee58d41c15eab1', 'e49b2cc3f9aacd500b11a35b1c57112d', '942a84f05f4ab956125f68ec0963481f']
# 4  lineup 1: ['52c6125836c465f4ac5232121dacb49d', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618', '6f6a807d57aae8f651222523dc82dc35']
# Counter 314
# Event Num 456
# []
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 315
# Event Num 457
# []
# Rebound by 6f6a807d57aae8f651222523dc82dc35
# Defensive Rebound
# Counter 316
# Event Num 458
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 317
# Event Num 459
# []
# Rebound by 6f6a807d57aae8f651222523dc82dc35
# Offensive Rebound
# Counter 318
# Event Num 460
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 319
# Event Num 461
# []
# Rebound by e49b2cc3f9aacd500b11a35b1c57112d
# Defensive Rebound
# Counter 320
# Event Num 500
# []
# Missed Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d misses shot
# Counter 321
# Event Num 502
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 322
# Event Num 463
# []
# Substitution by 7f438c18058290903c46dfe9d71bd68a
# fb64ca4b8beaf4c4c6e4575fe2f3abd7  replacing  7f438c18058290903c46dfe9d71bd68a
# Counter 323
# Event Num 465
# []
# Missed Shot by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Missed shot possession fix
# Add off possession to subbed players ['7f438c18058290903c46dfe9d71bd68a']
# Add def possession to subbed players []
# Was offensive rebound, don't do anything for on court players
# 32c044aa84d75ccd78c3c9f2aeb33bd9 misses shot
# Counter 324
# Event Num 467
# []
# Rebound by 31598ba01a3fff03ed0a87d7dea11dfe
# Defensive Rebound
# Counter 325
# Event Num 468
# []
# Turnover by 31598ba01a3fff03ed0a87d7dea11dfe
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 326
# Event Num 470
# []
# Made Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 scores 2 points
# Counter 327
# Event Num 472
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 328
# Event Num 473
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 329
# Event Num 474
# []
# Foul by 6f6a807d57aae8f651222523dc82dc35
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 330
# Event Num 476
# []
# Foul by 52c6125836c465f4ac5232121dacb49d
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 331
# Event Num 478
# []
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Missed free throw by 942a84f05f4ab956125f68ec0963481f
# Counter 332
# Event Num 479
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 333
# Event Num 480
# []
# Free Throw by 942a84f05f4ab956125f68ec0963481f
# Missed last free throw by 942a84f05f4ab956125f68ec0963481f
# ftteam1 ['52c6125836c465f4ac5232121dacb49d', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618', '6f6a807d57aae8f651222523dc82dc35']
# Counter 334
# Event Num 481
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 335
# Event Num 482
# []
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 2 points
# Counter 336
# Event Num 484
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 337
# Event Num 486
# []
# Foul by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 338
# Event Num 488
# []
# Free Throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Made free throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Counter 339
# Event Num 489
# []
# Free Throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Made free throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Counter 340
# Event Num 490
# []
# Free Throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Made final free throw by 31598ba01a3fff03ed0a87d7dea11dfe
# Counter 341
# Event Num 491
# []
# Made Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 scores 3 points
# Counter 342
# Event Num 493
# []
# Missed Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 misses shot
# Counter 343
# Event Num 494
# []
# Rebound by 32c044aa84d75ccd78c3c9f2aeb33bd9
# Defensive Rebound
# Counter 344
# Event Num 495
# []
# Made Shot by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 32c044aa84d75ccd78c3c9f2aeb33bd9 scores 3 points
# Counter 345
# Event Num 497
# []
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 346
# Event Num 498
# []
# Substitution by 52c6125836c465f4ac5232121dacb49d
# 3626b893fc73a5cbd67d1ea48a5c7039  replacing  52c6125836c465f4ac5232121dacb49d
# Counter 347
# Event Num 503
# []
# Foul by 942a84f05f4ab956125f68ec0963481f
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 348
# Event Num 505
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 349
# Event Num 506
# []
# Rebound by a1591595c04d12e88e3cb427fb667618
# Offensive Rebound
# Counter 350
# Event Num 507
# []
# Made Shot by 6f6a807d57aae8f651222523dc82dc35
# 6f6a807d57aae8f651222523dc82dc35 scores 2 points
# Counter 351
# Event Num 509
# []
# Made Shot by e49b2cc3f9aacd500b11a35b1c57112d
# e49b2cc3f9aacd500b11a35b1c57112d scores 2 points
# Counter 352
# Event Num 510
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 353
# Event Num 511
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 354
# Event Num 512
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 355
# Event Num 513
# []
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 356
# Event Num 514
# []
# Rebound by 942a84f05f4ab956125f68ec0963481f
# Defensive Rebound
# Counter 357
# Event Num 515
# []
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 358
# Event Num 516
# []
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 359
# Event Num 517
# []
# Foul by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 360
# Event Num 519
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 361
# Event Num 694
# []
# Substitution by 32c044aa84d75ccd78c3c9f2aeb33bd9
# 7f438c18058290903c46dfe9d71bd68a  replacing  32c044aa84d75ccd78c3c9f2aeb33bd9
# Counter 362
# Event Num 520
# []
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Missed last free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# ftteam1 ['1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618', '6f6a807d57aae8f651222523dc82dc35', '3626b893fc73a5cbd67d1ea48a5c7039']
# Counter 363
# Event Num 521
# []
# Rebound by 6f6a807d57aae8f651222523dc82dc35
# Offensive Rebound
# Counter 364
# Event Num 522
# []
# Made Shot by 6f6a807d57aae8f651222523dc82dc35
# 6f6a807d57aae8f651222523dc82dc35 scores 2 points
# Counter 365
# Event Num 523
# []
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 366
# Event Num 524
# []
# Rebound by e49b2cc3f9aacd500b11a35b1c57112d
# Offensive Rebound
# Counter 367
# Event Num 525
# []
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 368
# Event Num 527
# []
# Foul by e49b2cc3f9aacd500b11a35b1c57112d
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 369
# Event Num 529
# []
# Substitution by 942a84f05f4ab956125f68ec0963481f
# 722a380c9b59ef42226e8d392824dcb9  replacing  942a84f05f4ab956125f68ec0963481f
# Counter 370
# Event Num 539
# []
# Substitution by e49b2cc3f9aacd500b11a35b1c57112d
# 95920e4bf5b6c15ba8dffbf959b38ba5  replacing  e49b2cc3f9aacd500b11a35b1c57112d
# Counter 371
# Event Num 533
# []
# Turnover by 1a6703883f8f47bb4daf09c03be3bda2
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 372
# Event Num 534
# []
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 373
# Event Num 535
# []
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Offensive Rebound
# Counter 374
# Event Num 536
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 375
# Event Num 537
# []
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Offensive Rebound
# Counter 376
# Event Num 538
# []
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 2 points
# Counter 377
# Event Num 541
# []
# Made Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 scores 3 points
# Counter 378
# Event Num 543
# []
# Turnover by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 8362dfecb7412f12a12713852d2ae566 turnover
# Counter 379
# Event Num 544
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 3 points
# Counter 380
# Event Num 545
# []
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 381
# Event Num 546
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 382
# Event Num 547
# []
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 383
# Event Num 548
# []
# Missed Shot by 6f6a807d57aae8f651222523dc82dc35
# 6f6a807d57aae8f651222523dc82dc35 misses shot
# Counter 384
# Event Num 549
# []
# Rebound by 22fab2ecad98e9fed46efe57558bc41f
# Counter 385
# Event Num 550
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Missed shot possession fix
# Add off possession to  ['1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618', '6f6a807d57aae8f651222523dc82dc35', '3626b893fc73a5cbd67d1ea48a5c7039']
# Add def possession to  ['1dabb767e07d0aa702ee58d41c15eab1', 'fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '722a380c9b59ef42226e8d392824dcb9', '95920e4bf5b6c15ba8dffbf959b38ba5']
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 386
# Event Num 551
# []
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 387
# Event Num 552
# []
# Rebound by f5f0b0fd479d7c889872298f95c3d810
# Counter 388
# Event Num 553
# []
# Turnover by f5f0b0fd479d7c889872298f95c3d810
# Missed shot possession fix
# Was offensive rebound, don't do anything for on court players
# cd45058739ed0ac8229849c6249aad48 turnover
# Counter 389
# Event Num 554
# []
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 390
# Event Num 555
# []
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 391
# Event Num 556
# []
# Missed Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a misses shot
# Counter 392
# Event Num 692
# []
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# Offensive Rebound
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 393
# Event Num 557
# [557]
# Rebound by 722a380c9b59ef42226e8d392824dcb9
# Counter 394
# Event Num 693
# [557]
# Rebound by 1dabb767e07d0aa702ee58d41c15eab1
# Offensive Rebound
# Counter 395
# Event Num 558
# [557]
# Made Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 scores 3 points
# Counter 396
# Event Num 560
# [557]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 397
# Event Num 561
# [557]
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Defensive Rebound
# Counter 398
# Event Num 562
# [557]
# Missed Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 misses shot
# Counter 399
# Event Num 563
# [557]
# Rebound by 3626b893fc73a5cbd67d1ea48a5c7039
# Defensive Rebound
# Counter 400
# Event Num 564
# [557]
# Missed Shot by 3626b893fc73a5cbd67d1ea48a5c7039
# 3626b893fc73a5cbd67d1ea48a5c7039 misses shot
# Counter 401
# Event Num 565
# [557]
# Rebound by 95920e4bf5b6c15ba8dffbf959b38ba5
# Defensive Rebound
# Counter 402
# Event Num 566
# [557]
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 403
# Event Num 567
# [557]
# Foul by 6f6a807d57aae8f651222523dc82dc35
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 404
# Event Num 569
# [557]
# Substitution by 95920e4bf5b6c15ba8dffbf959b38ba5
# ef8b068ab7ac9d387b256404acd24cd5  replacing  95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 405
# Event Num 571
# [557]
# Timeout by f5f0b0fd479d7c889872298f95c3d810
# Counter 406
# Event Num 572
# [557]
# Substitution by 6f6a807d57aae8f651222523dc82dc35
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  6f6a807d57aae8f651222523dc82dc35
# Counter 407
# Event Num 574
# [557]
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 408
# Event Num 575
# [557]
# Foul by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 409
# Event Num 578
# [557]
# Instant Replay by af6cef8da151542d872f94fee4de5593
# Counter 410
# Event Num 579
# [557]
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 411
# Event Num 580
# [557]
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# 95920e4bf5b6c15ba8dffbf959b38ba5  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 412
# Event Num 581
# [557]
# Substitution by 1dabb767e07d0aa702ee58d41c15eab1
# 32c044aa84d75ccd78c3c9f2aeb33bd9  replacing  1dabb767e07d0aa702ee58d41c15eab1
# Counter 413
# Event Num 586
# [557]
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made final free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 414
# Event Num 587
# [557]
# Substitution by ef8b068ab7ac9d387b256404acd24cd5
# 722a380c9b59ef42226e8d392824dcb9  replacing  ef8b068ab7ac9d387b256404acd24cd5
# Counter 415
# Event Num 589
# [557]
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 416
# Event Num 599
# [557]
# Substitution by 0b978fcfa7f2ec839c563a755e345ff8
# 6f6a807d57aae8f651222523dc82dc35  replacing  0b978fcfa7f2ec839c563a755e345ff8
# Counter 417
# Event Num 590
# [557]
# Made Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 scores 2 points
# Counter 418
# Event Num 591
# [557]
# Made Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 scores 2 points
# Counter 419
# Event Num 592
# [557]
# Foul by 95920e4bf5b6c15ba8dffbf959b38ba5
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 420
# Event Num 594
# [557]
# Free Throw by 1a6703883f8f47bb4daf09c03be3bda2
# Made final free throw by 1a6703883f8f47bb4daf09c03be3bda2
# Counter 421
# Event Num 595
# [557]
# Foul by 31598ba01a3fff03ed0a87d7dea11dfe
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 422
# Event Num 597
# [557]
# Free Throw by 722a380c9b59ef42226e8d392824dcb9
# Made free throw by 722a380c9b59ef42226e8d392824dcb9
# Counter 423
# Event Num 601
# [557]
# Free Throw by 722a380c9b59ef42226e8d392824dcb9
# Missed last free throw by 722a380c9b59ef42226e8d392824dcb9
# ftteam1 ['1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618', '3626b893fc73a5cbd67d1ea48a5c7039', '6f6a807d57aae8f651222523dc82dc35']
# Counter 424
# Event Num 602
# [557]
# Rebound by 7f438c18058290903c46dfe9d71bd68a
# Offensive Rebound
# Counter 425
# Event Num 598
# [557]
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 4 ended
# Counter 426
# Event Num 607
# [557]
# Start Period by 0370a0d090da0d0edc6319f120187e0e
# 5  lineup 0: ['fb64ca4b8beaf4c4c6e4575fe2f3abd7', '7f438c18058290903c46dfe9d71bd68a', '1dabb767e07d0aa702ee58d41c15eab1', '95920e4bf5b6c15ba8dffbf959b38ba5', '722a380c9b59ef42226e8d392824dcb9']
# 5  lineup 1: ['52c6125836c465f4ac5232121dacb49d', '3626b893fc73a5cbd67d1ea48a5c7039', '1a6703883f8f47bb4daf09c03be3bda2', '31598ba01a3fff03ed0a87d7dea11dfe', 'a1591595c04d12e88e3cb427fb667618']
# Counter 427
# Event Num 697
# [557]
# Jump Ball by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 428
# Event Num 611
# [557]
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 429
# Event Num 612
# [557]
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 430
# Event Num 613
# [557]
# Foul by 1dabb767e07d0aa702ee58d41c15eab1
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 431
# Event Num 615
# [557]
# Foul by 722a380c9b59ef42226e8d392824dcb9
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 432
# Event Num 617
# [557]
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 433
# Event Num 618
# [557]
# Free Throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Made final free throw by 3626b893fc73a5cbd67d1ea48a5c7039
# Counter 434
# Event Num 619
# [557]
# Missed Shot by 722a380c9b59ef42226e8d392824dcb9
# 722a380c9b59ef42226e8d392824dcb9 misses shot
# Counter 435
# Event Num 621
# [557]
# Rebound by a1591595c04d12e88e3cb427fb667618
# Defensive Rebound
# Counter 436
# Event Num 622
# [557]
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 437
# Event Num 624
# [557]
# Missed Shot by 95920e4bf5b6c15ba8dffbf959b38ba5
# 95920e4bf5b6c15ba8dffbf959b38ba5 misses shot
# Counter 438
# Event Num 625
# [557]
# Rebound by 31598ba01a3fff03ed0a87d7dea11dfe
# Defensive Rebound
# Counter 439
# Event Num 626
# [557]
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 440
# Event Num 628
# [557]
# Timeout by 22fab2ecad98e9fed46efe57558bc41f
# Counter 441
# Event Num 632
# [557]
# Foul by 3626b893fc73a5cbd67d1ea48a5c7039
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 442
# Event Num 634
# [557]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 443
# Event Num 635
# [557]
# Rebound by 52c6125836c465f4ac5232121dacb49d
# Defensive Rebound
# Counter 444
# Event Num 636
# [557]
# Made Shot by 52c6125836c465f4ac5232121dacb49d
# 52c6125836c465f4ac5232121dacb49d scores 2 points
# Counter 445
# Event Num 638
# [557]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 446
# Event Num 639
# [557]
# Rebound by 1dabb767e07d0aa702ee58d41c15eab1
# Offensive Rebound
# Counter 447
# Event Num 640
# [557]
# Made Shot by 1dabb767e07d0aa702ee58d41c15eab1
# 1dabb767e07d0aa702ee58d41c15eab1 scores 2 points
# Counter 448
# Event Num 641
# [557]
# Made Shot by a1591595c04d12e88e3cb427fb667618
# a1591595c04d12e88e3cb427fb667618 scores 3 points
# Counter 449
# Event Num 643
# [557]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 450
# Event Num 644
# [557]
# Rebound by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Offensive Rebound
# Counter 451
# Event Num 645
# [557]
# Foul by a1591595c04d12e88e3cb427fb667618
# Foul on team cd45058739ed0ac8229849c6249aad48
# Counter 452
# Event Num 647
# [557]
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 453
# Event Num 648
# [557]
# Substitution by 95920e4bf5b6c15ba8dffbf959b38ba5
# ef8b068ab7ac9d387b256404acd24cd5  replacing  95920e4bf5b6c15ba8dffbf959b38ba5
# Counter 454
# Event Num 650
# [557]
# Free Throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Made final free throw by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 455
# Event Num 651
# [557]
# Made Shot by 31598ba01a3fff03ed0a87d7dea11dfe
# 31598ba01a3fff03ed0a87d7dea11dfe scores 3 points
# Counter 456
# Event Num 653
# [557]
# Missed Shot by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# fb64ca4b8beaf4c4c6e4575fe2f3abd7 misses shot
# Counter 457
# Event Num 654
# [557]
# Rebound by 1a6703883f8f47bb4daf09c03be3bda2
# Defensive Rebound
# Counter 458
# Event Num 655
# [557]
# Missed Shot by 1a6703883f8f47bb4daf09c03be3bda2
# 1a6703883f8f47bb4daf09c03be3bda2 misses shot
# Counter 459
# Event Num 657
# [557]
# Rebound by 7f438c18058290903c46dfe9d71bd68a
# Defensive Rebound
# Counter 460
# Event Num 658
# [557]
# Made Shot by 7f438c18058290903c46dfe9d71bd68a
# 7f438c18058290903c46dfe9d71bd68a scores 3 points
# Counter 461
# Event Num 662
# [557]
# Foul by ef8b068ab7ac9d387b256404acd24cd5
# Foul on team 8362dfecb7412f12a12713852d2ae566
# Counter 462
# Event Num 665
# [557]
# Instant Replay by 7bc394309ee52d00e1b33282b36f5a99
# Counter 463
# Event Num 688
# [557]
# Ejection by ef8b068ab7ac9d387b256404acd24cd5
# Counter 464
# Event Num 666
# [557]
# Free Throw by 52c6125836c465f4ac5232121dacb49d
# Made free throw by 52c6125836c465f4ac5232121dacb49d
# Counter 465
# Event Num 667
# [557]
# Free Throw by 52c6125836c465f4ac5232121dacb49d
# Made free throw by 52c6125836c465f4ac5232121dacb49d
# Counter 466
# Event Num 668
# [557]
# Substitution by 31598ba01a3fff03ed0a87d7dea11dfe
# 821887f9a002be16b5f79729fae59e01  replacing  31598ba01a3fff03ed0a87d7dea11dfe
# Counter 467
# Event Num 669
# [557]
# Substitution by a1591595c04d12e88e3cb427fb667618
# 6f6a807d57aae8f651222523dc82dc35  replacing  a1591595c04d12e88e3cb427fb667618
# Counter 468
# Event Num 670
# [557]
# Substitution by 1a6703883f8f47bb4daf09c03be3bda2
# 3d75035d20b173a867d4bf32c8a58f0b  replacing  1a6703883f8f47bb4daf09c03be3bda2
# Counter 469
# Event Num 671
# [557]
# Substitution by 52c6125836c465f4ac5232121dacb49d
# 0b978fcfa7f2ec839c563a755e345ff8  replacing  52c6125836c465f4ac5232121dacb49d
# Counter 470
# Event Num 672
# [557]
# Substitution by 3626b893fc73a5cbd67d1ea48a5c7039
# fbcda0bcb861e4726ca8871b8965ede4  replacing  3626b893fc73a5cbd67d1ea48a5c7039
# Counter 471
# Event Num 673
# [557]
# Substitution by 722a380c9b59ef42226e8d392824dcb9
# 619d3e44dc84b366bd685de3e94b3bec  replacing  722a380c9b59ef42226e8d392824dcb9
# Counter 472
# Event Num 674
# [557]
# Substitution by 7f438c18058290903c46dfe9d71bd68a
# c950aaad2e56c87e9ac7281016d37cb6  replacing  7f438c18058290903c46dfe9d71bd68a
# Counter 473
# Event Num 675
# [557]
# Substitution by fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 36fdadf436b164ee29174c8e1fde7271  replacing  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# Counter 474
# Event Num 676
# [557]
# Substitution by 1dabb767e07d0aa702ee58d41c15eab1
# e49b2cc3f9aacd500b11a35b1c57112d  replacing  1dabb767e07d0aa702ee58d41c15eab1
# Counter 475
# Event Num 677
# [557]
# Substitution by ef8b068ab7ac9d387b256404acd24cd5
# 8c7a7249d80b1489594b3a2a87f3f19d  replacing  ef8b068ab7ac9d387b256404acd24cd5
# Counter 476
# Event Num 690
# [557]
# End Period by 0370a0d090da0d0edc6319f120187e0e
# 5 ended
# Counter 477
# Event Num 0
# [557]
# Final Box Printed by 0370a0d090da0d0edc6319f120187e0e

# %%
gameDict
# Out:
# {'0b978fcfa7f2ec839c563a755e345ff8': array([29, 20, 22, 23]),
#  '14de632b07100527b0ced12fd4eeffb7': array([0, 0, 0, 0]),
#  '18a823379f2bf4e4be8b419698cde91c': array([0, 0, 0, 0]),
#  '1a6703883f8f47bb4daf09c03be3bda2': array([113, 103,  86,  87]),
#  '1dabb767e07d0aa702ee58d41c15eab1': array([73, 78, 69, 67]),
#  '255fe2a8be0ed5c06dd99969ab4fea55': array([ 6, 12,  9,  8]),
#  '31598ba01a3fff03ed0a87d7dea11dfe': array([108,  99,  85,  86]),
#  '32c044aa84d75ccd78c3c9f2aeb33bd9': array([41, 29, 32, 31]),
#  '3626b893fc73a5cbd67d1ea48a5c7039': array([113,  96,  86,  87]),
#  '36fdadf436b164ee29174c8e1fde7271': array([0, 0, 1, 0]),
#  '3d75035d20b173a867d4bf32c8a58f0b': array([29, 27, 25, 26]),
#  '52c6125836c465f4ac5232121dacb49d': array([39, 36, 36, 35]),
#  '619d3e44dc84b366bd685de3e94b3bec': array([0, 0, 1, 0]),
#  '6f6a807d57aae8f651222523dc82dc35': array([49, 59, 47, 49]),
#  '722a380c9b59ef42226e8d392824dcb9': array([67, 78, 55, 55]),
#  '7f438c18058290903c46dfe9d71bd68a': array([76, 98, 75, 73]),
#  '821887f9a002be16b5f79729fae59e01': array([6, 8, 7, 8]),
#  '8c7a7249d80b1489594b3a2a87f3f19d': array([0, 0, 1, 0]),
#  '942a84f05f4ab956125f68ec0963481f': array([40, 37, 37, 38]),
#  '94e99d76e87ee926faab66d382b3a955': array([0, 0, 0, 0]),
#  '95920e4bf5b6c15ba8dffbf959b38ba5': array([83, 96, 76, 72]),
#  'a1591595c04d12e88e3cb427fb667618': array([113, 100,  86,  89]),
#  'bfef77a3e57907855444410d490e7bfd': array([15, 10, 12, 13]),
#  'c950aaad2e56c87e9ac7281016d37cb6': array([0, 0, 1, 0]),
#  'e49b2cc3f9aacd500b11a35b1c57112d': array([37, 29, 35, 33]),
#  'ef8b068ab7ac9d387b256404acd24cd5': array([49, 58, 40, 41]),
#  'f3d6e924c2736c9e5771b0784e31c2df': array([0, 0, 0, 0]),
#  'fb64ca4b8beaf4c4c6e4575fe2f3abd7': array([104, 117,  92,  89]),
#  'fbcda0bcb861e4726ca8871b8965ede4': array([0, 0, 0, 1]),
#  'ff59dc439c6c323320bc355afe884fcb': array([0, 0, 0, 0])}

# %%
rdPBP = readablePlayByPlay(gamePlayByPlay, gameLineup, eventCodes)
# Out:
# Team0 8362dfecb7412f12a12713852d2ae566
# Team1 cd45058739ed0ac8229849c6249aad48

# %%
rdPBP[:]
# Out:
#                                Game_id  Event_Num     Event_Msg_Type  Period  \
# 6315  3ce947db2df86b08a40b7526e2faaccb          2       Start Period       1
# 6316  3ce947db2df86b08a40b7526e2faaccb          4          Jump Ball       1
# 6317  3ce947db2df86b08a40b7526e2faaccb          7        Missed Shot       1
# 6318  3ce947db2df86b08a40b7526e2faaccb          8            Rebound       1
# 6319  3ce947db2df86b08a40b7526e2faaccb          9           Turnover       1
# 6320  3ce947db2df86b08a40b7526e2faaccb         11          Made Shot       1
# 6321  3ce947db2df86b08a40b7526e2faaccb         12        Missed Shot       1
# 6322  3ce947db2df86b08a40b7526e2faaccb         13            Rebound       1
# 6323  3ce947db2df86b08a40b7526e2faaccb         14          Made Shot       1
# 6324  3ce947db2df86b08a40b7526e2faaccb         15        Missed Shot       1
# 6325  3ce947db2df86b08a40b7526e2faaccb         16            Rebound       1
# 6326  3ce947db2df86b08a40b7526e2faaccb         17        Missed Shot       1
# 6327  3ce947db2df86b08a40b7526e2faaccb         18            Rebound       1
# 6328  3ce947db2df86b08a40b7526e2faaccb         19          Made Shot       1
# 6329  3ce947db2df86b08a40b7526e2faaccb         20          Made Shot       1
# 6330  3ce947db2df86b08a40b7526e2faaccb         22          Made Shot       1
# 6331  3ce947db2df86b08a40b7526e2faaccb         23               Foul       1
# 6332  3ce947db2df86b08a40b7526e2faaccb         25         Free Throw       1
# 6333  3ce947db2df86b08a40b7526e2faaccb         26               Foul       1
# 6334  3ce947db2df86b08a40b7526e2faaccb         28         Free Throw       1
# 6335  3ce947db2df86b08a40b7526e2faaccb         29         Free Throw       1
# 6336  3ce947db2df86b08a40b7526e2faaccb         30          Made Shot       1
# 6337  3ce947db2df86b08a40b7526e2faaccb         32           Turnover       1
# 6338  3ce947db2df86b08a40b7526e2faaccb         34          Made Shot       1
# 6339  3ce947db2df86b08a40b7526e2faaccb         36          Made Shot       1
# 6340  3ce947db2df86b08a40b7526e2faaccb         38          Made Shot       1
# 6341  3ce947db2df86b08a40b7526e2faaccb         39        Missed Shot       1
# 6342  3ce947db2df86b08a40b7526e2faaccb         40            Rebound       1
# 6343  3ce947db2df86b08a40b7526e2faaccb         41               Foul       1
# 6344  3ce947db2df86b08a40b7526e2faaccb         43          Made Shot       1
# ...                                ...        ...                ...     ...
# 6763  3ce947db2df86b08a40b7526e2faaccb        641          Made Shot       5
# 6764  3ce947db2df86b08a40b7526e2faaccb        643        Missed Shot       5
# 6765  3ce947db2df86b08a40b7526e2faaccb        644            Rebound       5
# 6766  3ce947db2df86b08a40b7526e2faaccb        645               Foul       5
# 6767  3ce947db2df86b08a40b7526e2faaccb        647         Free Throw       5
# 6768  3ce947db2df86b08a40b7526e2faaccb        648       Substitution       5
# 6769  3ce947db2df86b08a40b7526e2faaccb        650         Free Throw       5
# 6770  3ce947db2df86b08a40b7526e2faaccb        651          Made Shot       5
# 6771  3ce947db2df86b08a40b7526e2faaccb        653        Missed Shot       5
# 6772  3ce947db2df86b08a40b7526e2faaccb        654            Rebound       5
# 6773  3ce947db2df86b08a40b7526e2faaccb        655        Missed Shot       5
# 6774  3ce947db2df86b08a40b7526e2faaccb        657            Rebound       5
# 6775  3ce947db2df86b08a40b7526e2faaccb        658          Made Shot       5
# 6776  3ce947db2df86b08a40b7526e2faaccb        662               Foul       5
# 6777  3ce947db2df86b08a40b7526e2faaccb        665     Instant Replay       5
# 6778  3ce947db2df86b08a40b7526e2faaccb        688           Ejection       5
# 6779  3ce947db2df86b08a40b7526e2faaccb        666         Free Throw       5
# 6780  3ce947db2df86b08a40b7526e2faaccb        667         Free Throw       5
# 6787  3ce947db2df86b08a40b7526e2faaccb        668       Substitution       5
# 6784  3ce947db2df86b08a40b7526e2faaccb        669       Substitution       5
# 6789  3ce947db2df86b08a40b7526e2faaccb        670       Substitution       5
# 6783  3ce947db2df86b08a40b7526e2faaccb        671       Substitution       5
# 6785  3ce947db2df86b08a40b7526e2faaccb        672       Substitution       5
# 6788  3ce947db2df86b08a40b7526e2faaccb        673       Substitution       5
# 6786  3ce947db2df86b08a40b7526e2faaccb        674       Substitution       5
# 6782  3ce947db2df86b08a40b7526e2faaccb        675       Substitution       5
# 6790  3ce947db2df86b08a40b7526e2faaccb        676       Substitution       5
# 6781  3ce947db2df86b08a40b7526e2faaccb        677       Substitution       5
# 6791  3ce947db2df86b08a40b7526e2faaccb        690         End Period       5
# 6792  3ce947db2df86b08a40b7526e2faaccb          0  Final Box Printed       5
#
#       WC_Time  PC_Time                     Action_Type  Option1  Option2  \
# 6315   618770     7200                                        0        0
# 6316   618770     7200                                        0        0
# 6317   618960     7010                       Hook Shot        2        0
# 6318   619000     7000                         Unknown        0        0
# 6319   619040     6930                        Bad Pass        1        0
# 6320   619270     6700  Driving Finger Roll Layup Shot        2        0
# 6321   619470     6500        Turnaround Fadeaway shot        2        0
# 6322   619520     6490                         Unknown        0        0
# 6323   619600     6370                      Layup Shot        2        0
# 6324   619720     6290                       Jump Shot        3        0
# 6325   619740     6280                         Unknown        0        0
# 6326   619910     6060                       Jump Shot        3        0
# 6327   619940     6020                         Unknown        0        0
# 6328   619970     5990                Pullup Jump shot        3        1
# 6329   620160     5800              Fadeaway Jump Shot        2        0
# 6330   620310     5670  Driving Finger Roll Layup Shot        2        0
# 6331   620390     5670                        Shooting        0        0
# 6332   620620     5670               Free Throw 1 of 1        1        0
# 6333   620770     5570                        Shooting        0        0
# 6334   621090     5570               Free Throw 1 of 2        1        0
# 6335   621240     5570               Free Throw 2 of 2        1        0
# 6336   621390     5430      Driving Floating Jump Shot        2        0
# 6337   621580     5230                        Bad Pass        1        0
# 6338   621650     5170     Running Alley Oop Dunk Shot        2        1
# 6339   621770     5050                  Jump Bank Shot        2        0
# 6340   621890     4930              Fadeaway Jump Shot        2        0
# 6341   622040     4780                Pullup Jump shot        2        0
# 6342   622090     4770                         Unknown        0        0
# 6343   622120     4770                      Loose Ball        0        0
# 6344   622370     4620                       Jump Shot        3        0
# ...       ...      ...                             ...      ...      ...
# 6763   706250      960                       Jump Shot        3        0
# 6764   706390      880              Driving Layup Shot        2        0
# 6765   706420      860                         Unknown        0        0
# 6766   706450      830                        Shooting        0        0
# 6767   706770      830               Free Throw 1 of 2        1        0
# 6768   706830      830                                        0        0
# 6769   707040      830               Free Throw 2 of 2        1        0
# 6770   707250      640                       Jump Shot        3        0
# 6771   707390      571                Pullup Jump shot        3        0
# 6772   707440      520                         Unknown        0        0
# 6773   707620      341                      Layup Shot        2        0
# 6774   707670      292                         Unknown        0        0
# 6775   707690      277                Pullup Jump shot        3        1
# 6776   708360       26                 Flagrant Type 2        0        0
# 6777   709370       26                 Overturn Ruling        0        0
# 6778   710270       26                           Other        0        0
# 6779   711170       26      Free Throw Flagrant 1 of 2        1        0
# 6780   711230       26      Free Throw Flagrant 2 of 2        1        0
# 6787   711360       26                                        0        0
# 6784   711360       26                                        0        0
# 6789   711360       26                                        0        0
# 6783   711360       26                                        0        0
# 6785   711360       26                                        0        0
# 6788   711360       26                                        0        0
# 6786   711360       26                                        0        0
# 6782   711360       26                                        0        0
# 6790   711360       26                                        0        0
# 6781   711360       26                                        0        0
# 6791   713580        0                                        0        0
# 6792   737590        0                                        0        0
#
#       Option3    Team_id                           Person1  \
# 6315        0  Officials  0370a0d090da0d0edc6319f120187e0e
# 6316        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 6317        0      Team0  95920e4bf5b6c15ba8dffbf959b38ba5
# 6318        0      Team1  a1591595c04d12e88e3cb427fb667618
# 6319        0      Team1  a1591595c04d12e88e3cb427fb667618
# 6320        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6321        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 6322        0      Team0  95920e4bf5b6c15ba8dffbf959b38ba5
# 6323        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 6324        0      Team1  31598ba01a3fff03ed0a87d7dea11dfe
# 6325        0      Team0  ef8b068ab7ac9d387b256404acd24cd5
# 6326        0      Team0  95920e4bf5b6c15ba8dffbf959b38ba5
# 6327        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# 6328        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# 6329        0      Team0  95920e4bf5b6c15ba8dffbf959b38ba5
# 6330        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# 6331        1      Team0  ef8b068ab7ac9d387b256404acd24cd5
# 6332        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# 6333        2      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 6334        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6335        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6336        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 6337        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 6338        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 6339        0      Team0  95920e4bf5b6c15ba8dffbf959b38ba5
# 6340        0      Team1  31598ba01a3fff03ed0a87d7dea11dfe
# 6341        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 6342        0      Team0  22fab2ecad98e9fed46efe57558bc41f
# 6343        0      Team1  31598ba01a3fff03ed0a87d7dea11dfe
# 6344        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# ...       ...        ...                               ...
# 6763        0      Team1  a1591595c04d12e88e3cb427fb667618
# 6764        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6765        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6766        2      Team1  a1591595c04d12e88e3cb427fb667618
# 6767        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6768        0      Team0  95920e4bf5b6c15ba8dffbf959b38ba5
# 6769        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6770        0      Team1  31598ba01a3fff03ed0a87d7dea11dfe
# 6771        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6772        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# 6773        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# 6774        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 6775        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 6776        2      Team0  ef8b068ab7ac9d387b256404acd24cd5
# 6777        0      Team1  7bc394309ee52d00e1b33282b36f5a99
# 6778        0      Team0  ef8b068ab7ac9d387b256404acd24cd5
# 6779        0      Team1  52c6125836c465f4ac5232121dacb49d
# 6780        0      Team1  52c6125836c465f4ac5232121dacb49d
# 6787        0      Team1  31598ba01a3fff03ed0a87d7dea11dfe
# 6784        0      Team1  a1591595c04d12e88e3cb427fb667618
# 6789        0      Team1  1a6703883f8f47bb4daf09c03be3bda2
# 6783        0      Team1  52c6125836c465f4ac5232121dacb49d
# 6785        0      Team1  3626b893fc73a5cbd67d1ea48a5c7039
# 6788        0      Team0  722a380c9b59ef42226e8d392824dcb9
# 6786        0      Team0  7f438c18058290903c46dfe9d71bd68a
# 6782        0      Team0  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6790        0      Team0  1dabb767e07d0aa702ee58d41c15eab1
# 6781        0      Team0  ef8b068ab7ac9d387b256404acd24cd5
# 6791        0      Team0  0370a0d090da0d0edc6319f120187e0e
# 6792        0  Officials  0370a0d090da0d0edc6319f120187e0e
#
#                                Person2                           Person3  \
# 6315  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6316  ef8b068ab7ac9d387b256404acd24cd5  95920e4bf5b6c15ba8dffbf959b38ba5
# 6317  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6318  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6319  fb64ca4b8beaf4c4c6e4575fe2f3abd7  0370a0d090da0d0edc6319f120187e0e
# 6320  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6321  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6322  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6323  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6324  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6325  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6326  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6327  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6328  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6329  7f438c18058290903c46dfe9d71bd68a  0370a0d090da0d0edc6319f120187e0e
# 6330  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6331  1a6703883f8f47bb4daf09c03be3bda2  4c28632a1ac678cf75a2110234adbf29
# 6332  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6333  fb64ca4b8beaf4c4c6e4575fe2f3abd7  6095bcbf4e6a692492b2d9f0a3b975a8
# 6334  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6335  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6336  a1591595c04d12e88e3cb427fb667618  0370a0d090da0d0edc6319f120187e0e
# 6337  a1591595c04d12e88e3cb427fb667618  0370a0d090da0d0edc6319f120187e0e
# 6338  1a6703883f8f47bb4daf09c03be3bda2  0370a0d090da0d0edc6319f120187e0e
# 6339  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6340  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6341  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6342  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6343  ef8b068ab7ac9d387b256404acd24cd5  8b8d9227a96ad6ed93838617e3a2319a
# 6344  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# ...                                ...                               ...
# 6763  52c6125836c465f4ac5232121dacb49d  0370a0d090da0d0edc6319f120187e0e
# 6764  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6765  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6766  fb64ca4b8beaf4c4c6e4575fe2f3abd7  6095bcbf4e6a692492b2d9f0a3b975a8
# 6767  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6768  ef8b068ab7ac9d387b256404acd24cd5  0370a0d090da0d0edc6319f120187e0e
# 6769  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6770  a1591595c04d12e88e3cb427fb667618  0370a0d090da0d0edc6319f120187e0e
# 6771  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6772  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6773  0370a0d090da0d0edc6319f120187e0e  fb64ca4b8beaf4c4c6e4575fe2f3abd7
# 6774  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6775  722a380c9b59ef42226e8d392824dcb9  0370a0d090da0d0edc6319f120187e0e
# 6776  52c6125836c465f4ac5232121dacb49d  8b8d9227a96ad6ed93838617e3a2319a
# 6777  0370a0d090da0d0edc6319f120187e0e  6095bcbf4e6a692492b2d9f0a3b975a8
# 6778  0370a0d090da0d0edc6319f120187e0e  8b8d9227a96ad6ed93838617e3a2319a
# 6779  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6780  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6787  821887f9a002be16b5f79729fae59e01  0370a0d090da0d0edc6319f120187e0e
# 6784  6f6a807d57aae8f651222523dc82dc35  0370a0d090da0d0edc6319f120187e0e
# 6789  3d75035d20b173a867d4bf32c8a58f0b  0370a0d090da0d0edc6319f120187e0e
# 6783  0b978fcfa7f2ec839c563a755e345ff8  0370a0d090da0d0edc6319f120187e0e
# 6785  fbcda0bcb861e4726ca8871b8965ede4  0370a0d090da0d0edc6319f120187e0e
# 6788  619d3e44dc84b366bd685de3e94b3bec  0370a0d090da0d0edc6319f120187e0e
# 6786  c950aaad2e56c87e9ac7281016d37cb6  0370a0d090da0d0edc6319f120187e0e
# 6782  36fdadf436b164ee29174c8e1fde7271  0370a0d090da0d0edc6319f120187e0e
# 6790  e49b2cc3f9aacd500b11a35b1c57112d  0370a0d090da0d0edc6319f120187e0e
# 6781  8c7a7249d80b1489594b3a2a87f3f19d  0370a0d090da0d0edc6319f120187e0e
# 6791  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 6792  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#       Team_id_type  Person1_type  Person2_type  Person3_type
# 6315             0             0             0             0
# 6316             3             4             5             5
# 6317             3             5             0             0
# 6318             3             4             0             0
# 6319             2             4             5             0
# 6320             3             5             0             0
# 6321             2             4             0             0
# 6322             2             5             0             0
# 6323             3             5             0             0
# 6324             2             4             0             0
# 6325             2             5             0             0
# 6326             3             5             0             0
# 6327             3             4             0             0
# 6328             2             4             0             0
# 6329             3             5             5             0
# 6330             2             4             0             0
# 6331             2             5             4             1
# 6332             2             4             0             0
# 6333             3             4             5             1
# 6334             3             5             0             0
# 6335             3             5             0             0
# 6336             2             4             4             0
# 6337             3             5             4             0
# 6338             2             4             4             0
# 6339             3             5             0             0
# 6340             2             4             0             0
# 6341             3             5             0             0
# 6342             3             3             0             0
# 6343             3             4             5             1
# 6344             3             5             0             0
# ...            ...           ...           ...           ...
# 6763             2             4             4             0
# 6764             3             5             0             0
# 6765             3             5             0             0
# 6766             3             4             5             1
# 6767             3             5             0             0
# 6768             3             5             5             0
# 6769             3             5             0             0
# 6770             2             4             4             0
# 6771             3             5             0             0
# 6772             3             4             0             0
# 6773             2             4             0             5
# 6774             2             5             0             0
# 6775             3             5             5             0
# 6776             2             5             4             1
# 6777             2             0             0             1
# 6778             2             5             0             1
# 6779             2             4             0             0
# 6780             2             4             0             0
# 6787             3             4             4             0
# 6784             3             4             4             0
# 6789             3             4             4             0
# 6783             3             4             4             0
# 6785             3             4             4             0
# 6788             3             5             5             0
# 6786             3             5             5             0
# 6782             3             5             5             0
# 6790             3             5             5             0
# 6781             3             5             5             0
# 6791             3             0             0             0
# 6792             0             0             0             0
#
# [478 rows x 18 columns]

# %%
rdPBP[287:331]
# Out:
#                                 Game_id  Event_Num  Event_Msg_Type  Period  \
# 32873  dc3a96d83623f28fd84bd535e57c146f        406     Missed Shot       3
# 32874  dc3a96d83623f28fd84bd535e57c146f        407         Rebound       3
# 32875  dc3a96d83623f28fd84bd535e57c146f        408            Foul       3
# 32876  dc3a96d83623f28fd84bd535e57c146f        410    Substitution       3
# 32877  dc3a96d83623f28fd84bd535e57c146f        413            Foul       3
# 32878  dc3a96d83623f28fd84bd535e57c146f        415            Foul       3
# 32879  dc3a96d83623f28fd84bd535e57c146f        416      Free Throw       3
# 32880  dc3a96d83623f28fd84bd535e57c146f        417      Free Throw       3
# 32881  dc3a96d83623f28fd84bd535e57c146f        418      Free Throw       3
# 32882  dc3a96d83623f28fd84bd535e57c146f        419         Timeout       3
# 32883  dc3a96d83623f28fd84bd535e57c146f        420       Made Shot       3
# 32884  dc3a96d83623f28fd84bd535e57c146f        421            Foul       3
# 32885  dc3a96d83623f28fd84bd535e57c146f        423        Turnover       3
# 32886  dc3a96d83623f28fd84bd535e57c146f        425            Foul       3
# 32887  dc3a96d83623f28fd84bd535e57c146f        427    Substitution       3
# 32888  dc3a96d83623f28fd84bd535e57c146f        429            Foul       3
# 32889  dc3a96d83623f28fd84bd535e57c146f        431      Free Throw       3
# 32890  dc3a96d83623f28fd84bd535e57c146f        432      Free Throw       3
# 32891  dc3a96d83623f28fd84bd535e57c146f        433       Made Shot       3
# 32892  dc3a96d83623f28fd84bd535e57c146f        435     Missed Shot       3
# 32893  dc3a96d83623f28fd84bd535e57c146f        436         Rebound       3
# 32894  dc3a96d83623f28fd84bd535e57c146f        437            Foul       3
# 32895  dc3a96d83623f28fd84bd535e57c146f        439  Instant Replay       3
# 32896  dc3a96d83623f28fd84bd535e57c146f        440      Free Throw       3
# 32897  dc3a96d83623f28fd84bd535e57c146f        441    Substitution       3
# 32898  dc3a96d83623f28fd84bd535e57c146f        444      Free Throw       3
# 32899  dc3a96d83623f28fd84bd535e57c146f        445         Rebound       3
# 32900  dc3a96d83623f28fd84bd535e57c146f        446            Foul       3
# 32901  dc3a96d83623f28fd84bd535e57c146f        448      Free Throw       3
# 32902  dc3a96d83623f28fd84bd535e57c146f        449      Free Throw       3
# 32903  dc3a96d83623f28fd84bd535e57c146f        450     Missed Shot       3
# 32904  dc3a96d83623f28fd84bd535e57c146f        451         Rebound       3
# 32905  dc3a96d83623f28fd84bd535e57c146f        452            Foul       3
# 32906  dc3a96d83623f28fd84bd535e57c146f        454      Free Throw       3
# 32907  dc3a96d83623f28fd84bd535e57c146f        455         Rebound       3
# 32908  dc3a96d83623f28fd84bd535e57c146f        456    Substitution       3
# 32909  dc3a96d83623f28fd84bd535e57c146f        458      Free Throw       3
# 32910  dc3a96d83623f28fd84bd535e57c146f        459     Missed Shot       3
# 32911  dc3a96d83623f28fd84bd535e57c146f        461         Rebound       3
# 32912  dc3a96d83623f28fd84bd535e57c146f        462        Turnover       3
# 32913  dc3a96d83623f28fd84bd535e57c146f        463            Foul       3
# 32915  dc3a96d83623f28fd84bd535e57c146f        465      Free Throw       3
# 32914  dc3a96d83623f28fd84bd535e57c146f        466         Rebound       3
# 32916  dc3a96d83623f28fd84bd535e57c146f        467      Free Throw       3
#
#        WC_Time  PC_Time           Action_Type  Option1  Option2  Option3  \
# 32873   639810     3810             Jump Shot        3        0        0
# 32874   639840     3800               Unknown        0        0        0
# 32875   639860     3790              Personal        0        0        0
# 32876   639970     3790                              0        0        0
# 32877   640330     3640              Shooting        0        0        2
# 32878   640670     3640             Technical        0        0        1
# 32879   640760     3640  Free Throw Technical        1        0        0
# 32880   640970     3640     Free Throw 1 of 2        1        0        0
# 32881   641130     3640     Free Throw 2 of 2        1        0        0
# 32882   641230     3640               Regular        0        0        0
# 32883   643490     3490     Driving Hook Shot        2        0        0
# 32884   643580     3430              Personal        0        0        0
# 32885   643980     3270             Lost Ball        1        0        0
# 32886   644040     3220              Personal        0        0        0
# 32887   644150     3220                              0        0        0
# 32888   644410     3110              Shooting        1        0        2
# 32889   644620     3110     Free Throw 1 of 2        1        0        0
# 32890   644740     3110     Free Throw 2 of 2        1        0        0
# 32891   645000     2880    Driving Layup Shot        2        0        0
# 32892   645220     2660  Turnaround Hook Shot        2        0        0
# 32893   645250     2620               Unknown        0        0        0
# 32894   645300     2590              Shooting        1        0        2
# 32895   646090     2590        Support Ruling        0        0        0
# 32896   646490     2590     Free Throw 1 of 2        1        0        0
# 32897   646500     2590                              0        0        0
# 32898   646670     2590     Free Throw 2 of 2        2        0        0
# 32899   646680     2590               Unknown        0        0        0
# 32900   646800     2500              Personal        1        0        2
# 32901   647020     2500     Free Throw 1 of 2        1        0        0
# 32902   647160     2500     Free Throw 2 of 2        1        0        0
# 32903   647390     2280             Jump Shot        3        0        0
# 32904   647440     2280               Unknown        0        0        0
# 32905   647490     2200              Shooting        1        0        2
# 32906   647800     2200     Free Throw 1 of 2        2        1        0
# 32907   647800     2200        Normal Rebound        0        0        0
# 32908   647820     2200                              0        0        0
# 32909   648020     2200     Free Throw 2 of 2        1        1        0
# 32910   648140     2110    Driving Layup Shot        2        0        0
# 32911   648180     2100               Unknown        0        0        0
# 32912   648410     2100      Inbound Turnover        0        0        0
# 32913   648600     2000              Personal        1        0        2
# 32915   648850     2000     Free Throw 1 of 2        2        0        0
# 32914   648850     2000        Normal Rebound        0        0        0
# 32916   649000     2000     Free Throw 2 of 2        1        0        0
#
#       Team_id                           Person1  \
# 32873   Team0  8c646f2710d4f64955903039fdc6374e
# 32874   Team1  95c8abc40fb4ecf4fa5627975450dc95
# 32875   Team0  b43d8e250bbf5bf03bcbbd2f48141acd
# 32876   Team0  4b35bf5cc8eebb940aa41c466bff7277
# 32877   Team0  8c646f2710d4f64955903039fdc6374e
# 32878   Team0  8c646f2710d4f64955903039fdc6374e
# 32879   Team1  95c8abc40fb4ecf4fa5627975450dc95
# 32880   Team1  b265ffd84dbeef427136d140811e7d5f
# 32881   Team1  b265ffd84dbeef427136d140811e7d5f
# 32882   Team0  f3d9bebad56898206207ca7cc07323f7
# 32883   Team0  8c646f2710d4f64955903039fdc6374e
# 32884   Team0  e9b4d02c8216e149e1b0c69c9feb6541
# 32885   Team1  3007e387a7d41a704390cb5878271b9a
# 32886   Team1  324b2f11b1cd08156cceb7206ef69820
# 32887   Team1  b265ffd84dbeef427136d140811e7d5f
# 32888   Team1  95c8abc40fb4ecf4fa5627975450dc95
# 32889   Team0  8c646f2710d4f64955903039fdc6374e
# 32890   Team0  8c646f2710d4f64955903039fdc6374e
# 32891   Team1  324b2f11b1cd08156cceb7206ef69820
# 32892   Team0  87d5036c732e89f1d2566f24b5c17113
# 32893   Team1  324b2f11b1cd08156cceb7206ef69820
# 32894   Team0  e9b4d02c8216e149e1b0c69c9feb6541
# 32895   Team1  7c3f56dc0114eb3e23ab5f72fece7aa1
# 32896   Team1  324b2f11b1cd08156cceb7206ef69820
# 32897   Team0  87d5036c732e89f1d2566f24b5c17113
# 32898   Team1  324b2f11b1cd08156cceb7206ef69820
# 32899   Team0  6a47aad050b23defa36c9d566a0570ff
# 32900   Team1  fe8aca56ad93b72526d622348b190ec3
# 32901   Team0  4b35bf5cc8eebb940aa41c466bff7277
# 32902   Team0  4b35bf5cc8eebb940aa41c466bff7277
# 32903   Team1  9cf34a85700c146eaf259ed7a818ad63
# 32904   Team0  6a47aad050b23defa36c9d566a0570ff
# 32905   Team1  324b2f11b1cd08156cceb7206ef69820
# 32906   Team0  b43d8e250bbf5bf03bcbbd2f48141acd
# 32907   Team0  f3d9bebad56898206207ca7cc07323f7
# 32908   Team0  e9b4d02c8216e149e1b0c69c9feb6541
# 32909   Team0  b43d8e250bbf5bf03bcbbd2f48141acd
# 32910   Team1  9cf34a85700c146eaf259ed7a818ad63
# 32911   Team1  9cae6a7543015cd3dd8ce41776bef14d
# 32912   Team1  fe8aca56ad93b72526d622348b190ec3
# 32913   Team1  95c8abc40fb4ecf4fa5627975450dc95
# 32915   Team0  8c646f2710d4f64955903039fdc6374e
# 32914   Team0  f3d9bebad56898206207ca7cc07323f7
# 32916   Team0  8c646f2710d4f64955903039fdc6374e
#
#                                 Person2                           Person3  \
# 32873  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32874  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32875  95c8abc40fb4ecf4fa5627975450dc95  4be6e006a878ead702fec2abcf8b904a
# 32876  e9b4d02c8216e149e1b0c69c9feb6541  0370a0d090da0d0edc6319f120187e0e
# 32877  b265ffd84dbeef427136d140811e7d5f  227d578f7628770519b586873c704e07
# 32878  0370a0d090da0d0edc6319f120187e0e  4be6e006a878ead702fec2abcf8b904a
# 32879  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32880  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32881  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32882  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32883  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32884  fe8aca56ad93b72526d622348b190ec3  4be6e006a878ead702fec2abcf8b904a
# 32885  e9b4d02c8216e149e1b0c69c9feb6541  0370a0d090da0d0edc6319f120187e0e
# 32886  87d5036c732e89f1d2566f24b5c17113  227d578f7628770519b586873c704e07
# 32887  9cf34a85700c146eaf259ed7a818ad63  0370a0d090da0d0edc6319f120187e0e
# 32888  8c646f2710d4f64955903039fdc6374e  a1277b068e23d54de9770dd59b31879e
# 32889  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32890  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32891  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32892  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32893  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32894  324b2f11b1cd08156cceb7206ef69820  227d578f7628770519b586873c704e07
# 32895  0370a0d090da0d0edc6319f120187e0e  227d578f7628770519b586873c704e07
# 32896  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32897  4b35bf5cc8eebb940aa41c466bff7277  0370a0d090da0d0edc6319f120187e0e
# 32898  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32899  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32900  4b35bf5cc8eebb940aa41c466bff7277  227d578f7628770519b586873c704e07
# 32901  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32902  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32903  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32904  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32905  b43d8e250bbf5bf03bcbbd2f48141acd  4be6e006a878ead702fec2abcf8b904a
# 32906  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32907  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32908  f42e50d6a567798c9540b0cf7447337e  0370a0d090da0d0edc6319f120187e0e
# 32909  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32910  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32911  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32912  0370a0d090da0d0edc6319f120187e0e  4be6e006a878ead702fec2abcf8b904a
# 32913  8c646f2710d4f64955903039fdc6374e  a1277b068e23d54de9770dd59b31879e
# 32915  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32914  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 32916  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 32873             3             5             0             0
# 32874             3             4             0             0
# 32875             2             5             4             1
# 32876             2             5             5             0
# 32877             2             5             4             1
# 32878             2             5             0             1
# 32879             2             4             0             0
# 32880             2             4             0             0
# 32881             2             4             0             0
# 32882             3             3             0             0
# 32883             3             5             0             0
# 32884             2             5             4             1
# 32885             2             4             5             0
# 32886             3             4             5             1
# 32887             3             4             4             0
# 32888             3             4             5             1
# 32889             3             5             0             0
# 32890             3             5             0             0
# 32891             2             4             0             0
# 32892             3             5             0             0
# 32893             3             4             0             0
# 32894             2             5             4             1
# 32895             2             0             0             1
# 32896             2             4             0             0
# 32897             2             5             5             0
# 32898             2             4             0             0
# 32899             2             5             0             0
# 32900             3             4             5             1
# 32901             3             5             0             0
# 32902             3             5             0             0
# 32903             2             4             0             0
# 32904             2             5             0             0
# 32905             3             4             5             1
# 32906             3             5             0             0
# 32907             3             3             0             0
# 32908             2             5             5             0
# 32909             3             5             0             0
# 32910             2             4             0             0
# 32911             2             2             0             0
# 32912             2             4             0             1
# 32913             3             4             5             1
# 32915             3             5             0             0
# 32914             3             3             0             0
# 32916             3             5             0             0

# %%
np.round(100*21.0/16, 2)
# Out:
# 131.25

# %%
rdPBPsmall = rdPBP[419:424]
rdPBPsmall
# Out:
#                                 Game_id  Event_Num Event_Msg_Type  Period  \
# 25659  bb4e1b593cc210dec5fdcb0f7eb4739d        609    Missed Shot       4
# 25661  bb4e1b593cc210dec5fdcb0f7eb4739d        610        Rebound       4
# 25660  bb4e1b593cc210dec5fdcb0f7eb4739d        611      Made Shot       4
# 25662  bb4e1b593cc210dec5fdcb0f7eb4739d        612           Foul       4
# 25663  bb4e1b593cc210dec5fdcb0f7eb4739d        614     Free Throw       4
#
#        WC_Time  PC_Time         Action_Type  Option1  Option2  Option3  \
# 25659   557230     1970  Floating Jump shot        2        0        0
# 25661   557280     1920             Unknown        0        0        0
# 25660   557280     1920   Putback Dunk Shot        2        0        0
# 25662   557350     1880            Shooting        0        0        2
# 25663   557590     1880   Free Throw 1 of 2        1        0        0
#
#       Team_id                           Person1  \
# 25659   Team0  ff52c317e26534ae1679da3c917e9fec
# 25661   Team0  83c15c0962941640faab838a8f6f151d
# 25660   Team0  83c15c0962941640faab838a8f6f151d
# 25662   Team0  7dfbb5980c066844384ba7424aceae47
# 25663   Team1  f562f72f83b8e06b60ff184531b07056
#
#                                 Person2                           Person3  \
# 25659  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25661  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25660  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
# 25662  f562f72f83b8e06b60ff184531b07056  5201a0c1055bebf092c5ce178e5c7863
# 25663  0370a0d090da0d0edc6319f120187e0e  0370a0d090da0d0edc6319f120187e0e
#
#        Team_id_type  Person1_type  Person2_type  Person3_type
# 25659             2             4             0             0
# 25661             2             4             0             0
# 25660             2             4             0             0
# 25662             3             4             5             1
# 25663             3             5             0             0

# %%
for i in xrange(1,5):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-730b0db7cc97> in <module>()
# ----> 1 for i in xrange(1,5):
#       2     print(i)
#
# NameError: name 'xrange' is not defined

# %%
ser = (rdPBPsmall['Event_Num'] == rdPBPsmallReb['Event_Num'])
np.where(ser.values == True)[0][0]
# Out:
# 1

# %%
for p in rdPBPsmall[5:].itertuples():
    print('d')

# %%
i = np.where(GameIDs=='bb4e1b593cc210dec5fdcb0f7eb4739d')
print (i, GameIDs[i])
# Out:
# (array([55], dtype=int64),) ['bb4e1b593cc210dec5fdcb0f7eb4739d']

# %%
# Out:
# array(['97b8982d363b55efc61eae5d969d7f44'], dtype=object)
